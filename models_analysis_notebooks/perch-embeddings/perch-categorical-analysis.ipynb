# %% [markdown]
# # Perch Multi Seed Validation
# #### 5 Random (but reproducible) seeds are selected for 5 different runs of train/test
# #### Models have been optimised and verified on validation sets thoroughly, running a final train/test evaluation here
# #### The setup:
#
# - 4 fold StratifiedGroupKFold for stratification and ensuring each cat_id group only appears in one set at a time
# - Final scores averaged over the 4 folds
# - For each seed run we will explore the cat_id predictions through majority voting
# - For each run we will explore the potential impact of gender
# - Includes visualisations & analysis
#
# The dataset is highly unbalanced.

# %%
# Standard imports
import numpy as np
import pandas as pd
import random
from datetime import datetime
from collections import Counter

# Sklearn imports
from sklearn.model_selection import train_test_split, GroupShuffleSplit, GroupKFold, StratifiedGroupKFold
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, RobustScaler, StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.inspection import permutation_importance

# Imbalanced-learn import
from imblearn.over_sampling import SMOTE

# TensorFlow and Keras imports
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, BatchNormalization, concatenate
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Adamax, AdamW
from tensorflow.keras.callbacks import EarlyStopping, Callback
from tensorflow.keras.utils import to_categorical
from keras.regularizers import l1, l2, L1L2

# Optuna import
import optuna

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Import statistical tests
from scipy.stats import levene

from IPython.display import display
import time

# %%
# Track running time (including analysis)
start_time = time.time()

# %%
# Set an initial seed for reproducibility
np.random.seed(42)  

# Generate a list of 5 random seeds
random_seeds = np.random.randint(0, 10000, size=5)
print("Random Seeds:", random_seeds)
# Out:
# Random Seeds: [7270  860 5390 5191 5734]

# %% [markdown]
# #### TOTAL RESULTS ACROSS SEED INITIATION

# %%
# Lists to collect statistics across all CVs
all_losses, all_accuracies, all_precisions, all_recalls, all_f1 = [], [], [], [], []
average_fold_losses, average_fold_accuracies, average_fold_precisions, average_fold_recalls, average_fold_f1 = [], [], [], [], []
all_majority_vote_accuracies, all_majority_vote_details, all_class_stats, all_gender_stats  = [], [], [], []

# training accuracies
all_best_training_acc = []
total_training_acc = []

# %% [markdown]
# ## Define Functions

# %%
def check_initial_group_split(groups_train, groups_test):
    """
    Check if any group is present in both the train and test sets.

    Parameters:
    - groups_train: Array of group identifiers for the train set
    - groups_test: Array of group identifiers for the test set

    Returns:
    - Prints out any groups found in both sets and the count of such groups
    """
    train_groups = set(groups_train)
    test_groups = set(groups_test)
    common_groups = train_groups.intersection(test_groups)

    if common_groups:
        print(f"Warning: Found {len(common_groups)} common groups in both train/validation and test sets: {common_groups}")
    else:
        print("No common groups found between train and test sets.")

# %%
# Function to perform the swaps based on cat_id, ensuring swaps within the same age_group
def swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids):
    for cat_id in specific_cat_ids:
        # Check if the specific cat_id is not in the training set
        if cat_id not in dataframe.iloc[train_val_idx]['cat_id'].values:
            # Get the age_group of this cat_id
            age_group = dataframe[dataframe['cat_id'] == cat_id]['age_group'].iloc[0]
                
            # Find a different cat_id within the same age_group in the train set that is not in the test set
            other_cat_ids_in_age_group = dataframe[(dataframe['age_group'] == age_group) & 
                                                   (dataframe['cat_id'] != cat_id) &
                                                   (~dataframe['cat_id'].isin(dataframe.iloc[test_idx]['cat_id']))]['cat_id'].unique()
            
            # Choose one other cat_id for swapping
            if len(other_cat_ids_in_age_group) > 0:
                other_cat_id = np.random.choice(other_cat_ids_in_age_group)

                # Find all instances of the other_cat_id in the train set
                other_cat_id_train_val_indices = train_val_idx[dataframe.iloc[train_val_idx]['cat_id'] == other_cat_id]
                
                # Find all instances of the specific cat_id in the test set
                cat_id_test_indices = test_idx[dataframe.iloc[test_idx]['cat_id'] == cat_id]
                
                # Swap the indices
                train_val_idx = np.setdiff1d(train_val_idx, other_cat_id_train_val_indices, assume_unique=True)
                test_idx = np.setdiff1d(test_idx, cat_id_test_indices, assume_unique=True)

                train_val_idx = np.concatenate((train_val_idx, cat_id_test_indices))
                test_idx = np.concatenate((test_idx, other_cat_id_train_val_indices))
            else:
                print(f"No alternative cat_id found in the same age_group as {cat_id} for swapping.")
                
    return train_val_idx, test_idx

# %%
# Function to identify differences in groups
def find_group_differences(original, new):
    # Convert numpy arrays to sets for easy difference computation
    original_set = set(original)
    new_set = set(new)
    # Find differences
    moved_to_new = new_set - original_set
    moved_to_original = original_set - new_set
    return moved_to_new, moved_to_original

# %%
# create custom logger function for local logs & stored in a .txt
def logger(message, file=None):
    print(message)
    if file is not None:
        with open(file, "a") as log_file:
            log_file.write(message + "\n")

log_file_path = "perch_categorical-logs.txt"

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid", palette="deep")

# Define a custom color palette
colors = ["#6aabd1", "#b6e2d3", "#dac292"] 
sns.set_palette(sns.color_palette(colors))

# Function to create bar plots with enhanced style
def styled_barplot(data, x, y, title, xlabel, ylabel):
    plt.figure(figsize=(8, 4))
    bar_plot = sns.barplot(x=x, y=y, data=data, errorbar=None, width=0.5)  
    plt.title(title, fontsize=16, fontweight='bold', color="#333333")
    plt.xlabel(xlabel, fontsize=14, fontweight='bold', color="#333333")
    plt.ylabel(ylabel, fontsize=14, fontweight='bold', color="#333333")
    plt.xticks(fontsize=12, color="#333333")
    plt.yticks(fontsize=12, color="#333333")
    plt.ylim(0, 100) 

    # Adding value labels on top of each bar
    for p in bar_plot.patches:
        height = p.get_height()
        # Annotate the height value on the bar
        bar_plot.annotate(f'{height:.1f}', 
                          (p.get_x() + p.get_width() / 2., height), 
                          ha='center', va='center', 
                          xytext=(0, 9), 
                          textcoords='offset points', fontsize=12, color="#333333")

    plt.show()

# %%
def styled_barplot_with_average(data, x, y, title, xlabel, ylabel, average_line=None):
    plt.figure(figsize=(8, 4))
    bar_plot = sns.barplot(x=x, y=y, data=data, errorbar=None, width=0.5)  
    plt.title(title, fontsize=16, fontweight='bold', color="#333333")
    plt.xlabel(xlabel, fontsize=14, fontweight='bold', color="#333333")
    plt.ylabel(ylabel, fontsize=14, fontweight='bold', color="#333333")
    plt.xticks(fontsize=12, color="#333333")
    plt.yticks(fontsize=12, color="#333333")
    plt.ylim(0, 100) 
    
    # Adding value labels on top of each bar
    for p in bar_plot.patches:
        height = p.get_height()
        bar_plot.annotate(f'{height:.1f}', 
                          (p.get_x() + p.get_width() / 2., height), 
                          ha='center', va='center', 
                          xytext=(0, 9), 
                          textcoords='offset points', fontsize=12, color="#333333")
    
    if average_line is not None:
        plt.axhline(y=average_line, color='red', linestyle='--', 
                    label=f'Macro-Averaged Accuracy: {average_line:.1f}%')
        plt.legend(fontsize=10)
    
    plt.show()

# %%
def plot_all_metrics(losses, accuracies, precisions, recalls, f1, metrics_across, x_axis_label):
    fig, ax = plt.subplots(figsize=(12, 8))
    seeds = range(1, len(losses) + 1)

    ax.plot(seeds, losses, marker='o', color='blue', label='Loss')
    ax.plot(seeds, accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(seeds, precisions, marker='o', color='red', label='Precision')
    ax.plot(seeds, recalls, marker='o', color='purple', label='Recall')
    ax.plot(seeds, f1, marker='o', color='orange', label='F1 Score')

    ax.set_title(f'Metrics Across {metrics_across}')
    ax.set_xlabel(x_axis_label)
    ax.set_ylabel('Metric Value')
    ax.set_xticks(seeds)
    ax.legend()
    ax.grid(True)

    return fig

# %%
# store epoch accs
class AccuracyHistory(Callback):
    def on_train_begin(self, logs={}):
        self.acc = []

    def on_epoch_end(self, batch, logs={}):
        self.acc.append(logs.get('accuracy'))

# %% [markdown]
# # RANDOM SEED 1

# %% [markdown]
# ## Prepare Data

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[0])) 
np.random.seed(int(random_seeds[0]))
tf.random.set_seed(int(random_seeds[0]))

# Load datasets
dataframe = pd.read_csv('perch_looped_embeddings.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 10),
    'senior': (10, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     405
# senior    253
# kitten    135
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[0]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

cv_training_acc_total = []
cv_training_acc_best = []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    accuracy_history = AccuracyHistory()

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]

    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_val),
        y=y_train_val
    )
    weight_dict = {i: class_weights[i] for i in range(len(class_weights))}

    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adam': Adam(learning_rate=0.007402414884293732)
    }
    
    # Full model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(512, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.15688606637942396))  
    model_full.add(Dense(64, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.28869063762474007))  
    model_full.add(Dense(128, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.27322054853254163))   
    model_full.add(Dense(32, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.4064145271744943))  
    model_full.add(Dense(3, activation='softmax'))  
    
    optimizer = optimizers['Adam']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=32,
                                  verbose=1, callbacks=[early_stopping, accuracy_history], class_weight=weight_dict)
    
    
    # log epochs
    best_epoch_index = np.argmin(history_full.history['loss'])  
    best_training_accuracy = accuracy_history.acc[best_epoch_index]

    # Append training acc to total  
    all_best_training_acc.append(best_training_accuracy)
    total_training_acc.append(accuracy_history.acc)

    # Append training acc just for this CV
    cv_training_acc_total.append(accuracy_history.acc)
    cv_training_acc_best.append(best_training_accuracy)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
average_fold_f1.append(unseen_set_avg_f1)
average_fold_losses.append(unseen_set_avg_loss)
average_fold_accuracies.append(unseen_set_avg_acc)
average_fold_precisions.append(unseen_set_avg_precision)
average_fold_recalls.append(unseen_set_avg_recall)

# Append all to total lists
all_f1.append(unseen_f1)
all_losses.append(unseen_losses)
all_accuracies.append(unseen_accuracies)
all_precisions.append(unseen_precisions)
all_recalls.append(unseen_recalls)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# outer_fold 1
# Train Set Group Distribution:
# 000A    39
# 103A    33
# 047A    22
# 000B    19
# 057A    17
#         ..
# 049A     1
# 064A     1
# 096A     1
# 043A     1
# 026B     1
# Name: cat_id, Length: 82, dtype: int64
# Testing Set Group Distribution:
# 046A    45
# 002B    30
# 020A    20
# 074A    16
# 106A    13
# 111A    12
# 028A    11
# 067A    11
# 063A    11
# 005A     9
# 036A     7
# 023A     6
# 050A     5
# 070A     5
# 003A     4
# 025C     4
# 056A     3
# 012A     3
# 010A     3
# 093A     2
# 032A     2
# 038A     2
# 061A     2
# 037A     2
# 076A     1
# 073A     1
# 041A     1
# 019B     1
# 090A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# F    212
# X    184
# M    163
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    123
# X     92
# F     19
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 071A, 097B, 019A, 062A, 022...
# kitten    [044A, 014B, 040A, 047A, 042A, 109A, 043A, 049...
# senior    [015A, 097A, 001A, 103A, 057A, 101A, 104A, 055...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [074A, 067A, 020A, 002B, 005A, 023A, 063A, 038...
# kitten                             [111A, 046A, 050A, 041A]
# senior     [093A, 028A, 106A, 025C, 056A, 061A, 090A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 44, 'kitten': 12, 'senior': 26}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 4, 'senior': 8}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '004A' '006A' '007A' '008A' '009A' '011A'
#  '013B' '014A' '014B' '015A' '016A' '018A' '019A' '021A' '022A' '023B'
#  '025A' '025B' '026A' '026B' '026C' '027A' '029A' '031A' '033A' '034A'
#  '035A' '039A' '040A' '042A' '043A' '044A' '045A' '047A' '048A' '049A'
#  '051A' '051B' '052A' '053A' '054A' '055A' '057A' '058A' '059A' '060A'
#  '062A' '064A' '065A' '066A' '068A' '069A' '071A' '072A' '075A' '087A'
#  '088A' '091A' '092A' '094A' '095A' '096A' '097A' '097B' '099A' '100A'
#  '101A' '102A' '103A' '104A' '105A' '108A' '109A' '110A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['002B' '003A' '005A' '010A' '012A' '019B' '020A' '023A' '024A' '025C'
#  '028A' '032A' '036A' '037A' '038A' '041A' '046A' '050A' '056A' '061A'
#  '063A' '067A' '070A' '073A' '074A' '076A' '090A' '093A' '106A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'040A'}
# Moved to Test Set:
# {'040A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '004A' '006A' '007A' '008A' '009A' '011A'
#  '013B' '014A' '014B' '015A' '016A' '018A' '019A' '021A' '022A' '023B'
#  '025A' '025B' '026A' '026B' '026C' '027A' '029A' '031A' '033A' '034A'
#  '035A' '039A' '042A' '043A' '044A' '045A' '046A' '047A' '048A' '049A'
#  '051A' '051B' '052A' '053A' '054A' '055A' '057A' '058A' '059A' '060A'
#  '062A' '064A' '065A' '066A' '068A' '069A' '071A' '072A' '075A' '087A'
#  '088A' '091A' '092A' '094A' '095A' '096A' '097A' '097B' '099A' '100A'
#  '101A' '102A' '103A' '104A' '105A' '108A' '109A' '110A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '003A' '005A' '010A' '012A' '019B' '020A' '023A' '024A' '025C'
#  '028A' '032A' '036A' '037A' '038A' '040A' '041A' '050A' '056A' '061A'
#  '063A' '067A' '070A' '073A' '074A' '076A' '090A' '093A' '106A' '111A']
# Length of X_train_val:
# 594
# Length of y_train_val:
# 594
# Length of groups_train_val:
# 594
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     271
# senior    216
# kitten     72
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     134
# kitten     63
# senior     37
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     271
# senior    216
# kitten    107
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     134
# senior     37
# kitten     28
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 271, 2: 216, 1: 107})
# Epoch 1/1500
# 19/19 [==============================] - 1s 4ms/step - loss: 0.9936 - accuracy: 0.5741
# Epoch 2/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4396 - accuracy: 0.8131
# Epoch 3/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2776 - accuracy: 0.8687
# Epoch 4/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2597 - accuracy: 0.9057
# Epoch 5/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1707 - accuracy: 0.9276
# Epoch 6/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1333 - accuracy: 0.9562
# Epoch 7/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0710 - accuracy: 0.9714
# Epoch 8/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0829 - accuracy: 0.9714
# Epoch 9/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0865 - accuracy: 0.9663
# Epoch 10/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0599 - accuracy: 0.9714
# Epoch 11/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0545 - accuracy: 0.9865
# Epoch 12/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1109 - accuracy: 0.9714
# Epoch 13/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0487 - accuracy: 0.9848
# Epoch 14/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1282 - accuracy: 0.9680
# Epoch 15/1500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0925 - accuracy: 0.9646
# Epoch 16/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0595 - accuracy: 0.9798
# Epoch 17/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0534 - accuracy: 0.9882
# Epoch 18/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0409 - accuracy: 0.9815
# Epoch 19/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0744 - accuracy: 0.9731
# Epoch 20/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0817 - accuracy: 0.9764
# Epoch 21/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0364 - accuracy: 0.9899
# Epoch 22/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1018 - accuracy: 0.9613
# Epoch 23/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0661 - accuracy: 0.9815
# Epoch 24/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0562 - accuracy: 0.9848
# Epoch 25/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0244 - accuracy: 0.9899
# Epoch 26/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0448 - accuracy: 0.9848
# Epoch 27/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0325 - accuracy: 0.9916
# Epoch 28/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0366 - accuracy: 0.9865
# Epoch 29/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0631 - accuracy: 0.9832
# Epoch 30/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0163 - accuracy: 0.9949
# Epoch 31/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0302 - accuracy: 0.9899
# Epoch 32/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0416 - accuracy: 0.9882
# Epoch 33/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0507 - accuracy: 0.9815
# Epoch 34/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0585 - accuracy: 0.9815
# Epoch 35/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1173 - accuracy: 0.9596
# Epoch 36/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0484 - accuracy: 0.9865
# Epoch 37/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0554 - accuracy: 0.9747
# Epoch 38/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0799 - accuracy: 0.9798
# Epoch 39/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0908 - accuracy: 0.9764
# Epoch 40/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0370 - accuracy: 0.9949
# Epoch 41/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0807 - accuracy: 0.9731
# Epoch 42/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0496 - accuracy: 0.9832
# Epoch 43/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0331 - accuracy: 0.9882
# Epoch 44/1500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0237 - accuracy: 0.9933
# Epoch 45/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0373 - accuracy: 0.9882
# Epoch 46/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0396 - accuracy: 0.9832
# Epoch 47/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0270 - accuracy: 0.9916
# Epoch 48/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0486 - accuracy: 0.9848
# Epoch 49/1500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0289 - accuracy: 0.9933
# Epoch 50/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0241 - accuracy: 0.9933
# Epoch 51/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0260 - accuracy: 0.9899
# Epoch 52/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0344 - accuracy: 0.9933
# Epoch 53/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0107 - accuracy: 0.9966
# Epoch 54/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0082 - accuracy: 0.9966
# Epoch 55/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0265 - accuracy: 0.9882
# Epoch 56/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0472 - accuracy: 0.9848
# Epoch 57/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0331 - accuracy: 0.9899
# Epoch 58/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0219 - accuracy: 0.9916
# Epoch 59/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0208 - accuracy: 0.9933
# Epoch 60/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0319 - accuracy: 0.9899
# Epoch 61/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0469 - accuracy: 0.9916
# Epoch 62/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0221 - accuracy: 0.9949
# Epoch 63/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 0.9966
# Epoch 64/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0813 - accuracy: 0.9697
# Epoch 65/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1043 - accuracy: 0.9781
# Epoch 66/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0343 - accuracy: 0.9865
# Epoch 67/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0563 - accuracy: 0.9832
# Epoch 68/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0679 - accuracy: 0.9798
# Epoch 69/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0251 - accuracy: 0.9966
# Epoch 70/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0295 - accuracy: 0.9916
# Epoch 71/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 0.9966
# Epoch 72/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0257 - accuracy: 0.9916
# Epoch 73/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0152 - accuracy: 0.9949
# Epoch 74/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 75/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0131 - accuracy: 0.9933
# Epoch 76/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 0.9983
# Epoch 77/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0180 - accuracy: 0.9966
# Epoch 78/1500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0195 - accuracy: 0.9949
# Epoch 79/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0044 - accuracy: 0.9983
# Epoch 80/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 81/1500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0185 - accuracy: 0.9966
# Epoch 82/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0264 - accuracy: 0.9949
# Epoch 83/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0168 - accuracy: 0.9966
# Epoch 84/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0419 - accuracy: 0.9882
# Epoch 85/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0426 - accuracy: 0.9865
# Epoch 86/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0582 - accuracy: 0.9882
# Epoch 87/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0508 - accuracy: 0.9882
# Epoch 88/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0515 - accuracy: 0.9865
# Epoch 89/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0279 - accuracy: 0.9882
# Epoch 90/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0131 - accuracy: 0.9933
# Epoch 91/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0186 - accuracy: 0.9949
# Epoch 92/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0141 - accuracy: 0.9966
# Epoch 93/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0207 - accuracy: 0.9949
# Epoch 94/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0115 - accuracy: 0.9966
# Epoch 95/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 0.9949
# Epoch 96/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0451 - accuracy: 0.9865
# Epoch 97/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0636 - accuracy: 0.9731
# Epoch 98/1500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0224 - accuracy: 0.9882
# Epoch 99/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0194 - accuracy: 0.9949
# Epoch 100/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 0.9966
# Epoch 101/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0069 - accuracy: 0.9983
# Epoch 102/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0129 - accuracy: 0.9949
# Epoch 103/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0101 - accuracy: 0.9966
# Epoch 104/1500
# 14/19 [=====================>........] - ETA: 0s - loss: 0.0106 - accuracy: 0.9911Restoring model weights from the end of the best epoch: 74.
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 0.9933
# Epoch 104: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 2.2754 - accuracy: 0.6482
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.57 (17/30)
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 199, Predictions: 199, Actuals: 199, Gender: 199
# Final Test Results - Loss: 2.2753818035125732, Accuracy: 0.6482412219047546, Precision: 0.6620580108952202, Recall: 0.7476132849267177, F1 Score: 0.6681685273790537
# Confusion Matrix:
#  [[76  6 52]
#  [ 0 28  0]
#  [10  2 25]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 002B    30
# 020A    20
# 057A    17
# 074A    16
#         ..
# 041A     1
# 049A     1
# 064A     1
# 073A     1
# 026B     1
# Name: cat_id, Length: 85, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 103A    33
# 047A    22
# 000B    19
# 019A    17
# 097B    14
# 055A    12
# 051B     9
# 072A     9
# 016A     9
# 095A     7
# 015A     7
# 117A     7
# 031A     7
# 008A     5
# 094A     5
# 044A     5
# 104A     4
# 006A     3
# 018A     2
# 102A     2
# 025B     2
# 091A     1
# 092A     1
# 026C     1
# 066A     1
# 088A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    209
# M    200
# F    140
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    91
# M    86
# X    67
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [033A, 071A, 074A, 067A, 020A, 062A, 002B, 022...
# kitten    [014B, 111A, 040A, 046A, 042A, 109A, 050A, 043...
# senior    [093A, 097A, 001A, 028A, 057A, 106A, 101A, 039...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 000A, 097B, 019A, 095A, 072A, 000B, 031...
# kitten                                         [044A, 047A]
# senior    [015A, 103A, 104A, 055A, 091A, 051B, 117A, 008...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 47, 'kitten': 14, 'senior': 24}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 2, 'senior': 10}
# Unique Training/Validation Group IDs:
# ['001A' '002A' '002B' '003A' '004A' '005A' '007A' '009A' '010A' '011A'
#  '012A' '013B' '014A' '014B' '019B' '020A' '021A' '022A' '023A' '023B'
#  '024A' '025A' '025C' '026A' '026B' '027A' '028A' '029A' '032A' '033A'
#  '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '042A' '043A'
#  '045A' '046A' '048A' '049A' '050A' '051A' '052A' '053A' '054A' '056A'
#  '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A' '067A'
#  '068A' '069A' '070A' '071A' '073A' '074A' '075A' '076A' '087A' '090A'
#  '093A' '096A' '097A' '099A' '100A' '101A' '105A' '106A' '108A' '109A'
#  '110A' '111A' '113A' '115A' '116A']
# Unique Test Group IDs:
# ['000A' '000B' '006A' '008A' '015A' '016A' '018A' '019A' '025B' '026C'
#  '031A' '044A' '047A' '051B' '055A' '066A' '072A' '088A' '091A' '092A'
#  '094A' '095A' '097B' '102A' '103A' '104A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'073A'}
# Moved to Test Set:
# {'073A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '005A' '007A' '009A' '010A'
#  '011A' '012A' '013B' '014A' '014B' '019B' '020A' '021A' '022A' '023A'
#  '023B' '024A' '025A' '025C' '026A' '026B' '027A' '028A' '029A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '042A'
#  '043A' '045A' '046A' '048A' '049A' '050A' '051A' '052A' '053A' '054A'
#  '056A' '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A'
#  '067A' '068A' '069A' '070A' '071A' '074A' '075A' '076A' '087A' '090A'
#  '093A' '096A' '097A' '099A' '100A' '101A' '105A' '106A' '108A' '109A'
#  '110A' '111A' '113A' '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '006A' '008A' '015A' '016A' '018A' '019A' '025B' '026C' '031A'
#  '044A' '047A' '051B' '055A' '066A' '072A' '073A' '088A' '091A' '092A'
#  '094A' '095A' '097B' '102A' '103A' '104A' '117A']
# Length of X_train_val:
# 587
# Length of y_train_val:
# 587
# Length of groups_train_val:
# 587
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     280
# senior    161
# kitten    108
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     125
# senior     92
# kitten     27
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     318
# senior    161
# kitten    108
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# senior    92
# adult     87
# kitten    27
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 318, 2: 161, 1: 108})
# Epoch 1/1500
# 19/19 [==============================] - 1s 4ms/step - loss: 1.0584 - accuracy: 0.5128
# Epoch 2/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.5196 - accuracy: 0.7342
# Epoch 3/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3841 - accuracy: 0.8194
# Epoch 4/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3133 - accuracy: 0.8705
# Epoch 5/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2054 - accuracy: 0.9233
# Epoch 6/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1493 - accuracy: 0.9250
# Epoch 7/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1187 - accuracy: 0.9574
# Epoch 8/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0828 - accuracy: 0.9727
# Epoch 9/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0630 - accuracy: 0.9830
# Epoch 10/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1225 - accuracy: 0.9591
# Epoch 11/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1485 - accuracy: 0.9557
# Epoch 12/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0908 - accuracy: 0.9608
# Epoch 13/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0553 - accuracy: 0.9761
# Epoch 14/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0817 - accuracy: 0.9676
# Epoch 15/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0837 - accuracy: 0.9744
# Epoch 16/1500
# 19/19 [==============================] - 0s 7ms/step - loss: 0.1521 - accuracy: 0.9506
# Epoch 17/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1104 - accuracy: 0.9574
# Epoch 18/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0960 - accuracy: 0.9608
# Epoch 19/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0724 - accuracy: 0.9796
# Epoch 20/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0969 - accuracy: 0.9676
# Epoch 21/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0703 - accuracy: 0.9744
# Epoch 22/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0351 - accuracy: 0.9915
# Epoch 23/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0512 - accuracy: 0.9830
# Epoch 24/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0853 - accuracy: 0.9693
# Epoch 25/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0626 - accuracy: 0.9761
# Epoch 26/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1069 - accuracy: 0.9710
# Epoch 27/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1260 - accuracy: 0.9523
# Epoch 28/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0879 - accuracy: 0.9608
# Epoch 29/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0586 - accuracy: 0.9761
# Epoch 30/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0206 - accuracy: 0.9932
# Epoch 31/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0283 - accuracy: 0.9915
# Epoch 32/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0474 - accuracy: 0.9847
# Epoch 33/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0201 - accuracy: 0.9932
# Epoch 34/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0201 - accuracy: 0.9932
# Epoch 35/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0170 - accuracy: 0.9932
# Epoch 36/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0193 - accuracy: 0.9932
# Epoch 37/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0209 - accuracy: 0.9949
# Epoch 38/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0446 - accuracy: 0.9898
# Epoch 39/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0345 - accuracy: 0.9881
# Epoch 40/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0350 - accuracy: 0.9898
# Epoch 41/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0527 - accuracy: 0.9847
# Epoch 42/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0285 - accuracy: 0.9898
# Epoch 43/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0830 - accuracy: 0.9796
# Epoch 44/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0397 - accuracy: 0.9847
# Epoch 45/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0753 - accuracy: 0.9761
# Epoch 46/1500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0727 - accuracy: 0.9779
# Epoch 47/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0207 - accuracy: 0.9949
# Epoch 48/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 0.9983
# Epoch 49/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0191 - accuracy: 0.9949
# Epoch 50/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0460 - accuracy: 0.9898
# Epoch 51/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0365 - accuracy: 0.9898
# Epoch 52/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0405 - accuracy: 0.9881
# Epoch 53/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0433 - accuracy: 0.9881
# Epoch 54/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0497 - accuracy: 0.9813
# Epoch 55/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0313 - accuracy: 0.9915
# Epoch 56/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0326 - accuracy: 0.9847
# Epoch 57/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0200 - accuracy: 0.9898
# Epoch 58/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0242 - accuracy: 0.9898
# Epoch 59/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 60/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0265 - accuracy: 0.9966
# Epoch 61/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0236 - accuracy: 0.9932
# Epoch 62/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 0.9932
# Epoch 63/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0194 - accuracy: 0.9949
# Epoch 64/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0280 - accuracy: 0.9898
# Epoch 65/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0752 - accuracy: 0.9830
# Epoch 66/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0350 - accuracy: 0.9898
# Epoch 67/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0262 - accuracy: 0.9881
# Epoch 68/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0236 - accuracy: 0.9932
# Epoch 69/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0159 - accuracy: 0.9949
# Epoch 70/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 0.9966
# Epoch 71/1500
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0084 - accuracy: 0.9966
# Epoch 72/1500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0312 - accuracy: 0.9949
# Epoch 73/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 0.9949
# Epoch 74/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 0.9983
# Epoch 75/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0577 - accuracy: 0.9915
# Epoch 76/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 0.9932
# Epoch 77/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0100 - accuracy: 0.9966
# Epoch 78/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0199 - accuracy: 0.9881
# Epoch 79/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0362 - accuracy: 0.9830
# Epoch 80/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0242 - accuracy: 0.9915
# Epoch 81/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0134 - accuracy: 0.9915
# Epoch 82/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 0.9949
# Epoch 83/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0269 - accuracy: 0.9915
# Epoch 84/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0408 - accuracy: 0.9847
# Epoch 85/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0729 - accuracy: 0.9761
# Epoch 86/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0797 - accuracy: 0.9761
# Epoch 87/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0494 - accuracy: 0.9864
# Epoch 88/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0724 - accuracy: 0.9796
# Epoch 89/1500
# 15/19 [======================>.......] - ETA: 0s - loss: 0.0711 - accuracy: 0.9792Restoring model weights from the end of the best epoch: 59.
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0746 - accuracy: 0.9779
# Epoch 89: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 2.5375 - accuracy: 0.6262
# 7/7 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Majority Vote Accuracy for cat_id for this fold: 0.63 (17/27)
# Before appending - Cat IDs: 199, Predictions: 199, Actuals: 199, Gender: 199
# After appending - Cat IDs: 405, Predictions: 405, Actuals: 405, Gender: 405
# Final Test Results - Loss: 2.5375308990478516, Accuracy: 0.6262136101722717, Precision: 0.7121913580246915, Recall: 0.5357598978288634, F1 Score: 0.546553598608393
# Confusion Matrix:
#  [[77  2  8]
#  [21  6  0]
#  [46  0 46]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
#         ..
# 041A     1
# 092A     1
# 049A     1
# 096A     1
# 026B     1
# Name: cat_id, Length: 83, dtype: int64
# Testing Set Group Distribution:
# 057A    17
# 029A    15
# 116A    12
# 042A    11
# 059A    10
# 025A    10
# 033A     9
# 065A     9
# 071A     9
# 013B     8
# 027A     7
# 099A     6
# 007A     6
# 075A     5
# 108A     5
# 021A     5
# 023B     4
# 045A     4
# 105A     3
# 060A     3
# 113A     3
# 052A     2
# 035A     2
# 011A     2
# 064A     1
# 048A     1
# 004A     1
# 115A     1
# 110A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    229
# M    222
# F    170
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    64
# F    61
# X    47
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 097B, 019A, 074A, 067A, 020A, 062...
# kitten    [044A, 014B, 111A, 040A, 046A, 047A, 109A, 050...
# senior    [093A, 015A, 097A, 001A, 103A, 028A, 106A, 101...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 071A, 029A, 065A, 027A, 013B, 099A, 007...
# kitten                       [042A, 045A, 048A, 115A, 110A]
# senior     [057A, 059A, 025A, 113A, 116A, 060A, 108A, 011A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 46, 'kitten': 11, 'senior': 26}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 16, 'kitten': 5, 'senior': 8}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '005A' '006A' '008A' '009A'
#  '010A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '022A' '023A' '024A' '025B' '025C' '026A' '026B' '026C' '028A' '031A'
#  '032A' '034A' '036A' '037A' '038A' '039A' '040A' '041A' '043A' '044A'
#  '046A' '047A' '049A' '050A' '051A' '051B' '053A' '054A' '055A' '056A'
#  '058A' '061A' '062A' '063A' '066A' '067A' '068A' '069A' '070A' '072A'
#  '073A' '074A' '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A'
#  '095A' '096A' '097A' '097B' '100A' '101A' '102A' '103A' '104A' '106A'
#  '109A' '111A' '117A']
# Unique Test Group IDs:
# ['004A' '007A' '011A' '013B' '021A' '023B' '025A' '027A' '029A' '033A'
#  '035A' '042A' '045A' '048A' '052A' '057A' '059A' '060A' '064A' '065A'
#  '071A' '075A' '099A' '105A' '108A' '110A' '113A' '115A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '005A' '006A' '008A' '009A'
#  '010A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '022A' '023A' '024A' '025B' '025C' '026A' '026B' '026C' '028A' '031A'
#  '032A' '034A' '036A' '037A' '038A' '039A' '040A' '041A' '043A' '044A'
#  '046A' '047A' '049A' '050A' '051A' '051B' '053A' '054A' '055A' '056A'
#  '058A' '061A' '062A' '063A' '066A' '067A' '068A' '069A' '070A' '072A'
#  '073A' '074A' '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A'
#  '095A' '096A' '097A' '097B' '100A' '101A' '102A' '103A' '104A' '106A'
#  '109A' '111A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['004A' '007A' '011A' '013B' '021A' '023B' '025A' '027A' '029A' '033A'
#  '035A' '042A' '045A' '048A' '052A' '057A' '059A' '060A' '064A' '065A'
#  '071A' '075A' '099A' '105A' '108A' '110A' '113A' '115A' '116A']
# Length of X_train_val:
# 621
# Length of y_train_val:
# 621
# Length of groups_train_val:
# 621
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     313
# senior    191
# kitten    117
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     92
# senior    62
# kitten    18
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     313
# senior    191
# kitten    117
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     92
# senior    62
# kitten    18
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 313, 2: 191, 1: 117})
# Epoch 1/1500
# 20/20 [==============================] - 1s 4ms/step - loss: 0.8335 - accuracy: 0.6280
# Epoch 2/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4739 - accuracy: 0.7858
# Epoch 3/1500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.3072 - accuracy: 0.8663
# Epoch 4/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1743 - accuracy: 0.9356
# Epoch 5/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1581 - accuracy: 0.9227
# Epoch 6/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1293 - accuracy: 0.9469
# Epoch 7/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0925 - accuracy: 0.9742
# Epoch 8/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0863 - accuracy: 0.9662
# Epoch 9/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0960 - accuracy: 0.9549
# Epoch 10/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1399 - accuracy: 0.9533
# Epoch 11/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0743 - accuracy: 0.9694
# Epoch 12/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1997 - accuracy: 0.9501
# Epoch 13/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1215 - accuracy: 0.9581
# Epoch 14/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0839 - accuracy: 0.9646
# Epoch 15/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0600 - accuracy: 0.9823
# Epoch 16/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0395 - accuracy: 0.9855
# Epoch 17/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0511 - accuracy: 0.9871
# Epoch 18/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0241 - accuracy: 0.9887
# Epoch 19/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0383 - accuracy: 0.9887
# Epoch 20/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0379 - accuracy: 0.9871
# Epoch 21/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0865 - accuracy: 0.9823
# Epoch 22/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1082 - accuracy: 0.9581
# Epoch 23/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0683 - accuracy: 0.9726
# Epoch 24/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0685 - accuracy: 0.9742
# Epoch 25/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0648 - accuracy: 0.9758
# Epoch 26/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1495 - accuracy: 0.9597
# Epoch 27/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0946 - accuracy: 0.9678
# Epoch 28/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0708 - accuracy: 0.9775
# Epoch 29/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0270 - accuracy: 0.9903
# Epoch 30/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0240 - accuracy: 0.9936
# Epoch 31/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0185 - accuracy: 0.9919
# Epoch 32/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0244 - accuracy: 0.9919
# Epoch 33/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0173 - accuracy: 0.9936
# Epoch 34/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0195 - accuracy: 0.9936
# Epoch 35/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0335 - accuracy: 0.9887
# Epoch 36/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0173 - accuracy: 0.9887
# Epoch 37/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0303 - accuracy: 0.9919
# Epoch 38/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0137 - accuracy: 0.9936
# Epoch 39/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0728 - accuracy: 0.9807
# Epoch 40/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0390 - accuracy: 0.9839
# Epoch 41/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0238 - accuracy: 0.9919
# Epoch 42/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0341 - accuracy: 0.9887
# Epoch 43/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0321 - accuracy: 0.9887
# Epoch 44/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0227 - accuracy: 0.9936
# Epoch 45/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0362 - accuracy: 0.9855
# Epoch 46/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0111 - accuracy: 0.9968
# Epoch 47/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0477 - accuracy: 0.9871
# Epoch 48/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0768 - accuracy: 0.9791
# Epoch 49/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0565 - accuracy: 0.9871
# Epoch 50/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 0.9952
# Epoch 51/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0184 - accuracy: 0.9936
# Epoch 52/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0260 - accuracy: 0.9936
# Epoch 53/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1314 - accuracy: 0.9758
# Epoch 54/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0682 - accuracy: 0.9742
# Epoch 55/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0576 - accuracy: 0.9823
# Epoch 56/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0393 - accuracy: 0.9919
# Epoch 57/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 58/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 0.9984
# Epoch 59/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0567 - accuracy: 0.9936
# Epoch 60/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1891 - accuracy: 0.9404
# Epoch 61/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0818 - accuracy: 0.9710
# Epoch 62/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0305 - accuracy: 0.9919
# Epoch 63/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0568 - accuracy: 0.9775
# Epoch 64/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0343 - accuracy: 0.9871
# Epoch 65/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0264 - accuracy: 0.9968
# Epoch 66/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0300 - accuracy: 0.9919
# Epoch 67/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0507 - accuracy: 0.9758
# Epoch 68/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1028 - accuracy: 0.9694
# Epoch 69/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0294 - accuracy: 0.9839
# Epoch 70/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0324 - accuracy: 0.9903
# Epoch 71/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 0.9984
# Epoch 72/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0327 - accuracy: 0.9887
# Epoch 73/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0152 - accuracy: 0.9952
# Epoch 74/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9968
# Epoch 75/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 0.9984
# Epoch 76/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 77/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 0.9984
# Epoch 78/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 0.9984
# Epoch 79/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 80/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9968
# Epoch 81/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0377 - accuracy: 0.9871
# Epoch 82/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0463 - accuracy: 0.9919
# Epoch 83/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 0.9984
# Epoch 84/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0591 - accuracy: 0.9903
# Epoch 85/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0322 - accuracy: 0.9919
# Epoch 86/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0148 - accuracy: 0.9936
# Epoch 87/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0311 - accuracy: 0.9871
# Epoch 88/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0111 - accuracy: 0.9952
# Epoch 89/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0137 - accuracy: 0.9952
# Epoch 90/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0355 - accuracy: 0.9903
# Epoch 91/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0664 - accuracy: 0.9823
# Epoch 92/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0231 - accuracy: 0.9968
# Epoch 93/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0378 - accuracy: 0.9871
# Epoch 94/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0271 - accuracy: 0.9887
# Epoch 95/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0266 - accuracy: 0.9919
# Epoch 96/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0193 - accuracy: 0.9903
# Epoch 97/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 0.9984
# Epoch 98/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0187 - accuracy: 0.9936
# Epoch 99/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 0.9919
# Epoch 100/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0224 - accuracy: 0.9936
# Epoch 101/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0241 - accuracy: 0.9903
# Epoch 102/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0269 - accuracy: 0.9919
# Epoch 103/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0810 - accuracy: 0.9807
# Epoch 104/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0612 - accuracy: 0.9807
# Epoch 105/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0450 - accuracy: 0.9887
# Epoch 106/1500
# 15/20 [=====================>........] - ETA: 0s - loss: 0.0743 - accuracy: 0.9792Restoring model weights from the end of the best epoch: 76.
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0792 - accuracy: 0.9791
# Epoch 106: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 3.0206 - accuracy: 0.6105
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.79 (23/29)
# Before appending - Cat IDs: 405, Predictions: 405, Actuals: 405, Gender: 405
# After appending - Cat IDs: 577, Predictions: 577, Actuals: 577, Gender: 577
# Final Test Results - Loss: 3.0206429958343506, Accuracy: 0.6104651093482971, Precision: 0.6641711229946524, Recall: 0.5732299620798919, F1 Score: 0.5990713482482779
# Confusion Matrix:
#  [[55  2 35]
#  [10  8  0]
#  [20  0 42]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
#         ..
# 041A     1
# 092A     1
# 076A     1
# 064A     1
# 024A     1
# Name: cat_id, Length: 86, dtype: int64
# Testing Set Group Distribution:
# 097A    15
# 002A    13
# 051A    12
# 101A    12
# 014B    10
# 040A    10
# 001A     9
# 022A     9
# 068A     8
# 039A     6
# 109A     5
# 009A     4
# 026A     4
# 014A     3
# 053A     3
# 034A     3
# 058A     3
# 062A     3
# 069A     2
# 054A     2
# 087A     2
# 096A     1
# 043A     1
# 049A     1
# 100A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    273
# X    206
# F    171
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    70
# F    60
# M    13
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 071A, 097B, 019A, 074A, 067...
# kitten    [044A, 111A, 046A, 047A, 042A, 050A, 041A, 045...
# senior    [093A, 015A, 103A, 028A, 057A, 106A, 104A, 055...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [062A, 022A, 034A, 002A, 009A, 014A, 087A, 069...
# kitten                       [014B, 040A, 109A, 043A, 049A]
# senior     [097A, 001A, 101A, 039A, 054A, 051A, 058A, 053A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 49, 'kitten': 11, 'senior': 26}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 13, 'kitten': 5, 'senior': 8}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002B' '003A' '004A' '005A' '006A' '007A' '008A' '010A'
#  '011A' '012A' '013B' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '023A' '023B' '024A' '025A' '025B' '025C' '026C' '027A' '028A' '029A'
#  '031A' '032A' '033A' '035A' '036A' '037A' '038A' '041A' '042A' '044A'
#  '045A' '046A' '047A' '048A' '050A' '051B' '052A' '055A' '056A' '057A'
#  '059A' '060A' '061A' '063A' '064A' '065A' '066A' '067A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '076A' '088A' '090A' '091A' '092A' '093A'
#  '094A' '095A' '097B' '099A' '102A' '103A' '104A' '105A' '106A' '108A'
#  '110A' '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['001A' '002A' '009A' '014A' '014B' '022A' '026A' '026B' '034A' '039A'
#  '040A' '043A' '049A' '051A' '053A' '054A' '058A' '062A' '068A' '069A'
#  '087A' '096A' '097A' '100A' '101A' '109A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002B' '003A' '004A' '005A' '006A' '007A' '008A' '010A'
#  '011A' '012A' '013B' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '023A' '023B' '024A' '025A' '025B' '025C' '026C' '027A' '028A' '029A'
#  '031A' '032A' '033A' '035A' '036A' '037A' '038A' '041A' '042A' '044A'
#  '045A' '046A' '047A' '048A' '050A' '051B' '052A' '055A' '056A' '057A'
#  '059A' '060A' '061A' '063A' '064A' '065A' '066A' '067A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '076A' '088A' '090A' '091A' '092A' '093A'
#  '094A' '095A' '097B' '099A' '102A' '103A' '104A' '105A' '106A' '108A'
#  '110A' '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002A' '009A' '014A' '014B' '022A' '026A' '026B' '034A' '039A'
#  '040A' '043A' '049A' '051A' '053A' '054A' '058A' '062A' '068A' '069A'
#  '087A' '096A' '097A' '100A' '101A' '109A']
# Length of X_train_val:
# 650
# Length of y_train_val:
# 650
# Length of groups_train_val:
# 650
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     351
# senior    191
# kitten    108
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# senior    62
# adult     54
# kitten    27
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     351
# senior    191
# kitten    108
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# senior    62
# adult     54
# kitten    27
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 351, 2: 191, 1: 108})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/1500
# 21/21 [==============================] - 1s 4ms/step - loss: 0.9818 - accuracy: 0.5523
# Epoch 2/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.5193 - accuracy: 0.7200
# Epoch 3/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4009 - accuracy: 0.7969
# Epoch 4/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2745 - accuracy: 0.8785
# Epoch 5/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2016 - accuracy: 0.9154
# Epoch 6/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1732 - accuracy: 0.9185
# Epoch 7/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1209 - accuracy: 0.9477
# Epoch 8/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1371 - accuracy: 0.9538
# Epoch 9/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0834 - accuracy: 0.9723
# Epoch 10/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0688 - accuracy: 0.9692
# Epoch 11/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1012 - accuracy: 0.9662
# Epoch 12/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0965 - accuracy: 0.9631
# Epoch 13/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1336 - accuracy: 0.9538
# Epoch 14/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0997 - accuracy: 0.9477
# Epoch 15/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0892 - accuracy: 0.9708
# Epoch 16/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0629 - accuracy: 0.9754
# Epoch 17/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0808 - accuracy: 0.9800
# Epoch 18/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0630 - accuracy: 0.9754
# Epoch 19/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0549 - accuracy: 0.9754
# Epoch 20/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0768 - accuracy: 0.9862
# Epoch 21/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0445 - accuracy: 0.9815
# Epoch 22/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0289 - accuracy: 0.9877
# Epoch 23/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0617 - accuracy: 0.9769
# Epoch 24/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1598 - accuracy: 0.9462
# Epoch 25/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1055 - accuracy: 0.9615
# Epoch 26/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1023 - accuracy: 0.9723
# Epoch 27/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1137 - accuracy: 0.9569
# Epoch 28/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1081 - accuracy: 0.9723
# Epoch 29/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0658 - accuracy: 0.9769
# Epoch 30/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0729 - accuracy: 0.9754
# Epoch 31/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1344 - accuracy: 0.9569
# Epoch 32/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1478 - accuracy: 0.9492
# Epoch 33/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0524 - accuracy: 0.9908
# Epoch 34/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0622 - accuracy: 0.9769
# Epoch 35/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0781 - accuracy: 0.9677
# Epoch 36/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0268 - accuracy: 0.9954
# Epoch 37/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0344 - accuracy: 0.9846
# Epoch 38/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0564 - accuracy: 0.9831
# Epoch 39/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0255 - accuracy: 0.9892
# Epoch 40/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0387 - accuracy: 0.9892
# Epoch 41/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0559 - accuracy: 0.9815
# Epoch 42/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0261 - accuracy: 0.9908
# Epoch 43/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0639 - accuracy: 0.9754
# Epoch 44/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1741 - accuracy: 0.9431
# Epoch 45/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0727 - accuracy: 0.9754
# Epoch 46/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0235 - accuracy: 0.9923
# Epoch 47/1500
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0465 - accuracy: 0.9862
# Epoch 48/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0335 - accuracy: 0.9908
# Epoch 49/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0316 - accuracy: 0.9892
# Epoch 50/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0345 - accuracy: 0.9877
# Epoch 51/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0366 - accuracy: 0.9877
# Epoch 52/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0649 - accuracy: 0.9754
# Epoch 53/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0257 - accuracy: 0.9908
# Epoch 54/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0193 - accuracy: 0.9954
# Epoch 55/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0626 - accuracy: 0.9723
# Epoch 56/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0364 - accuracy: 0.9785
# Epoch 57/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0192 - accuracy: 0.9954
# Epoch 58/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0388 - accuracy: 0.9862
# Epoch 59/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0256 - accuracy: 0.9969
# Epoch 60/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0484 - accuracy: 0.9815
# Epoch 61/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0860 - accuracy: 0.9769
# Epoch 62/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0292 - accuracy: 0.9923
# Epoch 63/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0479 - accuracy: 0.9892
# Epoch 64/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0394 - accuracy: 0.9831
# Epoch 65/1500
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0501 - accuracy: 0.9862
# Epoch 66/1500
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0602 - accuracy: 0.9815
# Epoch 67/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0452 - accuracy: 0.9831
# Epoch 68/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0230 - accuracy: 0.9892
# Epoch 69/1500
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0111 - accuracy: 0.9969
# Epoch 70/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 0.9923
# Epoch 71/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 0.9985
# Epoch 72/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0752 - accuracy: 0.9877
# Epoch 73/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0503 - accuracy: 0.9846
# Epoch 74/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0209 - accuracy: 0.9969
# Epoch 75/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0129 - accuracy: 0.9969
# Epoch 76/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0234 - accuracy: 0.9908
# Epoch 77/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0176 - accuracy: 0.9892
# Epoch 78/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 0.9969
# Epoch 79/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0426 - accuracy: 0.9846
# Epoch 80/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0414 - accuracy: 0.9877
# Epoch 81/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0173 - accuracy: 0.9877
# Epoch 82/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0292 - accuracy: 0.9908
# Epoch 83/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0479 - accuracy: 0.9846
# Epoch 84/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 0.9954
# Epoch 85/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 0.9908
# Epoch 86/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0274 - accuracy: 0.9954
# Epoch 87/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0160 - accuracy: 0.9938
# Epoch 88/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0135 - accuracy: 0.9985
# Epoch 89/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0397 - accuracy: 0.9862
# Epoch 90/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0554 - accuracy: 0.9846
# Epoch 91/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0179 - accuracy: 0.9923
# Epoch 92/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0283 - accuracy: 0.9908
# Epoch 93/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0351 - accuracy: 0.9831
# Epoch 94/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9938
# Epoch 95/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0082 - accuracy: 0.9954
# Epoch 96/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0245 - accuracy: 0.9892
# Epoch 97/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0747 - accuracy: 0.9708
# Epoch 98/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0966 - accuracy: 0.9585
# Epoch 99/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1074 - accuracy: 0.9692
# Epoch 100/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0369 - accuracy: 0.9877
# Epoch 101/1500
# 15/21 [====================>.........] - ETA: 0s - loss: 0.0597 - accuracy: 0.9771Restoring model weights from the end of the best epoch: 71.
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0478 - accuracy: 0.9815
# Epoch 101: early stopping
# 5/5 [==============================] - 0s 2ms/step - loss: 1.6550 - accuracy: 0.7343
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.77 (20/26)
# Before appending - Cat IDs: 577, Predictions: 577, Actuals: 577, Gender: 577
# After appending - Cat IDs: 720, Predictions: 720, Actuals: 720, Gender: 720
# Final Test Results - Loss: 1.6550275087356567, Accuracy: 0.7342657446861267, Precision: 0.7507155867811606, Recall: 0.7148546395858224, F1 Score: 0.7281577707081418
# Confusion Matrix:
#  [[40  4 10]
#  [ 7 17  3]
#  [14  0 48]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.6354878112359666
#
# Final Average Loss across all UNSEEN TEST sets: 2.372145801782608
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6547964215278625
#
# Final Average Precision across all UNSEEN TEST sets: 0.6972840196739312
#
# Final Average Recall across all UNSEEN TEST sets: 0.6428644461053238

# %%
seed_1_folds_values = [unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1]

seed_1_training_acc_values = cv_training_acc_total

# Plotting all fold metrics
seed_1_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 720, Predictions: 720, Actuals: 720, Gender: 720

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.69 (76/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 64    058A                           [senior, senior, senior]        senior           senior                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 77    071A  [senior, adult, adult, adult, adult, senior, a...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 73    067A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, kitten, adult, a...         adult            adult                   True
# 70    064A                                            [adult]         adult            adult                   True
# 69    063A  [adult, adult, adult, adult, senior, adult, se...         adult            adult                   True
# 68    062A                              [adult, adult, adult]         adult            adult                   True
# 65    059A  [senior, senior, senior, senior, senior, senio...        senior           senior                   True
# 63    057A  [senior, senior, senior, adult, senior, senior...        senior           senior                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 62    056A                           [senior, senior, senior]        senior           senior                   True
# 61    055A  [adult, senior, adult, adult, senior, senior, ...        senior           senior                   True
# 59    053A                           [senior, senior, senior]        senior           senior                   True
# 56    051A  [senior, senior, adult, adult, senior, senior,...        senior           senior                   True
# 1     001A  [senior, senior, senior, adult, senior, senior...        senior           senior                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 50    044A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 79    073A                                    [senior, adult]         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 84    088A                                            [adult]         adult            adult                   True
# 108   116A  [senior, senior, adult, senior, adult, adult, ...        senior           senior                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                            [adult, senior, senior]        senior           senior                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 102   108A             [senior, adult, adult, senior, senior]        senior           senior                   True
# 100   105A                             [adult, adult, senior]         adult            adult                   True
# 98    103A  [adult, senior, senior, adult, adult, senior, ...        senior           senior                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 96    101A  [adult, senior, senior, senior, senior, senior...        senior           senior                   True
# 95    100A                                            [adult]         adult            adult                   True
# 94    099A        [adult, adult, adult, kitten, adult, adult]         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, kit...         adult            adult                   True
# 92    097A  [senior, senior, senior, senior, senior, senio...        senior           senior                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 89    094A            [senior, adult, senior, senior, senior]        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 55    050A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 109   117A  [senior, adult, senior, senior, adult, adult, ...        senior           senior                   True
# 34    027A  [adult, senior, adult, adult, adult, senior, s...         adult            adult                   True
# 22    020A  [adult, senior, senior, adult, senior, adult, ...         adult            adult                   True
# 23    021A               [adult, adult, adult, senior, adult]         adult            adult                   True
# 24    022A  [adult, adult, adult, kitten, adult, adult, ki...         adult            adult                   True
# 16    014B  [adult, kitten, kitten, adult, kitten, kitten,...        kitten           kitten                   True
# 26    023B                     [adult, adult, senior, senior]         adult            adult                   True
# 27    024A                                           [senior]        senior           senior                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 28    025A  [senior, senior, senior, senior, adult, senior...        senior           senior                   True
# 13    012A                             [adult, senior, adult]         adult            adult                   True
# 30    025C                   [senior, senior, senior, senior]        senior           senior                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 10    009A                     [adult, senior, senior, adult]         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 20    019A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 35    028A  [senior, senior, senior, senior, senior, senio...        senior           senior                   True
# 7     006A                              [adult, adult, adult]         adult            adult                   True
# 2     002A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 3     002B  [adult, senior, senior, adult, adult, adult, a...         adult            adult                   True
# 4     003A                      [kitten, adult, adult, adult]         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 41    035A                                    [adult, senior]         adult            adult                   True
# 39    033A  [adult, adult, senior, adult, senior, senior, ...         adult            adult                   True
# 40    034A                             [adult, senior, adult]         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 37    031A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 8     007A       [senior, adult, adult, adult, senior, adult]         adult            adult                   True
# 103   109A               [senior, adult, adult, adult, adult]         adult           kitten                  False
# 12    011A                                     [adult, adult]         adult           senior                  False
# 99    104A                       [adult, adult, adult, adult]         adult           senior                  False
# 6     005A  [senior, senior, senior, senior, senior, senio...        senior            adult                  False
# 101   106A  [adult, adult, senior, adult, senior, adult, a...         adult           senior                  False
# 11    010A                           [senior, senior, senior]        senior            adult                  False
# 17    015A  [adult, adult, senior, senior, adult, adult, a...         adult           senior                  False
# 18    016A  [adult, adult, adult, senior, adult, senior, s...         adult           senior                  False
# 88    093A                                   [kitten, kitten]        kitten           senior                  False
# 9     008A               [adult, adult, adult, senior, adult]         adult           senior                  False
# 45    039A         [adult, adult, adult, adult, adult, adult]         adult           senior                  False
# 86    091A                                            [adult]         adult           senior                  False
# 33    026C                                           [kitten]        kitten            adult                  False
# 44    038A                                   [kitten, kitten]        kitten            adult                  False
# 43    037A                                   [senior, senior]        senior            adult                  False
# 51    045A                     [kitten, kitten, adult, adult]         adult           kitten                  False
# 52    047A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 42    036A  [senior, senior, senior, senior, senior, adult...        senior            adult                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, sen...         adult           senior                  False
# 58    052A                                   [senior, senior]        senior            adult                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 36    029A  [senior, senior, senior, senior, senior, senio...        senior            adult                  False
# 66    060A                              [adult, adult, adult]         adult           senior                  False
# 21    019B                                           [senior]        senior            adult                  False
# 67    061A                                    [adult, senior]         adult           senior                  False
# 32    026B                                           [senior]        senior            adult                  False
# 29    025B                                   [senior, senior]        senior            adult                  False
# 72    066A                                           [senior]        senior            adult                  False
# 74    068A  [senior, senior, adult, kitten, senior, kitten...        senior            adult                  False
# 75    069A                                   [senior, senior]        senior            adult                  False
# 48    042A  [adult, kitten, adult, adult, adult, adult, ad...         adult           kitten                  False
# 80    074A  [senior, senior, senior, adult, senior, senior...        senior            adult                  False
# 82    076A                                           [senior]        senior            adult                  False
# 25    023A     [senior, senior, senior, adult, adult, senior]        senior            adult                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']
# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()
# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')
# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Calculate the class statistics
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    accuracy=('Majority_Correct', lambda x: x.mean() * 100),
    total_count=('Majority_Correct', 'size')
).reset_index()

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group   accuracy  total_count
# 0            adult  72.131148           61
# 1           kitten  73.333333           15
# 2           senior  61.764706           34

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# For each fold
fold_class_stats = full_results.groupby('actual_age_group').agg(
    accuracy=('correct', lambda x: x.mean() * 100),
    total_count=('correct', 'size')
).reset_index()

# Store for final evaluation 
all_class_stats.append(fold_class_stats)

# Log the detailed stats
print("Detailed Class Statistics for this fold:")
print(fold_class_stats)
# Out:
# Detailed Class Statistics for this fold:
#   actual_age_group   accuracy  total_count
# 0            adult  67.574932          367
# 1           kitten  59.000000          100
# 2           senior  63.636364          253

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(fold_class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    192      144     75.00
# 1          M    286      163     56.99
# 2          X    242      161     66.53

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.6909090909090909]
# Total Class Statistics so far:
#  [  actual_age_group   accuracy  total_count
# 0            adult  67.574932          367
# 1           kitten  59.000000          100
# 2           senior  63.636364          253]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    192      144     75.00
# 1          M    286      163     56.99
# 2          X    242      161     66.53]

# %% [markdown]
# # RANDOM SEED 2

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[1]))
np.random.seed(int(random_seeds[1]))
tf.random.set_seed(int(random_seeds[1]))

# Load datasets
dataframe = pd.read_csv('perch_looped_embeddings.csv')



def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 10),
    'senior': (10, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     405
# senior    253
# kitten    135
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[1]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

cv_training_acc_total = []
cv_training_acc_best = []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )
    
    accuracy_history = AccuracyHistory()

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_val),
        y=y_train_val
    )
    weight_dict = {i: class_weights[i] for i in range(len(class_weights))}

    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adam': Adam(learning_rate=0.007402414884293732)
    }
    
    # Full model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(512, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.15688606637942396))  
    model_full.add(Dense(64, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.28869063762474007))  
    model_full.add(Dense(128, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.27322054853254163))   
    model_full.add(Dense(32, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.4064145271744943))  
    model_full.add(Dense(3, activation='softmax'))  
    
    optimizer = optimizers['Adam']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=32,
                                  verbose=1, callbacks=[early_stopping, accuracy_history], class_weight=weight_dict)
    
    
    # log epochs
    best_epoch_index = np.argmin(history_full.history['loss'])  
    best_training_accuracy = accuracy_history.acc[best_epoch_index]

    # Append training acc to total  
    all_best_training_acc.append(best_training_accuracy)
    total_training_acc.append(accuracy_history.acc)

    # Append training acc just for this CV
    cv_training_acc_total.append(accuracy_history.acc)
    cv_training_acc_best.append(best_training_accuracy)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
average_fold_f1.append(unseen_set_avg_f1)
average_fold_losses.append(unseen_set_avg_loss)
average_fold_accuracies.append(unseen_set_avg_acc)
average_fold_precisions.append(unseen_set_avg_precision)
average_fold_recalls.append(unseen_set_avg_recall)

# Append all to total lists
all_f1.append(unseen_f1)
all_losses.append(unseen_losses)
all_accuracies.append(unseen_accuracies)
all_precisions.append(unseen_precisions)
all_recalls.append(unseen_recalls)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 020A    20
# 074A    16
# 097A    15
# 097B    14
# 002A    13
# 106A    13
# 101A    12
# 116A    12
# 055A    12
# 051A    12
# 111A    12
# 063A    11
# 059A    10
# 040A    10
# 025A    10
# 071A     9
# 016A     9
# 005A     9
# 051B     9
# 072A     9
# 033A     9
# 068A     8
# 031A     7
# 036A     7
# 117A     7
# 015A     7
# 095A     7
# 099A     6
# 039A     6
# 023A     6
# 075A     5
# 094A     5
# 070A     5
# 050A     5
# 108A     5
# 008A     5
# 109A     5
# 045A     4
# 003A     4
# 104A     4
# 026A     4
# 010A     3
# 012A     3
# 058A     3
# 060A     3
# 053A     3
# 006A     3
# 034A     3
# 062A     3
# 113A     3
# 105A     3
# 102A     2
# 061A     2
# 025B     2
# 011A     2
# 093A     2
# 035A     2
# 037A     2
# 038A     2
# 052A     2
# 087A     2
# 069A     2
# 054A     2
# 115A     1
# 100A     1
# 090A     1
# 110A     1
# 024A     1
# 043A     1
# 048A     1
# 019B     1
# 088A     1
# 066A     1
# 026C     1
# 092A     1
# 064A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    22
# 000B    19
# 057A    17
# 019A    17
# 029A    15
# 028A    11
# 067A    11
# 042A    11
# 014B    10
# 001A     9
# 022A     9
# 065A     9
# 013B     8
# 027A     7
# 007A     6
# 021A     5
# 044A     5
# 025C     4
# 009A     4
# 023B     4
# 014A     3
# 056A     3
# 032A     2
# 018A     2
# 076A     1
# 091A     1
# 096A     1
# 073A     1
# 049A     1
# 041A     1
# 004A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    221
# X    185
# F    167
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    91
# M    65
# F    64
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 071A, 097B, 074A, 020A, 062...
# kitten    [111A, 040A, 046A, 109A, 050A, 043A, 045A, 048...
# senior    [093A, 015A, 097A, 103A, 106A, 101A, 104A, 055...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [019A, 067A, 022A, 029A, 065A, 009A, 027A, 013...
# kitten                 [044A, 014B, 047A, 042A, 049A, 041A]
# senior                 [001A, 028A, 057A, 091A, 025C, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 43, 'kitten': 10, 'senior': 28}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 6, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000A' '002A' '002B' '003A' '005A' '006A' '008A' '010A' '011A' '012A'
#  '015A' '016A' '019B' '020A' '023A' '024A' '025A' '025B' '026A' '026B'
#  '026C' '031A' '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A'
#  '043A' '045A' '046A' '048A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '066A' '068A'
#  '069A' '070A' '071A' '072A' '074A' '075A' '087A' '088A' '090A' '092A'
#  '093A' '094A' '095A' '097A' '097B' '099A' '100A' '101A' '102A' '103A'
#  '104A' '105A' '106A' '108A' '109A' '110A' '111A' '113A' '115A' '116A'
#  '117A']
# Unique Test Group IDs:
# ['000B' '001A' '004A' '007A' '009A' '013B' '014A' '014B' '018A' '019A'
#  '021A' '022A' '023B' '025C' '027A' '028A' '029A' '032A' '041A' '042A'
#  '044A' '047A' '049A' '056A' '057A' '065A' '067A' '073A' '076A' '091A'
#  '096A']
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '002A' '002B' '003A' '005A' '006A' '008A' '010A' '011A' '012A'
#  '015A' '016A' '019B' '020A' '023A' '024A' '025A' '025B' '026A' '026B'
#  '026C' '031A' '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A'
#  '043A' '045A' '046A' '048A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '066A' '068A'
#  '069A' '070A' '071A' '072A' '074A' '075A' '087A' '088A' '090A' '092A'
#  '093A' '094A' '095A' '097A' '097B' '099A' '100A' '101A' '102A' '103A'
#  '104A' '105A' '106A' '108A' '109A' '110A' '111A' '113A' '115A' '116A'
#  '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '001A' '004A' '007A' '009A' '013B' '014A' '014B' '018A' '019A'
#  '021A' '022A' '023B' '025C' '027A' '028A' '029A' '032A' '041A' '042A'
#  '044A' '047A' '049A' '056A' '057A' '065A' '067A' '073A' '076A' '091A'
#  '096A']
# Length of X_train_val:
# 573
# Length of y_train_val:
# 573
# Length of groups_train_val:
# 573
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     280
# senior    208
# kitten     85
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     125
# kitten     50
# senior     45
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     280
# senior    208
# kitten     85
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     125
# kitten     50
# senior     45
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 280, 2: 208, 1: 85})
# Epoch 1/1500
# 18/18 [==============================] - 1s 4ms/step - loss: 1.0078 - accuracy: 0.5724
# Epoch 2/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5020 - accuracy: 0.7452
# Epoch 3/1500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3393 - accuracy: 0.8377
# Epoch 4/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2307 - accuracy: 0.9023
# Epoch 5/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1444 - accuracy: 0.9389
# Epoch 6/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1411 - accuracy: 0.9389
# Epoch 7/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1138 - accuracy: 0.9546
# Epoch 8/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1039 - accuracy: 0.9599
# Epoch 9/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0949 - accuracy: 0.9668
# Epoch 10/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0389 - accuracy: 0.9825
# Epoch 11/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0322 - accuracy: 0.9895
# Epoch 12/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0559 - accuracy: 0.9825
# Epoch 13/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0823 - accuracy: 0.9703
# Epoch 14/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0903 - accuracy: 0.9651
# Epoch 15/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0707 - accuracy: 0.9895
# Epoch 16/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0358 - accuracy: 0.9878
# Epoch 17/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0836 - accuracy: 0.9668
# Epoch 18/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0461 - accuracy: 0.9825
# Epoch 19/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0568 - accuracy: 0.9843
# Epoch 20/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0603 - accuracy: 0.9843
# Epoch 21/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0335 - accuracy: 0.9878
# Epoch 22/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0506 - accuracy: 0.9808
# Epoch 23/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0373 - accuracy: 0.9878
# Epoch 24/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0292 - accuracy: 0.9878
# Epoch 25/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0353 - accuracy: 0.9895
# Epoch 26/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0322 - accuracy: 0.9860
# Epoch 27/1500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0224 - accuracy: 0.9913
# Epoch 28/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0415 - accuracy: 0.9895
# Epoch 29/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0392 - accuracy: 0.9878
# Epoch 30/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0329 - accuracy: 0.9860
# Epoch 31/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0568 - accuracy: 0.9721
# Epoch 32/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0292 - accuracy: 0.9860
# Epoch 33/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0151 - accuracy: 0.9895
# Epoch 34/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0217 - accuracy: 0.9895
# Epoch 35/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0166 - accuracy: 0.9948
# Epoch 36/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0239 - accuracy: 0.9913
# Epoch 37/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0250 - accuracy: 0.9948
# Epoch 38/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 0.9930
# Epoch 39/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 0.9965
# Epoch 40/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0172 - accuracy: 0.9948
# Epoch 41/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 0.9948
# Epoch 42/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0422 - accuracy: 0.9913
# Epoch 43/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1066 - accuracy: 0.9878
# Epoch 44/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0935 - accuracy: 0.9703
# Epoch 45/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0644 - accuracy: 0.9825
# Epoch 46/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0307 - accuracy: 0.9878
# Epoch 47/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0321 - accuracy: 0.9878
# Epoch 48/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0799 - accuracy: 0.9843
# Epoch 49/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0780 - accuracy: 0.9738
# Epoch 50/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0171 - accuracy: 0.9965
# Epoch 51/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0237 - accuracy: 0.9913
# Epoch 52/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0484 - accuracy: 0.9930
# Epoch 53/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0686 - accuracy: 0.9913
# Epoch 54/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0305 - accuracy: 0.9930
# Epoch 55/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0457 - accuracy: 0.9878
# Epoch 56/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0135 - accuracy: 0.9948
# Epoch 57/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0546 - accuracy: 0.9791
# Epoch 58/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0271 - accuracy: 0.9930
# Epoch 59/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0741 - accuracy: 0.9808
# Epoch 60/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0870 - accuracy: 0.9825
# Epoch 61/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0283 - accuracy: 0.9913
# Epoch 62/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0214 - accuracy: 0.9913
# Epoch 63/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 0.9948
# Epoch 64/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 0.9948
# Epoch 65/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0375 - accuracy: 0.9860
# Epoch 66/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 67/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0331 - accuracy: 0.9895
# Epoch 68/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0208 - accuracy: 0.9930
# Epoch 69/1500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0227 - accuracy: 0.9948
# Epoch 70/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0201 - accuracy: 0.9930
# Epoch 71/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0221 - accuracy: 0.9930
# Epoch 72/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0337 - accuracy: 0.9825
# Epoch 73/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 74/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 0.9948
# Epoch 75/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0048 - accuracy: 0.9983
# Epoch 76/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0107 - accuracy: 0.9930
# Epoch 77/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 0.9983
# Epoch 78/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0241 - accuracy: 0.9895
# Epoch 79/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0163 - accuracy: 0.9895
# Epoch 80/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0153 - accuracy: 0.9965
# Epoch 81/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 0.9983
# Epoch 82/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0275 - accuracy: 0.9930
# Epoch 83/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0259 - accuracy: 0.9895
# Epoch 84/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0141 - accuracy: 0.9913
# Epoch 85/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0317 - accuracy: 0.9895
# Epoch 86/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0126 - accuracy: 0.9965
# Epoch 87/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0177 - accuracy: 0.9948
# Epoch 88/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 89/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9948
# Epoch 90/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0123 - accuracy: 0.9983
# Epoch 91/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 0.9948
# Epoch 92/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 0.9965
# Epoch 93/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0148 - accuracy: 0.9930
# Epoch 94/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0091 - accuracy: 0.9983
# Epoch 95/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0073 - accuracy: 0.9965
# Epoch 96/1500
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1096 - accuracy: 0.9833    Restoring model weights from the end of the best epoch: 66.
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0952 - accuracy: 0.9825
# Epoch 96: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 3.1128 - accuracy: 0.5000
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.61 (19/31)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 220, Predictions: 220, Actuals: 220, Gender: 220
# Final Test Results - Loss: 3.112839937210083, Accuracy: 0.5, Precision: 0.4633658522547411, Recall: 0.4762962962962963, F1 Score: 0.4401919629192356
# Confusion Matrix:
#  [[70 13 42]
#  [33  9  8]
#  [14  0 31]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 047A    22
# 020A    20
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 029A    15
# 106A    13
# 111A    12
# 116A    12
# 101A    12
# 055A    12
# 028A    11
# 042A    11
# 067A    11
# 014B    10
# 040A    10
# 051B     9
# 016A     9
# 072A     9
# 065A     9
# 022A     9
# 001A     9
# 033A     9
# 068A     8
# 013B     8
# 036A     7
# 015A     7
# 027A     7
# 117A     7
# 007A     6
# 039A     6
# 023A     6
# 021A     5
# 044A     5
# 075A     5
# 109A     5
# 008A     5
# 070A     5
# 094A     5
# 108A     5
# 050A     5
# 025C     4
# 023B     4
# 009A     4
# 104A     4
# 003A     4
# 026A     4
# 056A     3
# 060A     3
# 006A     3
# 034A     3
# 113A     3
# 014A     3
# 105A     3
# 062A     3
# 018A     2
# 037A     2
# 102A     2
# 061A     2
# 011A     2
# 035A     2
# 093A     2
# 052A     2
# 038A     2
# 032A     2
# 091A     1
# 088A     1
# 024A     1
# 100A     1
# 115A     1
# 096A     1
# 076A     1
# 019B     1
# 004A     1
# 049A     1
# 043A     1
# 048A     1
# 066A     1
# 073A     1
# 064A     1
# 026C     1
# 041A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 103A    33
# 002B    30
# 097A    15
# 097B    14
# 002A    13
# 051A    12
# 063A    11
# 025A    10
# 059A    10
# 005A     9
# 071A     9
# 095A     7
# 031A     7
# 099A     6
# 045A     4
# 012A     3
# 010A     3
# 058A     3
# 053A     3
# 025B     2
# 087A     2
# 054A     2
# 069A     2
# 092A     1
# 110A     1
# 090A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    215
# M    188
# F    138
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    98
# F    93
# X    61
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 033A, 019A, 074A, 067A, 020A, 062A, 022...
# kitten    [044A, 014B, 111A, 040A, 046A, 047A, 042A, 109...
# senior    [093A, 015A, 001A, 028A, 057A, 106A, 101A, 104...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000A, 071A, 097B, 002B, 095A, 005A, 002A, 063...
# kitten                                         [045A, 110A]
# senior    [097A, 103A, 059A, 025A, 054A, 051A, 058A, 053...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 46, 'kitten': 14, 'senior': 25}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 16, 'kitten': 2, 'senior': 9}
# Unique Training/Validation Group IDs:
# ['000B' '001A' '003A' '004A' '006A' '007A' '008A' '009A' '011A' '013B'
#  '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A' '022A'
#  '023A' '023B' '024A' '025C' '026A' '026B' '026C' '027A' '028A' '029A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A'
#  '042A' '043A' '044A' '046A' '047A' '048A' '049A' '050A' '051B' '052A'
#  '055A' '056A' '057A' '060A' '061A' '062A' '064A' '065A' '066A' '067A'
#  '068A' '070A' '072A' '073A' '074A' '075A' '076A' '088A' '091A' '093A'
#  '094A' '096A' '100A' '101A' '102A' '104A' '105A' '106A' '108A' '109A'
#  '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '002A' '002B' '005A' '010A' '012A' '025A' '025B' '031A' '045A'
#  '051A' '053A' '054A' '058A' '059A' '063A' '069A' '071A' '087A' '090A'
#  '092A' '095A' '097A' '097B' '099A' '103A' '110A']
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'003A'}
# Moved to Test Set:
# {'003A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '004A' '006A' '007A' '008A' '009A' '011A' '013B'
#  '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A' '022A'
#  '023A' '023B' '024A' '025C' '026A' '026B' '026C' '027A' '028A' '029A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A'
#  '042A' '043A' '044A' '046A' '047A' '048A' '049A' '050A' '051B' '052A'
#  '055A' '056A' '057A' '060A' '061A' '062A' '064A' '065A' '066A' '067A'
#  '068A' '070A' '072A' '073A' '074A' '075A' '076A' '088A' '091A' '093A'
#  '094A' '096A' '100A' '101A' '102A' '104A' '105A' '106A' '108A' '109A'
#  '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002A' '002B' '003A' '005A' '010A' '012A' '025A' '025B' '031A' '045A'
#  '051A' '053A' '054A' '058A' '059A' '063A' '069A' '071A' '087A' '090A'
#  '092A' '095A' '097A' '097B' '099A' '103A' '110A']
# Length of X_train_val:
# 576
# Length of y_train_val:
# 576
# Length of groups_train_val:
# 576
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     247
# senior    164
# kitten    130
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     158
# senior     89
# kitten      5
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     282
# senior    164
# kitten    130
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     123
# senior     89
# kitten      5
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 282, 2: 164, 1: 130})
# Epoch 1/1500
# 18/18 [==============================] - 1s 4ms/step - loss: 0.9520 - accuracy: 0.5833
# Epoch 2/1500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4818 - accuracy: 0.7847
# Epoch 3/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3139 - accuracy: 0.8646
# Epoch 4/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2532 - accuracy: 0.9045
# Epoch 5/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1964 - accuracy: 0.9288
# Epoch 6/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1469 - accuracy: 0.9410
# Epoch 7/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1631 - accuracy: 0.9497
# Epoch 8/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0911 - accuracy: 0.9670
# Epoch 9/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0918 - accuracy: 0.9688
# Epoch 10/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0519 - accuracy: 0.9792
# Epoch 11/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0751 - accuracy: 0.9722
# Epoch 12/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0963 - accuracy: 0.9653
# Epoch 13/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0517 - accuracy: 0.9826
# Epoch 14/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0498 - accuracy: 0.9809
# Epoch 15/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0339 - accuracy: 0.9878
# Epoch 16/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0730 - accuracy: 0.9792
# Epoch 17/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1035 - accuracy: 0.9670
# Epoch 18/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0744 - accuracy: 0.9809
# Epoch 19/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0417 - accuracy: 0.9861
# Epoch 20/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0359 - accuracy: 0.9878
# Epoch 21/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0521 - accuracy: 0.9792
# Epoch 22/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0712 - accuracy: 0.9844
# Epoch 23/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0392 - accuracy: 0.9913
# Epoch 24/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0523 - accuracy: 0.9861
# Epoch 25/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0238 - accuracy: 0.9878
# Epoch 26/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0564 - accuracy: 0.9861
# Epoch 27/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0283 - accuracy: 0.9913
# Epoch 28/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0430 - accuracy: 0.9878
# Epoch 29/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0327 - accuracy: 0.9896
# Epoch 30/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0545 - accuracy: 0.9861
# Epoch 31/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.9913
# Epoch 32/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0107 - accuracy: 0.9983
# Epoch 33/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0402 - accuracy: 0.9896
# Epoch 34/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0584 - accuracy: 0.9844
# Epoch 35/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 0.9931
# Epoch 36/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0323 - accuracy: 0.9896
# Epoch 37/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 0.9948
# Epoch 38/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0350 - accuracy: 0.9896
# Epoch 39/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0376 - accuracy: 0.9965
# Epoch 40/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 41/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0236 - accuracy: 0.9948
# Epoch 42/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0502 - accuracy: 0.9913
# Epoch 43/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0352 - accuracy: 0.9913
# Epoch 44/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 0.9965
# Epoch 45/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0425 - accuracy: 0.9878
# Epoch 46/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0244 - accuracy: 0.9913
# Epoch 47/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0564 - accuracy: 0.9792
# Epoch 48/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0741 - accuracy: 0.9792
# Epoch 49/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0753 - accuracy: 0.9809
# Epoch 50/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0560 - accuracy: 0.9809
# Epoch 51/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0203 - accuracy: 0.9896
# Epoch 52/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0610 - accuracy: 0.9861
# Epoch 53/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0253 - accuracy: 0.9878
# Epoch 54/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0235 - accuracy: 0.9931
# Epoch 55/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0111 - accuracy: 0.9965
# Epoch 56/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0331 - accuracy: 0.9931
# Epoch 57/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9965
# Epoch 58/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0184 - accuracy: 0.9931
# Epoch 59/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0337 - accuracy: 0.9896
# Epoch 60/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0553 - accuracy: 0.9844
# Epoch 61/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0579 - accuracy: 0.9844
# Epoch 62/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0798 - accuracy: 0.9740
# Epoch 63/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0353 - accuracy: 0.9844
# Epoch 64/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0390 - accuracy: 0.9826
# Epoch 65/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0292 - accuracy: 0.9913
# Epoch 66/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0266 - accuracy: 0.9913
# Epoch 67/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0107 - accuracy: 0.9965
# Epoch 68/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0105 - accuracy: 0.9965
# Epoch 69/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 0.9948
# Epoch 70/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 0.9983
# Epoch 71/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 72/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0120 - accuracy: 0.9965
# Epoch 73/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0242 - accuracy: 0.9931
# Epoch 74/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0501 - accuracy: 0.9896
# Epoch 75/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0376 - accuracy: 0.9913
# Epoch 76/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0475 - accuracy: 0.9809
# Epoch 77/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0263 - accuracy: 0.9931
# Epoch 78/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0231 - accuracy: 0.9913
# Epoch 79/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0365 - accuracy: 0.9948
# Epoch 80/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0238 - accuracy: 0.9896
# Epoch 81/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0116 - accuracy: 0.9965
# Epoch 82/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0104 - accuracy: 0.9983
# Epoch 83/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0296 - accuracy: 0.9896
# Epoch 84/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 0.9965
# Epoch 85/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 0.9965
# Epoch 86/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 0.9931
# Epoch 87/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 0.9983
# Epoch 88/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0336 - accuracy: 0.9931
# Epoch 89/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0640 - accuracy: 0.9878
# Epoch 90/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0341 - accuracy: 0.9878
# Epoch 91/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1319 - accuracy: 0.9757
# Epoch 92/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0518 - accuracy: 0.9809
# Epoch 93/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0477 - accuracy: 0.9861
# Epoch 94/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0321 - accuracy: 0.9931
# Epoch 95/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0229 - accuracy: 0.9948
# Epoch 96/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0214 - accuracy: 0.9948
# Epoch 97/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 0.9983
# Epoch 98/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0156 - accuracy: 0.9948
# Epoch 99/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0076 - accuracy: 0.9983
# Epoch 100/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 0.9965
# Epoch 101/1500
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0052 - accuracy: 0.9980    Restoring model weights from the end of the best epoch: 71.
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 0.9983
# Epoch 101: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 2.4908 - accuracy: 0.6498
# 7/7 [==============================] - 0s 866us/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Majority Vote Accuracy for cat_id for this fold: 0.70 (19/27)
# Before appending - Cat IDs: 220, Predictions: 220, Actuals: 220, Gender: 220
# After appending - Cat IDs: 437, Predictions: 437, Actuals: 437, Gender: 437
# Final Test Results - Loss: 2.4907634258270264, Accuracy: 0.6497696042060852, Precision: 0.49484754803903735, Recall: 0.5061173533083646, F1 Score: 0.49967709885742667
# Confusion Matrix:
#  [[82  5 36]
#  [ 4  1  0]
#  [31  0 58]]
# outer_fold 3
# Train Set Group Distribution:
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 000B    19
# 019A    17
# 057A    17
# 029A    15
# 097A    15
# 097B    14
# 002A    13
# 055A    12
# 051A    12
# 111A    12
# 067A    11
# 063A    11
# 028A    11
# 042A    11
# 059A    10
# 025A    10
# 014B    10
# 072A     9
# 051B     9
# 065A     9
# 005A     9
# 071A     9
# 033A     9
# 022A     9
# 001A     9
# 068A     8
# 013B     8
# 036A     7
# 031A     7
# 015A     7
# 027A     7
# 095A     7
# 099A     6
# 023A     6
# 007A     6
# 021A     5
# 044A     5
# 025C     4
# 045A     4
# 026A     4
# 023B     4
# 009A     4
# 003A     4
# 012A     3
# 056A     3
# 105A     3
# 058A     3
# 006A     3
# 053A     3
# 014A     3
# 034A     3
# 010A     3
# 060A     3
# 035A     2
# 011A     2
# 061A     2
# 037A     2
# 025B     2
# 032A     2
# 087A     2
# 018A     2
# 093A     2
# 054A     2
# 069A     2
# 073A     1
# 024A     1
# 090A     1
# 100A     1
# 110A     1
# 091A     1
# 115A     1
# 004A     1
# 049A     1
# 066A     1
# 076A     1
# 096A     1
# 043A     1
# 041A     1
# 092A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    45
# 020A    20
# 074A    16
# 106A    13
# 116A    12
# 101A    12
# 040A    10
# 016A     9
# 117A     7
# 039A     6
# 108A     5
# 109A     5
# 050A     5
# 075A     5
# 008A     5
# 070A     5
# 094A     5
# 104A     4
# 113A     3
# 062A     3
# 038A     2
# 102A     2
# 052A     2
# 026C     1
# 048A     1
# 088A     1
# 019B     1
# 064A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    210
# X    199
# F    178
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    77
# M    76
# F    53
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 071A, 097B, 019A, 067A, 002...
# kitten    [044A, 014B, 111A, 047A, 042A, 043A, 049A, 041...
# senior    [093A, 015A, 097A, 001A, 103A, 028A, 057A, 055...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [074A, 020A, 062A, 038A, 070A, 075A, 064A, 052...
# kitten                       [040A, 046A, 109A, 050A, 048A]
# senior    [106A, 101A, 104A, 039A, 113A, 116A, 117A, 008...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 50, 'kitten': 11, 'senior': 23}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 12, 'kitten': 5, 'senior': 11}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '009A' '010A' '011A' '012A' '013B' '014A' '014B' '015A' '018A' '019A'
#  '021A' '022A' '023A' '023B' '024A' '025A' '025B' '025C' '026A' '026B'
#  '027A' '028A' '029A' '031A' '032A' '033A' '034A' '035A' '036A' '037A'
#  '041A' '042A' '043A' '044A' '045A' '047A' '049A' '051A' '051B' '053A'
#  '054A' '055A' '056A' '057A' '058A' '059A' '060A' '061A' '063A' '065A'
#  '066A' '067A' '068A' '069A' '071A' '072A' '073A' '076A' '087A' '090A'
#  '091A' '092A' '093A' '095A' '096A' '097A' '097B' '099A' '100A' '103A'
#  '105A' '110A' '111A' '115A']
# Unique Test Group IDs:
# ['008A' '016A' '019B' '020A' '026C' '038A' '039A' '040A' '046A' '048A'
#  '050A' '052A' '062A' '064A' '070A' '074A' '075A' '088A' '094A' '101A'
#  '102A' '104A' '106A' '108A' '109A' '113A' '116A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'045A'}
# Moved to Test Set:
# {'045A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '009A' '010A' '011A' '012A' '013B' '014A' '014B' '015A' '018A' '019A'
#  '021A' '022A' '023A' '023B' '024A' '025A' '025B' '025C' '026A' '026B'
#  '027A' '028A' '029A' '031A' '032A' '033A' '034A' '035A' '036A' '037A'
#  '041A' '042A' '043A' '044A' '046A' '047A' '049A' '051A' '051B' '053A'
#  '054A' '055A' '056A' '057A' '058A' '059A' '060A' '061A' '063A' '065A'
#  '066A' '067A' '068A' '069A' '071A' '072A' '073A' '076A' '087A' '090A'
#  '091A' '092A' '093A' '095A' '096A' '097A' '097B' '099A' '100A' '103A'
#  '105A' '110A' '111A' '115A']
# AFTER SWAP - Unique Test Group IDs:
# ['008A' '016A' '019B' '020A' '026C' '038A' '039A' '040A' '045A' '048A'
#  '050A' '052A' '062A' '064A' '070A' '074A' '075A' '088A' '094A' '101A'
#  '102A' '104A' '106A' '108A' '109A' '113A' '116A' '117A']
# Length of X_train_val:
# 628
# Length of y_train_val:
# 628
# Length of groups_train_val:
# 628
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     346
# senior    172
# kitten     69
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# senior    81
# kitten    66
# adult     59
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     346
# senior    172
# kitten    110
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# senior    81
# adult     59
# kitten    25
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 346, 2: 172, 1: 110})
# Epoch 1/1500
# 20/20 [==============================] - 1s 3ms/step - loss: 0.9622 - accuracy: 0.5350
# Epoch 2/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5754 - accuracy: 0.7150
# Epoch 3/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2972 - accuracy: 0.8599
# Epoch 4/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1903 - accuracy: 0.9204
# Epoch 5/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1754 - accuracy: 0.9411
# Epoch 6/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1322 - accuracy: 0.9538
# Epoch 7/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1583 - accuracy: 0.9252
# Epoch 8/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0685 - accuracy: 0.9793
# Epoch 9/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0516 - accuracy: 0.9873
# Epoch 10/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0471 - accuracy: 0.9809
# Epoch 11/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1090 - accuracy: 0.9618
# Epoch 12/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1325 - accuracy: 0.9586
# Epoch 13/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0968 - accuracy: 0.9697
# Epoch 14/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1284 - accuracy: 0.9634
# Epoch 15/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0997 - accuracy: 0.9570
# Epoch 16/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0710 - accuracy: 0.9713
# Epoch 17/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0660 - accuracy: 0.9745
# Epoch 18/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0852 - accuracy: 0.9793
# Epoch 19/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0448 - accuracy: 0.9873
# Epoch 20/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0831 - accuracy: 0.9809
# Epoch 21/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0339 - accuracy: 0.9889
# Epoch 22/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0333 - accuracy: 0.9825
# Epoch 23/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0632 - accuracy: 0.9793
# Epoch 24/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0465 - accuracy: 0.9777
# Epoch 25/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0224 - accuracy: 0.9920
# Epoch 26/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0369 - accuracy: 0.9825
# Epoch 27/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0159 - accuracy: 0.9904
# Epoch 28/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0350 - accuracy: 0.9825
# Epoch 29/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1783 - accuracy: 0.9522
# Epoch 30/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0542 - accuracy: 0.9777
# Epoch 31/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0512 - accuracy: 0.9873
# Epoch 32/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0531 - accuracy: 0.9889
# Epoch 33/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0606 - accuracy: 0.9809
# Epoch 34/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0410 - accuracy: 0.9777
# Epoch 35/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0683 - accuracy: 0.9761
# Epoch 36/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0400 - accuracy: 0.9904
# Epoch 37/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0582 - accuracy: 0.9841
# Epoch 38/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0464 - accuracy: 0.9841
# Epoch 39/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0322 - accuracy: 0.9857
# Epoch 40/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0493 - accuracy: 0.9841
# Epoch 41/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0404 - accuracy: 0.9920
# Epoch 42/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0275 - accuracy: 0.9841
# Epoch 43/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0247 - accuracy: 0.9889
# Epoch 44/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0259 - accuracy: 0.9920
# Epoch 45/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0406 - accuracy: 0.9857
# Epoch 46/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 0.9936
# Epoch 47/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0569 - accuracy: 0.9904
# Epoch 48/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0591 - accuracy: 0.9761
# Epoch 49/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0956 - accuracy: 0.9761
# Epoch 50/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0434 - accuracy: 0.9904
# Epoch 51/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0400 - accuracy: 0.9761
# Epoch 52/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0493 - accuracy: 0.9825
# Epoch 53/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0659 - accuracy: 0.9841
# Epoch 54/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0530 - accuracy: 0.9809
# Epoch 55/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0179 - accuracy: 0.9936
# Epoch 56/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0196 - accuracy: 0.9920
# Epoch 57/1500
# 15/20 [=====================>........] - ETA: 0s - loss: 0.0210 - accuracy: 0.9937Restoring model weights from the end of the best epoch: 27.
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0167 - accuracy: 0.9952
# Epoch 57: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 2.6743 - accuracy: 0.6000
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.57 (16/28)
# Before appending - Cat IDs: 437, Predictions: 437, Actuals: 437, Gender: 437
# After appending - Cat IDs: 602, Predictions: 602, Actuals: 602, Gender: 602
# Final Test Results - Loss: 2.674304723739624, Accuracy: 0.6000000238418579, Precision: 0.6202150537634409, Recall: 0.6377819627537141, F1 Score: 0.6085631925326581
# Confusion Matrix:
#  [[42  6 11]
#  [ 7 18  0]
#  [35  7 39]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 097A    15
# 029A    15
# 097B    14
# 002A    13
# 106A    13
# 101A    12
# 116A    12
# 051A    12
# 067A    11
# 028A    11
# 042A    11
# 063A    11
# 040A    10
# 014B    10
# 025A    10
# 059A    10
# 071A     9
# 001A     9
# 065A     9
# 005A     9
# 016A     9
# 022A     9
# 013B     8
# 117A     7
# 027A     7
# 031A     7
# 095A     7
# 039A     6
# 099A     6
# 007A     6
# 050A     5
# 021A     5
# 008A     5
# 109A     5
# 075A     5
# 094A     5
# 044A     5
# 070A     5
# 108A     5
# 025C     4
# 045A     4
# 023B     4
# 104A     4
# 009A     4
# 012A     3
# 053A     3
# 058A     3
# 056A     3
# 010A     3
# 113A     3
# 062A     3
# 014A     3
# 018A     2
# 025B     2
# 054A     2
# 032A     2
# 069A     2
# 102A     2
# 087A     2
# 052A     2
# 038A     2
# 048A     1
# 110A     1
# 019B     1
# 088A     1
# 004A     1
# 026C     1
# 091A     1
# 096A     1
# 041A     1
# 092A     1
# 049A     1
# 064A     1
# 076A     1
# 073A     1
# 090A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 111A    12
# 055A    12
# 072A     9
# 051B     9
# 033A     9
# 068A     8
# 036A     7
# 015A     7
# 023A     6
# 003A     4
# 026A     4
# 060A     3
# 006A     3
# 105A     3
# 034A     3
# 093A     2
# 035A     2
# 011A     2
# 061A     2
# 037A     2
# 043A     1
# 066A     1
# 115A     1
# 100A     1
# 024A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    239
# X    229
# F    210
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    47
# X    47
# F    21
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [000A, 071A, 097B, 019A, 074A, 067A, 020A, 062...
# kitten    [044A, 014B, 040A, 046A, 047A, 042A, 109A, 050...
# senior    [097A, 001A, 103A, 028A, 057A, 106A, 101A, 104...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 033A, 034A, 072A, 023A, 026A, 105A, 068...
# kitten                                   [111A, 043A, 115A]
# senior     [093A, 015A, 055A, 051B, 060A, 011A, 061A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 47, 'kitten': 13, 'senior': 26}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 3, 'senior': 8}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '005A' '007A' '008A' '009A'
#  '010A' '012A' '013B' '014A' '014B' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023B' '025A' '025B' '025C' '026C' '027A' '028A' '029A'
#  '031A' '032A' '038A' '039A' '040A' '041A' '042A' '044A' '045A' '046A'
#  '047A' '048A' '049A' '050A' '051A' '052A' '053A' '054A' '056A' '057A'
#  '058A' '059A' '062A' '063A' '064A' '065A' '067A' '069A' '070A' '071A'
#  '073A' '074A' '075A' '076A' '087A' '088A' '090A' '091A' '092A' '094A'
#  '095A' '096A' '097A' '097B' '099A' '101A' '102A' '103A' '104A' '106A'
#  '108A' '109A' '110A' '113A' '116A' '117A']
# Unique Test Group IDs:
# ['003A' '006A' '011A' '015A' '023A' '024A' '026A' '026B' '033A' '034A'
#  '035A' '036A' '037A' '043A' '051B' '055A' '060A' '061A' '066A' '068A'
#  '072A' '093A' '100A' '105A' '111A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '005A' '007A' '008A' '009A'
#  '010A' '012A' '013B' '014A' '014B' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023B' '025A' '025B' '025C' '026C' '027A' '028A' '029A'
#  '031A' '032A' '038A' '039A' '040A' '041A' '042A' '044A' '045A' '046A'
#  '047A' '048A' '049A' '050A' '051A' '052A' '053A' '054A' '056A' '057A'
#  '058A' '059A' '062A' '063A' '064A' '065A' '067A' '069A' '070A' '071A'
#  '073A' '074A' '075A' '076A' '087A' '088A' '090A' '091A' '092A' '094A'
#  '095A' '096A' '097A' '097B' '099A' '101A' '102A' '103A' '104A' '106A'
#  '108A' '109A' '110A' '113A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['003A' '006A' '011A' '015A' '023A' '024A' '026A' '026B' '033A' '034A'
#  '035A' '036A' '037A' '043A' '051B' '055A' '060A' '061A' '066A' '068A'
#  '072A' '093A' '100A' '105A' '111A' '115A']
# Length of X_train_val:
# 678
# Length of y_train_val:
# 678
# Length of groups_train_val:
# 678
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     342
# senior    215
# kitten    121
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     63
# senior    38
# kitten    14
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     342
# senior    215
# kitten    121
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     63
# senior    38
# kitten    14
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 342, 2: 215, 1: 121})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/1500
# 22/22 [==============================] - 1s 4ms/step - loss: 0.9920 - accuracy: 0.5590
# Epoch 2/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.5157 - accuracy: 0.7714
# Epoch 3/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3961 - accuracy: 0.8378
# Epoch 4/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3118 - accuracy: 0.8805
# Epoch 5/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2204 - accuracy: 0.9204
# Epoch 6/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1473 - accuracy: 0.9351
# Epoch 7/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1416 - accuracy: 0.9528
# Epoch 8/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1520 - accuracy: 0.9395
# Epoch 9/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1785 - accuracy: 0.9336
# Epoch 10/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1098 - accuracy: 0.9587
# Epoch 11/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1353 - accuracy: 0.9587
# Epoch 12/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1830 - accuracy: 0.9292
# Epoch 13/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1441 - accuracy: 0.9351
# Epoch 14/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0743 - accuracy: 0.9735
# Epoch 15/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0920 - accuracy: 0.9808
# Epoch 16/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1010 - accuracy: 0.9617
# Epoch 17/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1343 - accuracy: 0.9572
# Epoch 18/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1132 - accuracy: 0.9602
# Epoch 19/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0694 - accuracy: 0.9779
# Epoch 20/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1007 - accuracy: 0.9572
# Epoch 21/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0828 - accuracy: 0.9631
# Epoch 22/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0362 - accuracy: 0.9897
# Epoch 23/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0318 - accuracy: 0.9882
# Epoch 24/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0611 - accuracy: 0.9779
# Epoch 25/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0858 - accuracy: 0.9661
# Epoch 26/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0835 - accuracy: 0.9587
# Epoch 27/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1253 - accuracy: 0.9631
# Epoch 28/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0550 - accuracy: 0.9764
# Epoch 29/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0335 - accuracy: 0.9897
# Epoch 30/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0288 - accuracy: 0.9912
# Epoch 31/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0527 - accuracy: 0.9838
# Epoch 32/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1056 - accuracy: 0.9661
# Epoch 33/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0565 - accuracy: 0.9823
# Epoch 34/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0584 - accuracy: 0.9808
# Epoch 35/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1149 - accuracy: 0.9617
# Epoch 36/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0566 - accuracy: 0.9779
# Epoch 37/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0413 - accuracy: 0.9838
# Epoch 38/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0422 - accuracy: 0.9838
# Epoch 39/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0246 - accuracy: 0.9941
# Epoch 40/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0328 - accuracy: 0.9941
# Epoch 41/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0420 - accuracy: 0.9897
# Epoch 42/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0542 - accuracy: 0.9808
# Epoch 43/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0612 - accuracy: 0.9764
# Epoch 44/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0779 - accuracy: 0.9823
# Epoch 45/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0510 - accuracy: 0.9853
# Epoch 46/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0441 - accuracy: 0.9853
# Epoch 47/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0198 - accuracy: 0.9956
# Epoch 48/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0281 - accuracy: 0.9897
# Epoch 49/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 0.9985
# Epoch 50/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0314 - accuracy: 0.9882
# Epoch 51/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0300 - accuracy: 0.9912
# Epoch 52/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0126 - accuracy: 0.9971
# Epoch 53/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0303 - accuracy: 0.9912
# Epoch 54/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0430 - accuracy: 0.9853
# Epoch 55/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0795 - accuracy: 0.9764
# Epoch 56/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0402 - accuracy: 0.9838
# Epoch 57/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0309 - accuracy: 0.9882
# Epoch 58/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1393 - accuracy: 0.9528
# Epoch 59/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0631 - accuracy: 0.9764
# Epoch 60/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0324 - accuracy: 0.9897
# Epoch 61/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0379 - accuracy: 0.9941
# Epoch 62/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0478 - accuracy: 0.9838
# Epoch 63/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0593 - accuracy: 0.9794
# Epoch 64/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0257 - accuracy: 0.9912
# Epoch 65/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0692 - accuracy: 0.9779
# Epoch 66/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0185 - accuracy: 0.9971
# Epoch 67/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0296 - accuracy: 0.9971
# Epoch 68/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0578 - accuracy: 0.9867
# Epoch 69/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0547 - accuracy: 0.9808
# Epoch 70/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0735 - accuracy: 0.9823
# Epoch 71/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1194 - accuracy: 0.9543
# Epoch 72/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0872 - accuracy: 0.9720
# Epoch 73/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0528 - accuracy: 0.9838
# Epoch 74/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0490 - accuracy: 0.9808
# Epoch 75/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0329 - accuracy: 0.9882
# Epoch 76/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0359 - accuracy: 0.9867
# Epoch 77/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0567 - accuracy: 0.9808
# Epoch 78/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0183 - accuracy: 0.9941
# Epoch 79/1500
# 16/22 [====================>.........] - ETA: 0s - loss: 0.0159 - accuracy: 0.9922Restoring model weights from the end of the best epoch: 49.
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0153 - accuracy: 0.9941
# Epoch 79: early stopping
# 4/4 [==============================] - 0s 1ms/step - loss: 1.6515 - accuracy: 0.6957
# 4/4 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.65 (17/26)
# Before appending - Cat IDs: 602, Predictions: 602, Actuals: 602, Gender: 602
# After appending - Cat IDs: 717, Predictions: 717, Actuals: 717, Gender: 717
# Final Test Results - Loss: 1.6515061855316162, Accuracy: 0.695652186870575, Precision: 0.7107167004732927, Recall: 0.759120022277917, F1 Score: 0.7315336992756348
# Confusion Matrix:
#  [[44  1 18]
#  [ 0 14  0]
#  [14  2 22]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5699914883962388
#
# Final Average Loss across all UNSEEN TEST sets: 2.4823535680770874
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.

# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    192      144     75.00
# 1          M    286      163     56.99
# 2          X    242      161     66.53,   all_gender  count  correct  accuracy
# 0          F    192      134     69.79
# 1          M    290      159     54.83
# 2          X    235      137     58.30]

# %% [markdown]
# # RANDOM SEED 3

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[2]))
np.random.seed(int(random_seeds[2]))
tf.random.set_seed(int(random_seeds[2]))

# Load datasets
dataframe = pd.read_csv('perch_looped_embeddings.csv')


def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 10),
    'senior': (10, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     405
# senior    253
# kitten    135
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[2]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

cv_training_acc_total = []
cv_training_acc_best = []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )
    
    accuracy_history = AccuracyHistory()

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_val),
        y=y_train_val
    )
    weight_dict = {i: class_weights[i] for i in range(len(class_weights))}

    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adam': Adam(learning_rate=0.007402414884293732)
    }
    
    # Full model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(512, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.15688606637942396))  
    model_full.add(Dense(64, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.28869063762474007))  
    model_full.add(Dense(128, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.27322054853254163))   
    model_full.add(Dense(32, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.4064145271744943))  
    model_full.add(Dense(3, activation='softmax'))  
    
    optimizer = optimizers['Adam']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=32,
                                  verbose=1, callbacks=[early_stopping, accuracy_history], class_weight=weight_dict)
    
    
    # log epochs
    best_epoch_index = np.argmin(history_full.history['loss'])  
    best_training_accuracy = accuracy_history.acc[best_epoch_index]

    # Append training acc to total  
    all_best_training_acc.append(best_training_accuracy)
    total_training_acc.append(accuracy_history.acc)

    # Append training acc just for this CV
    cv_training_acc_total.append(accuracy_history.acc)
    cv_training_acc_best.append(best_training_accuracy)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
average_fold_f1.append(unseen_set_avg_f1)
average_fold_losses.append(unseen_set_avg_loss)
average_fold_accuracies.append(unseen_set_avg_acc)
average_fold_precisions.append(unseen_set_avg_precision)
average_fold_recalls.append(unseen_set_avg_recall)

# Append all to total lists
all_f1.append(unseen_f1)
all_losses.append(unseen_losses)
all_accuracies.append(unseen_accuracies)
all_precisions.append(unseen_precisions)
all_recalls.append(unseen_recalls)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 103A    33
# 047A    22
# 020A    20
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 002A    13
# 055A    12
# 101A    12
# 116A    12
# 042A    11
# 028A    11
# 063A    11
# 040A    10
# 025A    10
# 059A    10
# 014B    10
# 071A     9
# 001A     9
# 051B     9
# 033A     9
# 013B     8
# 068A     8
# 036A     7
# 117A     7
# 031A     7
# 027A     7
# 015A     7
# 023A     6
# 039A     6
# 099A     6
# 044A     5
# 075A     5
# 050A     5
# 094A     5
# 008A     5
# 108A     5
# 109A     5
# 026A     4
# 003A     4
# 009A     4
# 104A     4
# 053A     3
# 012A     3
# 056A     3
# 058A     3
# 060A     3
# 006A     3
# 105A     3
# 014A     3
# 062A     3
# 034A     3
# 113A     3
# 011A     2
# 093A     2
# 037A     2
# 052A     2
# 038A     2
# 069A     2
# 032A     2
# 054A     2
# 061A     2
# 019B     1
# 110A     1
# 115A     1
# 100A     1
# 090A     1
# 024A     1
# 026C     1
# 004A     1
# 096A     1
# 092A     1
# 049A     1
# 064A     1
# 043A     1
# 076A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 002B    30
# 106A    13
# 111A    12
# 051A    12
# 067A    11
# 022A     9
# 005A     9
# 072A     9
# 065A     9
# 016A     9
# 095A     7
# 007A     6
# 021A     5
# 070A     5
# 025C     4
# 023B     4
# 045A     4
# 010A     3
# 087A     2
# 018A     2
# 035A     2
# 102A     2
# 025B     2
# 073A     1
# 091A     1
# 041A     1
# 066A     1
# 048A     1
# 088A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    246
# M    176
# F    155
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    110
# F     76
# X     30
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 033A, 071A, 097B, 019A, 074A, 020A, 062...
# kitten    [044A, 014B, 040A, 046A, 047A, 042A, 109A, 050...
# senior    [093A, 015A, 097A, 001A, 103A, 028A, 057A, 101...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000A, 067A, 002B, 022A, 095A, 005A, 072A, 065...
# kitten                             [111A, 041A, 045A, 048A]
# senior                       [106A, 091A, 025C, 051A, 016A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 41, 'kitten': 12, 'senior': 29}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 21, 'kitten': 4, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000B' '001A' '002A' '003A' '004A' '006A' '008A' '009A' '011A' '012A'
#  '013B' '014A' '014B' '015A' '019A' '019B' '020A' '023A' '024A' '025A'
#  '026A' '026B' '026C' '027A' '028A' '029A' '031A' '032A' '033A' '034A'
#  '036A' '037A' '038A' '039A' '040A' '042A' '043A' '044A' '046A' '047A'
#  '049A' '050A' '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A'
#  '059A' '060A' '061A' '062A' '063A' '064A' '068A' '069A' '071A' '074A'
#  '075A' '076A' '090A' '092A' '093A' '094A' '096A' '097A' '097B' '099A'
#  '100A' '101A' '103A' '104A' '105A' '108A' '109A' '110A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['000A' '002B' '005A' '007A' '010A' '016A' '018A' '021A' '022A' '023B'
#  '025B' '025C' '035A' '041A' '045A' '048A' '051A' '065A' '066A' '067A'
#  '070A' '072A' '073A' '087A' '088A' '091A' '095A' '102A' '106A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'105A'}
# Moved to Test Set:
# {'105A'}
# Removed from Test Set
# {'000A'}
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '006A' '008A' '009A' '011A'
#  '012A' '013B' '014A' '014B' '015A' '019A' '019B' '020A' '023A' '024A'
#  '025A' '026A' '026B' '026C' '027A' '028A' '029A' '031A' '032A' '033A'
#  '034A' '036A' '037A' '038A' '039A' '040A' '042A' '043A' '044A' '046A'
#  '047A' '049A' '050A' '051B' '052A' '053A' '054A' '055A' '056A' '057A'
#  '058A' '059A' '060A' '061A' '062A' '063A' '064A' '068A' '069A' '071A'
#  '074A' '075A' '076A' '090A' '092A' '093A' '094A' '096A' '097A' '097B'
#  '099A' '100A' '101A' '103A' '104A' '108A' '109A' '110A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '005A' '007A' '010A' '016A' '018A' '021A' '022A' '023B' '025B'
#  '025C' '035A' '041A' '045A' '048A' '051A' '065A' '066A' '067A' '070A'
#  '072A' '073A' '087A' '088A' '091A' '095A' '102A' '105A' '106A' '111A']
# Length of X_train_val:
# 613
# Length of y_train_val:
# 613
# Length of groups_train_val:
# 613
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     246
# senior    214
# kitten    117
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     159
# senior     39
# kitten     18
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     282
# senior    214
# kitten    117
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     123
# senior     39
# kitten     18
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 282, 2: 214, 1: 117})
# Epoch 1/1500
# 20/20 [==============================] - 1s 4ms/step - loss: 1.0442 - accuracy: 0.5628
# Epoch 2/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4959 - accuracy: 0.7847
# Epoch 3/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3188 - accuracy: 0.8662
# Epoch 4/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2117 - accuracy: 0.9119
# Epoch 5/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1926 - accuracy: 0.9299
# Epoch 6/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1227 - accuracy: 0.9576
# Epoch 7/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1225 - accuracy: 0.9494
# Epoch 8/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1072 - accuracy: 0.9657
# Epoch 9/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1246 - accuracy: 0.9625
# Epoch 10/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1077 - accuracy: 0.9625
# Epoch 11/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0907 - accuracy: 0.9641
# Epoch 12/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0562 - accuracy: 0.9853
# Epoch 13/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0806 - accuracy: 0.9804
# Epoch 14/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0678 - accuracy: 0.9788
# Epoch 15/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1449 - accuracy: 0.9657
# Epoch 16/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1399 - accuracy: 0.9364
# Epoch 17/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1187 - accuracy: 0.9625
# Epoch 18/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0573 - accuracy: 0.9853
# Epoch 19/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1182 - accuracy: 0.9560
# Epoch 20/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0834 - accuracy: 0.9690
# Epoch 21/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0639 - accuracy: 0.9821
# Epoch 22/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0509 - accuracy: 0.9837
# Epoch 23/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0880 - accuracy: 0.9706
# Epoch 24/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0504 - accuracy: 0.9837
# Epoch 25/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0565 - accuracy: 0.9869
# Epoch 26/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0567 - accuracy: 0.9804
# Epoch 27/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0535 - accuracy: 0.9853
# Epoch 28/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0510 - accuracy: 0.9788
# Epoch 29/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0763 - accuracy: 0.9804
# Epoch 30/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0653 - accuracy: 0.9755
# Epoch 31/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0213 - accuracy: 0.9984
# Epoch 32/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0520 - accuracy: 0.9869
# Epoch 33/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0414 - accuracy: 0.9853
# Epoch 34/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0822 - accuracy: 0.9706
# Epoch 35/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0806 - accuracy: 0.9706
# Epoch 36/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0486 - accuracy: 0.9837
# Epoch 37/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0540 - accuracy: 0.9869
# Epoch 38/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0524 - accuracy: 0.9837
# Epoch 39/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0787 - accuracy: 0.9739
# Epoch 40/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0644 - accuracy: 0.9788
# Epoch 41/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0289 - accuracy: 0.9935
# Epoch 42/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0749 - accuracy: 0.9755
# Epoch 43/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1221 - accuracy: 0.9755
# Epoch 44/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1553 - accuracy: 0.9478
# Epoch 45/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0631 - accuracy: 0.9772
# Epoch 46/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0394 - accuracy: 0.9886
# Epoch 47/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0305 - accuracy: 0.9886
# Epoch 48/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0355 - accuracy: 0.9902
# Epoch 49/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0799 - accuracy: 0.9739
# Epoch 50/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0980 - accuracy: 0.9625
# Epoch 51/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1042 - accuracy: 0.9641
# Epoch 52/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0513 - accuracy: 0.9804
# Epoch 53/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0422 - accuracy: 0.9837
# Epoch 54/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0496 - accuracy: 0.9886
# Epoch 55/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0434 - accuracy: 0.9853
# Epoch 56/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0584 - accuracy: 0.9788
# Epoch 57/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0334 - accuracy: 0.9886
# Epoch 58/1500
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0366 - accuracy: 0.9886
# Epoch 59/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0136 - accuracy: 0.9951
# Epoch 60/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 61/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0252 - accuracy: 0.9967
# Epoch 62/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1028 - accuracy: 0.9755
# Epoch 63/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1020 - accuracy: 0.9674
# Epoch 64/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0668 - accuracy: 0.9804
# Epoch 65/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0403 - accuracy: 0.9837
# Epoch 66/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0478 - accuracy: 0.9804
# Epoch 67/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0258 - accuracy: 0.9918
# Epoch 68/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0362 - accuracy: 0.9918
# Epoch 69/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0452 - accuracy: 0.9869
# Epoch 70/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0788 - accuracy: 0.9869
# Epoch 71/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0539 - accuracy: 0.9788
# Epoch 72/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0318 - accuracy: 0.9886
# Epoch 73/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0266 - accuracy: 0.9935
# Epoch 74/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0291 - accuracy: 0.9935
# Epoch 75/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0525 - accuracy: 0.9918
# Epoch 76/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1464 - accuracy: 0.9429
# Epoch 77/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0600 - accuracy: 0.9788
# Epoch 78/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0797 - accuracy: 0.9723
# Epoch 79/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0792 - accuracy: 0.9723
# Epoch 80/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0637 - accuracy: 0.9788
# Epoch 81/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0411 - accuracy: 0.9918
# Epoch 82/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0566 - accuracy: 0.9804
# Epoch 83/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0423 - accuracy: 0.9837
# Epoch 84/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0730 - accuracy: 0.9804
# Epoch 85/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0374 - accuracy: 0.9902
# Epoch 86/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0544 - accuracy: 0.9886
# Epoch 87/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0368 - accuracy: 0.9869
# Epoch 88/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0680 - accuracy: 0.9755
# Epoch 89/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1812 - accuracy: 0.9445
# Epoch 90/1500
# 17/20 [========================>.....] - ETA: 0s - loss: 0.0665 - accuracy: 0.9743Restoring model weights from the end of the best epoch: 60.
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0654 - accuracy: 0.9772
# Epoch 90: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 2.2554 - accuracy: 0.6222
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.73 (22/30)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 180, Predictions: 180, Actuals: 180, Gender: 180
# Final Test Results - Loss: 2.2553765773773193, Accuracy: 0.6222222447395325, Precision: 0.5871635610766046, Recall: 0.6948439997220485, F1 Score: 0.6172483173494298
# Confusion Matrix:
#  [[74 10 39]
#  [ 1 17  0]
#  [17  1 21]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 019A    17
# 057A    17
# 074A    16
# 097B    14
# 106A    13
# 002A    13
# 111A    12
# 051A    12
# 055A    12
# 101A    12
# 063A    11
# 067A    11
# 014B    10
# 059A    10
# 040A    10
# 022A     9
# 016A     9
# 071A     9
# 033A     9
# 051B     9
# 065A     9
# 072A     9
# 005A     9
# 013B     8
# 095A     7
# 036A     7
# 031A     7
# 015A     7
# 027A     7
# 023A     6
# 099A     6
# 007A     6
# 008A     5
# 075A     5
# 050A     5
# 021A     5
# 094A     5
# 070A     5
# 025C     4
# 023B     4
# 026A     4
# 045A     4
# 009A     4
# 056A     3
# 010A     3
# 062A     3
# 058A     3
# 012A     3
# 060A     3
# 053A     3
# 105A     3
# 113A     3
# 025B     2
# 102A     2
# 037A     2
# 035A     2
# 011A     2
# 061A     2
# 054A     2
# 018A     2
# 038A     2
# 087A     2
# 069A     2
# 032A     2
# 049A     1
# 019B     1
# 100A     1
# 091A     1
# 110A     1
# 115A     1
# 088A     1
# 092A     1
# 004A     1
# 076A     1
# 048A     1
# 066A     1
# 096A     1
# 043A     1
# 073A     1
# 041A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    22
# 020A    20
# 000B    19
# 097A    15
# 029A    15
# 116A    12
# 042A    11
# 028A    11
# 025A    10
# 001A     9
# 068A     8
# 117A     7
# 039A     6
# 044A     5
# 108A     5
# 109A     5
# 003A     4
# 104A     4
# 006A     3
# 014A     3
# 034A     3
# 052A     2
# 093A     2
# 064A     1
# 026C     1
# 090A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    234
# X    198
# F    156
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    78
# F    75
# M    52
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [000A, 033A, 071A, 097B, 019A, 074A, 067A, 062...
# kitten    [014B, 111A, 040A, 046A, 050A, 043A, 049A, 041...
# senior    [015A, 103A, 057A, 106A, 101A, 055A, 091A, 059...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 020A, 029A, 034A, 014A, 000B, 068A, 003...
# kitten                             [044A, 047A, 042A, 109A]
# senior    [093A, 097A, 001A, 028A, 104A, 039A, 025A, 116...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 51, 'kitten': 12, 'senior': 22}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 11, 'kitten': 4, 'senior': 12}
# Unique Training/Validation Group IDs:
# ['000A' '002A' '002B' '004A' '005A' '007A' '008A' '009A' '010A' '011A'
#  '012A' '013B' '014B' '015A' '016A' '018A' '019A' '019B' '021A' '022A'
#  '023A' '023B' '025B' '025C' '026A' '026B' '027A' '031A' '032A' '033A'
#  '035A' '036A' '037A' '038A' '040A' '041A' '043A' '045A' '046A' '048A'
#  '049A' '050A' '051A' '051B' '053A' '054A' '055A' '056A' '057A' '058A'
#  '059A' '060A' '061A' '062A' '063A' '065A' '066A' '067A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '091A' '092A'
#  '094A' '095A' '096A' '097B' '099A' '100A' '101A' '102A' '103A' '105A'
#  '106A' '110A' '111A' '113A' '115A']
# Unique Test Group IDs:
# ['000B' '001A' '003A' '006A' '014A' '020A' '024A' '025A' '026C' '028A'
#  '029A' '034A' '039A' '042A' '044A' '047A' '052A' '064A' '068A' '090A'
#  '093A' '097A' '104A' '108A' '109A' '116A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '002A' '002B' '004A' '005A' '007A' '008A' '009A' '010A' '011A'
#  '012A' '013B' '014B' '015A' '016A' '018A' '019A' '019B' '021A' '022A'
#  '023A' '023B' '025B' '025C' '026A' '026B' '027A' '031A' '032A' '033A'
#  '035A' '036A' '037A' '038A' '040A' '041A' '043A' '045A' '046A' '048A'
#  '049A' '050A' '051A' '051B' '053A' '054A' '055A' '056A' '057A' '058A'
#  '059A' '060A' '061A' '062A' '063A' '065A' '066A' '067A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '091A' '092A'
#  '094A' '095A' '096A' '097B' '099A' '100A' '101A' '102A' '103A' '105A'
#  '106A' '110A' '111A' '113A' '115A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '001A' '003A' '006A' '014A' '020A' '024A' '025A' '026C' '028A'
#  '029A' '034A' '039A' '042A' '044A' '047A' '052A' '064A' '068A' '090A'
#  '093A' '097A' '104A' '108A' '109A' '116A' '117A']
# Length of X_train_val:
# 588
# Length of y_train_val:
# 588
# Length of groups_train_val:
# 588
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     326
# senior    170
# kitten     92
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# senior    83
# adult     79
# kitten    43
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     326
# senior    170
# kitten     92
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# senior    83
# adult     79
# kitten    43
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 326, 2: 170, 1: 92})
# Epoch 1/1500
# 19/19 [==============================] - 1s 4ms/step - loss: 1.0461 - accuracy: 0.5255
# Epoch 2/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.4993 - accuracy: 0.7296
# Epoch 3/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3573 - accuracy: 0.8214
# Epoch 4/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2635 - accuracy: 0.8793
# Epoch 5/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1793 - accuracy: 0.9269
# Epoch 6/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1493 - accuracy: 0.9388
# Epoch 7/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0977 - accuracy: 0.9592
# Epoch 8/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1029 - accuracy: 0.9643
# Epoch 9/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0861 - accuracy: 0.9711
# Epoch 10/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0695 - accuracy: 0.9728
# Epoch 11/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0561 - accuracy: 0.9745
# Epoch 12/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0819 - accuracy: 0.9677
# Epoch 13/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0934 - accuracy: 0.9694
# Epoch 14/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1065 - accuracy: 0.9694
# Epoch 15/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1551 - accuracy: 0.9405
# Epoch 16/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0927 - accuracy: 0.9711
# Epoch 17/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1100 - accuracy: 0.9660
# Epoch 18/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0737 - accuracy: 0.9728
# Epoch 19/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1005 - accuracy: 0.9762
# Epoch 20/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0553 - accuracy: 0.9830
# Epoch 21/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1082 - accuracy: 0.9779
# Epoch 22/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0389 - accuracy: 0.9864
# Epoch 23/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0225 - accuracy: 0.9932
# Epoch 24/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0229 - accuracy: 0.9932
# Epoch 25/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0171 - accuracy: 0.9966
# Epoch 26/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0450 - accuracy: 0.9847
# Epoch 27/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0597 - accuracy: 0.9796
# Epoch 28/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0636 - accuracy: 0.9762
# Epoch 29/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0572 - accuracy: 0.9813
# Epoch 30/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0676 - accuracy: 0.9796
# Epoch 31/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0645 - accuracy: 0.9796
# Epoch 32/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0718 - accuracy: 0.9711
# Epoch 33/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1325 - accuracy: 0.9507
# Epoch 34/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0860 - accuracy: 0.9745
# Epoch 35/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0745 - accuracy: 0.9745
# Epoch 36/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0425 - accuracy: 0.9864
# Epoch 37/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0475 - accuracy: 0.9796
# Epoch 38/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0265 - accuracy: 0.9949
# Epoch 39/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0266 - accuracy: 0.9966
# Epoch 40/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0573 - accuracy: 0.9796
# Epoch 41/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0325 - accuracy: 0.9847
# Epoch 42/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0270 - accuracy: 0.9932
# Epoch 43/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0494 - accuracy: 0.9762
# Epoch 44/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0381 - accuracy: 0.9847
# Epoch 45/1500
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0241 - accuracy: 0.9932
# Epoch 46/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0313 - accuracy: 0.9898
# Epoch 47/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0541 - accuracy: 0.9813
# Epoch 48/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0779 - accuracy: 0.9813
# Epoch 49/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0938 - accuracy: 0.9643
# Epoch 50/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0827 - accuracy: 0.9813
# Epoch 51/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0626 - accuracy: 0.9796
# Epoch 52/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0283 - accuracy: 0.9915
# Epoch 53/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0192 - accuracy: 0.9915
# Epoch 54/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0307 - accuracy: 0.9915
# Epoch 55/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 0.9983
# Epoch 56/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0167 - accuracy: 0.9949
# Epoch 57/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0469 - accuracy: 0.9830
# Epoch 58/1500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0452 - accuracy: 0.9796
# Epoch 59/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 60/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0148 - accuracy: 0.9949
# Epoch 61/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0181 - accuracy: 0.9915
# Epoch 62/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 0.9966
# Epoch 63/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0129 - accuracy: 0.9966
# Epoch 64/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0086 - accuracy: 0.9983
# Epoch 65/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 0.9966
# Epoch 66/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0050 - accuracy: 0.9983
# Epoch 67/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0495 - accuracy: 0.9779
# Epoch 68/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0354 - accuracy: 0.9915
# Epoch 69/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9932
# Epoch 70/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0216 - accuracy: 0.9898
# Epoch 71/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 0.9932
# Epoch 72/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 0.9966
# Epoch 73/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0197 - accuracy: 0.9949
# Epoch 74/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0304 - accuracy: 0.9864
# Epoch 75/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0200 - accuracy: 0.9949
# Epoch 76/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0245 - accuracy: 0.9881
# Epoch 77/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0111 - accuracy: 0.9966
# Epoch 78/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0158 - accuracy: 0.9949
# Epoch 79/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0250 - accuracy: 0.9915
# Epoch 80/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 0.9966
# Epoch 81/1500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0239 - accuracy: 0.9932
# Epoch 82/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 0.9966
# Epoch 83/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0317 - accuracy: 0.9864
# Epoch 84/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0496 - accuracy: 0.9830
# Epoch 85/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0244 - accuracy: 0.9915
# Epoch 86/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0167 - accuracy: 0.9915
# Epoch 87/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 88/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 0.9949
# Epoch 89/1500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0285 - accuracy: 0.9915
# Epoch 90/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0549 - accuracy: 0.9830
# Epoch 91/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0466 - accuracy: 0.9881
# Epoch 92/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0972 - accuracy: 0.9779
# Epoch 93/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0608 - accuracy: 0.9830
# Epoch 94/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0382 - accuracy: 0.9864
# Epoch 95/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0303 - accuracy: 0.9898
# Epoch 96/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 0.9932
# Epoch 97/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 0.9983
# Epoch 98/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 0.9966
# Epoch 99/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 0.9983
# Epoch 100/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 101/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0086 - accuracy: 0.9966
# Epoch 102/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0628 - accuracy: 0.9830
# Epoch 103/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0260 - accuracy: 0.9898
# Epoch 104/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0564 - accuracy: 0.9881
# Epoch 105/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0190 - accuracy: 0.9915
# Epoch 106/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 0.9966
# Epoch 107/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0085 - accuracy: 0.9949
# Epoch 108/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 109/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0574 - accuracy: 0.9932
# Epoch 110/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 0.9932
# Epoch 111/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 0.9966
# Epoch 112/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0040 - accuracy: 0.9966
# Epoch 113/1500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0115 - accuracy: 0.9966
# Epoch 114/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0172 - accuracy: 0.9898
# Epoch 115/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 116/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0126 - accuracy: 0.9915
# Epoch 117/1500
# 14/19 [=====================>........] - ETA: 0s - loss: 0.0223 - accuracy: 0.9911Restoring model weights from the end of the best epoch: 87.
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0250 - accuracy: 0.9898
# Epoch 117: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 4.0814 - accuracy: 0.5463
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.63 (17/27)
# Before appending - Cat IDs: 180, Predictions: 180, Actuals: 180, Gender: 180
# After appending - Cat IDs: 385, Predictions: 385, Actuals: 385, Gender: 385
# Final Test Results - Loss: 4.0813751220703125, Accuracy: 0.5463414788246155, Precision: 0.5807126854077745, Recall: 0.4861175641630402, F1 Score: 0.48197868587939513
# Confusion Matrix:
#  [[50  2 27]
#  [33  7  3]
#  [26  2 55]]
# outer_fold 3
# Train Set Group Distribution:
# 000A    39
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 106A    13
# 051A    12
# 111A    12
# 116A    12
# 042A    11
# 067A    11
# 028A    11
# 025A    10
# 014B    10
# 022A     9
# 016A     9
# 001A     9
# 033A     9
# 005A     9
# 072A     9
# 065A     9
# 068A     8
# 036A     7
# 095A     7
# 117A     7
# 031A     7
# 039A     6
# 099A     6
# 007A     6
# 075A     5
# 021A     5
# 050A     5
# 109A     5
# 070A     5
# 108A     5
# 044A     5
# 023B     4
# 025C     4
# 045A     4
# 009A     4
# 104A     4
# 003A     4
# 026A     4
# 060A     3
# 053A     3
# 010A     3
# 012A     3
# 006A     3
# 014A     3
# 062A     3
# 034A     3
# 105A     3
# 102A     2
# 035A     2
# 052A     2
# 038A     2
# 061A     2
# 018A     2
# 087A     2
# 069A     2
# 025B     2
# 093A     2
# 032A     2
# 054A     2
# 048A     1
# 110A     1
# 088A     1
# 090A     1
# 004A     1
# 026C     1
# 066A     1
# 091A     1
# 041A     1
# 092A     1
# 064A     1
# 073A     1
# 043A     1
# 076A     1
# 024A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    45
# 103A    33
# 057A    17
# 019A    17
# 002A    13
# 101A    12
# 055A    12
# 063A    11
# 059A    10
# 040A    10
# 071A     9
# 051B     9
# 013B     8
# 015A     7
# 027A     7
# 023A     6
# 008A     5
# 094A     5
# 113A     3
# 056A     3
# 058A     3
# 011A     2
# 037A     2
# 096A     1
# 049A     1
# 019B     1
# 115A     1
# 100A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    202
# F    181
# X    155
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    121
# M     84
# F     50
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 097B, 074A, 067A, 020A, 062...
# kitten    [044A, 014B, 111A, 047A, 042A, 109A, 050A, 043...
# senior    [093A, 097A, 001A, 028A, 106A, 104A, 091A, 039...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [071A, 019A, 002A, 023A, 063A, 027A, 013B, 096...
# kitten                             [040A, 046A, 049A, 115A]
# senior    [015A, 103A, 057A, 101A, 055A, 059A, 113A, 051...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 50, 'kitten': 12, 'senior': 21}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 12, 'kitten': 4, 'senior': 13}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '004A' '005A' '006A' '007A' '009A'
#  '010A' '012A' '014A' '014B' '016A' '018A' '020A' '021A' '022A' '023B'
#  '024A' '025A' '025B' '025C' '026A' '026C' '028A' '029A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '038A' '039A' '041A' '042A' '043A' '044A'
#  '045A' '047A' '048A' '050A' '051A' '052A' '053A' '054A' '060A' '061A'
#  '062A' '064A' '065A' '066A' '067A' '068A' '069A' '070A' '072A' '073A'
#  '074A' '075A' '076A' '087A' '088A' '090A' '091A' '092A' '093A' '095A'
#  '097A' '097B' '099A' '102A' '104A' '105A' '106A' '108A' '109A' '110A'
#  '111A' '116A' '117A']
# Unique Test Group IDs:
# ['002A' '008A' '011A' '013B' '015A' '019A' '019B' '023A' '026B' '027A'
#  '037A' '040A' '046A' '049A' '051B' '055A' '056A' '057A' '058A' '059A'
#  '063A' '071A' '094A' '096A' '100A' '101A' '103A' '113A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'048A'}
# Moved to Test Set:
# {'048A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '004A' '005A' '006A' '007A' '009A'
#  '010A' '012A' '014A' '014B' '016A' '018A' '020A' '021A' '022A' '023B'
#  '024A' '025A' '025B' '025C' '026A' '026C' '028A' '029A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '038A' '039A' '041A' '042A' '043A' '044A'
#  '045A' '046A' '047A' '050A' '051A' '052A' '053A' '054A' '060A' '061A'
#  '062A' '064A' '065A' '066A' '067A' '068A' '069A' '070A' '072A' '073A'
#  '074A' '075A' '076A' '087A' '088A' '090A' '091A' '092A' '093A' '095A'
#  '097A' '097B' '099A' '102A' '104A' '105A' '106A' '108A' '109A' '110A'
#  '111A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002A' '008A' '011A' '013B' '015A' '019A' '019B' '023A' '026B' '027A'
#  '037A' '040A' '048A' '049A' '051B' '055A' '056A' '057A' '058A' '059A'
#  '063A' '071A' '094A' '096A' '100A' '101A' '103A' '113A' '115A']
# Length of X_train_val:
# 582
# Length of y_train_val:
# 582
# Length of groups_train_val:
# 582
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     328
# senior    132
# kitten     78
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# senior    121
# adult      77
# kitten     57
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     328
# senior    132
# kitten    122
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# senior    121
# adult      77
# kitten     13
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Age group distribution: Counter({0: 328, 2: 132, 1: 122})
# Epoch 1/1500
# 19/19 [==============================] - 1s 3ms/step - loss: 1.0954 - accuracy: 0.5017
# Epoch 2/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.6424 - accuracy: 0.6856
# Epoch 3/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.4133 - accuracy: 0.8127
# Epoch 4/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2792 - accuracy: 0.8729
# Epoch 5/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2397 - accuracy: 0.8952
# Epoch 6/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1466 - accuracy: 0.9364
# Epoch 7/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1364 - accuracy: 0.9605
# Epoch 8/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1511 - accuracy: 0.9485
# Epoch 9/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1413 - accuracy: 0.9502
# Epoch 10/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1228 - accuracy: 0.9605
# Epoch 11/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0972 - accuracy: 0.9553
# Epoch 12/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0934 - accuracy: 0.9674
# Epoch 13/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0933 - accuracy: 0.9691
# Epoch 14/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0569 - accuracy: 0.9794
# Epoch 15/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0752 - accuracy: 0.9794
# Epoch 16/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1201 - accuracy: 0.9674
# Epoch 17/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0681 - accuracy: 0.9708
# Epoch 18/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9674
# Epoch 19/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0763 - accuracy: 0.9742
# Epoch 20/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0701 - accuracy: 0.9777
# Epoch 21/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0370 - accuracy: 0.9897
# Epoch 22/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0301 - accuracy: 0.9897
# Epoch 23/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0185 - accuracy: 0.9966
# Epoch 24/1500
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0363 - accuracy: 0.9897
# Epoch 25/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0957 - accuracy: 0.9725
# Epoch 26/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0707 - accuracy: 0.9828
# Epoch 27/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1366 - accuracy: 0.9588
# Epoch 28/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0734 - accuracy: 0.9725
# Epoch 29/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0814 - accuracy: 0.9725
# Epoch 30/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1365 - accuracy: 0.9605
# Epoch 31/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0758 - accuracy: 0.9759
# Epoch 32/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1031 - accuracy: 0.9725
# Epoch 33/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1067 - accuracy: 0.9674
# Epoch 34/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0502 - accuracy: 0.9845
# Epoch 35/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0467 - accuracy: 0.9845
# Epoch 36/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0720 - accuracy: 0.9742
# Epoch 37/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0561 - accuracy: 0.9777
# Epoch 38/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0750 - accuracy: 0.9639
# Epoch 39/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1478 - accuracy: 0.9450
# Epoch 40/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0541 - accuracy: 0.9845
# Epoch 41/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0466 - accuracy: 0.9845
# Epoch 42/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0620 - accuracy: 0.9794
# Epoch 43/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0203 - accuracy: 0.9948
# Epoch 44/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0538 - accuracy: 0.9811
# Epoch 45/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0479 - accuracy: 0.9794
# Epoch 46/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0450 - accuracy: 0.9897
# Epoch 47/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0273 - accuracy: 0.9914
# Epoch 48/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0314 - accuracy: 0.9845
# Epoch 49/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0464 - accuracy: 0.9811
# Epoch 50/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0350 - accuracy: 0.9863
# Epoch 51/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0662 - accuracy: 0.9845
# Epoch 52/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0803 - accuracy: 0.9811
# Epoch 53/1500
# 13/19 [===================>..........] - ETA: 0s - loss: 0.0333 - accuracy: 0.9880Restoring model weights from the end of the best epoch: 23.
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0446 - accuracy: 0.9863
# Epoch 53: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 1.7447 - accuracy: 0.6825
# 7/7 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Majority Vote Accuracy for cat_id for this fold: 0.69 (20/29)
# Before appending - Cat IDs: 385, Predictions: 385, Actuals: 385, Gender: 385
# After appending - Cat IDs: 596, Predictions: 596, Actuals: 596, Gender: 596
# Final Test Results - Loss: 1.7446887493133545, Accuracy: 0.6824644804000854, Precision: 0.7566760037348272, Recall: 0.7965367965367965, F1 Score: 0.7528344671201813
# Confusion Matrix:
#  [[65  1 11]
#  [ 0 13  0]
#  [54  1 66]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 057A    17
# 019A    17
# 097A    15
# 029A    15
# 106A    13
# 002A    13
# 116A    12
# 111A    12
# 051A    12
# 101A    12
# 055A    12
# 028A    11
# 067A    11
# 042A    11
# 063A    11
# 040A    10
# 025A    10
# 059A    10
# 051B     9
# 016A     9
# 065A     9
# 001A     9
# 071A     9
# 072A     9
# 005A     9
# 022A     9
# 013B     8
# 068A     8
# 095A     7
# 117A     7
# 015A     7
# 027A     7
# 023A     6
# 039A     6
# 007A     6
# 108A     5
# 094A     5
# 070A     5
# 044A     5
# 008A     5
# 021A     5
# 109A     5
# 003A     4
# 025C     4
# 023B     4
# 045A     4
# 104A     4
# 058A     3
# 056A     3
# 006A     3
# 113A     3
# 014A     3
# 034A     3
# 010A     3
# 102A     2
# 037A     2
# 011A     2
# 035A     2
# 025B     2
# 052A     2
# 087A     2
# 018A     2
# 093A     2
# 026C     1
# 024A     1
# 090A     1
# 100A     1
# 091A     1
# 115A     1
# 096A     1
# 041A     1
# 019B     1
# 088A     1
# 073A     1
# 048A     1
# 066A     1
# 064A     1
# 049A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 074A    16
# 097B    14
# 014B    10
# 033A     9
# 036A     7
# 031A     7
# 099A     6
# 075A     5
# 050A     5
# 026A     4
# 009A     4
# 062A     3
# 060A     3
# 053A     3
# 012A     3
# 105A     3
# 061A     2
# 032A     2
# 054A     2
# 038A     2
# 069A     2
# 043A     1
# 092A     1
# 004A     1
# 076A     1
# 110A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    246
# X    229
# F    201
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    47
# M    40
# F    30
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 071A, 019A, 067A, 020A, 002B, 022...
# kitten    [044A, 111A, 040A, 046A, 047A, 042A, 109A, 049...
# senior    [093A, 015A, 097A, 001A, 103A, 028A, 057A, 106...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 097B, 074A, 062A, 009A, 038A, 099A, 069...
# kitten                             [014B, 050A, 043A, 110A]
# senior                             [054A, 060A, 053A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 44, 'kitten': 12, 'senior': 30}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 4, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '005A' '006A' '007A' '008A'
#  '010A' '011A' '013B' '014A' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023A' '023B' '024A' '025A' '025B' '025C' '026B' '026C'
#  '027A' '028A' '029A' '034A' '035A' '037A' '039A' '040A' '041A' '042A'
#  '044A' '045A' '046A' '047A' '048A' '049A' '051A' '051B' '052A' '055A'
#  '056A' '057A' '058A' '059A' '063A' '064A' '065A' '066A' '067A' '068A'
#  '070A' '071A' '072A' '073A' '087A' '088A' '090A' '091A' '093A' '094A'
#  '095A' '096A' '097A' '100A' '101A' '102A' '103A' '104A' '106A' '108A'
#  '109A' '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['004A' '009A' '012A' '014B' '026A' '031A' '032A' '033A' '036A' '038A'
#  '043A' '050A' '053A' '054A' '060A' '061A' '062A' '069A' '074A' '075A'
#  '076A' '092A' '097B' '099A' '105A' '110A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '005A' '006A' '007A' '008A'
#  '010A' '011A' '013B' '014A' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023A' '023B' '024A' '025A' '025B' '025C' '026B' '026C'
#  '027A' '028A' '029A' '034A' '035A' '037A' '039A' '040A' '041A' '042A'
#  '044A' '045A' '046A' '047A' '048A' '049A' '051A' '051B' '052A' '055A'
#  '056A' '057A' '058A' '059A' '063A' '064A' '065A' '066A' '067A' '068A'
#  '070A' '071A' '072A' '073A' '087A' '088A' '090A' '091A' '093A' '094A'
#  '095A' '096A' '097A' '100A' '101A' '102A' '103A' '104A' '106A' '108A'
#  '109A' '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['004A' '009A' '012A' '014B' '026A' '031A' '032A' '033A' '036A' '038A'
#  '043A' '050A' '053A' '054A' '060A' '061A' '062A' '069A' '074A' '075A'
#  '076A' '092A' '097B' '099A' '105A' '110A']
# Length of X_train_val:
# 676
# Length of y_train_val:
# 676
# Length of groups_train_val:
# 676
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     315
# senior    243
# kitten    118
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     90
# kitten    17
# senior    10
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     315
# senior    243
# kitten    118
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     90
# kitten    17
# senior    10
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 315, 2: 243, 1: 118})
# Epoch 1/1500
# 22/22 [==============================] - 1s 4ms/step - loss: 0.9770 - accuracy: 0.5695
# Epoch 2/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4808 - accuracy: 0.7796
# Epoch 3/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3248 - accuracy: 0.8728
# Epoch 4/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2868 - accuracy: 0.8950
# Epoch 5/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1890 - accuracy: 0.9305
# Epoch 6/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2130 - accuracy: 0.9260
# Epoch 7/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1865 - accuracy: 0.9334
# Epoch 8/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2194 - accuracy: 0.9157
# Epoch 9/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2114 - accuracy: 0.9172
# Epoch 10/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1086 - accuracy: 0.9660
# Epoch 11/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1138 - accuracy: 0.9586
# Epoch 12/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1426 - accuracy: 0.9453
# Epoch 13/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1129 - accuracy: 0.9482
# Epoch 14/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1650 - accuracy: 0.9453
# Epoch 15/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1434 - accuracy: 0.9482
# Epoch 16/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0987 - accuracy: 0.9704
# Epoch 17/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0998 - accuracy: 0.9601
# Epoch 18/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0870 - accuracy: 0.9793
# Epoch 19/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0918 - accuracy: 0.9660
# Epoch 20/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0776 - accuracy: 0.9749
# Epoch 21/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0744 - accuracy: 0.9719
# Epoch 22/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0720 - accuracy: 0.9734
# Epoch 23/1500
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0646 - accuracy: 0.9704
# Epoch 24/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0838 - accuracy: 0.9689
# Epoch 25/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0996 - accuracy: 0.9704
# Epoch 26/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0841 - accuracy: 0.9734
# Epoch 27/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0833 - accuracy: 0.9675
# Epoch 28/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1172 - accuracy: 0.9571
# Epoch 29/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2587 - accuracy: 0.9112
# Epoch 30/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1760 - accuracy: 0.9393
# Epoch 31/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1384 - accuracy: 0.9438
# Epoch 32/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0674 - accuracy: 0.9808
# Epoch 33/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1104 - accuracy: 0.9763
# Epoch 34/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1063 - accuracy: 0.9527
# Epoch 35/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1039 - accuracy: 0.9601
# Epoch 36/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0826 - accuracy: 0.9704
# Epoch 37/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0750 - accuracy: 0.9734
# Epoch 38/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0872 - accuracy: 0.9704
# Epoch 39/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0791 - accuracy: 0.9719
# Epoch 40/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0653 - accuracy: 0.9793
# Epoch 41/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0773 - accuracy: 0.9778
# Epoch 42/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0547 - accuracy: 0.9793
# Epoch 43/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0699 - accuracy: 0.9749
# Epoch 44/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0430 - accuracy: 0.9852
# Epoch 45/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0213 - accuracy: 0.9970
# Epoch 46/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 0.9956
# Epoch 47/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0410 - accuracy: 0.9926
# Epoch 48/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1151 - accuracy: 0.9497
# Epoch 49/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0817 - accuracy: 0.9704
# Epoch 50/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0685 - accuracy: 0.9734
# Epoch 51/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0942 - accuracy: 0.9704
# Epoch 52/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0823 - accuracy: 0.9645
# Epoch 53/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0417 - accuracy: 0.9882
# Epoch 54/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0875 - accuracy: 0.9689
# Epoch 55/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0696 - accuracy: 0.9763
# Epoch 56/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0434 - accuracy: 0.9867
# Epoch 57/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0984 - accuracy: 0.9645
# Epoch 58/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0594 - accuracy: 0.9822
# Epoch 59/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0563 - accuracy: 0.9778
# Epoch 60/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0245 - accuracy: 0.9926
# Epoch 61/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0260 - accuracy: 0.9911
# Epoch 62/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0283 - accuracy: 0.9896
# Epoch 63/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0417 - accuracy: 0.9808
# Epoch 64/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0440 - accuracy: 0.9867
# Epoch 65/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0414 - accuracy: 0.9852
# Epoch 66/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0356 - accuracy: 0.9882
# Epoch 67/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0555 - accuracy: 0.9852
# Epoch 68/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0566 - accuracy: 0.9926
# Epoch 69/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1457 - accuracy: 0.9423
# Epoch 70/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0791 - accuracy: 0.9749
# Epoch 71/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0472 - accuracy: 0.9926
# Epoch 72/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 0.9941
# Epoch 73/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0393 - accuracy: 0.9852
# Epoch 74/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0410 - accuracy: 0.9867
# Epoch 75/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0208 - accuracy: 0.9970
# Epoch 76/1500
# 15/22 [===================>..........] - ETA: 0s - loss: 0.0218 - accuracy: 0.9937Restoring model weights from the end of the best epoch: 46.
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0281 - accuracy: 0.9941
# Epoch 76: early stopping
# 4/4 [==============================] - 0s 1ms/step - loss: 1.6399 - accuracy: 0.6838
# 4/4 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.69 (18/26)
# Before appending - Cat IDs: 596, Predictions: 596, Actuals: 596, Gender: 596
# After appending - Cat IDs: 713, Predictions: 713, Actuals: 713, Gender: 713
# Final Test Results - Loss: 1.6399449110031128, Accuracy: 0.6837607026100159, Precision: 0.5384703196347033, Recall: 0.5760348583877996, F1 Score: 0.5408884163846271
# Confusion Matrix:
#  [[65  7 18]
#  [ 2 12  3]
#  [ 6  1  3]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5982374716834084
#
# Final Average Loss across all UNSEEN TEST sets: 2.430346339941025
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6336972266435623
#
# Final Average Precision across all UNSEEN TEST sets: 0.6157556424634775
#
# Final Average Recall across all UNSEEN TEST sets: 0.6383833047024212

# %%
seed_3_folds_values = [unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1]

seed_3_training_acc_values = cv_training_acc_total

# Plotting all fold metrics
seed_3_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 713, Predictions: 713, Actuals: 713, Gender: 713

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.68 (75/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, senior, adult, adult, kitten, adult, a...         adult            adult                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 77    071A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, kit...         adult            adult                   True
#
activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.4064145271744943))  
    model_full.add(Dense(3, activation='softmax'))  
    
    optimizer = optimizers['Adam']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=32,
                                  verbose=1, callbacks=[early_stopping, accuracy_history], class_weight=weight_dict)
    
    
    # log epochs
    best_epoch_index = np.argmin(history_full.history['loss'])  
    best_training_accuracy = accuracy_history.acc[best_epoch_index]

    # Append training acc to total  
    all_best_training_acc.append(best_training_accuracy)
    total_training_acc.append(accuracy_history.acc)

    # Append training acc just for this CV
    cv_training_acc_total.append(accuracy_history.acc)
    cv_training_acc_best.append(best_training_accuracy)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
average_fold_f1.append(unseen_set_avg_f1)
average_fold_losses.append(unseen_set_avg_loss)
average_fold_accuracies.append(unseen_set_avg_acc)
average_fold_precisions.append(unseen_set_avg_precision)
average_fold_recalls.append(unseen_set_avg_recall)

# Append all to total lists
all_f1.append(unseen_f1)
all_losses.append(unseen_losses)
all_accuracies.append(unseen_accuracies)
all_precisions.append(unseen_precisions)
all_recalls.append(unseen_recalls)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 103A    33
# 002B    30
# 047A    22
# 000B    19
# 019A    17
# 057A    17
# 074A    16
# 097A    15
# 029A    15
# 106A    13
# 055A    12
# 101A    12
# 116A    12
# 111A    12
# 042A    11
# 028A    11
# 063A    11
# 059A    10
# 014B    10
# 040A    10
# 001A     9
# 022A     9
# 051B     9
# 033A     9
# 005A     9
# 071A     9
# 072A     9
# 016A     9
# 013B     8
# 068A     8
# 027A     7
# 036A     7
# 031A     7
# 015A     7
# 095A     7
# 039A     6
# 099A     6
# 008A     5
# 094A     5
# 075A     5
# 050A     5
# 021A     5
# 108A     5
# 109A     5
# 070A     5
# 003A     4
# 026A     4
# 025C     4
# 045A     4
# 009A     4
# 023B     4
# 060A     3
# 056A     3
# 034A     3
# 014A     3
# 105A     3
# 069A     2
# 018A     2
# 102A     2
# 061A     2
# 032A     2
# 052A     2
# 011A     2
# 038A     2
# 090A     1
# 048A     1
# 100A     1
# 110A     1
# 115A     1
# 088A     1
# 076A     1
# 066A     1
# 026C     1
# 041A     1
# 092A     1
# 049A     1
# 096A     1
# 091A     1
# 064A     1
# 073A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 020A    20
# 097B    14
# 002A    13
# 051A    12
# 067A    11
# 025A    10
# 065A     9
# 117A     7
# 023A     6
# 007A     6
# 044A     5
# 104A     4
# 053A     3
# 010A     3
# 012A     3
# 058A     3
# 006A     3
# 113A     3
# 062A     3
# 054A     2
# 087A     2
# 035A     2
# 037A     2
# 025B     2
# 093A     2
# 043A     1
# 004A     1
# 019B     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    241
# M    231
# F    128
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    103
# M     55
# X     35
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [033A, 071A, 019A, 074A, 002B, 022A, 029A, 095...
# kitten    [014B, 111A, 040A, 046A, 047A, 042A, 109A, 050...
# senior    [015A, 097A, 001A, 103A, 028A, 057A, 106A, 101...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 000A, 097B, 067A, 020A, 062A, 065A, 002...
# kitten                                         [044A, 043A]
# senior    [093A, 104A, 025A, 113A, 054A, 117A, 051A, 058...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 44, 'kitten': 14, 'senior': 24}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 2, 'senior': 10}
# Unique Training/Validation Group IDs:
# ['000B' '001A' '002B' '003A' '005A' '008A' '009A' '011A' '013B' '014A'
#  '014B' '015A' '016A' '018A' '019A' '021A' '022A' '023B' '025C' '026A'
#  '026B' '026C' '027A' '028A' '029A' '031A' '032A' '033A' '034A' '036A'
#  '038A' '039A' '040A' '041A' '042A' '045A' '046A' '047A' '048A' '049A'
#  '050A' '051B' '052A' '055A' '056A' '057A' '059A' '060A' '061A' '063A'
#  '064A' '066A' '068A' '069A' '070A' '071A' '072A' '073A' '074A' '075A'
#  '076A' '088A' '090A' '091A' '092A' '094A' '095A' '096A' '097A' '099A'
#  '100A' '101A' '102A' '103A' '105A' '106A' '108A' '109A' '110A' '111A'
#  '115A' '116A']
# Unique Test Group IDs:
# ['000A' '002A' '004A' '006A' '007A' '010A' '012A' '019B' '020A' '023A'
#  '024A' '025A' '025B' '035A' '037A' '043A' '044A' '051A' '053A' '054A'
#  '058A' '062A' '065A' '067A' '087A' '093A' '097B' '104A' '113A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'000B'}
# Moved to Test Set:
# {'000B'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '003A' '005A' '008A' '009A' '011A' '013B' '014A'
#  '014B' '015A' '016A' '018A' '019A' '021A' '022A' '023B' '025C' '026A'
#  '026B' '026C' '027A' '028A' '029A' '031A' '032A' '033A' '034A' '036A'
#  '038A' '039A' '040A' '041A' '042A' '045A' '046A' '047A' '048A' '049A'
#  '050A' '051B' '052A' '055A' '056A' '057A' '059A' '060A' '061A' '063A'
#  '064A' '066A' '068A' '069A' '070A' '071A' '072A' '073A' '074A' '075A'
#  '076A' '088A' '090A' '091A' '092A' '094A' '095A' '096A' '097A' '099A'
#  '100A' '101A' '102A' '103A' '105A' '106A' '108A' '109A' '110A' '111A'
#  '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002A' '004A' '006A' '007A' '010A' '012A' '019B' '020A' '023A'
#  '024A' '025A' '025B' '035A' '037A' '043A' '044A' '051A' '053A' '054A'
#  '058A' '062A' '065A' '067A' '087A' '093A' '097B' '104A' '113A' '117A']
# Length of X_train_val:
# 620
# Length of y_train_val:
# 620
# Length of groups_train_val:
# 620
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Train Age Group Distribution BEFORE SWAP:
# adult     265
# senior    206
# kitten    129
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     140
# senior     47
# kitten      6
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     285
# senior    206
# kitten    129
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     120
# senior     47
# kitten      6
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 285, 2: 206, 1: 129})
# Epoch 1/1500
# 20/20 [==============================] - 1s 4ms/step - loss: 1.0691 - accuracy: 0.5371
# Epoch 2/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4874 - accuracy: 0.7871
# Epoch 3/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3488 - accuracy: 0.8629
# Epoch 4/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1944 - accuracy: 0.9258
# Epoch 5/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1471 - accuracy: 0.9323
# Epoch 6/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1215 - accuracy: 0.9548
# Epoch 7/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0889 - accuracy: 0.9661
# Epoch 8/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1411 - accuracy: 0.9500
# Epoch 9/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0872 - accuracy: 0.9629
# Epoch 10/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0767 - accuracy: 0.9758
# Epoch 11/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0706 - accuracy: 0.9710
# Epoch 12/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0793 - accuracy: 0.9790
# Epoch 13/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0496 - accuracy: 0.9823
# Epoch 14/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0719 - accuracy: 0.9694
# Epoch 15/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1157 - accuracy: 0.9710
# Epoch 16/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1356 - accuracy: 0.9548
# Epoch 17/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0969 - accuracy: 0.9661
# Epoch 18/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0937 - accuracy: 0.9742
# Epoch 19/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0845 - accuracy: 0.9742
# Epoch 20/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0338 - accuracy: 0.9903
# Epoch 21/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0436 - accuracy: 0.9790
# Epoch 22/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0532 - accuracy: 0.9823
# Epoch 23/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0546 - accuracy: 0.9903
# Epoch 24/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0258 - accuracy: 0.9903
# Epoch 25/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1100 - accuracy: 0.9677
# Epoch 26/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0642 - accuracy: 0.9806
# Epoch 27/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0573 - accuracy: 0.9790
# Epoch 28/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0326 - accuracy: 0.9871
# Epoch 29/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0332 - accuracy: 0.9855
# Epoch 30/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0154 - accuracy: 0.9952
# Epoch 31/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0468 - accuracy: 0.9855
# Epoch 32/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0458 - accuracy: 0.9871
# Epoch 33/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0643 - accuracy: 0.9806
# Epoch 34/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0481 - accuracy: 0.9790
# Epoch 35/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0336 - accuracy: 0.9871
# Epoch 36/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1016 - accuracy: 0.9742
# Epoch 37/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0328 - accuracy: 0.9887
# Epoch 38/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0264 - accuracy: 0.9871
# Epoch 39/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0296 - accuracy: 0.9919
# Epoch 40/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0240 - accuracy: 0.9919
# Epoch 41/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0629 - accuracy: 0.9790
# Epoch 42/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0372 - accuracy: 0.9903
# Epoch 43/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0318 - accuracy: 0.9935
# Epoch 44/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0362 - accuracy: 0.9871
# Epoch 45/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0411 - accuracy: 0.9935
# Epoch 46/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0212 - accuracy: 0.9952
# Epoch 47/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0169 - accuracy: 0.9968
# Epoch 48/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 0.9984
# Epoch 49/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 50/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 0.9984
# Epoch 51/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0071 - accuracy: 0.9984
# Epoch 52/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0403 - accuracy: 0.9919
# Epoch 53/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0375 - accuracy: 0.9871
# Epoch 54/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0367 - accuracy: 0.9919
# Epoch 55/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0493 - accuracy: 0.9887
# Epoch 56/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0202 - accuracy: 0.9887
# Epoch 57/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0957 - accuracy: 0.9823
# Epoch 58/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0620 - accuracy: 0.9823
# Epoch 59/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0201 - accuracy: 0.9952
# Epoch 60/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0303 - accuracy: 0.9887
# Epoch 61/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0726 - accuracy: 0.9823
# Epoch 62/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0457 - accuracy: 0.9855
# Epoch 63/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 0.9952
# Epoch 64/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0311 - accuracy: 0.9952
# Epoch 65/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0495 - accuracy: 0.9903
# Epoch 66/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0569 - accuracy: 0.9823
# Epoch 67/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 68/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.9968
# Epoch 69/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0387 - accuracy: 0.9823
# Epoch 70/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0462 - accuracy: 0.9823
# Epoch 71/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0205 - accuracy: 0.9903
# Epoch 72/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0604 - accuracy: 0.9839
# Epoch 73/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0852 - accuracy: 0.9726
# Epoch 74/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0440 - accuracy: 0.9855
# Epoch 75/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0346 - accuracy: 0.9871
# Epoch 76/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0367 - accuracy: 0.9887
# Epoch 77/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0529 - accuracy: 0.9839
# Epoch 78/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0437 - accuracy: 0.9887
# Epoch 79/1500
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0385 - accuracy: 0.9922Restoring model weights from the end of the best epoch: 49.
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0348 - accuracy: 0.9935
# Epoch 79: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 1.7375 - accuracy: 0.6994
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.60 (18/30)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 173, Predictions: 173, Actuals: 173, Gender: 173
# Final Test Results - Loss: 1.737455129623413, Accuracy: 0.6994219422340393, Precision: 0.5750605326876513, Recall: 0.5979905437352245, F1 Score: 0.5855725286065844
# Confusion Matrix:
#  [[94  2 24]
#  [ 3  3  0]
#  [21  2 24]]
# outer_fold 2
# Train Set Group Distribution:
# 000A    39
# 103A    33
# 002B    30
# 020A    20
# 019A    17
# 057A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 002A    13
# 055A    12
# 116A    12
# 101A    12
# 051A    12
# 111A    12
# 028A    11
# 063A    11
# 067A    11
# 042A    11
# 059A    10
# 025A    10
# 014B    10
# 065A     9
# 071A     9
# 072A     9
# 016A     9
# 005A     9
# 033A     9
# 013B     8
# 031A     7
# 015A     7
# 117A     7
# 095A     7
# 027A     7
# 036A     7
# 099A     6
# 007A     6
# 039A     6
# 023A     6
# 021A     5
# 070A     5
# 044A     5
# 109A     5
# 026A     4
# 045A     4
# 104A     4
# 023B     4
# 025C     4
# 003A     4
# 010A     3
# 060A     3
# 053A     3
# 058A     3
# 012A     3
# 006A     3
# 034A     3
# 113A     3
# 062A     3
# 018A     2
# 093A     2
# 025B     2
# 037A     2
# 102A     2
# 011A     2
# 035A     2
# 052A     2
# 038A     2
# 087A     2
# 054A     2
# 032A     2
# 092A     1
# 088A     1
# 100A     1
# 076A     1
# 043A     1
# 019B     1
# 004A     1
# 041A     1
# 073A     1
# 066A     1
# 064A     1
# 096A     1
# 091A     1
# 024A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    45
# 047A    22
# 000B    19
# 106A    13
# 040A    10
# 001A     9
# 051B     9
# 022A     9
# 068A     8
# 050A     5
# 075A     5
# 008A     5
# 094A     5
# 108A     5
# 009A     4
# 105A     3
# 056A     3
# 014A     3
# 069A     2
# 061A     2
# 115A     1
# 090A     1
# 110A     1
# 049A     1
# 048A     1
# 026C     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    234
# F    189
# X    177
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    99
# M    52
# F    42
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 071A, 097B, 019A, 074A, 067...
# kitten     [044A, 014B, 111A, 042A, 109A, 043A, 041A, 045A]
# senior    [093A, 015A, 097A, 103A, 028A, 057A, 101A, 104...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [022A, 009A, 014A, 069A, 000B, 105A, 068A, 075...
# kitten     [040A, 046A, 047A, 050A, 049A, 048A, 115A, 110A]
# senior    [001A, 106A, 051B, 056A, 008A, 094A, 108A, 061...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 52, 'kitten': 8, 'senior': 25}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 10, 'kitten': 8, 'senior': 9}
# Unique Training/Validation Group IDs:
# ['000A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '010A' '011A'
#  '012A' '013B' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '023A' '023B' '024A' '025A' '025B' '025C' '026A' '027A' '028A' '029A'
#  '031A' '032A' '033A' '034A' '035A' '036A' '037A' '038A' '039A' '041A'
#  '042A' '043A' '044A' '045A' '051A' '052A' '053A' '054A' '055A' '057A'
#  '058A' '059A' '060A' '062A' '063A' '064A' '065A' '066A' '067A' '070A'
#  '071A' '072A' '073A' '074A' '076A' '087A' '088A' '091A' '092A' '093A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '104A'
#  '109A' '111A' '113A' '116A' '117A']
# Unique Test Group IDs:
# ['000B' '001A' '008A' '009A' '014A' '022A' '026B' '026C' '040A' '046A'
#  '047A' '048A' '049A' '050A' '051B' '056A' '061A' '068A' '069A' '075A'
#  '090A' '094A' '105A' '106A' '108A' '110A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'044A'}
# Moved to Test Set:
# {'044A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '010A' '011A'
#  '012A' '013B' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '023A' '023B' '024A' '025A' '025B' '025C' '026A' '027A' '028A' '029A'
#  '031A' '032A' '033A' '034A' '035A' '036A' '037A' '038A' '039A' '041A'
#  '042A' '043A' '045A' '046A' '051A' '052A' '053A' '054A' '055A' '057A'
#  '058A' '059A' '060A' '062A' '063A' '064A' '065A' '066A' '067A' '070A'
#  '071A' '072A' '073A' '074A' '076A' '087A' '088A' '091A' '092A' '093A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '104A'
#  '109A' '111A' '113A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '001A' '008A' '009A' '014A' '022A' '026B' '026C' '040A' '044A'
#  '047A' '048A' '049A' '050A' '051B' '056A' '061A' '068A' '069A' '075A'
#  '090A' '094A' '105A' '106A' '108A' '110A' '115A']
# Length of X_train_val:
# 640
# Length of y_train_val:
# 640
# Length of groups_train_val:
# 640
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Train Age Group Distribution BEFORE SWAP:
# adult     350
# senior    201
# kitten     49
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# kitten    86
# adult     55
# senior    52
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     350
# senior    201
# kitten     89
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     55
# senior    52
# kitten    46
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 350, 2: 201, 1: 89})
# Epoch 1/1500
# 20/20 [==============================] - 1s 3ms/step - loss: 0.8857 - accuracy: 0.5422
# Epoch 2/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4642 - accuracy: 0.7891
# Epoch 3/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2686 - accuracy: 0.8859
# Epoch 4/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2446 - accuracy: 0.8984
# Epoch 5/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1707 - accuracy: 0.9375
# Epoch 6/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1186 - accuracy: 0.9641
# Epoch 7/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0834 - accuracy: 0.9672
# Epoch 8/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0783 - accuracy: 0.9719
# Epoch 9/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0591 - accuracy: 0.9812
# Epoch 10/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0646 - accuracy: 0.9766
# Epoch 11/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0910 - accuracy: 0.9688
# Epoch 12/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0441 - accuracy: 0.9859
# Epoch 13/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0699 - accuracy: 0.9812
# Epoch 14/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1121 - accuracy: 0.9656
# Epoch 15/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0353 - accuracy: 0.9812
# Epoch 16/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1424 - accuracy: 0.9516
# Epoch 17/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1417 - accuracy: 0.9516
# Epoch 18/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0787 - accuracy: 0.9703
# Epoch 19/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0624 - accuracy: 0.9828
# Epoch 20/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0541 - accuracy: 0.9812
# Epoch 21/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1186 - accuracy: 0.9656
# Epoch 22/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0436 - accuracy: 0.9844
# Epoch 23/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0774 - accuracy: 0.9781
# Epoch 24/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0361 - accuracy: 0.9859
# Epoch 25/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0627 - accuracy: 0.9812
# Epoch 26/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0811 - accuracy: 0.9703
# Epoch 27/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0395 - accuracy: 0.9844
# Epoch 28/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0249 - accuracy: 0.9953
# Epoch 29/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0212 - accuracy: 0.9937
# Epoch 30/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0236 - accuracy: 0.9922
# Epoch 31/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0256 - accuracy: 0.9906
# Epoch 32/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 0.9953
# Epoch 33/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0279 - accuracy: 0.9906
# Epoch 34/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0278 - accuracy: 0.9891
# Epoch 35/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0420 - accuracy: 0.9828
# Epoch 36/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0907 - accuracy: 0.9781
# Epoch 37/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0386 - accuracy: 0.9906
# Epoch 38/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0645 - accuracy: 0.9797
# Epoch 39/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 0.9984
# Epoch 40/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0241 - accuracy: 0.9891
# Epoch 41/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 0.9969
# Epoch 42/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0134 - accuracy: 0.9922
# Epoch 43/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0137 - accuracy: 0.9953
# Epoch 44/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 0.9953
# Epoch 45/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 0.9937
# Epoch 46/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0274 - accuracy: 0.9922
# Epoch 47/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0205 - accuracy: 0.9969
# Epoch 48/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0377 - accuracy: 0.9859
# Epoch 49/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0560 - accuracy: 0.9734
# Epoch 50/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0427 - accuracy: 0.9812
# Epoch 51/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0244 - accuracy: 0.9859
# Epoch 52/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1251 - accuracy: 0.9781
# Epoch 53/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0474 - accuracy: 0.9844
# Epoch 54/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0788 - accuracy: 0.9766
# Epoch 55/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0446 - accuracy: 0.9859
# Epoch 56/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 0.9922
# Epoch 57/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0413 - accuracy: 0.9844
# Epoch 58/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0797 - accuracy: 0.9797
# Epoch 59/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0089 - accuracy: 0.9984
# Epoch 60/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0254 - accuracy: 0.9906
# Epoch 61/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0352 - accuracy: 0.9891
# Epoch 62/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 0.9922
# Epoch 63/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0469 - accuracy: 0.9859
# Epoch 64/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0207 - accuracy: 0.9953
# Epoch 65/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 0.9922
# Epoch 66/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0164 - accuracy: 0.9922
# Epoch 67/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0375 - accuracy: 0.9891
# Epoch 68/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0313 - accuracy: 0.9937
# Epoch 69/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0148 - accuracy: 0.9937
# Epoch 70/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0183 - accuracy: 0.9922
# Epoch 71/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 0.9937
# Epoch 72/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0563 - accuracy: 0.9812
# Epoch 73/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0285 - accuracy: 0.9859
# Epoch 74/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0138 - accuracy: 0.9953
# Epoch 75/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9937
# Epoch 76/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0195 - accuracy: 0.9953
# Epoch 77/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0330 - accuracy: 0.9891
# Epoch 78/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0124 - accuracy: 0.9922
# Epoch 79/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0337 - accuracy: 0.9906
# Epoch 80/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0319 - accuracy: 0.9937
# Epoch 81/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 0.9937
# Epoch 82/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0419 - accuracy: 0.9875
# Epoch 83/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0589 - accuracy: 0.9875
# Epoch 84/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0398 - accuracy: 0.9859
# Epoch 85/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0111 - accuracy: 0.9969
# Epoch 86/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 87/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 0.9969
# Epoch 88/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0086 - accuracy: 0.9969
# Epoch 89/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 90/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 0.9984
# Epoch 91/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 0.9937
# Epoch 92/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 0.9969
# Epoch 93/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 94/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 0.9937
# Epoch 95/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0281 - accuracy: 0.9922
# Epoch 96/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0129 - accuracy: 0.9953
# Epoch 97/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 0.9953
# Epoch 98/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0427 - accuracy: 0.9891
# Epoch 99/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0532 - accuracy: 0.9812
# Epoch 100/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0137 - accuracy: 0.9969
# Epoch 101/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0347 - accuracy: 0.9844
# Epoch 102/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0199 - accuracy: 0.9922
# Epoch 103/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0120 - accuracy: 0.9969
# Epoch 104/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0310 - accuracy: 0.9937
# Epoch 105/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0239 - accuracy: 0.9937
# Epoch 106/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 107/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 0.9969
# Epoch 108/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 0.9984
# Epoch 109/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0104 - accuracy: 0.9953
# Epoch 110/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0230 - accuracy: 0.9937
# Epoch 111/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0089 - accuracy: 0.9953
# Epoch 112/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0381 - accuracy: 0.9937
# Epoch 113/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0407 - accuracy: 0.9859
# Epoch 114/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0297 - accuracy: 0.9859
# Epoch 115/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0220 - accuracy: 0.9922
# Epoch 116/1500
# 15/20 [=====================>........] - ETA: 0s - loss: 0.0686 - accuracy: 0.9792    Restoring model weights from the end of the best epoch: 86.
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0526 - accuracy: 0.9844
# Epoch 116: early stopping
# 5/5 [==============================] - 0s 1ms/step - loss: 3.1253 - accuracy: 0.5817
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.67 (18/27)
# Before appending - Cat IDs: 173, Predictions: 173, Actuals: 173, Gender: 173
# After appending - Cat IDs: 326, Predictions: 326, Actuals: 326, Gender: 326
# Final Test Results - Loss: 3.125311851501465, Accuracy: 0.5816993713378906, Precision: 0.6641975308641975, Recall: 0.5745718050065877, F1 Score: 0.5863886861052662
# Confusion Matrix:
#  [[41  4 10]
#  [24 22  0]
#  [25  1 26]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 047A    22
# 020A    20
# 000B    19
# 074A    16
# 029A    15
# 097B    14
# 002A    13
# 106A    13
# 116A    12
# 051A    12
# 055A    12
# 063A    11
# 028A    11
# 067A    11
# 025A    10
# 040A    10
# 014B    10
# 022A     9
# 016A     9
# 005A     9
# 072A     9
# 065A     9
# 051B     9
# 001A     9
# 068A     8
# 117A     7
# 015A     7
# 036A     7
# 099A     6
# 023A     6
# 007A     6
# 044A     5
# 075A     5
# 050A     5
# 108A     5
# 008A     5
# 094A     5
# 025C     4
# 045A     4
# 023B     4
# 104A     4
# 026A     4
# 009A     4
# 060A     3
# 056A     3
# 012A     3
# 058A     3
# 006A     3
# 053A     3
# 105A     3
# 113A     3
# 014A     3
# 034A     3
# 062A     3
# 010A     3
# 035A     2
# 061A     2
# 037A     2
# 025B     2
# 052A     2
# 054A     2
# 069A     2
# 018A     2
# 093A     2
# 038A     2
# 087A     2
# 049A     1
# 024A     1
# 090A     1
# 110A     1
# 115A     1
# 019B     1
# 026C     1
# 088A     1
# 004A     1
# 048A     1
# 066A     1
# 076A     1
# 096A     1
# 043A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 002B    30
# 057A    17
# 019A    17
# 097A    15
# 111A    12
# 101A    12
# 042A    11
# 059A    10
# 033A     9
# 071A     9
# 013B     8
# 027A     7
# 095A     7
# 031A     7
# 039A     6
# 021A     5
# 070A     5
# 109A     5
# 003A     4
# 032A     2
# 102A     2
# 011A     2
# 041A     1
# 091A     1
# 092A     1
# 064A     1
# 073A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# F    197
# X    179
# M    176
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    110
# X     97
# F     34
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 097B, 074A, 067A, 020A, 062A, 022...
# kitten    [044A, 014B, 040A, 046A, 047A, 050A, 043A, 049...
# senior    [093A, 015A, 001A, 028A, 106A, 104A, 055A, 025...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 071A, 019A, 002B, 095A, 027A, 013B, 070...
# kitten                             [111A, 042A, 109A, 041A]
# senior     [097A, 103A, 057A, 101A, 091A, 039A, 059A, 011A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 45, 'kitten': 12, 'senior': 26}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 17, 'kitten': 4, 'senior': 8}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '004A' '005A' '006A' '007A' '008A' '009A'
#  '010A' '012A' '014A' '014B' '015A' '016A' '018A' '019B' '020A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '025C' '026A' '026B' '026C' '028A'
#  '029A' '034A' '035A' '036A' '037A' '038A' '040A' '043A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '056A' '058A' '060A' '061A' '062A' '063A' '065A' '066A' '067A'
#  '068A' '069A' '072A' '074A' '075A' '076A' '087A' '088A' '090A' '093A'
#  '094A' '096A' '097B' '099A' '104A' '105A' '106A' '108A' '110A' '113A'
#  '115A' '116A' '117A']
# Unique Test Group IDs:
# ['002B' '003A' '011A' '013B' '019A' '021A' '027A' '031A' '032A' '033A'
#  '039A' '041A' '042A' '057A' '059A' '064A' '070A' '071A' '073A' '091A'
#  '092A' '095A' '097A' '100A' '101A' '102A' '103A' '109A' '111A']
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '004A' '005A' '006A' '007A' '008A' '009A'
#  '010A' '012A' '014A' '014B' '015A' '016A' '018A' '019B' '020A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '025C' '026A' '026B' '026C' '028A'
#  '029A' '034A' '035A' '036A' '037A' '038A' '040A' '043A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '056A' '058A' '060A' '061A' '062A' '063A' '065A' '066A' '067A'
#  '068A' '069A' '072A' '074A' '075A' '076A' '087A' '088A' '090A' '093A'
#  '094A' '096A' '097B' '099A' '104A' '105A' '106A' '108A' '110A' '113A'
#  '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '003A' '011A' '013B' '019A' '021A' '027A' '031A' '032A' '033A'
#  '039A' '041A' '042A' '057A' '059A' '064A' '070A' '071A' '073A' '091A'
#  '092A' '095A' '097A' '100A' '101A' '102A' '103A' '109A' '111A']
# Length of X_train_val:
# 552
# Length of y_train_val:
# 552
# Length of groups_train_val:
# 552
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     289
# senior    157
# kitten    106
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     116
# senior     96
# kitten     29
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     289
# senior    157
# kitten    106
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     116
# senior     96
# kitten     29
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 289, 2: 157, 1: 106})
# Epoch 1/1500
# 18/18 [==============================] - 1s 4ms/step - loss: 1.1325 - accuracy: 0.5362
# Epoch 2/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5824 - accuracy: 0.7246
# Epoch 3/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3833 - accuracy: 0.8152
# Epoch 4/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3251 - accuracy: 0.8623
# Epoch 5/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2152 - accuracy: 0.9112
# Epoch 6/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1690 - accuracy: 0.9493
# Epoch 7/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1419 - accuracy: 0.9529
# Epoch 8/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1101 - accuracy: 0.9583
# Epoch 9/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1184 - accuracy: 0.9529
# Epoch 10/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0655 - accuracy: 0.9783
# Epoch 11/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0785 - accuracy: 0.9728
# Epoch 12/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0888 - accuracy: 0.9710
# Epoch 13/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0671 - accuracy: 0.9656
# Epoch 14/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0514 - accuracy: 0.9855
# Epoch 15/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1155 - accuracy: 0.9620
# Epoch 16/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0807 - accuracy: 0.9674
# Epoch 17/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1147 - accuracy: 0.9620
# Epoch 18/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0799 - accuracy: 0.9728
# Epoch 19/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0704 - accuracy: 0.9710
# Epoch 20/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0443 - accuracy: 0.9837
# Epoch 21/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0556 - accuracy: 0.9891
# Epoch 22/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0855 - accuracy: 0.9746
# Epoch 23/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0565 - accuracy: 0.9746
# Epoch 24/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0437 - accuracy: 0.9855
# Epoch 25/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0847 - accuracy: 0.9638
# Epoch 26/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0769 - accuracy: 0.9728
# Epoch 27/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0520 - accuracy: 0.9801
# Epoch 28/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0763 - accuracy: 0.9819
# Epoch 29/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0434 - accuracy: 0.9837
# Epoch 30/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0758 - accuracy: 0.9746
# Epoch 31/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0584 - accuracy: 0.9819
# Epoch 32/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0870 - accuracy: 0.9656
# Epoch 33/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0386 - accuracy: 0.9819
# Epoch 34/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0502 - accuracy: 0.9819
# Epoch 35/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0380 - accuracy: 0.9855
# Epoch 36/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0513 - accuracy: 0.9746
# Epoch 37/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0488 - accuracy: 0.9873
# Epoch 38/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0896 - accuracy: 0.9819
# Epoch 39/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0682 - accuracy: 0.9728
# Epoch 40/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1027 - accuracy: 0.9656
# Epoch 41/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0708 - accuracy: 0.9764
# Epoch 42/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0537 - accuracy: 0.9891
# Epoch 43/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0268 - accuracy: 0.9928
# Epoch 44/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0415 - accuracy: 0.9873
# Epoch 45/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0152 - accuracy: 0.9964
# Epoch 46/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 0.9982
# Epoch 47/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0307 - accuracy: 0.9873
# Epoch 48/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0765 - accuracy: 0.9764
# Epoch 49/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0762 - accuracy: 0.9728
# Epoch 50/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0427 - accuracy: 0.9891
# Epoch 51/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0495 - accuracy: 0.9764
# Epoch 52/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0384 - accuracy: 0.9873
# Epoch 53/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0204 - accuracy: 0.9964
# Epoch 54/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0238 - accuracy: 0.9891
# Epoch 55/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0205 - accuracy: 0.9909
# Epoch 56/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0285 - accuracy: 0.9946
# Epoch 57/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0681 - accuracy: 0.9764
# Epoch 58/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0760 - accuracy: 0.9692
# Epoch 59/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0534 - accuracy: 0.9764
# Epoch 60/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0882 - accuracy: 0.9692
# Epoch 61/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0416 - accuracy: 0.9819
# Epoch 62/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0264 - accuracy: 0.9928
# Epoch 63/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0296 - accuracy: 0.9909
# Epoch 64/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0196 - accuracy: 0.9946
# Epoch 65/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0387 - accuracy: 0.9909
# Epoch 66/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0353 - accuracy: 0.9855
# Epoch 67/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0328 - accuracy: 0.9946
# Epoch 68/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 0.9964
# Epoch 69/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 70/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0313 - accuracy: 0.9964
# Epoch 71/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 0.9946
# Epoch 72/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9964
# Epoch 73/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 0.9946
# Epoch 74/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 75/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 0.9982
# Epoch 76/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0164 - accuracy: 0.9909
# Epoch 77/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0663 - accuracy: 0.9819
# Epoch 78/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0756 - accuracy: 0.9783
# Epoch 79/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0534 - accuracy: 0.9837
# Epoch 80/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0596 - accuracy: 0.9783
# Epoch 81/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0505 - accuracy: 0.9873
# Epoch 82/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0287 - accuracy: 0.9873
# Epoch 83/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0258 - accuracy: 0.9928
# Epoch 84/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0630 - accuracy: 0.9801
# Epoch 85/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0711 - accuracy: 0.9764
# Epoch 86/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0960 - accuracy: 0.9710
# Epoch 87/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0385 - accuracy: 0.9855
# Epoch 88/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0421 - accuracy: 0.9909
# Epoch 89/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0289 - accuracy: 0.9891
# Epoch 90/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0456 - accuracy: 0.9837
# Epoch 91/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 0.9964
# Epoch 92/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0338 - accuracy: 0.9909
# Epoch 93/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0721 - accuracy: 0.9674
# Epoch 94/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0796 - accuracy: 0.9620
# Epoch 95/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0623 - accuracy: 0.9783
# Epoch 96/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0601 - accuracy: 0.9837
# Epoch 97/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0381 - accuracy: 0.9855
# Epoch 98/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0355 - accuracy: 0.9873
# Epoch 99/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0563 - accuracy: 0.9801
# Epoch 100/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0345 - accuracy: 0.9819
# Epoch 101/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 0.9946
# Epoch 102/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0137 - accuracy: 0.9946
# Epoch 103/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0540 - accuracy: 0.9855
# Epoch 104/1500
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0323 - accuracy: 0.9961Restoring model weights from the end of the best epoch: 74.
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0377 - accuracy: 0.9928
# Epoch 104: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 2.1493 - accuracy: 0.6805
# 8/8 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.79 (23/29)
# Before appending - Cat IDs: 326, Predictions: 326, Actuals: 326, Gender: 326
# After appending - Cat IDs: 567, Predictions: 567, Actuals: 567, Gender: 567
# Final Test Results - Loss: 2.149271011352539, Accuracy: 0.680497944355011, Precision: 0.7556721056721055, Recall: 0.6661877394636014, F1 Score: 0.6971193572178794
# Confusion Matrix:
#  [[93  1 22]
#  [ 6 19  4]
#  [44  0 52]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 057A    17
# 019A    17
# 097A    15
# 097B    14
# 002A    13
# 106A    13
# ...
# 039A     6
# 007A     6
# 075A     5
# 050A     5
# 021A     5
# 044A     5
# 108A     5
# 109A     5
# 008A     5
# 094A     5
# 070A     5
# 009A     4
# 104A     4
# 003A     4
# 010A     3
# 056A     3
# 012A     3
# 053A     3
# 058A     3
# 006A     3
# 105A     3
# 014A     3
# 113A     3
# 062A     3
# 093A     2
# 025B     2
# 037A     2
# 102A     2
# 061A     2
# 011A     2
# 054A     2
# 035A     2
# 069A     2
# 032A     2
# 087A     2
# 026C     1
# 024A     1
# 090A     1
# 100A     1
# 110A     1
# 043A     1
# 115A     1
# 073A     1
# 041A     1
# 064A     1
# 019B     1
# 004A     1
# 048A     1
# 049A     1
# 092A     1
# 091A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 074A    16
# 029A    15
# 055A    12
# 116A    12
# 028A    11
# 063A    11
# 014B    10
# 005A     9
# 072A     9
# 016A     9
# 015A     7
# 036A     7
# 099A     6
# 026A     4
# 045A     4
# 023B     4
# 025C     4
# 060A     3
# 034A     3
# 018A     2
# 038A     2
# 052A     2
# 096A     1
# 076A     1
# 066A     1
# 088A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    231
# M    217
# F    179
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    69
# F    52
# X    45
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 071A, 097B, 019A, 067A, 020...
# kitten    [044A, 111A, 040A, 046A, 047A, 042A, 109A, 050...
# senior    [093A, 097A, 001A, 103A, 057A, 106A, 101A, 104...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [074A, 029A, 034A, 005A, 072A, 063A, 038A, 099...
# kitten                                         [014B, 045A]
# senior           [015A, 028A, 055A, 116A, 025C, 016A, 060A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 45, 'kitten': 14, 'senior': 27}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 17, 'kitten': 2, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '006A' '007A' '008A'
#  '009A' '010A' '011A' '012A' '013B' '014A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '024A' '025A' '025B' '026B' '026C' '027A' '031A' '032A'
#  '033A' '035A' '037A' '039A' '040A' '041A' '042A' '043A' '044A' '046A'
#  '047A' '048A' '049A' '050A' '051A' '051B' '053A' '054A' '056A' '057A'
#  '058A' '059A' '061A' '062A' '064A' '065A' '067A' '068A' '069A' '070A'
#  '071A' '073A' '075A' '087A' '090A' '091A' '092A' '093A' '094A' '095A'
#  '097A' '097B' '100A' '101A' '102A' '103A' '104A' '105A' '106A' '108A'
#  '109A' '110A' '111A' '113A' '115A' '117A']
# Unique Test Group IDs:
# ['005A' '014B' '015A' '016A' '018A' '023B' '025C' '026A' '028A' '029A'
#  '034A' '036A' '038A' '045A' '052A' '055A' '060A' '063A' '066A' '072A'
#  '074A' '076A' '088A' '096A' '099A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '006A' '007A' '008A'
#  '009A' '010A' '011A' '012A' '013B' '014A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '024A' '025A' '025B' '026B' '026C' '027A' '031A' '032A'
#  '033A' '035A' '037A' '039A' '040A' '041A' '042A' '043A' '044A' '046A'
#  '047A' '048A' '049A' '050A' '051A' '051B' '053A' '054A' '056A' '057A'
#  '058A' '059A' '061A' '062A' '064A' '065A' '067A' '068A' '069A' '070A'
#  '071A' '073A' '075A' '087A' '090A' '091A' '092A' '093A' '094A' '095A'
#  '097A' '097B' '100A' '101A' '102A' '103A' '104A' '105A' '106A' '108A'
#  '109A' '110A' '111A' '113A' '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['005A' '014B' '015A' '016A' '018A' '023B' '025C' '026A' '028A' '029A'
#  '034A' '036A' '038A' '045A' '052A' '055A' '060A' '063A' '066A' '072A'
#  '074A' '076A' '088A' '096A' '099A' '116A']
# Length of X_train_val:
# 627
# Length of y_train_val:
# 627
# Length of groups_train_val:
# 627
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     311
# senior    195
# kitten    121
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     94
# senior    58
# kitten    14
# Name: age_group, dtype: int64
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Train Age Group Distribution AFTER SWAP:
# adult     311
# senior    195
# kitten    121
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     94
# senior    58
# kitten    14
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 311, 2: 195, 1: 121})
# Epoch 1/1500
# 20/20 [==============================] - 1s 4ms/step - loss: 0.9573 - accuracy: 0.5869
# Epoch 2/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4426 - accuracy: 0.8006
# Epoch 3/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3256 - accuracy: 0.8820
# Epoch 4/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2174 - accuracy: 0.9203
# Epoch 5/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2089 - accuracy: 0.9187
# Epoch 6/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1597 - accuracy: 0.9426
# Epoch 7/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1319 - accuracy: 0.9442
# Epoch 8/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0915 - accuracy: 0.9713
# Epoch 9/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0620 - accuracy: 0.9729
# Epoch 10/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0784 - accuracy: 0.9665
# Epoch 11/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0922 - accuracy: 0.9649
# Epoch 12/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0818 - accuracy: 0.9665
# Epoch 13/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1100 - accuracy: 0.9633
# Epoch 14/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0983 - accuracy: 0.9697
# Epoch 15/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9793
# Epoch 16/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0637 - accuracy: 0.9729
# Epoch 17/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0785 - accuracy: 0.9713
# Epoch 18/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0379 - accuracy: 0.9872
# Epoch 19/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0336 - accuracy: 0.9841
# Epoch 20/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0331 - accuracy: 0.9920
# Epoch 21/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0413 - accuracy: 0.9888
# Epoch 22/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0305 - accuracy: 0.9952
# Epoch 23/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0279 - accuracy: 0.9936
# Epoch 24/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0455 - accuracy: 0.9841
# Epoch 25/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0676 - accuracy: 0.9809
# Epoch 26/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0463 - accuracy: 0.9856
# Epoch 27/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0820 - accuracy: 0.9761
# Epoch 28/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0392 - accuracy: 0.9841
# Epoch 29/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0558 - accuracy: 0.9856
# Epoch 30/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0371 - accuracy: 0.9841
# Epoch 31/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0238 - accuracy: 0.9888
# Epoch 32/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0220 - accuracy: 0.9936
# Epoch 33/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0250 - accuracy: 0.9920
# Epoch 34/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0502 - accuracy: 0.9841
# Epoch 35/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0517 - accuracy: 0.9856
# Epoch 36/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0652 - accuracy: 0.9809
# Epoch 37/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.9904
# Epoch 38/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0397 - accuracy: 0.9856
# Epoch 39/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0370 - accuracy: 0.9888
# Epoch 40/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 0.9984
# Epoch 41/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0170 - accuracy: 0.9904
# Epoch 42/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 0.9936
# Epoch 43/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 0.9952
# Epoch 44/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0469 - accuracy: 0.9904
# Epoch 45/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0472 - accuracy: 0.9841
# Epoch 46/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0193 - accuracy: 0.9904
# Epoch 47/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0276 - accuracy: 0.9888
# Epoch 48/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0523 - accuracy: 0.9841
# Epoch 49/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0177 - accuracy: 0.9920
# Epoch 50/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 0.9984
# Epoch 51/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0225 - accuracy: 0.9904
# Epoch 52/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0139 - accuracy: 0.9952
# Epoch 53/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 0.9984
# Epoch 54/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 0.9936
# Epoch 55/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0313 - accuracy: 0.9888
# Epoch 56/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0124 - accuracy: 0.9968
# Epoch 57/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 0.9952
# Epoch 58/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0443 - accuracy: 0.9872
# Epoch 59/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0356 - accuracy: 0.9904
# Epoch 60/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0194 - accuracy: 0.9904
# Epoch 61/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 0.9952
# Epoch 62/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0342 - accuracy: 0.9888
# Epoch 63/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0765 - accuracy: 0.9713
# Epoch 64/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0583 - accuracy: 0.9761
# Epoch 65/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0582 - accuracy: 0.9793
# Epoch 66/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 67/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0112 - accuracy: 0.9968
# Epoch 68/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0336 - accuracy: 0.9936
# Epoch 69/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 0.9920
# Epoch 70/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 0.9936
# Epoch 71/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 0.9984
# Epoch 72/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 0.9952
# Epoch 73/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0175 - accuracy: 0.9904
# Epoch 74/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0399 - accuracy: 0.9809
# Epoch 75/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0336 - accuracy: 0.9856
# Epoch 76/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0387 - accuracy: 0.9920
# Epoch 77/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0650 - accuracy: 0.9809
# Epoch 78/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0639 - accuracy: 0.9793
# Epoch 79/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0833 - accuracy: 0.9793
# Epoch 80/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0359 - accuracy: 0.9904
# Epoch 81/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0126 - accuracy: 0.9968
# Epoch 82/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 0.9952
# Epoch 83/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0197 - accuracy: 0.9936
# Epoch 84/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0190 - accuracy: 0.9936
# Epoch 85/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 0.9904
# Epoch 86/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0124 - accuracy: 0.9952
# Epoch 87/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 0.9968
# Epoch 88/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0839 - accuracy: 0.9729
# Epoch 89/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0212 - accuracy: 0.9936
# Epoch 90/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0361 - accuracy: 0.9888
# Epoch 91/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0609 - accuracy: 0.9872
# Epoch 92/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 93/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0190 - accuracy: 0.9920
# Epoch 94/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0164 - accuracy: 0.9968
# Epoch 95/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0364 - accuracy: 0.9872
# Epoch 96/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 0.9936
# Epoch 97/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0187 - accuracy: 0.9968
# Epoch 98/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0333 - accuracy: 0.9952
# Epoch 99/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0273 - accuracy: 0.9904
# Epoch 100/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0383 - accuracy: 0.9904
# Epoch 101/1500
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0178 - accuracy: 0.9961Restoring model weights from the end of the best epoch: 71.
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0170 - accuracy: 0.9952
# Epoch 101: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 3.1873 - accuracy: 0.6205
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.65 (17/26)
# Before appending - Cat IDs: 567, Predictions: 567, Actuals: 567, Gender: 567
# After appending - Cat IDs: 733, Predictions: 733, Actuals: 733, Gender: 733
# Final Test Results - Loss: 3.1872897148132324, Accuracy: 0.6204819083213806, Precision: 0.5961538461538461, Recall: 0.6603256122698529, F1 Score: 0.611837327523602
# Confusion Matrix:
#  [[51  8 35]
#  [ 3 10  1]
#  [14  2 42]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.620229474863333
#
# Final Average Loss across all UNSEEN TEST sets: 2.5498319268226624
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6455252915620804
#
# Final Average Precision across all UNSEEN TEST sets: 0.6477710038444502
#
# Final Average Recall across all UNSEEN TEST sets: 0.6247689251188167

# %%
seed_4_folds_values = [unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1]

seed_4_training_acc_values = cv_training_acc_total

# Plotting all fold metrics
seed_4_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 733, Predictions: 733, Actuals: 733, Gender: 733

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0

# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    192      144     75.00
# 1          M    286      163     56.99
# 2          X    242      161     66.53,   all_gender  count  correct  accuracy
# 0          F    192      134     69.79
# 1          M    290      159     54.83
# 2          X    235      137     58.30,   all_gender  count  correct  accuracy
# 0          F    192      125     65.10
# 1          M    289      171     59.17
# 2          X    232      152     65.52,   all_gender  count  correct  accuracy
# 0          F    211      156     73.93
# 1          M    286      164     57.34
# 2          X    236      157     66.53]

# %% [markdown]
# # RANDOM SEED 5

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[4]))
np.random.seed(int(random_seeds[4]))
tf.random.set_seed(int(random_seeds[4]))

# Load datasets
dataframe = pd.read_csv('perch_looped_embeddings.csv')


def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 10),
    'senior': (10, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     405
# senior    253
# kitten    135
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[4]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

cv_training_acc_total = []
cv_training_acc_best = []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )
    
    accuracy_history = AccuracyHistory()

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_val),
        y=y_train_val
    )
    weight_dict = {i: class_weights[i] for i in range(len(class_weights))}

    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adam': Adam(learning_rate=0.007402414884293732)
    }
    
    # Full model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(512, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.15688606637942396))  
    model_full.add(Dense(64, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.28869063762474007))  
    model_full.add(Dense(128, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.27322054853254163))   
    model_full.add(Dense(32, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.4064145271744943))  
    model_full.add(Dense(3, activation='softmax'))  
    
    optimizer = optimizers['Adam']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=32,
                                  verbose=1, callbacks=[early_stopping, accuracy_history], class_weight=weight_dict)
    
    
    # log epochs
    best_epoch_index = np.argmin(history_full.history['loss'])  
    best_training_accuracy = accuracy_history.acc[best_epoch_index]

    # Append training acc to total  
    all_best_training_acc.append(best_training_accuracy)
    total_training_acc.append(accuracy_history.acc)

    # Append training acc just for this CV
    cv_training_acc_total.append(accuracy_history.acc)
    cv_training_acc_best.append(best_training_accuracy)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
average_fold_f1.append(unseen_set_avg_f1)
average_fold_losses.append(unseen_set_avg_loss)
average_fold_accuracies.append(unseen_set_avg_acc)
average_fold_precisions.append(unseen_set_avg_precision)
average_fold_recalls.append(unseen_set_avg_recall)

# Append all to total lists
all_f1.append(unseen_f1)
all_losses.append(unseen_losses)
all_accuracies.append(unseen_accuracies)
all_precisions.append(unseen_precisions)
all_recalls.append(unseen_recalls)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 103A    33
# 002B    30
# 047A    22
# 000B    19
# 057A    17
# 097A    15
# 106A    13
# 002A    13
# 055A    12
# 101A    12
# 111A    12
# 051A    12
# 063A    11
# 067A    11
# 028A    11
# 014B    10
# 025A    10
# 059A    10
# 040A    10
# 071A     9
# 051B     9
# 065A     9
# 016A     9
# 072A     9
# 033A     9
# 001A     9
# 068A     8
# 013B     8
# 036A     7
# 117A     7
# 031A     7
# 095A     7
# 027A     7
# 099A     6
# 023A     6
# 044A     5
# 075A     5
# 050A     5
# 109A     5
# 025C     4
# 104A     4
# 009A     4
# 026A     4
# 023B     4
# 056A     3
# 105A     3
# 012A     3
# 010A     3
# 058A     3
# 006A     3
# 034A     3
# 113A     3
# 014A     3
# 062A     3
# 018A     2
# 093A     2
# 102A     2
# 061A     2
# 011A     2
# 035A     2
# 052A     2
# 038A     2
# 069A     2
# 087A     2
# 049A     1
# 024A     1
# 090A     1
# 100A     1
# 076A     1
# 115A     1
# 088A     1
# 043A     1
# 048A     1
# 066A     1
# 073A     1
# 064A     1
# 026C     1
# 096A     1
# 041A     1
# 092A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 020A    20
# 019A    17
# 074A    16
# 029A    15
# 097B    14
# 116A    12
# 042A    11
# 022A     9
# 005A     9
# 015A     7
# 039A     6
# 007A     6
# 008A     5
# 108A     5
# 070A     5
# 094A     5
# 021A     5
# 045A     4
# 003A     4
# 060A     3
# 053A     3
# 054A     2
# 032A     2
# 037A     2
# 025B     2
# 091A     1
# 004A     1
# 019B     1
# 110A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    216
# M    193
# F    152
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    93
# F    79
# X    60
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 033A, 071A, 067A, 062A, 002B, 095A, 034...
# kitten    [044A, 014B, 111A, 040A, 046A, 047A, 109A, 050...
# senior    [093A, 097A, 001A, 103A, 028A, 057A, 106A, 101...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000A, 097B, 019A, 074A, 020A, 022A, 029A, 005...
# kitten                                   [042A, 045A, 110A]
# senior    [015A, 091A, 039A, 116A, 054A, 008A, 094A, 060...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 45, 'kitten': 13, 'senior': 24}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 17, 'kitten': 3, 'senior': 10}
# Unique Training/Validation Group IDs:
# ['000B' '001A' '002A' '002B' '006A' '009A' '010A' '011A' '012A' '013B'
#  '014A' '014B' '016A' '018A' '023A' '023B' '024A' '025A' '025C' '026A'
#  '026B' '026C' '027A' '028A' '031A' '033A' '034A' '035A' '036A' '038A'
#  '040A' '041A' '043A' '044A' '046A' '047A' '048A' '049A' '050A' '051A'
#  '051B' '052A' '055A' '056A' '057A' '058A' '059A' '061A' '062A' '063A'
#  '064A' '065A' '066A' '067A' '068A' '069A' '071A' '072A' '073A' '075A'
#  '076A' '087A' '088A' '090A' '092A' '093A' '095A' '096A' '097A' '099A'
#  '100A' '101A' '102A' '103A' '104A' '105A' '106A' '109A' '111A' '113A'
#  '115A' '117A']
# Unique Test Group IDs:
# ['000A' '003A' '004A' '005A' '007A' '008A' '015A' '019A' '019B' '020A'
#  '021A' '022A' '025B' '029A' '032A' '037A' '039A' '042A' '045A' '053A'
#  '054A' '060A' '070A' '074A' '091A' '094A' '097B' '108A' '110A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'073A'}
# Moved to Test Set:
# {'073A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '006A' '009A' '010A' '011A' '012A'
#  '013B' '014A' '014B' '016A' '018A' '023A' '023B' '024A' '025A' '025C'
#  '026A' '026B' '026C' '027A' '028A' '031A' '033A' '034A' '035A' '036A'
#  '038A' '040A' '041A' '043A' '044A' '046A' '047A' '048A' '049A' '050A'
#  '051A' '051B' '052A' '055A' '056A' '057A' '058A' '059A' '061A' '062A'
#  '063A' '064A' '065A' '066A' '067A' '068A' '069A' '071A' '072A' '075A'
#  '076A' '087A' '088A' '090A' '092A' '093A' '095A' '096A' '097A' '099A'
#  '100A' '101A' '102A' '103A' '104A' '105A' '106A' '109A' '111A' '113A'
#  '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['003A' '004A' '005A' '007A' '008A' '015A' '019A' '019B' '020A' '021A'
#  '022A' '025B' '029A' '032A' '037A' '039A' '042A' '045A' '053A' '054A'
#  '060A' '070A' '073A' '074A' '091A' '094A' '097B' '108A' '110A' '116A']
# Length of X_train_val:
# 599
# Length of y_train_val:
# 599
# Length of groups_train_val:
# 599
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     238
# senior    204
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     167
# senior     49
# kitten     16
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     276
# senior    204
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     129
# senior     49
# kitten     16
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 276, 2: 204, 1: 119})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/1500
# 19/19 [==============================] - 1s 4ms/step - loss: 1.0145 - accuracy: 0.5526
# Epoch 2/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.4308 - accuracy: 0.8147
# Epoch 3/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2644 - accuracy: 0.8965
# Epoch 4/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2036 - accuracy: 0.9282
# Epoch 5/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1246 - accuracy: 0.9533
# Epoch 6/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1083 - accuracy: 0.9649
# Epoch 7/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1052 - accuracy: 0.9666
# Epoch 8/1500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0582 - accuracy: 0.9800
# Epoch 9/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0273 - accuracy: 0.9967
# Epoch 10/1500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0719 - accuracy: 0.9783
# Epoch 11/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0593 - accuracy: 0.9783
# Epoch 12/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0953 - accuracy: 0.9666
# Epoch 13/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0625 - accuracy: 0.9800
# Epoch 14/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0567 - accuracy: 0.9833
# Epoch 15/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0686 - accuracy: 0.9766
# Epoch 16/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1107 - accuracy: 0.9649
# Epoch 17/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0544 - accuracy: 0.9800
# Epoch 18/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0539 - accuracy: 0.9783
# Epoch 19/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0393 - accuracy: 0.9917
# Epoch 20/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0169 - accuracy: 0.9967
# Epoch 21/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0635 - accuracy: 0.9883
# Epoch 22/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0548 - accuracy: 0.9883
# Epoch 23/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0131 - accuracy: 0.9950
# Epoch 24/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0191 - accuracy: 0.9950
# Epoch 25/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 0.9983
# Epoch 26/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0312 - accuracy: 0.9900
# Epoch 27/1500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0662 - accuracy: 0.9783
# Epoch 28/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0823 - accuracy: 0.9766
# Epoch 29/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1169 - accuracy: 0.9750
# Epoch 30/1500
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0397 - accuracy: 0.9883
# Epoch 31/1500
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0484 - accuracy: 0.9850
# Epoch 32/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0610 - accuracy: 0.9850
# Epoch 33/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0212 - accuracy: 0.9917
# Epoch 34/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0251 - accuracy: 0.9917
# Epoch 35/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0226 - accuracy: 0.9900
# Epoch 36/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0329 - accuracy: 0.9883
# Epoch 37/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0236 - accuracy: 0.9917
# Epoch 38/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0229 - accuracy: 0.9950
# Epoch 39/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0294 - accuracy: 0.9900
# Epoch 40/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0227 - accuracy: 0.9950
# Epoch 41/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0734 - accuracy: 0.9816
# Epoch 42/1500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0398 - accuracy: 0.9900
# Epoch 43/1500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0267 - accuracy: 0.9850
# Epoch 44/1500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0325 - accuracy: 0.9883
# Epoch 45/1500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0339 - accuracy: 0.9917
# Epoch 46/1500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0202 - accuracy: 0.9917
# Epoch 47/1500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0177 - accuracy: 0.9900
# Epoch 48/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0195 - accuracy: 0.9950
# Epoch 49/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 50/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 0.9917
# Epoch 51/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 0.9983
# Epoch 52/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0382 - accuracy: 0.9866
# Epoch 53/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0403 - accuracy: 0.9900
# Epoch 54/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 0.9950
# Epoch 55/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 0.9967
# Epoch 56/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0581 - accuracy: 0.9917
# Epoch 57/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0124 - accuracy: 0.9967
# Epoch 58/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 0.9933
# Epoch 59/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0089 - accuracy: 0.9983
# Epoch 60/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0435 - accuracy: 0.9917
# Epoch 61/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0464 - accuracy: 0.9833
# Epoch 62/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0633 - accuracy: 0.9766
# Epoch 63/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0327 - accuracy: 0.9900
# Epoch 64/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0324 - accuracy: 0.9900
# Epoch 65/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 0.9983
# Epoch 66/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 0.9967
# Epoch 67/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 0.9983
# Epoch 68/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 0.9950
# Epoch 69/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 0.9950
# Epoch 70/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0192 - accuracy: 0.9917
# Epoch 71/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0324 - accuracy: 0.9917
# Epoch 72/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0131 - accuracy: 0.9967
# Epoch 73/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0197 - accuracy: 0.9917
# Epoch 74/1500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0190 - accuracy: 0.9883
# Epoch 75/1500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 0.9950
# Epoch 76/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0652 - accuracy: 0.9900
# Epoch 77/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0235 - accuracy: 0.9967
# Epoch 78/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0683 - accuracy: 0.9850
# Epoch 79/1500
# 15/19 [======================>.......] - ETA: 0s - loss: 0.0249 - accuracy: 0.9875Restoring model weights from the end of the best epoch: 49.
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0277 - accuracy: 0.9866
# Epoch 79: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 3.7265 - accuracy: 0.5464
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.57 (17/30)
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 194, Predictions: 194, Actuals: 194, Gender: 194
# Final Test Results - Loss: 3.7265336513519287, Accuracy: 0.5463917255401611, Precision: 0.42214067278287465, Recall: 0.42430654432315557, F1 Score: 0.4121296161144358
# Confusion Matrix:
#  [[77  6 46]
#  [12  2  2]
#  [20  2 27]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 002A    13
# 055A    12
# 101A    12
# 051A    12
# 116A    12
# 028A    11
# 042A    11
# 063A    11
# 067A    11
# 025A    10
# 059A    10
# 014B    10
# 001A     9
# 072A     9
# 071A     9
# 065A     9
# 051B     9
# 005A     9
# 022A     9
# 033A     9
# 013B     8
# 068A     8
# 027A     7
# 095A     7
# 015A     7
# 117A     7
# 007A     6
# 099A     6
# 039A     6
# 108A     5
# 021A     5
# 075A     5
# 070A     5
# 050A     5
# 008A     5
# 094A     5
# 009A     4
# 104A     4
# 045A     4
# 003A     4
# 026A     4
# 056A     3
# 060A     3
# 053A     3
# 006A     3
# 113A     3
# 014A     3
# 034A     3
# 105A     3
# 037A     2
# 035A     2
# 052A     2
# 038A     2
# 018A     2
# 069A     2
# 025B     2
# 032A     2
# 054A     2
# 102A     2
# 019B     1
# 110A     1
# 100A     1
# 090A     1
# 091A     1
# 004A     1
# 048A     1
# 066A     1
# 073A     1
# 043A     1
# 076A     1
# 096A     1
# 024A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 106A    13
# 111A    12
# 040A    10
# 016A     9
# 031A     7
# 036A     7
# 023A     6
# 109A     5
# 044A     5
# 025C     4
# 023B     4
# 058A     3
# 062A     3
# 010A     3
# 012A     3
# 011A     2
# 087A     2
# 093A     2
# 061A     2
# 115A     1
# 088A     1
# 064A     1
# 026C     1
# 041A     1
# 092A     1
# 049A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    225
# F    221
# M    204
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    82
# X    51
# F    10
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 071A, 097B, 019A, 074A, 067...
# kitten    [014B, 046A, 047A, 042A, 050A, 043A, 045A, 048...
# senior    [015A, 097A, 001A, 028A, 057A, 101A, 104A, 055...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [062A, 023A, 087A, 031A, 036A, 064A, 023B, 092...
# kitten           [044A, 111A, 040A, 109A, 049A, 041A, 115A]
# senior     [093A, 103A, 106A, 025C, 058A, 016A, 011A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 49, 'kitten': 9, 'senior': 26}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 13, 'kitten': 7, 'senior': 8}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '013B' '014A' '014B' '015A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '024A' '025A' '025B' '026A' '027A' '028A' '029A' '032A'
#  '033A' '034A' '035A' '037A' '038A' '039A' '042A' '043A' '045A' '046A'
#  '047A' '048A' '050A' '051A' '051B' '052A' '053A' '054A' '055A' '056A'
#  '057A' '059A' '060A' '063A' '065A' '066A' '067A' '068A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '075A' '076A' '090A' '091A' '094A' '095A'
#  '096A' '097A' '097B' '099A' '100A' '101A' '102A' '104A' '105A' '108A'
#  '110A' '113A' '116A' '117A']
# Unique Test Group IDs:
# ['010A' '011A' '012A' '016A' '023A' '023B' '025C' '026B' '026C' '031A'
#  '036A' '040A' '041A' '044A' '049A' '058A' '061A' '062A' '064A' '087A'
#  '088A' '092A' '093A' '103A' '106A' '109A' '111A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '013B' '014A' '014B' '015A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '024A' '025A' '025B' '026A' '027A' '028A' '029A' '032A'
#  '033A' '034A' '035A' '037A' '038A' '039A' '042A' '043A' '045A' '046A'
#  '047A' '048A' '050A' '051A' '051B' '052A' '053A' '054A' '055A' '056A'
#  '057A' '059A' '060A' '063A' '065A' '066A' '067A' '068A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '075A' '076A' '090A' '091A' '094A' '095A'
#  '096A' '097A' '097B' '099A' '100A' '101A' '102A' '104A' '105A' '108A'
#  '110A' '113A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['010A' '011A' '012A' '016A' '023A' '023B' '025C' '026B' '026C' '031A'
#  '036A' '040A' '041A' '044A' '049A' '058A' '061A' '062A' '064A' '087A'
#  '088A' '092A' '093A' '103A' '106A' '109A' '111A' '115A']
# Length of X_train_val:
# 650
# Length of y_train_val:
# 650
# Length of groups_train_val:
# 650
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     365
# senior    185
# kitten    100
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# senior    68
# adult     40
# kitten    35
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     365
# senior    185
# kitten    100
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# senior    68
# adult     40
# kitten    35
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 365, 2: 185, 1: 100})
# Epoch 1/1500
# 21/21 [==============================] - 1s 3ms/step - loss: 1.1224 - accuracy: 0.4938
# Epoch 2/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5609 - accuracy: 0.7231
# Epoch 3/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3457 - accuracy: 0.8446
# Epoch 4/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.2429 - accuracy: 0.9185
# Epoch 5/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.2269 - accuracy: 0.8985
# Epoch 6/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1491 - accuracy: 0.9431
# Epoch 7/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1144 - accuracy: 0.9569
# Epoch 8/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1072 - accuracy: 0.9538
# Epoch 9/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0973 - accuracy: 0.9677
# Epoch 10/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0676 - accuracy: 0.9754
# Epoch 11/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.1244 - accuracy: 0.9523
# Epoch 12/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1553 - accuracy: 0.9431
# Epoch 13/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0552 - accuracy: 0.9846
# Epoch 14/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0590 - accuracy: 0.9846
# Epoch 15/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0818 - accuracy: 0.9800
# Epoch 16/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0843 - accuracy: 0.9754
# Epoch 17/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0609 - accuracy: 0.9785
# Epoch 18/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1433 - accuracy: 0.9585
# Epoch 19/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0587 - accuracy: 0.9862
# Epoch 20/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0566 - accuracy: 0.9862
# Epoch 21/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0579 - accuracy: 0.9785
# Epoch 22/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0428 - accuracy: 0.9815
# Epoch 23/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0646 - accuracy: 0.9785
# Epoch 24/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0525 - accuracy: 0.9831
# Epoch 25/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0385 - accuracy: 0.9785
# Epoch 26/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0464 - accuracy: 0.9815
# Epoch 27/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0242 - accuracy: 0.9938
# Epoch 28/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0252 - accuracy: 0.9938
# Epoch 29/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0307 - accuracy: 0.9892
# Epoch 30/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1043 - accuracy: 0.9677
# Epoch 31/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1204 - accuracy: 0.9646
# Epoch 32/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1013 - accuracy: 0.9692
# Epoch 33/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0899 - accuracy: 0.9662
# Epoch 34/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0387 - accuracy: 0.9877
# Epoch 35/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0406 - accuracy: 0.9862
# Epoch 36/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0310 - accuracy: 0.9892
# Epoch 37/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0713 - accuracy: 0.9723
# Epoch 38/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0600 - accuracy: 0.9769
# Epoch 39/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0504 - accuracy: 0.9831
# Epoch 40/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0454 - accuracy: 0.9831
# Epoch 41/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 0.9769
# Epoch 42/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0707 - accuracy: 0.9754
# Epoch 43/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0468 - accuracy: 0.9815
# Epoch 44/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0766 - accuracy: 0.9708
# Epoch 45/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0594 - accuracy: 0.9831
# Epoch 46/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0458 - accuracy: 0.9877
# Epoch 47/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0675 - accuracy: 0.9708
# Epoch 48/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0613 - accuracy: 0.9892
# Epoch 49/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0542 - accuracy: 0.9800
# Epoch 50/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0311 - accuracy: 0.9908
# Epoch 51/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0389 - accuracy: 0.9846
# Epoch 52/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0113 - accuracy: 0.9938
# Epoch 53/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0118 - accuracy: 0.9969
# Epoch 54/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0434 - accuracy: 0.9846
# Epoch 55/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0465 - accuracy: 0.9846
# Epoch 56/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0392 - accuracy: 0.9908
# Epoch 57/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1063 - accuracy: 0.9769
# Epoch 58/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0948 - accuracy: 0.9615
# Epoch 59/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0525 - accuracy: 0.9800
# Epoch 60/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0238 - accuracy: 0.9908
# Epoch 61/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0422 - accuracy: 0.9938
# Epoch 62/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0516 - accuracy: 0.9846
# Epoch 63/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0206 - accuracy: 0.9908
# Epoch 64/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0234 - accuracy: 0.9938
# Epoch 65/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0237 - accuracy: 0.9892
# Epoch 66/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 0.9985
# Epoch 67/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0251 - accuracy: 0.9938
# Epoch 68/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.9985
# Epoch 69/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 0.9892
# Epoch 70/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0071 - accuracy: 0.9969
# Epoch 71/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0557 - accuracy: 0.9862
# Epoch 72/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0250 - accuracy: 0.9938
# Epoch 73/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0326 - accuracy: 0.9862
# Epoch 74/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0525 - accuracy: 0.9892
# Epoch 75/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 0.9892
# Epoch 76/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0201 - accuracy: 0.9954
# Epoch 77/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0396 - accuracy: 0.9862
# Epoch 78/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0302 - accuracy: 0.9892
# Epoch 79/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 0.9954
# Epoch 80/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0284 - accuracy: 0.9938
# Epoch 81/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0687 - accuracy: 0.9708
# Epoch 82/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0474 - accuracy: 0.9800
# Epoch 83/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0398 - accuracy: 0.9846
# Epoch 84/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 0.9923
# Epoch 85/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0206 - accuracy: 0.9923
# Epoch 86/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0342 - accuracy: 0.9908
# Epoch 87/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0496 - accuracy: 0.9846
# Epoch 88/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0366 - accuracy: 0.9892
# Epoch 89/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0280 - accuracy: 0.9954
# Epoch 90/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0183 - accuracy: 0.9938
# Epoch 91/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0184 - accuracy: 0.9969
# Epoch 92/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0268 - accuracy: 0.9938
# Epoch 93/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0254 - accuracy: 0.9923
# Epoch 94/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0216 - accuracy: 0.9954
# Epoch 95/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 0.9954
# Epoch 96/1500
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0124 - accuracy: 0.9985
# Epoch 97/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 0.9923
# Epoch 98/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 0.9954
# Epoch 99/1500
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0407 - accuracy: 0.9954
# Epoch 100/1500
# 16/21 [=====================>........] - ETA: 0s - loss: 0.0065 - accuracy: 0.9980    Restoring model weights from the end of the best epoch: 70.
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 0.9969
# Epoch 100: early stopping
# 5/5 [==============================] - 0s 1ms/step - loss: 2.4348 - accuracy: 0.5944
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.61 (17/28)
# Before appending - Cat IDs: 194, Predictions: 194, Actuals: 194, Gender: 194
# After appending - Cat IDs: 337, Predictions: 337, Actuals: 337, Gender: 337
# Final Test Results - Loss: 2.4348368644714355, Accuracy: 0.5944055914878845, Precision: 0.7078144226738603, Recall: 0.6488795518207283, F1 Score: 0.6247162088356751
# Confusion Matrix:
#  [[34  0  6]
#  [ 9 25  1]
#  [40  2 26]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 047A    22
# 020A    20
# 019A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 002A    13
# 106A    13
# 116A    12
# 101A    12
# 111A    12
# 042A    11
# 063A    11
# 025A    10
# 040A    10
# 059A    10
# 014B    10
# 071A     9
# 051B     9
# 016A     9
# 022A     9
# 033A     9
# 005A     9
# 001A     9
# 013B     8
# 117A     7
# 031A     7
# 036A     7
# 015A     7
# 023A     6
# 039A     6
# 099A     6
# 007A     6
# 050A     5
# 109A     5
# 094A     5
# 070A     5
# 008A     5
# 021A     5
# 108A     5
# 044A     5
# 003A     4
# 025C     4
# 045A     4
# 104A     4
# 023B     4
# 060A     3
# 012A     3
# 053A     3
# 010A     3
# 006A     3
# 058A     3
# 062A     3
# 034A     3
# 052A     2
# 061A     2
# 037A     2
# 011A     2
# 025B     2
# 102A     2
# 087A     2
# 093A     2
# 032A     2
# 054A     2
# 110A     1
# 090A     1
# 024A     1
# 115A     1
# 064A     1
# 066A     1
# 019B     1
# 088A     1
# 004A     1
# 073A     1
# 091A     1
# 026C     1
# 041A     1
# 092A     1
# 049A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 002B    30
# 000B    19
# 057A    17
# 055A    12
# 051A    12
# 028A    11
# 067A    11
# 072A     9
# 065A     9
# 068A     8
# 095A     7
# 027A     7
# 075A     5
# 026A     4
# 009A     4
# 113A     3
# 105A     3
# 014A     3
# 056A     3
# 069A     2
# 018A     2
# 038A     2
# 035A     2
# 076A     1
# 096A     1
# 043A     1
# 048A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    232
# M    219
# F    152
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    79
# M    67
# X    44
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 071A, 097B, 019A, 074A, 020...
# kitten    [044A, 014B, 111A, 040A, 046A, 047A, 042A, 109...
# senior    [093A, 015A, 097A, 001A, 103A, 106A, 101A, 104...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [067A, 002B, 095A, 072A, 065A, 009A, 027A, 038...
# kitten                                         [043A, 048A]
# senior                 [028A, 057A, 055A, 113A, 056A, 051A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 42, 'kitten': 14, 'senior': 28}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 20, 'kitten': 2, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '003A' '004A' '005A' '006A' '007A' '008A' '010A'
#  '011A' '012A' '013B' '014B' '015A' '016A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '023B' '024A' '025A' '025B' '025C' '026B' '026C' '029A'
#  '031A' '032A' '033A' '034A' '036A' '037A' '039A' '040A' '041A' '042A'
#  '044A' '045A' '046A' '047A' '049A' '050A' '051B' '052A' '053A' '054A'
#  '058A' '059A' '060A' '061A' '062A' '063A' '064A' '066A' '070A' '071A'
#  '073A' '074A' '087A' '088A' '090A' '091A' '092A' '093A' '094A' '097A'
#  '097B' '099A' '101A' '102A' '103A' '104A' '106A' '108A' '109A' '110A'
#  '111A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000B' '002B' '009A' '014A' '018A' '026A' '027A' '028A' '035A' '038A'
#  '043A' '048A' '051A' '055A' '056A' '057A' '065A' '067A' '068A' '069A'
#  '072A' '075A' '076A' '095A' '096A' '100A' '105A' '113A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '003A' '004A' '005A' '006A' '007A' '008A' '010A'
#  '011A' '012A' '013B' '014B' '015A' '016A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '023B' '024A' '025A' '025B' '025C' '026B' '026C' '029A'
#  '031A' '032A' '033A' '034A' '036A' '037A' '039A' '040A' '041A' '042A'
#  '044A' '045A' '046A' '047A' '049A' '050A' '051B' '052A' '053A' '054A'
#  '058A' '059A' '060A' '061A' '062A' '063A' '064A' '066A' '070A' '071A'
#  '073A' '074A' '087A' '088A' '090A' '091A' '092A' '093A' '094A' '097A'
#  '097B' '099A' '101A' '102A' '103A' '104A' '106A' '108A' '109A' '110A'
#  '111A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002B' '009A' '014A' '018A' '026A' '027A' '028A' '035A' '038A'
#  '043A' '048A' '051A' '055A' '056A' '057A' '065A' '067A' '068A' '069A'
#  '072A' '075A' '076A' '095A' '096A' '100A' '105A' '113A']
# Length of X_train_val:
# 603
# Length of y_train_val:
# 603
# Length of groups_train_val:
# 603
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     275
# senior    195
# kitten    133
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     130
# senior     58
# kitten      2
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     275
# senior    195
# kitten    133
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     130
# senior     58
# kitten      2
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 275, 2: 195, 1: 133})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/1500
# 19/19 [==============================] - 1s 3ms/step - loss: 0.9848 - accuracy: 0.5622
# Epoch 2/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.5483 - accuracy: 0.7380
# Epoch 3/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2966 - accuracy: 0.8690
# Epoch 4/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2168 - accuracy: 0.9088
# Epoch 5/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1452 - accuracy: 0.9502
# Epoch 6/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1403 - accuracy: 0.9403
# Epoch 7/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0758 - accuracy: 0.9718
# Epoch 8/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1320 - accuracy: 0.9602
# Epoch 9/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1418 - accuracy: 0.9403
# Epoch 10/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0850 - accuracy: 0.9768
# Epoch 11/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0675 - accuracy: 0.9685
# Epoch 12/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1139 - accuracy: 0.9602
# Epoch 13/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1161 - accuracy: 0.9652
# Epoch 14/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1026 - accuracy: 0.9701
# Epoch 15/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0611 - accuracy: 0.9834
# Epoch 16/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0418 - accuracy: 0.9867
# Epoch 17/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0381 - accuracy: 0.9867
# Epoch 18/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 0.9934
# Epoch 19/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0430 - accuracy: 0.9801
# Epoch 20/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0510 - accuracy: 0.9818
# Epoch 21/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0661 - accuracy: 0.9751
# Epoch 22/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0459 - accuracy: 0.9834
# Epoch 23/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0800 - accuracy: 0.9768
# Epoch 24/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0429 - accuracy: 0.9900
# Epoch 25/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0582 - accuracy: 0.9851
# Epoch 26/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0364 - accuracy: 0.9851
# Epoch 27/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0955 - accuracy: 0.9718
# Epoch 28/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0520 - accuracy: 0.9834
# Epoch 29/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0547 - accuracy: 0.9834
# Epoch 30/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0150 - accuracy: 0.9983
# Epoch 31/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0313 - accuracy: 0.9917
# Epoch 32/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0415 - accuracy: 0.9834
# Epoch 33/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0463 - accuracy: 0.9818
# Epoch 34/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0342 - accuracy: 0.9851
# Epoch 35/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0298 - accuracy: 0.9950
# Epoch 36/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 0.9917
# Epoch 37/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 38/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0341 - accuracy: 0.9900
# Epoch 39/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 0.9934
# Epoch 40/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 0.9967
# Epoch 41/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 0.9950
# Epoch 42/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 0.9917
# Epoch 43/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0243 - accuracy: 0.9967
# Epoch 44/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0363 - accuracy: 0.9900
# Epoch 45/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0576 - accuracy: 0.9851
# Epoch 46/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0433 - accuracy: 0.9834
# Epoch 47/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0284 - accuracy: 0.9917
# Epoch 48/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0247 - accuracy: 0.9934
# Epoch 49/1500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0287 - accuracy: 0.9917
# Epoch 50/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 0.9967
# Epoch 51/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 52/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0121 - accuracy: 0.9950
# Epoch 53/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0148 - accuracy: 0.9934
# Epoch 54/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0479 - accuracy: 0.9851
# Epoch 55/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0525 - accuracy: 0.9818
# Epoch 56/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0609 - accuracy: 0.9784
# Epoch 57/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0281 - accuracy: 0.9900
# Epoch 58/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0266 - accuracy: 0.9917
# Epoch 59/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0974 - accuracy: 0.9818
# Epoch 60/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0886 - accuracy: 0.9701
# Epoch 61/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0524 - accuracy: 0.9867
# Epoch 62/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0433 - accuracy: 0.9884
# Epoch 63/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0273 - accuracy: 0.9950
# Epoch 64/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0461 - accuracy: 0.9867
# Epoch 65/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0250 - accuracy: 0.9917
# Epoch 66/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0158 - accuracy: 0.9950
# Epoch 67/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0350 - accuracy: 0.9867
# Epoch 68/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 0.9983
# Epoch 69/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0360 - accuracy: 0.9900
# Epoch 70/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0486 - accuracy: 0.9884
# Epoch 71/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0105 - accuracy: 0.9967
# Epoch 72/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0229 - accuracy: 0.9950
# Epoch 73/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0399 - accuracy: 0.9884
# Epoch 74/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0334 - accuracy: 0.9867
# Epoch 75/1500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0299 - accuracy: 0.9917
# Epoch 76/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0529 - accuracy: 0.9851
# Epoch 77/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 0.9934
# Epoch 78/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0153 - accuracy: 0.9950
# Epoch 79/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0186 - accuracy: 0.9884
# Epoch 80/1500
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0415 - accuracy: 0.9900
# Epoch 81/1500
# 16/19 [========================>.....] - ETA: 0s - loss: 0.0295 - accuracy: 0.9922Restoring model weights from the end of the best epoch: 51.
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0253 - accuracy: 0.9934
# Epoch 81: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 1.9077 - accuracy: 0.7000
# 6/6 [==============================] - 0s 924us/step
# Majority Vote Accuracy for cat_id for this fold: 0.86 (24/28)
# Before appending - Cat IDs: 337, Predictions: 337, Actuals: 337, Gender: 337
# After appending - Cat IDs: 527, Predictions: 527, Actuals: 527, Gender: 527
# Final Test Results - Loss: 1.9076932668685913, Accuracy: 0.699999988079071, Precision: 0.5441396725879485, Recall: 0.8315649867374005, F1 Score: 0.5570838145244842
# Confusion Matrix:
#  [[80 13 37]
#  [ 0  2  0]
#  [ 7  0 51]]
# outer_fold 4
# Train Set Group Distribution:
# 000A    39
# 103A    33
# 002B    30
# 020A    20
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 029A    15
# 097B    14
# 106A    13
# 111A    12
# 051A    12
# 116A    12
# 055A    12
# 042A    11
# 028A    11
# 067A    11
# 040A    10
# 016A     9
# 022A     9
# 072A     9
# 065A     9
# 005A     9
# 068A     8
# 036A     7
# 031A     7
# 015A     7
# 095A     7
# 027A     7
# 007A     6
# 023A     6
# 039A     6
# 021A     5
# 070A     5
# 008A     5
# 094A     5
# 075A     5
# 108A     5
# 109A     5
# 044A     5
# 023B     4
# 003A     4
# 026A     4
# 025C     4
# 009A     4
# 045A     4
# 010A     3
# 105A     3
# 060A     3
# 062A     3
# 113A     3
# 056A     3
# 012A     3
# 058A     3
# 014A     3
# 053A     3
# 037A     2
# 061A     2
# 035A     2
# 032A     2
# 025B     2
# 018A     2
# 054A     2
# 069A     2
# 087A     2
# 038A     2
# 093A     2
# 011A     2
# 110A     1
# 115A     1
# 004A     1
# 019B     1
# 100A     1
# 088A     1
# 076A     1
# 048A     1
# 026C     1
# 041A     1
# 092A     1
# 049A     1
# 064A     1
# 043A     1
# 096A     1
# 091A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    45
# 047A    22
# 097A    15
# 002A    13
# 101A    12
# 063A    11
# 059A    10
# 025A    10
# 014B    10
# 051B     9
# 071A     9
# 001A     9
# 033A     9
# 013B     8
# 117A     7
# 099A     6
# 050A     5
# 104A     4
# 006A     3
# 034A     3
# 052A     2
# 102A     2
# 073A     1
# 066A     1
# 090A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    242
# F    168
# X    155
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    121
# F     63
# M     44
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [000A, 097B, 019A, 074A, 067A, 020A, 062A, 002...
# kitten    [044A, 111A, 040A, 042A, 109A, 043A, 049A, 041...
# senior    [093A, 015A, 103A, 028A, 057A, 106A, 055A, 091...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 033A, 071A, 034A, 002A, 063A, 013B, 099...
# kitten                             [014B, 046A, 047A, 050A]
# senior    [097A, 001A, 101A, 104A, 059A, 025A, 051B, 117...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 50, 'kitten': 12, 'senior': 24}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 12, 'kitten': 4, 'senior': 10}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002B' '003A' '004A' '005A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '014A' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '023B' '025B' '025C' '026A' '026B' '026C' '027A' '028A'
#  '029A' '031A' '032A' '035A' '036A' '037A' '038A' '039A' '040A' '041A'
#  '042A' '043A' '044A' '045A' '048A' '049A' '051A' '053A' '054A' '055A'
#  '056A' '057A' '058A' '060A' '061A' '062A' '064A' '065A' '067A' '068A'
#  '069A' '070A' '072A' '074A' '075A' '076A' '087A' '088A' '091A' '092A'
#  '093A' '094A' '095A' '096A' '097B' '100A' '103A' '105A' '106A' '108A'
#  '109A' '110A' '111A' '113A' '115A' '116A']
# Unique Test Group IDs:
# ['001A' '002A' '006A' '013B' '014B' '024A' '025A' '033A' '034A' '046A'
#  '047A' '050A' '051B' '052A' '059A' '063A' '066A' '071A' '073A' '090A'
#  '097A' '099A' '101A' '102A' '104A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'115A'}
# Moved to Test Set:
# {'115A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002B' '003A' '004A' '005A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '014A' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '023B' '025B' '025C' '026A' '026B' '026C' '027A' '028A'
#  '029A' '031A' '032A' '035A' '036A' '037A' '038A' '039A' '040A' '041A'
#  '042A' '043A' '044A' '045A' '046A' '048A' '049A' '051A' '053A' '054A'
#  '055A' '056A' '057A' '058A' '060A' '061A' '062A' '064A' '065A' '067A'
#  '068A' '069A' '070A' '072A' '074A' '075A' '076A' '087A' '088A' '091A'
#  '092A' '093A' '094A' '095A' '096A' '097B' '100A' '103A' '105A' '106A'
#  '108A' '109A' '110A' '111A' '113A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002A' '006A' '013B' '014B' '024A' '025A' '033A' '034A' '047A'
#  '050A' '051B' '052A' '059A' '063A' '066A' '071A' '073A' '090A' '097A'
#  '099A' '101A' '102A' '104A' '115A' '117A']
# Length of X_train_val:
# 609
# Length of y_train_val:
# 609
# Length of groups_train_val:
# 609
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     337
# senior    175
# kitten     53
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# kitten    82
# senior    78
# adult     68
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     337
# senior    175
# kitten     97
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# senior    78
# adult     68
# kitten    38
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 337, 2: 175, 1: 97})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/1500
# 20/20 [==============================] - 1s 4ms/step - loss: 1.0435 - accuracy: 0.5304
# Epoch 2/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5828 - accuracy: 0.7471
# Epoch 3/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3545 - accuracy: 0.8473
# Epoch 4/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2965 - accuracy: 0.8588
# Epoch 5/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1857 - accuracy: 0.9245
# Epoch 6/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.9573
# Epoch 7/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1035 - accuracy: 0.9672
# Epoch 8/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1167 - accuracy: 0.9524
# Epoch 9/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0942 - accuracy: 0.9606
# Epoch 10/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1322 - accuracy: 0.9458
# Epoch 11/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0908 - accuracy: 0.9688
# Epoch 12/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1253 - accuracy: 0.9606
# Epoch 13/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0574 - accuracy: 0.9737
# Epoch 14/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0474 - accuracy: 0.9869
# Epoch 15/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0998 - accuracy: 0.9672
# Epoch 16/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1227 - accuracy: 0.9557
# Epoch 17/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0963 - accuracy: 0.9606
# Epoch 18/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0741 - accuracy: 0.9754
# Epoch 19/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0541 - accuracy: 0.9869
# Epoch 20/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0805 - accuracy: 0.9754
# Epoch 21/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0432 - accuracy: 0.9852
# Epoch 22/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0456 - accuracy: 0.9836
# Epoch 23/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0253 - accuracy: 0.9901
# Epoch 24/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0206 - accuracy: 0.9934
# Epoch 25/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 0.9934
# Epoch 26/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0441 - accuracy: 0.9869
# Epoch 27/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0410 - accuracy: 0.9869
# Epoch 28/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0710 - accuracy: 0.9704
# Epoch 29/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0646 - accuracy: 0.9704
# Epoch 30/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0787 - accuracy: 0.9704
# Epoch 31/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0398 - accuracy: 0.9885
# Epoch 32/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0448 - accuracy: 0.9836
# Epoch 33/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0538 - accuracy: 0.9803
# Epoch 34/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0372 - accuracy: 0.9852
# Epoch 35/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0500 - accuracy: 0.9885
# Epoch 36/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0302 - accuracy: 0.9869
# Epoch 37/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0390 - accuracy: 0.9918
# Epoch 38/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0480 - accuracy: 0.9803
# Epoch 39/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0213 - accuracy: 0.9967
# Epoch 40/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0309 - accuracy: 0.9885
# Epoch 41/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0588 - accuracy: 0.9869
# Epoch 42/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0590 - accuracy: 0.9787
# Epoch 43/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0280 - accuracy: 0.9901
# Epoch 44/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0398 - accuracy: 0.9901
# Epoch 45/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0658 - accuracy: 0.9688
# Epoch 46/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0684 - accuracy: 0.9803
# Epoch 47/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0264 - accuracy: 0.9901
# Epoch 48/1500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0528 - accuracy: 0.9852
# Epoch 49/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0382 - accuracy: 0.9901
# Epoch 50/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0172 - accuracy: 0.9951
# Epoch 51/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0553 - accuracy: 0.9770
# Epoch 52/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0319 - accuracy: 0.9869
# Epoch 53/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0315 - accuracy: 0.9934
# Epoch 54/1500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0545 - accuracy: 0.9852
# Epoch 55/1500
# 15/20 [=====================>........] - ETA: 0s - loss: 0.0147 - accuracy: 0.9979Restoring model weights from the end of the best epoch: 25.
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0150 - accuracy: 0.9967
# Epoch 55: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 1.8232 - accuracy: 0.6522
# 6/6 [==============================] - 0s 953us/step
# Majority Vote Accuracy for cat_id for this fold: 0.81 (21/26)
# Before appending - Cat IDs: 527, Predictions: 527, Actuals: 527, Gender: 527
# After appending - Cat IDs: 711, Predictions: 711, Actuals: 711, Gender: 711
# Final Test Results - Loss: 1.823183298110962, Accuracy: 0.6521739363670349, Precision: 0.7203215698361328, Recall: 0.6148620041808895, F1 Score: 0.6294029992238279
# Confusion Matrix:
#  [[55  2 11]
#  [21 15  2]
#  [27  1 50]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5558331596746058
#
# Final Average Loss across all UNSEEN TEST sets: 2.4730617702007294
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6232428103685379
#
# Final Average Precision across all UNSEEN TEST sets: 0.5986040844702041
#
# Final Average Recall across all UNSEEN TEST sets: 0.6299032717655435

# %%
seed_5_folds_values = [unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1]

seed_5_training_acc_values = cv_training_acc_total

# Plotting all fold metrics|
seed_5_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 711, Predictions: 711, Actuals: 711, Gender: 711

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.71 (78/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 69    063A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 80    074A  [senior, adult, kitten, adult, senior, senior,...         adult            adult                   True
# 79    073A                                    [senior, adult]         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, senior, ad...         adult            adult                   True
#
# 710   115A              kitten           kitten          X     True
#
# [711 rows x 5 columns]

# %% [markdown]
# ## Detailed Class Statistics

# %%
# For each fold
fold_class_stats = full_results.groupby('actual_age_group').agg(
    accuracy=('correct', lambda x: x.mean() * 100),
    total_count=('correct', 'size')
).reset_index()

# Store for final evaluation 
all_class_stats.append(fold_class_stats)

# Log the detailed stats
print("Detailed Class Statistics for this fold:")
print(fold_class_stats)
# Out:
# Detailed Class Statistics for this fold:
#   actual_age_group   accuracy  total_count
# 0            adult  67.029973          367
# 1           kitten  48.351648           91
# 2           senior  60.869565          253

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(fold_class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    192      144     75.00
# 1          M    286      155     54.20
# 2          X    233      145     62.23

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats) 
print("Total Majority Vote Statistics so far:\n", all_majority_vote_details) 
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.6909090909090909, 0.6363636363636364, 0.6818181818181818, 0.6818181818181818, 0.7090909090909091]
# Total Class Statistics so far:
#  [  actual_age_group   accuracy  total_count
# 0            adult  67.574932          367
# 1           kitten  59.000000          100
# 2           senior  63.636364          253,   actual_age_group   accuracy  total_count
# 0            adult  64.324324          370
# 1           kitten  44.680851           94
# 2           senior  59.288538          253,   actual_age_group   accuracy  total_count
# 0            adult  68.834688          369
# 1           kitten  53.846154           91
# 2           senior  57.312253          253,   actual_age_group   accuracy  total_count
# 0            adult  72.467532          385
# 1           kitten  56.842105           95
# 2           senior  56.916996          253,   actual_age_group   accuracy  total_count
# 0            adult  67.029973          367
# 1           kitten  48.351648           91
# 2           senior  60.869565          253]
# Total Majority Vote Statistics so far:
#  [  actual_age_group   accuracy  total_count
# 0            adult  72.131148           61
# 1           kitten  73.333333           15
# 2           senior  61.764706           34,   actual_age_group   accuracy  total_count
# 0            adult  68.852459           61
# 1           kitten  53.333333           15
# 2           senior  58.823529           34,   actual_age_group   accuracy  total_count
# 0            adult  72.131148           61
# 1           kitten  80.000000           15
# 2           senior  55.882353           34,   actual_age_group   accuracy  total_count
# 0            adult  72.131148           61
# 1           kitten  86.666667           15
# 2           senior  52.941176           34,   actual_age_group   accuracy  total_count
# 0            adult  80.327869           61
# 1           kitten  60.000000           15
# 2           senior  58.823529           34]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    192      144     75.00
# 1          M    286      163     56.99
# 2          X    242      161     66.53,   all_gender  count  correct  accuracy
# 0          F    192      134     69.79
# 1          M    290      159     54.83
# 2          X    235      137     58.30,   all_gender  count  correct  accuracy
# 0          F    192      125     65.10
# 1          M    289      171     59.17
# 2          X    232      152     65.52,   all_gender  count  correct  accuracy
# 0          F    211      156     73.93
# 1          M    286      164     57.34
# 2          X    236      157     66.53,   all_gender  count  correct  accuracy
# 0          F    192      144     75.00
# 1          M    286      155     54.20
# 2          X    233      145     62.23]

# %% [markdown]
# # --------------

# %% [markdown]
# # Total Final Results & Analysis

# %%
# Count unique cat_id per age group 
unique_cats_per_age_group = dataframe.groupby('age_group')['cat_id'].nunique()

# Display the counts
print("Unique cat_id counts in original dataframe:", unique_cats_per_age_group)
# Out:
# Unique cat_id counts in original dataframe: age_group
# adult     62
# kitten    16
# senior    34
# Name: cat_id, dtype: int64

# %% [markdown]
# ## Metrics

# %%
# Calculate overall metrics
overall_avg_loss = np.mean(all_losses)
overall_avg_acc = np.mean(all_accuracies)
overall_avg_precision = np.mean(all_precisions)
overall_avg_recall = np.mean(all_recalls)
overall_avg_f1 = np.mean(all_f1)

print("Overall Average Metrics:")
print("Loss:", overall_avg_loss)
print("Accuracy:", overall_avg_acc)
print("Precision:", overall_avg_precision)
print("Recall:", overall_avg_recall)
print("F1 Score:", overall_avg_f1)
# Out:
# Overall Average Metrics:
# Loss: 2.4615478813648224
# Accuracy: 0.6337234407663346
# Precision: 0.6263402078169382
# Recall: 0.6261497712702356
# F1 Score: 0.5959558811707104

# %% [markdown]
# ## Majority Votes

# %%
# After calculating class_stats for each fold
all_majority_vote_details.append(class_stats)

# At the end, when calculating the final metrics:
total_majority_vote_details = pd.concat(all_majority_vote_details)

macro_avg_majority_vote_accuracy = (
    total_majority_vote_details.groupby('actual_age_group')['accuracy'].mean().mean()
)

print(f"Macro-Averaged Majority Vote Accuracy: {macro_avg_majority_vote_accuracy}")

# For class-wise accuracies:
macro_avg_class_accuracies = total_majority_vote_details.groupby('actual_age_group')['accuracy'].mean()

print("Macro-Averaged Class Accuracies:")
print(macro_avg_class_accuracies)

macro_avg_class_accuracies_df = macro_avg_class_accuracies.reset_index()
macro_avg_class_accuracies_df.columns = ['actual_age_group', 'accuracy']
# Out:
# Macro-Averaged Majority Vote Accuracy: 67.0163220115004
# Macro-Averaged Class Accuracies:
# actual_age_group
# adult     74.316940
# kitten    68.888889
# senior    57.843137
# Name: accuracy, dtype: float64

# %%
# Use the modified function
styled_barplot_with_average(macro_avg_class_accuracies_df, 'actual_age_group', 'accuracy', 
                            'Average Accuracy of Majority Votes by Age Group', 
                            'Age Group', 'Accuracy (%)', 
                            average_line=macro_avg_majority_vote_accuracy)

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the average class statistics across all folds and seeds
average_class_stats = pd.concat(all_class_stats).groupby('actual_age_group').agg({
    'accuracy': 'mean',
    'total_count': 'mean'
}).reset_index()
print("Average Class Statistics across all folds and seeds:")
print(average_class_stats)

# Calculate macro-averaged accuracy
macro_accuracy = average_class_stats['accuracy'].mean()
print(f"Macro-Averaged Accuracy: {macro_accuracy:.2f}%")

# Calculate macro-averaged accuracy for detailed class statistics
macro_avg_class_accuracy = average_class_stats['accuracy'].mean()
# Out:
# Average Class Statistics across all folds and seeds:
#   actual_age_group   accuracy  total_count
# 0            adult  68.046290        371.6
# 1           kitten  52.544152         94.2
# 2           senior  59.604743        253.0
# Macro-Averaged Accuracy: 60.07%

# %%
# Use the modified function for detailed class statistics
styled_barplot_with_average(average_class_stats, 'actual_age_group', 'accuracy', 
                            'Average Accuracy by Age Group', 
                            'Age Group', 'Accuracy (%)', 
                            average_line=macro_avg_class_accuracy)

# %%
# Concatenate all gender stats DataFrames and calculate the mean of accuracies
total_gender_stats = pd.concat(all_gender_stats)
average_gender_stats = total_gender_stats.groupby('all_gender').agg({
    'count': 'sum',  
    'correct': 'sum'  
}).reset_index()
average_gender_stats['accuracy'] = (average_gender_stats['correct'] / average_gender_stats['count']) * 100

print("Average Gender Accuracy:")
print(average_gender_stats)
# Out:
# Average Gender Accuracy:
#   all_gender  count  correct   accuracy
# 0          F    979      703  71.807967
# 1          M   1437      812  56.506611
# 2          X   1178      752  63.837012

# %%
# Plot for Accuracy by Gender
styled_barplot(total_gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# # Visualisations

# %%
# Plotting all metrics
metrics_across_seeds = plot_all_metrics(all_losses, all_accuracies, all_precisions, all_recalls, all_f1, "Seeds", "Seed Number")

# %% [markdown]
# ## Display the seed folds results together

# %%
# Create a figure with subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))  

# Flatten the axes array for easier indexing
axes = axes.flatten()

def plot_metrics_on_axes(ax, losses, accuracies, precisions, recalls, f1, title):
    ax.plot(range(1, len(losses)+1), losses, marker='o', color='blue', label='Loss')
    ax.plot(range(1, len(accuracies)+1), accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(range(1, len(precisions)+1), precisions, marker='o', color='red', label='Precision')
    ax.plot(range(1, len(recalls)+1), recalls, marker='o', color='purple', label='Recall')
    ax.plot(range(1, len(f1)+1), f1, marker='o', color='orange', label='F1 Score')
    ax.set_xticks([1, 2, 3, 4])  # Set x-axis ticks to full integers
    ax.set_title(title)
    ax.set_xlabel('Fold Number')
    ax.set_ylabel('Metric Value')
    ax.legend()
    ax.grid(True)

# Plot onto each axes object
plot_metrics_on_axes(axes[0], *seed_1_folds_values, "Seed 1 Metrics")
plot_metrics_on_axes(axes[1], *seed_2_folds_values, "Seed 2 Metrics")
plot_metrics_on_axes(axes[2], *seed_3_folds_values, "Seed 3 Metrics")
plot_metrics_on_axes(axes[3], *seed_4_folds_values, "Seed 4 Metrics")
plot_metrics_on_axes(axes[4], *seed_5_folds_values, "Seed 5 Metrics")

# Hide the unused subplot 
for ax in axes[5:]:
    ax.set_visible(False)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# # Statistics

# %%
# Calculate the standard deviation for each metric
std_loss = np.std(all_losses)
std_accuracy = np.std(all_accuracies)
std_precision = np.std(all_precisions)
std_recall = np.std(all_recalls)
std_f1 = np.std(all_f1)

print("Standard Deviations:")
print(f"Loss: {std_loss}")
print(f"Accuracy: {std_accuracy}")
print(f"Precision: {std_precision}")
print(f"Recall: {std_recall}")
print(f"F1 Score: {std_f1}")
# Out:
# Standard Deviations:
# Loss: 0.7031893300112941
# Accuracy: 0.05914717179533163
# Precision: 0.09759747498532441
# Recall: 0.10815465439352716
# F1 Score: 0.09116926234582005

# %%
# Calculate the interquartile range for each metric
iqr_loss = np.percentile(all_losses, 75) - np.percentile(all_losses, 25)
iqr_accuracy = np.percentile(all_accuracies, 75) - np.percentile(all_accuracies, 25)
iqr_precision = np.percentile(all_precisions, 75) - np.percentile(all_precisions, 25)
iqr_recall = np.percentile(all_recalls, 75) - np.percentile(all_recalls, 25)
iqr_f1 = np.percentile(all_f1, 75) - np.percentile(all_f1, 25)

print("Interquartile Ranges:")
print(f"Loss: {iqr_loss}")
print(f"Accuracy: {iqr_accuracy}")
print(f"Precision: {iqr_precision}")
print(f"Recall: {iqr_recall}")
print(f"F1 Score: {iqr_f1}")
# Out:
# Interquartile Ranges:
# Loss: 1.2401325702667236
# Accuracy: 0.08418712019920349
# Precision: 0.1437550471984168
# Recall: 0.13598421367085722
# F1 Score: 0.09395707821018284

# %% [markdown]
# ### Variation

# %%
# Calculate the variation for each metric
var_loss = np.var(all_losses)
var_accuracy = np.var(all_accuracies)
var_precision = np.var(all_precisions)
var_recall = np.var(all_recalls)
var_f1 = np.var(all_f1)

print("Variations:")
print(f"Loss: {var_loss}")
print(f"Accuracy: {var_accuracy}")
print(f"Precision: {var_precision}")
print(f"Recall: {var_recall}")
print(f"F1 Score: {var_f1}")
# Out:
# Variations:
# Loss: 0.49447523384173275
# Accuracy: 0.0034983879313864735
# Precision: 0.009525267123511025
# Recall: 0.011697429266983302
# F1 Score: 0.008311834396680961

# %% [markdown]
# ### Levene tests for variation significance between seeds

# %% [markdown]
# #### Levene across seeds for LOSS

# %%
# Levene across seeds for LOSS
stat_val, p_val = levene(seed_1_folds_values[0], seed_2_folds_values[0], seed_3_folds_values[0], seed_4_folds_values[0], seed_5_folds_values[0])
print(f'levene test statistic: {stat_val:.2f}, P-value: {p_val:.3f}')
# Out:
# levene test statistic: 0.27, P-value: 0.893

# %% [markdown]
# #### Levene across seeds for ACCURACY

# %%
# Levene across seeds for ACCURACY
stat_val, p_val = levene(seed_1_folds_values[1], seed_2_folds_values[1], seed_3_folds_values[1], seed_4_folds_values[1], seed_5_folds_values[1])
print(f'levene test statistic: {stat_val:.2f}, P-value: {p_val:.3f}')
# Out:
# levene test statistic: 0.27, P-value: 0.895

# %% [markdown]
# #### Levene across seeds for PRECISION

# %%
# Levene across seeds for PRECISION
stat_val, p_val = levene(seed_1_folds_values[2], seed_2_folds_values[2], seed_3_folds_values[2], seed_4_folds_values[2], seed_5_folds_values[2])
print(f'levene test statistic: {stat_val:.2f}, P-value: {p_val:.3f}')
# Out:
# levene test statistic: 1.47, P-value: 0.261

# %% [markdown]
# #### Levene across seeds for RECALL

# %%
# Levene across seeds for RECALL
stat_val, p_val = levene(seed_1_folds_values[3], seed_2_folds_values[3], seed_3_folds_values[3], seed_4_folds_values[3], seed_5_folds_values[3])
print(f'levene test statistic: {stat_val:.2f}, P-value: {p_val:.3f}')
# Out:
# levene test statistic: 0.96, P-value: 0.458

# %% [markdown]
# #### Levene across seeds for F1

# %%
# Levene across seeds for F1
stat_val, p_val = levene(seed_1_folds_values[4], seed_2_folds_values[4], seed_3_folds_values[4], seed_4_folds_values[4], seed_5_folds_values[4])
print(f'levene test statistic: {stat_val:.2f}, P-value: {p_val:.3f}')
# Out:
# levene test statistic: 0.81, P-value: 0.540

# %% [markdown]
# ## Print out measurements for future further analysis (without rerunning notebook)

# %%
seed_1_folds_values
# Out:
# [[2.2753818035125732,
#   2.5375308990478516,
#   3.0206429958343506,
#   1.6550275087356567],
#  [0.6482412219047546,
#   0.6262136101722717,
#   0.6104651093482971,
#   0.7342657446861267],
#  [0.6620580108952202,
#   0.7121913580246915,
#   0.6641711229946524,
#   0.7507155867811606],
#  [0.7476132849267177,
#   0.5357598978288634,
#   0.5732299620798919,
#   0.7148546395858224],
#  [0.6681685273790537,
#   0.546553598608393,
#   0.5990713482482779,
#   0.7281577707081418]]

# %%
seed_2_folds_values
# Out:
# [[3.112839937210083,
#   2.4907634258270264,
#   2.674304723739624,
#   1.6515061855316162],
#  [0.5, 0.6497696042060852, 0.6000000238418579, 0.695652186870575],
#  [0.4633658522547411,
#   0.49484754803903735,
#   0.6202150537634409,
#   0.7107167004732927],
#  [0.4762962962962963,
#   0.5061173533083646,
#   0.6377819627537141,
#   0.759120022277917],
#  [0.4401919629192356,
#   0.49967709885742667,
#   0.6085631925326581,
#   0.7315336992756348]]

# %%
seed_3_folds_values
# Out:
# [[2.2553765773773193,
#   4.0813751220703125,
#   1.7446887493133545,
#   1.6399449110031128],
#  [0.6222222447395325,
#   0.5463414788246155,
#   0.6824644804000854,
#   0.6837607026100159],
#  [0.5871635610766046,
#   0.5807126854077745,
#   0.7566760037348272,
#   0.5384703196347033],
#  [0.6948439997220485,
#   0.4861175641630402,
#   0.7965367965367965,
#   0.5760348583877996],
#  [0.6172483173494298,
#   0.48197868587939513,
#   0.7528344671201813,
#   0.5408884163846271]]

# %%
seed_4_folds_values
# Out:
# [[1.737455129623413, 3.125311851501465, 2.149271011352539, 3.1872897148132324],
#  [0.6994219422340393,
#   0.5816993713378906,
#   0.680497944355011,
#   0.6204819083213806],
#  [0.5750605326876513,
#   0.6641975308641975,

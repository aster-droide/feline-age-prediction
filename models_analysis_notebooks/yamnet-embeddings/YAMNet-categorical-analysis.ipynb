# %% [markdown]
# # YAMNet Multi Seed Validation
# #### 5 Random (but reproducible) seeds are selected for 5 different runs of train/test
# #### Models have been optimised and verified on validation sets thoroughly, running a final train/test evaluation here
# #### The setup:
#
# - 4 fold StratifiedGroupKFold for stratification and ensuring each cat_id group only appears in one set at a time
# - Final scores averaged over the 4 folds
# - For each seed run we will explore the cat_id predictions through majority voting
# - For each run we will explore the potential impact of gender
# - Includes visualisations & analysis
#
# The dataset is highly unbalanced.

# %%
# Standard imports
import numpy as np
import pandas as pd
import random
from datetime import datetime
from collections import Counter

# Sklearn imports
from sklearn.model_selection import train_test_split, GroupShuffleSplit, GroupKFold, StratifiedGroupKFold
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, RobustScaler, StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.inspection import permutation_importance

# Imbalanced-learn import
from imblearn.over_sampling import SMOTE

# TensorFlow and Keras imports
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, BatchNormalization, concatenate
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Adamax, AdamW
from tensorflow.keras.callbacks import EarlyStopping, Callback
from tensorflow.keras.utils import to_categorical
from keras.regularizers import l1, l2, L1L2

# Optuna import
import optuna

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Import statistical tests
from scipy.stats import levene

from IPython.display import display
import time

# %%
# Track running time (including analysis)
start_time = time.time()

# %%
# Set an initial seed for reproducibility
np.random.seed(42)  

# Generate a list of 5 random seeds
random_seeds = np.random.randint(0, 10000, size=5)
print("Random Seeds:", random_seeds)
# Out:
# Random Seeds: [7270  860 5390 5191 5734]

# %% [markdown]
# #### TOTAL RESULTS ACROSS SEED INITIATION

# %%
# Lists to collect statistics across all CVs
all_losses, all_accuracies, all_precisions, all_recalls, all_f1 = [], [], [], [], []
average_fold_losses, average_fold_accuracies, average_fold_precisions, average_fold_recalls, average_fold_f1 = [], [], [], [], []
all_majority_vote_accuracies, all_majority_vote_details, all_class_stats, all_gender_stats  = [], [], [], []

# training accuracies
all_best_training_acc = []
total_training_acc = []

# %% [markdown]
# ## Define Functions

# %%
def check_initial_group_split(groups_train, groups_test):
    """
    Check if any group is present in both the train and test sets.

    Parameters:
    - groups_train: Array of group identifiers for the train set
    - groups_test: Array of group identifiers for the test set

    Returns:
    - Prints out any groups found in both sets and the count of such groups
    """
    train_groups = set(groups_train)
    test_groups = set(groups_test)
    common_groups = train_groups.intersection(test_groups)

    if common_groups:
        print(f"Warning: Found {len(common_groups)} common groups in both train/validation and test sets: {common_groups}")
    else:
        print("No common groups found between train and test sets.")

# %%
# Function to perform the swaps based on cat_id, ensuring swaps within the same age_group
def swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids):
    for cat_id in specific_cat_ids:
        # Check if the specific cat_id is not in the training set
        if cat_id not in dataframe.iloc[train_val_idx]['cat_id'].values:
            # Get the age_group of this cat_id
            age_group = dataframe[dataframe['cat_id'] == cat_id]['age_group'].iloc[0]
                
            # Find a different cat_id within the same age_group in the train set that is not in the test set
            other_cat_ids_in_age_group = dataframe[(dataframe['age_group'] == age_group) & 
                                                   (dataframe['cat_id'] != cat_id) &
                                                   (~dataframe['cat_id'].isin(dataframe.iloc[test_idx]['cat_id']))]['cat_id'].unique()
            
            # Choose one other cat_id for swapping
            if len(other_cat_ids_in_age_group) > 0:
                other_cat_id = np.random.choice(other_cat_ids_in_age_group)

                # Find all instances of the other_cat_id in the train set
                other_cat_id_train_val_indices = train_val_idx[dataframe.iloc[train_val_idx]['cat_id'] == other_cat_id]
                
                # Find all instances of the specific cat_id in the test set
                cat_id_test_indices = test_idx[dataframe.iloc[test_idx]['cat_id'] == cat_id]
                
                # Swap the indices
                train_val_idx = np.setdiff1d(train_val_idx, other_cat_id_train_val_indices, assume_unique=True)
                test_idx = np.setdiff1d(test_idx, cat_id_test_indices, assume_unique=True)

                train_val_idx = np.concatenate((train_val_idx, cat_id_test_indices))
                test_idx = np.concatenate((test_idx, other_cat_id_train_val_indices))
            else:
                print(f"No alternative cat_id found in the same age_group as {cat_id} for swapping.")
                
    return train_val_idx, test_idx

# %%
# Function to identify differences in groups
def find_group_differences(original, new):
    # Convert numpy arrays to sets for easy difference computation
    original_set = set(original)
    new_set = set(new)
    # Find differences
    moved_to_new = new_set - original_set
    moved_to_original = original_set - new_set
    return moved_to_new, moved_to_original

# %%
# create custom logger function for local logs & stored in a .txt
def logger(message, file=None):
    print(message)
    if file is not None:
        with open(file, "a") as log_file:
            log_file.write(message + "\n")

log_file_path = "multi-seed-val-D13.txt"

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid", palette="deep")

# Define a custom color palette
colors = ["#6aabd1", "#b6e2d3", "#dac292"] 
sns.set_palette(sns.color_palette(colors))

# Function to create bar plots with enhanced style
def styled_barplot(data, x, y, title, xlabel, ylabel):
    plt.figure(figsize=(8, 4))
    bar_plot = sns.barplot(x=x, y=y, data=data, errorbar=None, width=0.5)  
    plt.title(title, fontsize=16, fontweight='bold', color="#333333")
    plt.xlabel(xlabel, fontsize=14, fontweight='bold', color="#333333")
    plt.ylabel(ylabel, fontsize=14, fontweight='bold', color="#333333")
    plt.xticks(fontsize=12, color="#333333")
    plt.yticks(fontsize=12, color="#333333")
    plt.ylim(0, 100) 

    # Adding value labels on top of each bar
    for p in bar_plot.patches:
        height = p.get_height()
        # Annotate the height value on the bar
        bar_plot.annotate(f'{height:.1f}', 
                          (p.get_x() + p.get_width() / 2., height), 
                          ha='center', va='center', 
                          xytext=(0, 9), 
                          textcoords='offset points', fontsize=12, color="#333333")

    plt.show()

# %%
def styled_barplot_with_average(data, x, y, title, xlabel, ylabel, average_line=None):
    plt.figure(figsize=(8, 4))
    bar_plot = sns.barplot(x=x, y=y, data=data, errorbar=None, width=0.5)  
    plt.title(title, fontsize=16, fontweight='bold', color="#333333")
    plt.xlabel(xlabel, fontsize=14, fontweight='bold', color="#333333")
    plt.ylabel(ylabel, fontsize=14, fontweight='bold', color="#333333")
    plt.xticks(fontsize=12, color="#333333")
    plt.yticks(fontsize=12, color="#333333")
    plt.ylim(0, 100) 
    
    # Adding value labels on top of each bar
    for p in bar_plot.patches:
        height = p.get_height()
        bar_plot.annotate(f'{height:.1f}', 
                          (p.get_x() + p.get_width() / 2., height), 
                          ha='center', va='center', 
                          xytext=(0, 9), 
                          textcoords='offset points', fontsize=12, color="#333333")
    
    if average_line is not None:
        plt.axhline(y=average_line, color='red', linestyle='--', 
                    label=f'Macro-Averaged Accuracy: {average_line:.1f}%')
        plt.legend(fontsize=10)
    
    plt.show()

# %%
def plot_all_metrics(losses, accuracies, precisions, recalls, f1, metrics_across, x_axis_label):
    fig, ax = plt.subplots(figsize=(12, 8))
    seeds = range(1, len(losses) + 1)

    ax.plot(seeds, losses, marker='o', color='blue', label='Loss')
    ax.plot(seeds, accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(seeds, precisions, marker='o', color='red', label='Precision')
    ax.plot(seeds, recalls, marker='o', color='purple', label='Recall')
    ax.plot(seeds, f1, marker='o', color='orange', label='F1 Score')

    ax.set_title(f'Metrics Across {metrics_across}')
    ax.set_xlabel(x_axis_label)
    ax.set_ylabel('Metric Value')
    ax.set_xticks(seeds)
    ax.legend()
    ax.grid(True)

    return fig

# %%
# store epoch accs
class AccuracyHistory(Callback):
    def on_train_begin(self, logs={}):
        self.acc = []

    def on_epoch_end(self, batch, logs={}):
        self.acc.append(logs.get('accuracy'))

# %% [markdown]
# # RANDOM SEED 1

# %% [markdown]
# ## Prepare Data

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[0])) 
np.random.seed(int(random_seeds[0]))
tf.random.set_seed(int(random_seeds[0]))

# Load datasets
dataframe = pd.read_csv('yamnet_looped_embeddings.csv')



def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 10),
    'senior': (10, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     472
# senior    320
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[0]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

cv_training_acc_total = []
cv_training_acc_best = []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    accuracy_history = AccuracyHistory()

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]

    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_val),
        y=y_train_val
    )
    weight_dict = {i: class_weights[i] for i in range(len(class_weights))}

    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.009272615392034748)
    }
    
    # Full model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.40037235360372386))   
    model_full.add(Dense(3, activation='softmax'))  
    
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=32,
                                  verbose=1, callbacks=[early_stopping, accuracy_history], class_weight=weight_dict)
    
    
    # log epochs
    best_epoch_index = np.argmin(history_full.history['loss'])  
    best_training_accuracy = accuracy_history.acc[best_epoch_index]

    # Append training acc to total  
    all_best_training_acc.append(best_training_accuracy)
    total_training_acc.append(accuracy_history.acc)

    # Append training acc just for this CV
    cv_training_acc_total.append(accuracy_history.acc)
    cv_training_acc_best.append(best_training_accuracy)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
average_fold_f1.append(unseen_set_avg_f1)
average_fold_losses.append(unseen_set_avg_loss)
average_fold_accuracies.append(unseen_set_avg_acc)
average_fold_precisions.append(unseen_set_avg_precision)
average_fold_recalls.append(unseen_set_avg_recall)

# Append all to total lists
all_f1.append(unseen_f1)
all_losses.append(unseen_losses)
all_accuracies.append(unseen_accuracies)
all_precisions.append(unseen_precisions)
all_recalls.append(unseen_recalls)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 047A    30
#         ..
# 049A     1
# 091A     1
# 024A     1
# 048A     1
# 100A     1
# Name: cat_id, Length: 86, dtype: int64
# Testing Set Group Distribution:
# 020A    23
# 055A    20
# 097B    14
# 068A    11
# 015A    10
# 014B    10
# 071A    10
# 033A     9
# 045A     9
# 013B     8
# 099A     7
# 031A     7
# 053A     7
# 108A     6
# 044A     5
# 104A     4
# 113A     3
# 056A     3
# 011A     3
# 093A     2
# 054A     2
# 088A     1
# 026C     1
# 019B     1
# 110A     1
# 043A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    313
# X    286
# F    191
# Name: gender, dtype: int64
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Testing Set Gender Distribution BEFORE SWAP:
# X    69
# F    66
# M    43
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 000B, 000A, 026A, 065A, 023B, 038...
# kitten    [046A, 042A, 109A, 040A, 047A, 049A, 048A, 111...
# senior    [028A, 117A, 106A, 057A, 001A, 090A, 051B, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 071A, 020A, 026C, 068A, 013B, 031A, 097...
# kitten                       [014B, 110A, 045A, 044A, 043A]
# senior    [015A, 053A, 113A, 055A, 054A, 108A, 011A, 104...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 51, 'kitten': 11, 'senior': 24}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 11, 'kitten': 5, 'senior': 10}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '012A' '014A' '016A' '018A' '019A' '021A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '025C' '026A' '026B' '027A' '028A'
#  '029A' '032A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A'
#  '042A' '046A' '047A' '048A' '049A' '050A' '051A' '051B' '052A' '057A'
#  '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A' '066A' '067A'
#  '069A' '070A' '072A' '073A' '074A' '075A' '076A' '087A' '090A' '091A'
#  '092A' '094A' '095A' '096A' '097A' '100A' '101A' '102A' '103A' '105A'
#  '106A' '109A' '111A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['011A' '013B' '014B' '015A' '019B' '020A' '026C' '031A' '033A' '043A'
#  '044A' '045A' '053A' '054A' '055A' '056A' '068A' '071A' '088A' '093A'
#  '097B' '099A' '104A' '108A' '110A' '113A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '012A' '014A' '016A' '018A' '019A' '021A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '025C' '026A' '026B' '027A' '028A'
#  '029A' '032A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A'
#  '042A' '046A' '047A' '048A' '049A' '050A' '051A' '051B' '052A' '057A'
#  '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A' '066A' '067A'
#  '069A' '070A' '072A' '073A' '074A' '075A' '076A' '087A' '090A' '091A'
#  '092A' '094A' '095A' '096A' '097A' '100A' '101A' '102A' '103A' '105A'
#  '106A' '109A' '111A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['011A' '013B' '014B' '015A' '019B' '020A' '026C' '031A' '033A' '043A'
#  '044A' '045A' '053A' '054A' '055A' '056A' '068A' '071A' '088A' '093A'
#  '097B' '099A' '104A' '108A' '110A' '113A']
# Length of X_train_val:
# 790
# Length of y_train_val:
# 790
# Length of groups_train_val:
# 790
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     380
# senior    260
# kitten    150
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     92
# senior    60
# kitten    26
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     380
# senior    260
# kitten    150
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     92
# senior    60
# kitten    26
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 380, 2: 260, 1: 150})
# Epoch 1/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4276 - accuracy: 0.5722
# Epoch 2/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5355 - accuracy: 0.7696
# Epoch 3/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3632 - accuracy: 0.8506
# Epoch 4/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2517 - accuracy: 0.8772
# Epoch 5/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2018 - accuracy: 0.9114
# Epoch 6/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2084 - accuracy: 0.9051
# Epoch 7/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1979 - accuracy: 0.9152
# Epoch 8/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1528 - accuracy: 0.9177
# Epoch 9/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1306 - accuracy: 0.9430
# Epoch 10/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1194 - accuracy: 0.9519
# Epoch 11/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0998 - accuracy: 0.9608
# Epoch 12/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1214 - accuracy: 0.9494
# Epoch 13/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0919 - accuracy: 0.9684
# Epoch 14/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1023 - accuracy: 0.9481
# Epoch 15/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0726 - accuracy: 0.9722
# Epoch 16/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0753 - accuracy: 0.9759
# Epoch 17/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9797
# Epoch 18/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0522 - accuracy: 0.9797
# Epoch 19/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0478 - accuracy: 0.9823
# Epoch 20/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0460 - accuracy: 0.9823
# Epoch 21/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0465 - accuracy: 0.9823
# Epoch 22/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0580 - accuracy: 0.9747
# Epoch 23/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0468 - accuracy: 0.9797
# Epoch 24/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0370 - accuracy: 0.9873
# Epoch 25/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0305 - accuracy: 0.9899
# Epoch 26/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0450 - accuracy: 0.9886
# Epoch 27/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0370 - accuracy: 0.9823
# Epoch 28/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0248 - accuracy: 0.9949
# Epoch 29/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0320 - accuracy: 0.9886
# Epoch 30/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0300 - accuracy: 0.9911
# Epoch 31/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0256 - accuracy: 0.9924
# Epoch 32/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0219 - accuracy: 0.9899
# Epoch 33/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0218 - accuracy: 0.9911
# Epoch 34/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0456 - accuracy: 0.9823
# Epoch 35/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0406 - accuracy: 0.9861
# Epoch 36/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0325 - accuracy: 0.9899
# Epoch 37/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0248 - accuracy: 0.9911
# Epoch 38/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0210 - accuracy: 0.9886
# Epoch 39/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0322 - accuracy: 0.9848
# Epoch 40/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0252 - accuracy: 0.9937
# Epoch 41/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0170 - accuracy: 0.9937
# Epoch 42/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 0.9975
# Epoch 43/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0239 - accuracy: 0.9873
# Epoch 44/1500
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0148 - accuracy: 0.9937
# Epoch 45/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 0.9987
# Epoch 46/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0234 - accuracy: 0.9911
# Epoch 47/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0203 - accuracy: 0.9899
# Epoch 48/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0202 - accuracy: 0.9937
# Epoch 49/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0213 - accuracy: 0.9949
# Epoch 50/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0113 - accuracy: 0.9987
# Epoch 51/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0287 - accuracy: 0.9899
# Epoch 52/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 0.9949
# Epoch 53/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 0.9924
# Epoch 54/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 0.9962
# Epoch 55/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 56/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 57/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0145 - accuracy: 0.9949
# Epoch 58/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 0.9975
# Epoch 59/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0136 - accuracy: 0.9937
# Epoch 60/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0152 - accuracy: 0.9924
# Epoch 61/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 0.9949
# Epoch 62/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 0.9937
# Epoch 63/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0115 - accuracy: 0.9975
# Epoch 64/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0195 - accuracy: 0.9949
# Epoch 65/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 0.9911
# Epoch 66/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0242 - accuracy: 0.9949
# Epoch 67/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0150 - accuracy: 0.9962
# Epoch 68/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 0.9962
# Epoch 69/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 70/1500
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0114 - accuracy: 0.9937
# Epoch 71/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 0.9987
# Epoch 72/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 0.9975
# Epoch 73/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 0.9962
# Epoch 74/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0037 - accuracy: 0.9987
# Epoch 75/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 0.9987
# Epoch 76/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0094 - accuracy: 0.9975
# Epoch 77/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0150 - accuracy: 0.9962
# Epoch 78/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 0.9987
# Epoch 79/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0091 - accuracy: 0.9962
# Epoch 80/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 0.9975
# Epoch 81/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 0.9987
# Epoch 82/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 0.9987
# Epoch 83/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 84/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 0.9987
# Epoch 85/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0107 - accuracy: 0.9949
# Epoch 86/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0120 - accuracy: 0.9924
# Epoch 87/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0144 - accuracy: 0.9949
# Epoch 88/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0165 - accuracy: 0.9924
# Epoch 89/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 0.9975
# Epoch 90/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 0.9975
# Epoch 91/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0076 - accuracy: 0.9975
# Epoch 92/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 0.9962
# Epoch 93/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0080 - accuracy: 0.9987
# Epoch 94/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0077 - accuracy: 0.9975
# Epoch 95/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 0.9924
# Epoch 96/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0110 - accuracy: 0.9962
# Epoch 97/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0150 - accuracy: 0.9937
# Epoch 98/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 0.9949
# Epoch 99/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.9987
# Epoch 100/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 0.9962
# Epoch 101/1500
#  9/25 [=========>....................] - ETA: 0s - loss: 0.0277 - accuracy: 0.9965Restoring model weights from the end of the best epoch: 71.
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0186 - accuracy: 0.9949
# Epoch 101: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 3.7060 - accuracy: 0.6517
# 6/6 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.77 (20/26)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 178, Predictions: 178, Actuals: 178, Gender: 178
# Final Test Results - Loss: 3.70603346824646, Accuracy: 0.6516854166984558, Precision: 0.635978835978836, Recall: 0.6336120401337793, F1 Score: 0.6345667722999143
# Confusion Matrix:
#  [[62  9 21]
#  [ 8 15  3]
#  [20  1 39]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 047A    30
#         ..
# 024A     1
# 091A     1
# 090A     1
# 026C     1
# 100A     1
# Name: cat_id, Length: 83, dtype: int64
# Testing Set Group Distribution:
# 000B    20
# 059A    18
# 097A    16
# 106A    15
# 028A    14
# 111A    13
# 039A    12
# 036A    11
# 025A    11
# 040A    10
# 095A     8
# 050A     7
# 109A     6
# 008A     6
# 021A     6
# 037A     6
# 034A     5
# 070A     5
# 009A     4
# 003A     4
# 105A     4
# 006A     3
# 058A     3
# 014A     3
# 061A     2
# 066A     2
# 032A     2
# 049A     1
# 041A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    288
# X    262
# F    200
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    93
# M    68
# F    57
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 033A, 071A, 020A, 000A, 026A, 065A, 023...
# kitten    [046A, 042A, 014B, 110A, 047A, 045A, 048A, 044...
# senior    [117A, 015A, 053A, 057A, 001A, 090A, 113A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [070A, 000B, 021A, 105A, 034A, 009A, 006A, 032...
# kitten                 [109A, 040A, 049A, 111A, 050A, 041A]
# senior    [028A, 106A, 097A, 059A, 025A, 058A, 061A, 008...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 48, 'kitten': 10, 'senior': 25}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 14, 'kitten': 6, 'senior': 9}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '004A' '005A' '007A' '010A' '011A' '012A'
#  '013B' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '022A' '023A'
#  '023B' '024A' '025B' '025C' '026A' '026B' '026C' '027A' '029A' '031A'
#  '033A' '035A' '038A' '042A' '043A' '044A' '045A' '046A' '047A' '048A'
#  '051A' '051B' '052A' '053A' '054A' '055A' '056A' '057A' '060A' '062A'
#  '063A' '064A' '065A' '067A' '068A' '069A' '071A' '072A' '073A' '074A'
#  '075A' '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A' '096A'
#  '097B' '099A' '100A' '101A' '102A' '103A' '104A' '108A' '110A' '113A'
#  '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000B' '003A' '006A' '008A' '009A' '014A' '021A' '025A' '028A' '032A'
#  '034A' '036A' '037A' '039A' '040A' '041A' '049A' '050A' '058A' '059A'
#  '061A' '066A' '070A' '095A' '097A' '105A' '106A' '109A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '004A' '005A' '007A' '010A' '011A' '012A'
#  '013B' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '022A' '023A'
#  '023B' '024A' '025B' '025C' '026A' '026B' '026C' '027A' '029A' '031A'
#  '033A' '035A' '038A' '042A' '043A' '044A' '045A' '046A' '047A' '048A'
#  '051A' '051B' '052A' '053A' '054A' '055A' '056A' '057A' '060A' '062A'
#  '063A' '064A' '065A' '067A' '068A' '069A' '071A' '072A' '073A' '074A'
#  '075A' '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A' '096A'
#  '097B' '099A' '100A' '101A' '102A' '103A' '104A' '108A' '110A' '113A'
#  '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '003A' '006A' '008A' '009A' '014A' '021A' '025A' '028A' '032A'
#  '034A' '036A' '037A' '039A' '040A' '041A' '049A' '050A' '058A' '059A'
#  '061A' '066A' '070A' '095A' '097A' '105A' '106A' '109A' '111A']
# Length of X_train_val:
# 750
# Length of y_train_val:
# 750
# Length of groups_train_val:
# 750
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     389
# senior    223
# kitten    138
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# senior    97
# adult     83
# kitten    38
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     389
# senior    223
# kitten    138
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# senior    97
# adult     83
# kitten    38
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 389, 2: 223, 1: 138})
# Epoch 1/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 1.5569 - accuracy: 0.5307
# Epoch 2/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5494 - accuracy: 0.7520
# Epoch 3/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3310 - accuracy: 0.8373
# Epoch 4/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2947 - accuracy: 0.8693
# Epoch 5/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2093 - accuracy: 0.9107
# Epoch 6/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1962 - accuracy: 0.9333
# Epoch 7/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1590 - accuracy: 0.9240
# Epoch 8/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1468 - accuracy: 0.9373
# Epoch 9/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1268 - accuracy: 0.9453
# Epoch 10/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1095 - accuracy: 0.9613
# Epoch 11/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0964 - accuracy: 0.9680
# Epoch 12/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0954 - accuracy: 0.9653
# Epoch 13/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1179 - accuracy: 0.9453
# Epoch 14/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0810 - accuracy: 0.9720
# Epoch 15/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0756 - accuracy: 0.9680
# Epoch 16/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0648 - accuracy: 0.9720
# Epoch 17/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0684 - accuracy: 0.9680
# Epoch 18/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0583 - accuracy: 0.9773
# Epoch 19/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0565 - accuracy: 0.9827
# Epoch 20/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0435 - accuracy: 0.9853
# Epoch 21/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0432 - accuracy: 0.9840
# Epoch 22/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0343 - accuracy: 0.9893
# Epoch 23/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0377 - accuracy: 0.9893
# Epoch 24/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0388 - accuracy: 0.9867
# Epoch 25/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0334 - accuracy: 0.9893
# Epoch 26/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0380 - accuracy: 0.9813
# Epoch 27/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0275 - accuracy: 0.9933
# Epoch 28/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0192 - accuracy: 0.9960
# Epoch 29/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0255 - accuracy: 0.9947
# Epoch 30/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0238 - accuracy: 0.9907
# Epoch 31/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0265 - accuracy: 0.9920
# Epoch 32/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0209 - accuracy: 0.9960
# Epoch 33/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0254 - accuracy: 0.9893
# Epoch 34/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 0.9960
# Epoch 35/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0156 - accuracy: 0.9960
# Epoch 36/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0178 - accuracy: 0.9947
# Epoch 37/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 0.9973
# Epoch 38/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0120 - accuracy: 0.9987
# Epoch 39/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0193 - accuracy: 0.9907
# Epoch 40/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 0.9947
# Epoch 41/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0190 - accuracy: 0.9920
# Epoch 42/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0192 - accuracy: 0.9933
# Epoch 43/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 44/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 0.9973
# Epoch 45/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 0.9973
# Epoch 46/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0111 - accuracy: 0.9987
# Epoch 47/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0131 - accuracy: 0.9973
# Epoch 48/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0147 - accuracy: 0.9960
# Epoch 49/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 0.9960
# Epoch 50/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0129 - accuracy: 0.9947
# Epoch 51/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 0.9960
# Epoch 52/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0107 - accuracy: 0.9973
# Epoch 53/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0071 - accuracy: 0.9973
# Epoch 54/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 0.9973
# Epoch 55/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 0.9920
# Epoch 56/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 0.9933
# Epoch 57/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0100 - accuracy: 0.9960
# Epoch 58/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 59/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 60/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 61/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 0.9987
# Epoch 62/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 0.9960
# Epoch 63/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0103 - accuracy: 0.9960
# Epoch 64/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0065 - accuracy: 0.9987
# Epoch 65/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 0.9933
# Epoch 66/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 0.9987
# Epoch 67/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0148 - accuracy: 0.9947
# Epoch 68/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 0.9987
# Epoch 69/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 0.9947
# Epoch 70/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 0.9987
# Epoch 71/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9960
# Epoch 72/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 73/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0079 - accuracy: 0.9960
# Epoch 74/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0072 - accuracy: 0.9973
# Epoch 75/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0165 - accuracy: 0.9920
# Epoch 76/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0126 - accuracy: 0.9947
# Epoch 77/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0243 - accuracy: 0.9893
# Epoch 78/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 0.9933
# Epoch 79/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 0.9973
# Epoch 80/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 0.9960
# Epoch 81/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 0.9960
# Epoch 82/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0150 - accuracy: 0.9933
# Epoch 83/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0113 - accuracy: 0.9987
# Epoch 84/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0059 - accuracy: 0.9973
# Epoch 85/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0061 - accuracy: 0.9987
# Epoch 86/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0061 - accuracy: 0.9973
# Epoch 87/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 0.9973
# Epoch 88/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0086 - accuracy: 0.9947
# Epoch 89/1500
# 17/24 [====================>.........] - ETA: 0s - loss: 0.0119 - accuracy: 0.9945    Restoring model weights from the end of the best epoch: 59.
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 0.9960
# Epoch 89: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 6.1831 - accuracy: 0.5321
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.55 (16/29)
# Before appending - Cat IDs: 178, Predictions: 178, Actuals: 178, Gender: 178
# After appending - Cat IDs: 396, Predictions: 396, Actuals: 396, Gender: 396
# Final Test Results - Loss: 6.183104515075684, Accuracy: 0.5321100950241089, Precision: 0.5477104924473345, Recall: 0.5384936381445479, F1 Score: 0.5379969663428033
# Confusion Matrix:
#  [[48 10 25]
#  [13 21  4]
#  [44  6 47]]
# outer_fold 3
# Train Set Group Distribution:
# 000A    39
# 047A    30
# 074A    25
# 020A    23
# 067A    20
#         ..
# 073A     1
# 088A     1
# 049A     1
# 043A     1
# 100A     1
# Name: cat_id, Length: 81, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 002B    36
# 103A    33
# 057A    28
# 029A    17
# 019A    17
# 042A    14
# 051A    12
# 063A    11
# 005A    11
# 022A     9
# 072A     9
# 065A     9
# 010A     8
# 027A     7
# 007A     6
# 012A     5
# 023B     5
# 052A     4
# 035A     4
# 018A     2
# 102A     2
# 069A     2
# 038A     2
# 087A     2
# 025B     2
# 092A     1
# 048A     1
# 096A     1
# 090A     1
# 115A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    221
# F    218
# X    201
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    154
# M    135
# F     39
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 033A, 000B, 071A, 020A, 000A, 026...
# kitten    [014B, 110A, 109A, 040A, 047A, 049A, 045A, 111...
# senior    [028A, 117A, 015A, 106A, 053A, 001A, 113A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [065A, 023B, 038A, 007A, 018A, 072A, 002B, 005...
# kitten                             [046A, 042A, 048A, 115A]
# senior                             [057A, 090A, 051A, 103A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 39, 'kitten': 12, 'senior': 30}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 23, 'kitten': 4, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '006A' '008A' '009A' '011A'
#  '013B' '014A' '014B' '015A' '016A' '019B' '020A' '021A' '023A' '024A'
#  '025A' '025C' '026A' '026B' '026C' '028A' '031A' '032A' '033A' '034A'
#  '036A' '037A' '039A' '040A' '041A' '043A' '044A' '045A' '047A' '049A'
#  '050A' '051B' '053A' '054A' '055A' '056A' '058A' '059A' '060A' '061A'
#  '062A' '064A' '066A' '067A' '068A' '070A' '071A' '073A' '074A' '075A'
#  '076A' '088A' '091A' '093A' '094A' '095A' '097A' '097B' '099A' '100A'
#  '101A' '104A' '105A' '106A' '108A' '109A' '110A' '111A' '113A' '116A'
#  '117A']
# Unique Test Group IDs:
# ['002B' '005A' '007A' '010A' '012A' '018A' '019A' '022A' '023B' '025B'
#  '027A' '029A' '035A' '038A' '042A' '046A' '048A' '051A' '052A' '057A'
#  '063A' '065A' '069A' '072A' '087A' '090A' '092A' '096A' '102A' '103A'
#  '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'043A'}
# Moved to Test Set:
# {'043A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '006A' '008A' '009A' '011A'
#  '013B' '014A' '014B' '015A' '016A' '019B' '020A' '021A' '023A' '024A'
#  '025A' '025C' '026A' '026B' '026C' '028A' '031A' '032A' '033A' '034A'
#  '036A' '037A' '039A' '040A' '041A' '044A' '045A' '046A' '047A' '049A'
#  '050A' '051B' '053A' '054A' '055A' '056A' '058A' '059A' '060A' '061A'
#  '062A' '064A' '066A' '067A' '068A' '070A' '071A' '073A' '074A' '075A'
#  '076A' '088A' '091A' '093A' '094A' '095A' '097A' '097B' '099A' '100A'
#  '101A' '104A' '105A' '106A' '108A' '109A' '110A' '111A' '113A' '116A'
#  '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '005A' '007A' '010A' '012A' '018A' '019A' '022A' '023B' '025B'
#  '027A' '029A' '035A' '038A' '042A' '043A' '048A' '051A' '052A' '057A'
#  '063A' '065A' '069A' '072A' '087A' '090A' '092A' '096A' '102A' '103A'
#  '115A']
# Length of X_train_val:
# 705
# Length of y_train_val:
# 705
# Length of groups_train_val:
# 705
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     300
# senior    246
# kitten     94
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     172
# kitten     82
# senior     74
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     300
# senior    246
# kitten    159
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     172
# senior     74
# kitten     17
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 300, 2: 246, 1: 159})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 1.3433 - accuracy: 0.6184
# Epoch 2/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.5091 - accuracy: 0.7702
# Epoch 3/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3349 - accuracy: 0.8454
# Epoch 4/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2303 - accuracy: 0.8936
# Epoch 5/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2057 - accuracy: 0.9163
# Epoch 6/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1619 - accuracy: 0.9262
# Epoch 7/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1457 - accuracy: 0.9319
# Epoch 8/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1428 - accuracy: 0.9390
# Epoch 9/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1336 - accuracy: 0.9433
# Epoch 10/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1078 - accuracy: 0.9504
# Epoch 11/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0971 - accuracy: 0.9660
# Epoch 12/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0712 - accuracy: 0.9787
# Epoch 13/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0722 - accuracy: 0.9759
# Epoch 14/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0669 - accuracy: 0.9716
# Epoch 15/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0740 - accuracy: 0.9617
# Epoch 16/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0769 - accuracy: 0.9730
# Epoch 17/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0625 - accuracy: 0.9816
# Epoch 18/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0491 - accuracy: 0.9901
# Epoch 19/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0400 - accuracy: 0.9915
# Epoch 20/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0432 - accuracy: 0.9844
# Epoch 21/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0426 - accuracy: 0.9844
# Epoch 22/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0343 - accuracy: 0.9872
# Epoch 23/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0439 - accuracy: 0.9816
# Epoch 24/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0470 - accuracy: 0.9830
# Epoch 25/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0337 - accuracy: 0.9915
# Epoch 26/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0385 - accuracy: 0.9887
# Epoch 27/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0247 - accuracy: 0.9929
# Epoch 28/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0388 - accuracy: 0.9844
# Epoch 29/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0319 - accuracy: 0.9915
# Epoch 30/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0283 - accuracy: 0.9915
# Epoch 31/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0158 - accuracy: 0.9957
# Epoch 32/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0368 - accuracy: 0.9887
# Epoch 33/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0291 - accuracy: 0.9858
# Epoch 34/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 0.9972
# Epoch 35/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0120 - accuracy: 0.9986
# Epoch 36/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0232 - accuracy: 0.9929
# Epoch 37/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0235 - accuracy: 0.9943
# Epoch 38/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0232 - accuracy: 0.9929
# Epoch 39/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0305 - accuracy: 0.9858
# Epoch 40/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0352 - accuracy: 0.9872
# Epoch 41/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0283 - accuracy: 0.9901
# Epoch 42/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0227 - accuracy: 0.9943
# Epoch 43/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 0.9957
# Epoch 44/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 0.9957
# Epoch 45/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0179 - accuracy: 0.9957
# Epoch 46/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 0.9972
# Epoch 47/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0147 - accuracy: 0.9929
# Epoch 48/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0188 - accuracy: 0.9915
# Epoch 49/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 0.9972
# Epoch 50/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 0.9986
# Epoch 51/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 0.9957
# Epoch 52/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 0.9986
# Epoch 53/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0288 - accuracy: 0.9872
# Epoch 54/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0125 - accuracy: 0.9986
# Epoch 55/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0155 - accuracy: 0.9915
# Epoch 56/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 0.9986
# Epoch 57/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0240 - accuracy: 0.9929
# Epoch 58/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.9986
# Epoch 59/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 0.9929
# Epoch 60/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0205 - accuracy: 0.9915
# Epoch 61/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0171 - accuracy: 0.9929
# Epoch 62/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0141 - accuracy: 0.9943
# Epoch 63/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0113 - accuracy: 0.9957
# Epoch 64/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0153 - accuracy: 0.9943
# Epoch 65/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0110 - accuracy: 0.9957
# Epoch 66/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0136 - accuracy: 0.9943
# Epoch 67/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 0.9957
# Epoch 68/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 0.9943
# Epoch 69/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0168 - accuracy: 0.9972
# Epoch 70/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0080 - accuracy: 0.9986
# Epoch 71/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 0.9957
# Epoch 72/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 0.9986
# Epoch 73/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 0.9972
# Epoch 74/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0085 - accuracy: 0.9957
# Epoch 75/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0095 - accuracy: 0.9957
# Epoch 76/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 0.9887
# Epoch 77/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 0.9915
# Epoch 78/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 0.9943
# Epoch 79/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 0.9972
# Epoch 80/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 0.9986
# Epoch 81/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0065 - accuracy: 0.9986
# Epoch 82/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 0.9915
# Epoch 83/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0279 - accuracy: 0.9943
# Epoch 84/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0134 - accuracy: 0.9957
# Epoch 85/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0147 - accuracy: 0.9929
# Epoch 86/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 0.9943
# Epoch 87/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0164 - accuracy: 0.9957
# Epoch 88/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 0.9957
# Epoch 89/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0111 - accuracy: 0.9986
# Epoch 90/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 0.9972
# Epoch 91/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0157 - accuracy: 0.9957
# Epoch 92/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0061 - accuracy: 0.9972
# Epoch 93/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 0.9972
# Epoch 94/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 0.9972
# Epoch 95/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 0.9972
# Epoch 96/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 0.9943
# Epoch 97/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0059 - accuracy: 0.9986
# Epoch 98/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0252 - accuracy: 0.9887
# Epoch 99/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0102 - accuracy: 0.9972
# Epoch 100/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 0.9986
# Epoch 101/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 0.9986
# Epoch 102/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.9972
# Epoch 103/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 0.9957
# Epoch 104/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 0.9957
# Epoch 105/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 0.9957
# Epoch 106/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 0.9972
# Epoch 107/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 0.9915
# Epoch 108/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 0.9972
# Epoch 109/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 0.9972
# Epoch 110/1500
# 17/23 [=====================>........] - ETA: 0s - loss: 0.0076 - accuracy: 0.9963Restoring model weights from the end of the best epoch: 80.
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0113 - accuracy: 0.9957
# Epoch 110: early stopping
# 9/9 [==============================] - 0s 1ms/step - loss: 5.7386 - accuracy: 0.4943
# 9/9 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.71 (22/31)
# Before appending - Cat IDs: 396, Predictions: 396, Actuals: 396, Gender: 396
# After appending - Cat IDs: 659, Predictions: 659, Actuals: 659, Gender: 659
# Final Test Results - Loss: 5.738619804382324, Accuracy: 0.4942965805530548, Precision: 0.4495572946692801, Recall: 0.6068140644064036, F1 Score: 0.47267809945294736
# Confusion Matrix:
#  [[80 31 61]
#  [ 2 15  0]
#  [36  3 35]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    66
# 002B    36
# 103A    33
# 057A    28
# 020A    23
#         ..
# 019B     1
# 026C     1
# 041A     1
# 115A     1
# 048A     1
# Name: cat_id, Length: 86, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 047A    30
# 074A    25
# 067A    20
# 101A    16
# 001A    15
# 002A    13
# 116A    12
# 016A    11
# 051B     9
# 094A     8
# 117A     7
# 025C     6
# 023A     6
# 075A     5
# 062A     5
# 026A     4
# 064A     3
# 060A     3
# 091A     1
# 073A     1
# 024A     1
# 076A     1
# 004A     1
# 026B     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    316
# M    246
# F    162
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    110
# F     95
# X     39
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [070A, 033A, 000B, 071A, 020A, 065A, 023B, 038...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 049A, 045...
# senior    [028A, 015A, 106A, 053A, 057A, 090A, 113A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 000A, 026A, 062A, 074A, 067A, 075A, 023...
# kitten                                               [047A]
# senior    [117A, 001A, 051B, 116A, 091A, 024A, 101A, 094...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 48, 'kitten': 15, 'senior': 23}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 14, 'kitten': 1, 'senior': 11}
# Unique Training/Validation Group IDs:
# ['000B' '002B' '003A' '005A' '006A' '007A' '008A' '009A' '010A' '011A'
#  '012A' '013B' '014A' '014B' '015A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023B' '025A' '025B' '026C' '027A' '028A' '029A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '042A'
#  '043A' '044A' '045A' '046A' '048A' '049A' '050A' '051A' '052A' '053A'
#  '054A' '055A' '056A' '057A' '058A' '059A' '061A' '063A' '065A' '066A'
#  '068A' '069A' '070A' '071A' '072A' '087A' '088A' '090A' '092A' '093A'
#  '095A' '096A' '097A' '097B' '099A' '102A' '103A' '104A' '105A' '106A'
#  '108A' '109A' '110A' '111A' '113A' '115A']
# Unique Test Group IDs:
# ['000A' '001A' '002A' '004A' '016A' '023A' '024A' '025C' '026A' '026B'
#  '047A' '051B' '060A' '062A' '064A' '067A' '073A' '074A' '075A' '076A'
#  '091A' '094A' '100A' '101A' '116A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# ...
# ['000A' '000B' '002B' '003A' '005A' '007A' '008A' '009A' '010A' '011A'
#  '012A' '013B' '014A' '014B' '015A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023B' '025A' '025B' '026C' '027A' '028A' '029A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '042A'
#  '043A' '044A' '045A' '046A' '048A' '049A' '050A' '051A' '052A' '053A'
#  '054A' '055A' '056A' '057A' '058A' '059A' '061A' '063A' '065A' '066A'
#  '068A' '069A' '070A' '071A' '072A' '087A' '088A' '090A' '092A' '093A'
#  '095A' '096A' '097A' '097B' '099A' '102A' '103A' '104A' '105A' '106A'
#  '108A' '109A' '110A' '111A' '113A' '115A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002A' '004A' '006A' '016A' '023A' '024A' '025C' '026A' '026B'
#  '047A' '051B' '060A' '062A' '064A' '067A' '073A' '074A' '075A' '076A'
#  '091A' '094A' '100A' '101A' '116A' '117A']
# Length of X_train_val:
# 760
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Length of y_train_val:
# 760
# Length of groups_train_val:
# 760
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     347
# senior    231
# kitten    146
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     125
# senior     89
# kitten     30
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     383
# senior    231
# kitten    146
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     89
# senior    89
# kitten    30
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 383, 2: 231, 1: 146})
# Epoch 1/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 1.3563 - accuracy: 0.5750
# Epoch 2/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5366 - accuracy: 0.7553
# Epoch 3/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3317 - accuracy: 0.8316
# Epoch 4/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2650 - accuracy: 0.8816
# Epoch 5/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2751 - accuracy: 0.8632
# Epoch 6/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1804 - accuracy: 0.9303
# Epoch 7/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1681 - accuracy: 0.9224
# Epoch 8/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1512 - accuracy: 0.9382
# Epoch 9/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1160 - accuracy: 0.9513
# Epoch 10/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1202 - accuracy: 0.9447
# Epoch 11/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1059 - accuracy: 0.9553
# Epoch 12/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0988 - accuracy: 0.9632
# Epoch 13/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0699 - accuracy: 0.9724
# Epoch 14/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0824 - accuracy: 0.9671
# Epoch 15/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0909 - accuracy: 0.9645
# Epoch 16/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0679 - accuracy: 0.9776
# Epoch 17/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0706 - accuracy: 0.9724
# Epoch 18/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0441 - accuracy: 0.9868
# Epoch 19/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0642 - accuracy: 0.9724
# Epoch 20/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0473 - accuracy: 0.9789
# Epoch 21/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0458 - accuracy: 0.9842
# Epoch 22/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0573 - accuracy: 0.9737
# Epoch 23/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0450 - accuracy: 0.9842
# Epoch 24/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0415 - accuracy: 0.9842
# Epoch 25/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0416 - accuracy: 0.9816
# Epoch 26/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0489 - accuracy: 0.9750
# Epoch 27/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0376 - accuracy: 0.9829
# Epoch 28/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0363 - accuracy: 0.9882
# Epoch 29/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0315 - accuracy: 0.9868
# Epoch 30/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0467 - accuracy: 0.9803
# Epoch 31/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.9961
# Epoch 32/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0284 - accuracy: 0.9908
# Epoch 33/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0298 - accuracy: 0.9868
# Epoch 34/1500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0178 - accuracy: 0.9921
# Epoch 35/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0173 - accuracy: 0.9961
# Epoch 36/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0144 - accuracy: 0.9961
# Epoch 37/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0163 - accuracy: 0.9947
# Epoch 38/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0239 - accuracy: 0.9882
# Epoch 39/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 0.9987
# Epoch 40/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 0.9934
# Epoch 41/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 0.9987
# Epoch 42/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0111 - accuracy: 0.9961
# Epoch 43/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 0.9974
# Epoch 44/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 0.9895
# Epoch 45/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0153 - accuracy: 0.9947
# Epoch 46/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 0.9934
# Epoch 47/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 0.9921
# Epoch 48/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0192 - accuracy: 0.9934
# Epoch 49/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0144 - accuracy: 0.9947
# Epoch 50/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0204 - accuracy: 0.9908
# Epoch 51/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0273 - accuracy: 0.9947
# Epoch 52/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0292 - accuracy: 0.9921
# Epoch 53/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.9908
# Epoch 54/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0141 - accuracy: 0.9947
# Epoch 55/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 0.9987
# Epoch 56/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0283 - accuracy: 0.9855
# Epoch 57/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0139 - accuracy: 0.9921
# Epoch 58/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0254 - accuracy: 0.9961
# Epoch 59/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 0.9921
# Epoch 60/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 0.9961
# Epoch 61/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0264 - accuracy: 0.9882
# Epoch 62/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.9882
# Epoch 63/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 0.9934
# Epoch 64/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0192 - accuracy: 0.9921
# Epoch 65/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 0.9961
# Epoch 66/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0255 - accuracy: 0.9882
# Epoch 67/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 0.9987
# Epoch 68/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 0.9987
# Epoch 69/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0101 - accuracy: 0.9987
# Epoch 70/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0295 - accuracy: 0.9908
# Epoch 71/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0446 - accuracy: 0.9895
# Epoch 72/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.9961
# Epoch 73/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0102 - accuracy: 0.9974
# Epoch 74/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0273 - accuracy: 0.9908
# Epoch 75/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 0.9908
# Epoch 76/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 0.9961
# Epoch 77/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 0.9961
# Epoch 78/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 0.9987
# Epoch 79/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0062 - accuracy: 0.9987
# Epoch 80/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 0.9974
# Epoch 81/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 0.9921
# Epoch 82/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 0.9947
# Epoch 83/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 0.9947
# Epoch 84/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0091 - accuracy: 0.9974
# Epoch 85/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0110 - accuracy: 0.9934
# Epoch 86/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 87/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0059 - accuracy: 0.9987
# Epoch 88/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0093 - accuracy: 0.9974
# Epoch 89/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.9987
# Epoch 90/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 0.9987
# Epoch 91/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 0.9987
# Epoch 92/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0205 - accuracy: 0.9895
# Epoch 93/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 0.9961
# Epoch 94/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0143 - accuracy: 0.9974
# Epoch 95/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0106 - accuracy: 0.9947
# Epoch 96/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0077 - accuracy: 0.9974
# Epoch 97/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0090 - accuracy: 0.9947
# Epoch 98/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0229 - accuracy: 0.9934
# Epoch 99/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 0.9974
# Epoch 100/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 101/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 0.9987
# Epoch 102/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 0.9974
# Epoch 103/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 0.9987
# Epoch 104/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 0.9974
# Epoch 105/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 0.9987
# Epoch 106/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 0.9987
# Epoch 107/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0148 - accuracy: 0.9934
# Epoch 108/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 0.9987
# Epoch 109/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0079 - accuracy: 0.9961
# Epoch 110/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 0.9987
# Epoch 111/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9961
# Epoch 112/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 0.9987
# Epoch 113/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.9961
# Epoch 114/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0114 - accuracy: 0.9974
# Epoch 115/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0213 - accuracy: 0.9947
# Epoch 116/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0194 - accuracy: 0.9961
# Epoch 117/1500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0143 - accuracy: 0.9961
# Epoch 118/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 0.9987
# Epoch 119/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 120/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 0.9974
# Epoch 121/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 122/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 123/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 0.9974
# Epoch 124/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 0.9974
# Epoch 125/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 0.9987
# Epoch 126/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 0.9987
# Epoch 127/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0054 - accuracy: 0.9987
# Epoch 128/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0062 - accuracy: 0.9987
# Epoch 129/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 0.9974
# Epoch 130/1500
# 15/24 [=================>............] - ETA: 0s - loss: 0.0078 - accuracy: 0.9958    Restoring model weights from the end of the best epoch: 100.
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 0.9974
# Epoch 130: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 5.6560 - accuracy: 0.5288
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.65 (17/26)
# Before appending - Cat IDs: 659, Predictions: 659, Actuals: 659, Gender: 659
# After appending - Cat IDs: 867, Predictions: 867, Actuals: 867, Gender: 867
# Final Test Results - Loss: 5.656033039093018, Accuracy: 0.5288461446762085, Precision: 0.522716049382716, Recall: 0.5077403245942572, F1 Score: 0.5121051534401984
# Confusion Matrix:
#  [[53 11 25]
#  [11 13  6]
#  [42  3 44]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5393367478839658
#
# Final Average Loss across all UNSEEN TEST sets: 5.320947706699371
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.551734559237957
#
# Final Average Precision across all UNSEEN TEST sets: 0.5389906681195417
#
# Final Average Recall across all UNSEEN TEST sets: 0.571665016819747

# %%
seed_1_folds_values = [unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1]

seed_1_training_acc_values = cv_training_acc_total

# Plotting all fold metrics
seed_1_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 867, Predictions: 867, Actuals: 867, Gender: 867

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.66 (73/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, senior, adult, adult, adult, se...         adult            adult                   True
# 50    044A             [kitten, adult, adult, kitten, kitten]        kitten           kitten                   True
# 93    097B  [senior, adult, adult, senior, adult, adult, a...         adult            adult                   True
# 94    099A  [adult, adult, senior, kitten, adult, adult, a...         adult            adult                   True
# 1     001A  [adult, adult, senior, senior, senior, senior,...        senior           senior                   True
# 95    100A                                            [adult]         adult            adult                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 52    047A  [adult, senior, kitten, kitten, kitten, adult,...        kitten           kitten                   True
# 51    045A  [kitten, senior, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 49    043A                                   [kitten, kitten]        kitten           kitten                   True
# 39    033A  [adult, adult, adult, adult, adult, senior, ad...         adult            adult                   True
# 48    042A  [kitten, kitten, kitten, adult, kitten, kitten...        kitten           kitten                   True
# 96    101A  [adult, senior, senior, adult, kitten, senior,...        senior           senior                   True
# 46    040A  [kitten, adult, adult, kitten, kitten, adult, ...        kitten           kitten                   True
# 97    102A                                    [senior, adult]         adult            adult                   True
# 44    038A                                    [adult, kitten]         adult            adult                   True
#
  False
# 54    049A                                            [adult]         adult           kitten                  False
# 56    051A  [adult, adult, adult, senior, senior, senior, ...         adult           senior                  False
# 57    051B  [adult, adult, adult, senior, adult, adult, ad...         adult           senior                  False
# 59    053A  [senior, adult, adult, adult, adult, adult, se...         adult           senior                  False
# 62    056A                             [adult, adult, senior]         adult           senior                  False
# 64    058A                            [kitten, adult, kitten]        kitten           senior                  False
# 66    060A                             [adult, adult, kitten]         adult           senior                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 69    063A  [kitten, kitten, kitten, kitten, kitten, adult...        kitten            adult                  False
# 70    064A                           [senior, senior, senior]        senior            adult                  False
# 72    066A                                   [senior, kitten]        kitten            adult                  False
# 109   117A  [senior, adult, adult, senior, senior, adult, ...         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']
# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()
# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')
# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Calculate the class statistics
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    accuracy=('Majority_Correct', lambda x: x.mean() * 100),
    total_count=('Majority_Correct', 'size')
).reset_index()

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group   accuracy  total_count
# 0            adult  78.688525           61
# 1           kitten  66.666667           15
# 2           senior  44.117647           34

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# For each fold
fold_class_stats = full_results.groupby('actual_age_group').agg(
    accuracy=('correct', lambda x: x.mean() * 100),
    total_count=('correct', 'size')
).reset_index()

# Store for final evaluation 
all_class_stats.append(fold_class_stats)

# Log the detailed stats
print("Detailed Class Statistics for this fold:")
print(fold_class_stats)
# Out:
# Detailed Class Statistics for this fold:
#   actual_age_group   accuracy  total_count
# 0            adult  55.733945          436
# 1           kitten  57.657658          111
# 2           senior  51.562500          320

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(fold_class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    218      127     58.26
# 1          M    359      183     50.97
# 2          X    290      162     55.86

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.6636363636363637]
# Total Class Statistics so far:
#  [  actual_age_group   accuracy  total_count
# 0            adult  55.733945          436
# 1           kitten  57.657658          111
# 2           senior  51.562500          320]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      127     58.26
# 1          M    359      183     50.97
# 2          X    290      162     55.86]

# %% [markdown]
# # RANDOM SEED 2

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[1]))
np.random.seed(int(random_seeds[1]))
tf.random.set_seed(int(random_seeds[1]))

# Load datasets
dataframe = pd.read_csv('yamnet_looped_embeddings.csv')



def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 10),
    'senior': (10, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     472
# senior    320
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[1]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

cv_training_acc_total = []
cv_training_acc_best = []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )
    
    accuracy_history = AccuracyHistory()

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_val),
        y=y_train_val
    )
    weight_dict = {i: class_weights[i] for i in range(len(class_weights))}

    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.009272615392034748)
    }
    
    # Full model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.40037235360372386))   
    model_full.add(Dense(3, activation='softmax'))  
    
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=32,
                                  verbose=1, callbacks=[early_stopping, accuracy_history], class_weight=weight_dict)
    
    
    # log epochs
    best_epoch_index = np.argmin(history_full.history['loss'])  
    best_training_accuracy = accuracy_history.acc[best_epoch_index]

    # Append training acc to total  
    all_best_training_acc.append(best_training_accuracy)
    total_training_acc.append(accuracy_history.acc)

    # Append training acc just for this CV
    cv_training_acc_total.append(accuracy_history.acc)
    cv_training_acc_best.append(best_training_accuracy)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
average_fold_f1.append(unseen_set_avg_f1)
average_fold_losses.append(unseen_set_avg_loss)
average_fold_accuracies.append(unseen_set_avg_acc)
average_fold_precisions.append(unseen_set_avg_precision)
average_fold_recalls.append(unseen_set_avg_recall)

# Append all to total lists
all_f1.append(unseen_f1)
all_losses.append(unseen_losses)
all_accuracies.append(unseen_accuracies)
all_precisions.append(unseen_precisions)
all_recalls.append(unseen_recalls)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 055A    20
# 067A    20
# 059A    18
# 029A    17
# 019A    17
# 101A    16
# 106A    15
# 001A    15
# 028A    14
# 097B    14
# 111A    13
# 002A    13
# 039A    12
# 116A    12
# 016A    11
# 036A    11
# 025A    11
# 071A    10
# 015A    10
# 014B    10
# 040A    10
# 045A     9
# 022A     9
# 051B     9
# 072A     9
# 065A     9
# 095A     8
# 010A     8
# 031A     7
# 027A     7
# 053A     7
# 037A     6
# 023A     6
# 025C     6
# 008A     6
# 109A     6
# 070A     5
# 075A     5
# 012A     5
# 044A     5
# 062A     5
# 023B     5
# 009A     4
# 052A     4
# 003A     4
# 105A     4
# 104A     4
# 035A     4
# 006A     3
# 056A     3
# 058A     3
# 113A     3
# 011A     3
# 064A     3
# 060A     3
# 014A     3
# 093A     2
# 025B     2
# 066A     2
# 032A     2
# 018A     2
# 054A     2
# 102A     2
# 073A     1
# 091A     1
# 026B     1
# 004A     1
# 076A     1
# 090A     1
# 115A     1
# 041A     1
# 110A     1
# 024A     1
# 088A     1
# 019B     1
# 026C     1
# 092A     1
# 043A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 000B    20
# 097A    16
# 042A    14
# 051A    12
# 068A    11
# 063A    11
# 005A    11
# 033A     9
# 094A     8
# 013B     8
# 050A     7
# 099A     7
# 117A     7
# 108A     6
# 021A     6
# 007A     6
# 034A     5
# 026A     4
# 038A     2
# 061A     2
# 087A     2
# 069A     2
# 049A     1
# 048A     1
# 096A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    312
# X    220
# F    191
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    135
# F     66
# M     44
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 071A, 020A, 000A, 065A, 023B, 026...
# kitten    [014B, 110A, 109A, 040A, 047A, 045A, 111A, 044...
# senior    [028A, 015A, 106A, 053A, 057A, 001A, 090A, 113...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 000B, 026A, 038A, 007A, 068A, 021A, 034...
# kitten                       [046A, 042A, 049A, 048A, 050A]
# senior                 [117A, 051A, 097A, 094A, 108A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 47, 'kitten': 11, 'senior': 28}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 5, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '006A' '008A' '009A' '010A'
#  '011A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '022A' '023A' '023B' '024A' '025A' '025B' '025C' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '035A' '036A' '037A' '039A' '040A' '041A'
#  '043A' '044A' '045A' '047A' '051B' '052A' '053A' '054A' '055A' '056A'
#  '057A' '058A' '059A' '060A' '062A' '064A' '065A' '066A' '067A' '070A'
#  '071A' '072A' '073A' '074A' '075A' '076A' '088A' '090A' '091A' '092A'
#  '093A' '095A' '097B' '100A' '101A' '102A' '103A' '104A' '105A' '106A'
#  '109A' '110A' '111A' '113A' '115A' '116A']
# Unique Test Group IDs:
# ['000B' '005A' '007A' '013B' '021A' '026A' '033A' '034A' '038A' '042A'
#  '046A' '048A' '049A' '050A' '051A' '061A' '063A' '068A' '069A' '087A'
#  '094A' '096A' '097A' '099A' '108A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'110A'}
# Moved to Test Set:
# {'110A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '006A' '008A' '009A' '010A'
#  '011A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '022A' '023A' '023B' '024A' '025A' '025B' '025C' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '035A' '036A' '037A' '039A' '040A' '041A'
#  '043A' '044A' '045A' '046A' '047A' '051B' '052A' '053A' '054A' '055A'
#  '056A' '057A' '058A' '059A' '060A' '062A' '064A' '065A' '066A' '067A'
#  '070A' '071A' '072A' '073A' '074A' '075A' '076A' '088A' '090A' '091A'
#  '092A' '093A' '095A' '097B' '100A' '101A' '102A' '103A' '104A' '105A'
#  '106A' '109A' '111A' '113A' '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '005A' '007A' '013B' '021A' '026A' '033A' '034A' '038A' '042A'
#  '048A' '049A' '050A' '051A' '061A' '063A' '068A' '069A' '087A' '094A'
#  '096A' '097A' '099A' '108A' '110A' '117A']
# Length of X_train_val:
# 788
# Length of y_train_val:
# 788
# Length of groups_train_val:
# 788
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     367
# senior    269
# kitten     87
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     105
# kitten     89
# senior     51
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     367
# senior    269
# kitten    152
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     105
# senior     51
# kitten     24
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 367, 2: 269, 1: 152})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.4484 - accuracy: 0.5520
# Epoch 2/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5787 - accuracy: 0.7449
# Epoch 3/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3559 - accuracy: 0.8376
# Epoch 4/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3067 - accuracy: 0.8541
# Epoch 5/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2294 - accuracy: 0.8909
# Epoch 6/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2138 - accuracy: 0.9074
# Epoch 7/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1729 - accuracy: 0.9251
# Epoch 8/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1448 - accuracy: 0.9327
# Epoch 9/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1288 - accuracy: 0.9505
# Epoch 10/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1298 - accuracy: 0.9454
# Epoch 11/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1118 - accuracy: 0.9454
# Epoch 12/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0963 - accuracy: 0.9607
# Epoch 13/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0784 - accuracy: 0.9670
# Epoch 14/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0878 - accuracy: 0.9543
# Epoch 15/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1123 - accuracy: 0.9594
# Epoch 16/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0593 - accuracy: 0.9746
# Epoch 17/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0483 - accuracy: 0.9848
# Epoch 18/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0540 - accuracy: 0.9835
# Epoch 19/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0442 - accuracy: 0.9848
# Epoch 20/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0549 - accuracy: 0.9810
# Epoch 21/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0538 - accuracy: 0.9772
# Epoch 22/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0433 - accuracy: 0.9835
# Epoch 23/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0573 - accuracy: 0.9721
# Epoch 24/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0485 - accuracy: 0.9860
# Epoch 25/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 0.9949
# Epoch 26/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0378 - accuracy: 0.9860
# Epoch 27/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0559 - accuracy: 0.9860
# Epoch 28/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0407 - accuracy: 0.9848
# Epoch 29/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0249 - accuracy: 0.9911
# Epoch 30/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0333 - accuracy: 0.9911
# Epoch 31/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0290 - accuracy: 0.9886
# Epoch 32/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0191 - accuracy: 0.9937
# Epoch 33/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0235 - accuracy: 0.9911
# Epoch 34/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0201 - accuracy: 0.9924
# Epoch 35/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0163 - accuracy: 0.9937
# Epoch 36/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 0.9962
# Epoch 37/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 0.9975
# Epoch 38/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 0.9975
# Epoch 39/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0185 - accuracy: 0.9937
# Epoch 40/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0303 - accuracy: 0.9886
# Epoch 41/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.9911
# Epoch 42/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0241 - accuracy: 0.9924
# Epoch 43/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0229 - accuracy: 0.9911
# Epoch 44/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 0.9937
# Epoch 45/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 0.9949
# Epoch 46/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 0.9949
# Epoch 47/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0245 - accuracy: 0.9873
# Epoch 48/1500
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0228 - accuracy: 0.9886
# Epoch 49/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 0.9886
# Epoch 50/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0150 - accuracy: 0.9962
# Epoch 51/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 0.9987
# Epoch 52/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 0.9962
# Epoch 53/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 0.9937
# Epoch 54/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0234 - accuracy: 0.9911
# Epoch 55/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 0.9949
# Epoch 56/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0178 - accuracy: 0.9949
# Epoch 57/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0172 - accuracy: 0.9937
# Epoch 58/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 0.9962
# Epoch 59/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0330 - accuracy: 0.9835
# Epoch 60/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0111 - accuracy: 0.9949
# Epoch 61/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0093 - accuracy: 0.9975
# Epoch 62/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 0.9987
# Epoch 63/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0111 - accuracy: 0.9975
# Epoch 64/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0196 - accuracy: 0.9962
# Epoch 65/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 0.9937
# Epoch 66/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 0.9975
# Epoch 67/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0175 - accuracy: 0.9924
# Epoch 68/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 0.9949
# Epoch 69/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0150 - accuracy: 0.9937
# Epoch 70/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0205 - accuracy: 0.9962
# Epoch 71/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0168 - accuracy: 0.9962
# Epoch 72/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0242 - accuracy: 0.9924
# Epoch 73/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0172 - accuracy: 0.9937
# Epoch 74/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0120 - accuracy: 0.9937
# Epoch 75/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0266 - accuracy: 0.9898
# Epoch 76/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 0.9937
# Epoch 77/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 0.9987
# Epoch 78/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0204 - accuracy: 0.9911
# Epoch 79/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0190 - accuracy: 0.9937
# Epoch 80/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0092 - accuracy: 0.9987
# Epoch 81/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0130 - accuracy: 0.9949
# Epoch 82/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 0.9987
# Epoch 83/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 84/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 0.9987
# Epoch 85/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0036 - accuracy: 0.9987
# Epoch 86/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 0.9987
# Epoch 87/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 88/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 0.9987
# Epoch 89/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 90/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 91/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 0.9962
# Epoch 92/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0121 - accuracy: 0.9949
# Epoch 93/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 94/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 0.9975
# Epoch 95/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 96/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.9975
# Epoch 97/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 0.9987
# Epoch 98/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 99/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0044 - accuracy: 0.9987
# Epoch 100/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 101/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 0.9962
# Epoch 102/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 103/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 0.9987
# Epoch 104/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0166 - accuracy: 0.9911
# Epoch 105/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 0.9949
# Epoch 106/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 0.9975
# Epoch 107/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9987
# Epoch 108/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0191 - accuracy: 0.9911
# Epoch 109/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 0.9949
# Epoch 110/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0166 - accuracy: 0.9924
# Epoch 111/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0204 - accuracy: 0.9911
# Epoch 112/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0170 - accuracy: 0.9924
# Epoch 113/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 114/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0100 - accuracy: 0.9949
# Epoch 115/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 0.9987
# Epoch 116/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0122 - accuracy: 0.9962
# Epoch 117/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 0.9975
# Epoch 118/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 119/1500
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 120/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 0.9975
# Epoch 121/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 0.9911
# Epoch 122/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 0.9975
# Epoch 123/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 0.9962
# Epoch 124/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 0.9987
# Epoch 125/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 0.9987
# Epoch 126/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0160 - accuracy: 0.9911
# Epoch 127/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 0.9975
# Epoch 128/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 0.9937
# Epoch 129/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0119 - accuracy: 0.9975
# Epoch 130/1500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0162 - accuracy: 0.9961Restoring model weights from the end of the best epoch: 100.
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0159 - accuracy: 0.9962
# Epoch 130: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 6.8229 - accuracy: 0.6000
# 6/6 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.65 (17/26)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 180, Predictions: 180, Actuals: 180, Gender: 180
# Final Test Results - Loss: 6.822924613952637, Accuracy: 0.6000000238418579, Precision: 0.5852152023085897, Recall: 0.6298319327731093, F1 Score: 0.6019473081328751
# Confusion Matrix:
#  [[62 10 33]
#  [ 6 18  0]
#  [21  2 28]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 000B    20
# 059A    18
# 019A    17
# 101A    16
# 097A    16
# 106A    15
# 001A    15
# 042A    14
# 097B    14
# 028A    14
# 002A    13
# 051A    12
# 116A    12
# 039A    12
# 036A    11
# 068A    11
# 063A    11
# 016A    11
# 005A    11
# 040A    10
# 071A    10
# 022A     9
# 072A     9
# 033A     9
# 045A     9
# 094A     8
# 010A     8
# 013B     8
# 027A     7
# 053A     7
# 050A     7
# 099A     7
# 117A     7
# 008A     6
# 108A     6
# 023A     6
# 025C     6
# 037A     6
# 021A     6
# 007A     6
# 034A     5
# 075A     5
# 044A     5
# 062A     5
# 070A     5
# 009A     4
# 052A     4
# 105A     4
# 026A     4
# 006A     3
# 064A     3
# 058A     3
# 011A     3
# 056A     3
# 087A     2
# 061A     2
# 038A     2
# 093A     2
# 069A     2
# 025B     2
# 032A     2
# 102A     2
# 054A     2
# 019B     1
# 115A     1
# 041A     1
# 024A     1
# 073A     1
# 096A     1
# 048A     1
# 092A     1
# 049A     1
# 110A     1
# 090A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 055A    20
# 067A    20
# 029A    17
# 111A    13
# 025A    11
# 015A    10
# 014B    10
# 051B     9
# 065A     9
# 095A     8
# 031A     7
# 109A     6
# 023B     5
# 012A     5
# 003A     4
# 104A     4
# 035A     4
# 014A     3
# 113A     3
# 060A     3
# 066A     2
# 018A     2
# 088A     1
# 043A     1
# 026C     1
# 091A     1
# 076A     1
# 004A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    321
# M    270
# F    195
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    86
# F    62
# X    34
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 033A, 000B, 071A, 020A, 000A, 026...
# kitten    [046A, 042A, 110A, 040A, 047A, 049A, 045A, 048...
# senior    [028A, 117A, 106A, 053A, 057A, 001A, 090A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [065A, 023B, 026C, 018A, 029A, 031A, 067A, 035...
# kitten                             [014B, 109A, 111A, 043A]
# senior     [015A, 113A, 051B, 091A, 055A, 025A, 060A, 104A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 45, 'kitten': 12, 'senior': 26}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 17, 'kitten': 4, 'senior': 8}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '005A' '006A' '007A' '008A' '009A'
#  '010A' '011A' '013B' '016A' '019A' '019B' '020A' '021A' '022A' '023A'
#  '024A' '025B' '025C' '026A' '026B' '027A' '028A' '032A' '033A' '034A'
#  '036A' '037A' '038A' '039A' '040A' '041A' '042A' '044A' '045A' '046A'
#  '047A' '048A' '049A' '050A' '051A' '052A' '053A' '054A' '056A' '057A'
#  '058A' '059A' '061A' '062A' '063A' '064A' '068A' '069A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '087A' '090A' '092A' '093A' '094A' '096A'
#  '097A' '097B' '099A' '101A' '102A' '103A' '105A' '106A' '108A' '110A'
#  '115A' '116A' '117A']
# Unique Test Group IDs:
# ['003A' '004A' '012A' '014A' '014B' '015A' '018A' '023B' '025A' '026C'
#  '029A' '031A' '035A' '043A' '051B' '055A' '060A' '065A' '066A' '067A'
#  '076A' '088A' '091A' '095A' '100A' '104A' '109A' '111A' '113A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '005A' '006A' '007A' '008A' '009A'
#  '010A' '011A' '013B' '016A' '019A' '019B' '020A' '021A' '022A' '023A'
#  '024A' '025B' '025C' '026A' '026B' '027A' '028A' '032A' '033A' '034A'
#  '036A' '037A' '038A' '039A' '040A' '041A' '042A' '044A' '045A' '046A'
#  '047A' '048A' '049A' '050A' '051A' '052A' '053A' '054A' '056A' '057A'
#  '058A' '059A' '061A' '062A' '063A' '064A' '068A' '069A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '087A' '090A' '092A' '093A' '094A' '096A'
#  '097A' '097B' '099A' '101A' '102A' '103A' '105A' '106A' '108A' '110A'
#  '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['003A' '004A' '012A' '014A' '014B' '015A' '018A' '023B' '025A' '026C'
#  '029A' '031A' '035A' '043A' '051B' '055A' '060A' '065A' '066A' '067A'
#  '076A' '088A' '091A' '095A' '100A' '104A' '109A' '111A' '113A']
# Length of X_train_val:
# 786
# Length of y_train_val:
# 786
# Length of groups_train_val:
# 786
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     381
# senior    259
# kitten    146
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     91
# senior    61
# kitten    30
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     381
# senior    259
# kitten    146
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     91
# senior    61
# kitten    30
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 381, 2: 259, 1: 146})
# Epoch 1/1500
# 25/25 [==============================] - 1s 8ms/step - loss: 1.2395 - accuracy: 0.5789
# Epoch 2/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5088 - accuracy: 0.7494
# Epoch 3/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3270 - accuracy: 0.8486
# Epoch 4/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2971 - accuracy: 0.8639
# Epoch 5/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2278 - accuracy: 0.8919
# Epoch 6/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2125 - accuracy: 0.8982
# Epoch 7/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1724 - accuracy: 0.9313
# Epoch 8/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1654 - accuracy: 0.9338
# Epoch 9/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1553 - accuracy: 0.9389
# Epoch 10/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1235 - accuracy: 0.9491
# Epoch 11/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1000 - accuracy: 0.9606
# Epoch 12/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0932 - accuracy: 0.9555
# Epoch 13/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0945 - accuracy: 0.9606
# Epoch 14/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0988 - accuracy: 0.9644
# Epoch 15/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0939 - accuracy: 0.9631
# Epoch 16/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0563 - accuracy: 0.9758
# Epoch 17/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0638 - accuracy: 0.9809
# Epoch 18/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0596 - accuracy: 0.9733
# Epoch 19/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0380 - accuracy: 0.9873
# Epoch 20/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0501 - accuracy: 0.9784
# Epoch 21/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0438 - accuracy: 0.9809
# Epoch 22/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0336 - accuracy: 0.9911
# Epoch 23/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0473 - accuracy: 0.9771
# Epoch 24/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0468 - accuracy: 0.9796
# Epoch 25/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0314 - accuracy: 0.9885
# Epoch 26/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0350 - accuracy: 0.9835
# Epoch 27/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0376 - accuracy: 0.9885
# Epoch 28/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0361 - accuracy: 0.9898
# Epoch 29/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0349 - accuracy: 0.9873
# Epoch 30/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0336 - accuracy: 0.9873
# Epoch 31/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0219 - accuracy: 0.9911
# Epoch 32/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 0.9936
# Epoch 33/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0263 - accuracy: 0.9873
# Epoch 34/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0241 - accuracy: 0.9898
# Epoch 35/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0241 - accuracy: 0.9924
# Epoch 36/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0236 - accuracy: 0.9911
# Epoch 37/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0208 - accuracy: 0.9936
# Epoch 38/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0155 - accuracy: 0.9962
# Epoch 39/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 0.9962
# Epoch 40/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0242 - accuracy: 0.9898
# Epoch 41/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 0.9924
# Epoch 42/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0288 - accuracy: 0.9885
# Epoch 43/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 0.9936
# Epoch 44/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0275 - accuracy: 0.9860
# Epoch 45/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0168 - accuracy: 0.9924
# Epoch 46/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 0.9975
# Epoch 47/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 0.9924
# Epoch 48/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0231 - accuracy: 0.9936
# Epoch 49/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 0.9924
# Epoch 50/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0197 - accuracy: 0.9924
# Epoch 51/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0207 - accuracy: 0.9924
# Epoch 52/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0227 - accuracy: 0.9924
# Epoch 53/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0170 - accuracy: 0.9911
# Epoch 54/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 0.9936
# Epoch 55/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0141 - accuracy: 0.9962
# Epoch 56/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0229 - accuracy: 0.9873
# Epoch 57/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0236 - accuracy: 0.9911
# Epoch 58/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 0.9924
# Epoch 59/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0235 - accuracy: 0.9924
# Epoch 60/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0079 - accuracy: 0.9987
# Epoch 61/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 62/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 0.9949
# Epoch 63/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0168 - accuracy: 0.9911
# Epoch 64/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 0.9987
# Epoch 65/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0126 - accuracy: 0.9949
# Epoch 66/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.9987
# Epoch 67/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 0.9936
# Epoch 68/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0269 - accuracy: 0.9885
# Epoch 69/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 0.9949
# Epoch 70/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0178 - accuracy: 0.9936
# Epoch 71/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 0.9949
# Epoch 72/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 0.9975
# Epoch 73/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 0.9936
# Epoch 74/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 0.9924
# Epoch 75/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 76/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.9962
# Epoch 77/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 0.9975
# Epoch 78/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9975
# Epoch 79/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0096 - accuracy: 0.9987
# Epoch 80/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 0.9975
# Epoch 81/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 82/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 0.9936
# Epoch 83/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 0.9936
# Epoch 84/1500
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9975
# Epoch 85/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 0.9936
# Epoch 86/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0080 - accuracy: 0.9962
# Epoch 87/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 0.9949
# Epoch 88/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0103 - accuracy: 0.9949
# Epoch 89/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 0.9949
# Epoch 90/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 0.9962
# Epoch 91/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0126 - accuracy: 0.9962
# Epoch 92/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 0.9975
# Epoch 93/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0115 - accuracy: 0.9962
# Epoch 94/1500
# 18/25 [====================>.........] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 64.
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 0.9987
# Epoch 94: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 3.9529 - accuracy: 0.5604
# 6/6 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.62 (18/29)
# Before appending - Cat IDs: 180, Predictions: 180, Actuals: 180, Gender: 180
# After appending - Cat IDs: 362, Predictions: 362, Actuals: 362, Gender: 362
# Final Test Results - Loss: 3.952930450439453, Accuracy: 0.5604395866394043, Precision: 0.5438177903931328, Recall: 0.5723032886967313, F1 Score: 0.5525823112568461
# Confusion Matrix:
#  [[45 17 29]
#  [10 17  3]
#  [18  3 40]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 055A    20
# 000B    20
# 067A    20
# 029A    17
# 097A    16
# 106A    15
# 097B    14
# 042A    14
# 111A    13
# 051A    12
# 116A    12
# 063A    11
# 016A    11
# 005A    11
# 068A    11
# 025A    11
# 036A    11
# 040A    10
# 015A    10
# 014B    10
# 022A     9
# 045A     9
# 033A     9
# 051B     9
# 072A     9
# 065A     9
# 013B     8
# 095A     8
# 094A     8
# 010A     8
# 031A     7
# 117A     7
# 053A     7
# 099A     7
# 050A     7
# 108A     6
# 007A     6
# 021A     6
# 109A     6
# 037A     6
# 012A     5
# 044A     5
# 075A     5
# 023B     5
# 034A     5
# 052A     4
# 104A     4
# 026A     4
# 003A     4
# 035A     4
# 014A     3
# 058A     3
# 056A     3
# 060A     3
# 113A     3
# 066A     2
# 061A     2
# 018A     2
# 025B     2
# 087A     2
# 069A     2
# 038A     2
# 102A     2
# 041A     1
# 115A     1
# 076A     1
# 004A     1
# 019B     1
# 048A     1
# 091A     1
# 110A     1
# 026C     1
# 073A     1
# 088A     1
# 096A     1
# 043A     1
# 049A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 059A    18
# 019A    17
# 101A    16
# 001A    15
# 028A    14
# 002A    13
# 039A    12
# 071A    10
# 027A     7
# 008A     6
# 025C     6
# 023A     6
# 062A     5
# 070A     5
# 009A     4
# 105A     4
# 011A     3
# 006A     3
# 064A     3
# 093A     2
# 032A     2
# 054A     2
# 092A     1
# 090A     1
# 024A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    244
# M    240
# F    201
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    116
# X    111
# F     56
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [033A, 000B, 000A, 026A, 065A, 023B, 038A, 026...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 049A, 045...
# senior    [117A, 015A, 106A, 053A, 113A, 051B, 116A, 091...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 070A, 071A, 020A, 105A, 062A, 009A, 006...
# kitten                                               [047A]
# senior    [028A, 057A, 001A, 090A, 024A, 101A, 059A, 054...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 46, 'kitten': 15, 'senior': 21}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 16, 'kitten': 1, 'senior': 13}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002B' '003A' '004A' '005A' '007A' '010A' '012A' '013B'
#  '014A' '014B' '015A' '016A' '018A' '019B' '021A' '022A' '023B' '025A'
#  '025B' '026A' '026C' '029A' '031A' '033A' '034A' '035A' '036A' '037A'
#  '038A' '040A' '041A' '042A' '043A' '044A' '045A' '046A' '048A' '049A'
#  '050A' '051A' '051B' '052A' '053A' '055A' '056A' '058A' '060A' '061A'
#  '063A' '065A' '066A' '067A' '068A' '069A' '072A' '073A' '075A' '076A'
#  '087A' '088A' '091A' '094A' '095A' '096A' '097A' '097B' '099A' '100A'
#  '102A' '103A' '104A' '106A' '108A' '109A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['001A' '002A' '006A' '008A' '009A' '011A' '019A' '020A' '023A' '024A'
#  '025C' '026B' '027A' '028A' '032A' '039A' '047A' '054A' '057A' '059A'
#  '062A' '064A' '070A' '071A' '074A' '090A' '092A' '093A' '101A' '105A']
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002B' '003A' '004A' '005A' '007A' '010A' '012A' '013B'
#  '014A' '014B' '015A' '016A' '018A' '019B' '021A' '022A' '023B' '025A'
#  '025B' '026A' '026C' '029A' '031A' '033A' '034A' '035A' '036A' '037A'
#  '038A' '040A' '041A' '042A' '043A' '044A' '045A' '046A' '048A' '049A'
#  '050A' '051A' '051B' '052A' '053A' '055A' '056A' '058A' '060A' '061A'
#  '063A' '065A' '066A' '067A' '068A' '069A' '072A' '073A' '075A' '076A'
#  '087A' '088A' '091A' '094A' '095A' '096A' '097A' '097B' '099A' '100A'
#  '102A' '103A' '104A' '106A' '108A' '109A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002A' '006A' '008A' '009A' '011A' '019A' '020A' '023A' '024A'
#  '025C' '026B' '027A' '028A' '032A' '039A' '047A' '054A' '057A' '059A'
#  '062A' '064A' '070A' '071A' '074A' '090A' '092A' '093A' '101A' '105A']
# Length of X_train_val:
# 685
# Length of y_train_val:
# 685
# Length of groups_train_val:
# 685
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     343
# senior    196
# kitten    146
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     129
# senior    124
# kitten     30
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     343
# senior    196
# kitten    146
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     129
# senior    124
# kitten     30
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 343, 2: 196, 1: 146})
# Epoch 1/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 1.3854 - accuracy: 0.5752
# Epoch 2/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.4376 - accuracy: 0.7985
# Epoch 3/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3106 - accuracy: 0.8642
# Epoch 4/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2711 - accuracy: 0.8672
# Epoch 5/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2233 - accuracy: 0.9080
# Epoch 6/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1968 - accuracy: 0.9109
# Epoch 7/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1787 - accuracy: 0.9197
# Epoch 8/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1542 - accuracy: 0.9474
# Epoch 9/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1354 - accuracy: 0.9460
# Epoch 10/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1026 - accuracy: 0.9591
# Epoch 11/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0980 - accuracy: 0.9518
# Epoch 12/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0837 - accuracy: 0.9708
# Epoch 13/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0848 - accuracy: 0.9591
# Epoch 14/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0741 - accuracy: 0.9781
# Epoch 15/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0552 - accuracy: 0.9839
# Epoch 16/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0829 - accuracy: 0.9606
# Epoch 17/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0692 - accuracy: 0.9781
# Epoch 18/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0395 - accuracy: 0.9883
# Epoch 19/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0341 - accuracy: 0.9898
# Epoch 20/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0352 - accuracy: 0.9927
# Epoch 21/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0322 - accuracy: 0.9912
# Epoch 22/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0384 - accuracy: 0.9825
# Epoch 23/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0566 - accuracy: 0.9825
# Epoch 24/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0593 - accuracy: 0.9752
# Epoch 25/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0499 - accuracy: 0.9839
# Epoch 26/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0482 - accuracy: 0.9825
# Epoch 27/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0346 - accuracy: 0.9839
# Epoch 28/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0351 - accuracy: 0.9869
# Epoch 29/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0269 - accuracy: 0.9898
# Epoch 30/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0268 - accuracy: 0.9927
# Epoch 31/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 0.9898
# Epoch 32/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0339 - accuracy: 0.9927
# Epoch 33/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 0.9883
# Epoch 34/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0267 - accuracy: 0.9883
# Epoch 35/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.9927
# Epoch 36/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 0.9927
# Epoch 37/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 0.9956
# Epoch 38/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0241 - accuracy: 0.9927
# Epoch 39/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 0.9869
# Epoch 40/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0207 - accuracy: 0.9927
# Epoch 41/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0366 - accuracy: 0.9869
# Epoch 42/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0164 - accuracy: 0.9971
# Epoch 43/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0113 - accuracy: 0.9971
# Epoch 44/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0086 - accuracy: 0.9971
# Epoch 45/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 0.9971
# Epoch 46/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 0.9971
# Epoch 47/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0134 - accuracy: 0.9956
# Epoch 48/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0159 - accuracy: 0.9956
# Epoch 49/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0234 - accuracy: 0.9898
# Epoch 50/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0164 - accuracy: 0.9956
# Epoch 51/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0237 - accuracy: 0.9942
# Epoch 52/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0112 - accuracy: 0.9956
# Epoch 53/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 0.9971
# Epoch 54/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 0.9927
# Epoch 55/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 0.9942
# Epoch 56/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 0.9927
# Epoch 57/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0203 - accuracy: 0.9956
# Epoch 58/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0214 - accuracy: 0.9942
# Epoch 59/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 0.9942
# Epoch 60/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0178 - accuracy: 0.9956
# Epoch 61/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0112 - accuracy: 0.9971
# Epoch 62/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0257 - accuracy: 0.9883
# Epoch 63/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 0.9956
# Epoch 64/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 0.9956
# Epoch 65/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9956
# Epoch 66/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0075 - accuracy: 0.9985
# Epoch 67/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0120 - accuracy: 0.9942
# Epoch 68/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0080 - accuracy: 0.9971
# Epoch 69/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 0.9971
# Epoch 70/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0072 - accuracy: 0.9985
# Epoch 71/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 72/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 73/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 74/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 0.9942
# Epoch 75/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 0.9956
# Epoch 76/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0122 - accuracy: 0.9985
# Epoch 77/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 78/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9985
# Epoch 79/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 80/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 81/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 0.9971
# Epoch 82/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0182 - accuracy: 0.9927
# Epoch 83/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 0.9985
# Epoch 84/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 0.9971
# ...
# Confusion Matrix:
#  [[88 13 28]
#  [15  6  9]
#  [55  0 69]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    66
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 055A    20
# 000B    20
# 067A    20
# 059A    18
# 029A    17
# 019A    17
# 097A    16
# 101A    16
# 001A    15
# 028A    14
# 042A    14
# 111A    13
# 002A    13
# 039A    12
# 051A    12
# 068A    11
# 005A    11
# 025A    11
# 063A    11
# 015A    10
# 014B    10
# 071A    10
# 065A     9
# 033A     9
# 051B     9
# 013B     8
# 095A     8
# 094A     8
# 031A     7
# 050A     7
# 099A     7
# 117A     7
# 027A     7
# 007A     6
# 023A     6
# 025C     6
# 108A     6
# 021A     6
# 109A     6
# 008A     6
# 012A     5
# 070A     5
# 034A     5
# 062A     5
# 023B     5
# 035A     4
# 003A     4
# 104A     4
# 026A     4
# 105A     4
# 009A     4
# 064A     3
# 060A     3
# 113A     3
# 014A     3
# 006A     3
# 011A     3
# 032A     2
# 054A     2
# 069A     2
# 038A     2
# 093A     2
# 018A     2
# 061A     2
# 087A     2
# 066A     2
# 026B     1
# 004A     1
# 076A     1
# 092A     1
# 088A     1
# 096A     1
# 043A     1
# 048A     1
# 049A     1
# 024A     1
# 091A     1
# 090A     1
# 026C     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 002B    36
# 103A    33
# 106A    15
# 097B    14
# 116A    12
# 016A    11
# 036A    11
# 040A    10
# 045A     9
# 072A     9
# 022A     9
# 010A     8
# 053A     7
# 037A     6
# 075A     5
# 044A     5
# 052A     4
# 058A     3
# 056A     3
# 102A     2
# 025B     2
# 110A     1
# 073A     1
# 019B     1
# 041A     1
# 115A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    280
# M    246
# F    184
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    110
# X     75
# F     73
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 033A, 000B, 071A, 020A, 026A, 065...
# kitten    [046A, 042A, 014B, 109A, 047A, 049A, 048A, 111...
# senior    [028A, 117A, 015A, 057A, 001A, 090A, 113A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000A, 072A, 002B, 022A, 010A, 075A, 102A, 097...
# kitten                 [110A, 040A, 045A, 044A, 041A, 115A]
# senior           [106A, 053A, 116A, 103A, 016A, 058A, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 48, 'kitten': 10, 'senior': 27}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 14, 'kitten': 6, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000B' '001A' '002A' '003A' '004A' '005A' '006A' '007A' '008A' '009A'
#  '011A' '012A' '013B' '014A' '014B' '015A' '018A' '019A' '020A' '021A'
#  '023A' '023B' '024A' '025A' '025C' '026A' '026B' '026C' '027A' '028A'
#  '029A' '031A' '032A' '033A' '034A' '035A' '038A' '039A' '042A' '043A'
#  '046A' '047A' '048A' '049A' '050A' '051A' '051B' '054A' '055A' '057A'
#  '059A' '060A' '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A'
#  '069A' '070A' '071A' '074A' '076A' '087A' '088A' '090A' '091A' '092A'
#  '093A' '094A' '095A' '096A' '097A' '099A' '100A' '101A' '104A' '105A'
#  '108A' '109A' '111A' '113A' '117A']
# Unique Test Group IDs:
# ['000A' '002B' '010A' '016A' '019B' '022A' '025B' '036A' '037A' '040A'
#  '041A' '044A' '045A' '052A' '053A' '056A' '058A' '072A' '073A' '075A'
#  '097B' '102A' '103A' '106A' '110A' '115A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'007A'}
# Moved to Test Set:
# {'007A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '005A' '006A' '008A' '009A'
#  '011A' '012A' '013B' '014A' '014B' '015A' '018A' '019A' '020A' '021A'
#  '023A' '023B' '024A' '025A' '025C' '026A' '026B' '026C' '027A' '028A'
#  '029A' '031A' '032A' '033A' '034A' '035A' '038A' '039A' '042A' '043A'
#  '046A' '047A' '048A' '049A' '050A' '051A' '051B' '054A' '055A' '057A'
#  '059A' '060A' '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A'
#  '069A' '070A' '071A' '074A' '076A' '087A' '088A' '090A' '091A' '092A'
#  '093A' '094A' '095A' '096A' '097A' '099A' '100A' '101A' '104A' '105A'
#  '108A' '109A' '111A' '113A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '007A' '010A' '016A' '019B' '022A' '025B' '036A' '037A' '040A'
#  '041A' '044A' '045A' '052A' '053A' '056A' '058A' '072A' '073A' '075A'
#  '097B' '102A' '103A' '106A' '110A' '115A' '116A']
# Length of X_train_val:
# 743
# Length of y_train_val:
# 743
# Length of groups_train_val:
# 743
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     325
# senior    236
# kitten    149
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     147
# senior     84
# kitten     27
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     358
# senior    236
# kitten    149
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     114
# senior     84
# kitten     27
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 358, 2: 236, 1: 149})
# Epoch 1/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 1.3114 - accuracy: 0.5693
# Epoch 2/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5285 - accuracy: 0.7564
# Epoch 3/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3406 - accuracy: 0.8466
# Epoch 4/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2461 - accuracy: 0.8923
# Epoch 5/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2078 - accuracy: 0.9233
# Epoch 6/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1782 - accuracy: 0.9273
# Epoch 7/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1920 - accuracy: 0.9166
# Epoch 8/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1643 - accuracy: 0.9367
# Epoch 9/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1238 - accuracy: 0.9462
# Epoch 10/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1396 - accuracy: 0.9462
# Epoch 11/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1017 - accuracy: 0.9596
# Epoch 12/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0993 - accuracy: 0.9610
# Epoch 13/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0986 - accuracy: 0.9596
# Epoch 14/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0881 - accuracy: 0.9583
# Epoch 15/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0963 - accuracy: 0.9650
# Epoch 16/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0608 - accuracy: 0.9812
# Epoch 17/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0577 - accuracy: 0.9785
# Epoch 18/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0516 - accuracy: 0.9852
# Epoch 19/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0412 - accuracy: 0.9892
# Epoch 20/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0388 - accuracy: 0.9892
# Epoch 21/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0404 - accuracy: 0.9879
# Epoch 22/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0514 - accuracy: 0.9838
# Epoch 23/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0350 - accuracy: 0.9892
# Epoch 24/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0419 - accuracy: 0.9865
# Epoch 25/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0327 - accuracy: 0.9919
# Epoch 26/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0304 - accuracy: 0.9919
# Epoch 27/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0288 - accuracy: 0.9946
# Epoch 28/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0368 - accuracy: 0.9906
# Epoch 29/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0255 - accuracy: 0.9946
# Epoch 30/1500
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0283 - accuracy: 0.9919
# Epoch 31/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0251 - accuracy: 0.9933
# Epoch 32/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0224 - accuracy: 0.9946
# Epoch 33/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0147 - accuracy: 0.9960
# Epoch 34/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0421 - accuracy: 0.9838
# Epoch 35/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 0.9973
# Epoch 36/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0252 - accuracy: 0.9852
# Epoch 37/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0316 - accuracy: 0.9852
# Epoch 38/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0125 - accuracy: 0.9960
# Epoch 39/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 0.9960
# Epoch 40/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0245 - accuracy: 0.9906
# Epoch 41/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0255 - accuracy: 0.9906
# Epoch 42/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0202 - accuracy: 0.9933
# Epoch 43/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0265 - accuracy: 0.9892
# Epoch 44/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0242 - accuracy: 0.9933
# Epoch 45/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0246 - accuracy: 0.9933
# Epoch 46/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0261 - accuracy: 0.9892
# Epoch 47/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 0.9987
# Epoch 48/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 0.9973
# Epoch 49/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0168 - accuracy: 0.9973
# Epoch 50/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0103 - accuracy: 0.9960
# Epoch 51/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 52/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0158 - accuracy: 0.9960
# Epoch 53/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0111 - accuracy: 0.9973
# Epoch 54/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 0.9919
# Epoch 55/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.9919
# Epoch 56/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 57/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0113 - accuracy: 0.9973
# Epoch 58/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0195 - accuracy: 0.9946
# Epoch 59/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0205 - accuracy: 0.9946
# Epoch 60/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 0.9933
# Epoch 61/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 62/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 0.9973
# Epoch 63/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0128 - accuracy: 0.9960
# Epoch 64/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.9960
# Epoch 65/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0095 - accuracy: 0.9946
# Epoch 66/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 0.9973
# Epoch 67/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 0.9987
# Epoch 68/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 69/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0128 - accuracy: 0.9973
# Epoch 70/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0257 - accuracy: 0.9906
# Epoch 71/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0242 - accuracy: 0.9879
# Epoch 72/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0207 - accuracy: 0.9919
# Epoch 73/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0320 - accuracy: 0.9906
# Epoch 74/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0083 - accuracy: 0.9973
# Epoch 75/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 0.9906
# Epoch 76/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0113 - accuracy: 0.9973
# Epoch 77/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0275 - accuracy: 0.9919
# Epoch 78/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0203 - accuracy: 0.9919
# Epoch 79/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 0.9946
# Epoch 80/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0121 - accuracy: 0.9973
# Epoch 81/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0131 - accuracy: 0.9973
# Epoch 82/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 0.9973
# Epoch 83/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 0.9987
# Epoch 84/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 0.9960
# Epoch 85/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0075 - accuracy: 0.9973
# Epoch 86/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 0.9973
# Epoch 87/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 0.9987
# Epoch 88/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0197 - accuracy: 0.9946
# Epoch 89/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0167 - accuracy: 0.9919
# Epoch 90/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0164 - accuracy: 0.9919
# Epoch 91/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 0.9919
# Epoch 92/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 0.9973
# Epoch 93/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0168 - accuracy: 0.9960
# Epoch 94/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0174 - accuracy: 0.9946
# Epoch 95/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0086 - accuracy: 0.9987
# Epoch 96/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 0.9973
# Epoch 97/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.9987
# Epoch 98/1500
# 18/24 [=====================>........] - ETA: 0s - loss: 0.0058 - accuracy: 0.9983Restoring model weights from the end of the best epoch: 68.
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 0.9987
# Epoch 98: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 4.0147 - accuracy: 0.5689
# 8/8 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.70 (19/27)
# Before appending - Cat IDs: 645, Predictions: 645, Actuals: 645, Gender: 645
# After appending - Cat IDs: 870, Predictions: 870, Actuals: 870, Gender: 870
# Final Test Results - Loss: 4.014749050140381, Accuracy: 0.5688889026641846, Precision: 0.5534354237562794, Recall: 0.5845864661654135, F1 Score: 0.56294726177145
# Confusion Matrix:
#  [[71 15 28]
#  [ 8 18  1]
#  [42  3 39]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5508807517321378
#
# Final Average Loss across all UNSEEN TEST sets: 4.912459969520569
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.5763250589370728
#
# Final Average Precision across all UNSEEN TEST sets: 0.5475916787167573
#
# Final Average Recall across all UNSEEN TEST sets: 0.5665656015370539

# %%
seed_2_folds_values = [unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1]

seed
  False
# 82    076A                                           [kitten]        kitten            adult                  False
# 76    070A             [adult, senior, senior, adult, senior]        senior            adult                  False
# 6     005A  [adult, senior, adult, senior, senior, senior,...        senior            adult                  False
# 7     006A                            [senior, senior, adult]        senior            adult                  False
# 9     008A         [adult, adult, adult, adult, adult, adult]         adult           senior                  False
# 11    010A  [senior, senior, adult, senior, adult, senior,...        senior            adult                  False
# 16    014B  [adult, adult, senior, senior, senior, kitten,...         adult           kitten                  False
# 17    015A  [adult, adult, senior, senior, adult, adult, s...         adult           senior                  False
# 18    016A  [kitten, adult, adult, adult, adult, adult, se...         adult           senior                  False
# 26    023B            [adult, senior, senior, senior, senior]        senior            adult                  False
# 28    025A  [adult, adult, adult, adult, adult, senior, se...         adult           senior                  False
# 36    029A  [adult, adult, senior, senior, senior, senior,...        senior            adult                  False
# 41    035A                    [kitten, senior, adult, senior]        senior            adult                  False
# 42    036A  [senior, senior, senior, adult, adult, adult, ...        senior            adult                  False
# 44    038A                                   [kitten, kitten]        kitten            adult                  False
# 45    039A  [senior, senior, adult, adult, senior, adult, ...         adult           senior                  False
# 52    047A  [adult, senior, kitten, adult, kitten, adult, ...         adult           kitten                  False
# 56    051A  [adult, adult, senior, adult, senior, senior, ...         adult           senior                  False
# 63    057A  [adult, adult, senior, senior, adult, senior, ...         adult           senior                  False
# 64    058A                            [kitten, adult, senior]         adult           senior                  False
# 66    060A                            [kitten, adult, kitten]        kitten           senior                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 69    063A  [kitten, adult, kitten, kitten, senior, adult,...        kitten            adult                  False
# 72    066A                                   [senior, kitten]        kitten            adult                  False
# 74    068A  [adult, adult, senior, senior, senior, adult, ...        senior            adult                  False
# 109   117A  [senior, adult, adult, senior, adult, adult, s...         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']
# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()
# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')
# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Calculate the class statistics
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    accuracy=('Majority_Correct', lambda x: x.mean() * 100),
    total_count=('Majority_Correct', 'size')
).reset_index()

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group   accuracy  total_count
# 0            adult  75.409836           61
# 1           kitten  66.666667           15
# 2           senior  52.941176           34

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# For each fold
fold_class_stats = full_results.groupby('actual_age_group').agg(
    accuracy=('correct', lambda x: x.mean() * 100),
    total_count=('correct', 'size')
).reset_index()

# Store for final evaluation 
all_class_stats.append(fold_class_stats)

# Log the detailed stats
print("Detailed Class Statistics for this fold:")
print(fold_class_stats)
# Out:
# Detailed Class Statistics for this fold:
#   actual_age_group   accuracy  total_count
# 0            adult  60.592255          439
# 1           kitten  53.153153          111
# 2           senior  55.000000          320

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(fold_class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    218      138     63.30
# 1          M    362      210     58.01
# 2          X    290      153     52.76

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.6636363636363637, 0.6727272727272727]
# Total Class Statistics so far:
#  [  actual_age_group   accuracy  total_count
# 0            adult  55.733945          436
# 1           kitten  57.657658          111
# 2           senior  51.562500          320,   actual_age_group   accuracy  total_count
# 0            adult  60.592255          439
# 1           kitten  53.153153          111
# 2           senior  55.000000          320]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      127     58.26
# 1          M    359      183     50.97
# 2          X    290      162     55.86,   all_gender  count  correct  accuracy
# 0          F    218      138     63.30
# 1          M    362      210     58.01
# 2          X    290      153     52.76]

# %% [markdown]
# # RANDOM SEED 3

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[2]))
np.random.seed(int(random_seeds[2]))
tf.random.set_seed(int(random_seeds[2]))

# Load datasets
dataframe = pd.read_csv('yamnet_looped_embeddings.csv')


def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 10),
    'senior': (10, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     472
# senior    320
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[2]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

cv_training_acc_total = []
cv_training_acc_best = []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )
    
    accuracy_history = AccuracyHistory()

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_val),
        y=y_train_val
    )
    weight_dict = {i: class_weights[i] for i in range(len(class_weights))}

    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.009272615392034748)
    }
    
    # Full model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.40037235360372386))   
    model_full.add(Dense(3, activation='softmax'))  
    
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=32,
                                  verbose=1, callbacks=[early_stopping, accuracy_history], class_weight=weight_dict)
    
    
    # log epochs
    best_epoch_index = np.argmin(history_full.history['loss'])  
    best_training_accuracy = accuracy_history.acc[best_epoch_index]

    # Append training acc to total  
    all_best_training_acc.append(best_training_accuracy)
    total_training_acc.append(accuracy_history.acc)

    # Append training acc just for this CV
    cv_training_acc_total.append(accuracy_history.acc)
    cv_training_acc_best.append(best_training_accuracy)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
average_fold_f1.append(unseen_set_avg_f1)
average_fold_losses.append(unseen_set_avg_loss)
average_fold_accuracies.append(unseen_set_avg_acc)
average_fold_precisions.append(unseen_set_avg_precision)
average_fold_recalls.append(unseen_set_avg_recall)

# Append all to total lists
all_f1.append(unseen_f1)
all_losses.append(unseen_losses)
all_accuracies.append(unseen_accuracies)
all_precisions.append(unseen_precisions)
all_recalls.append(unseen_recalls)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 067A    20
# 000B    20
# 055A    20
# 059A    18
# 029A    17
# 097A    16
# 101A    16
# 106A    15
# 001A    15
# 042A    14
# 028A    14
# 097B    14
# 002A    13
# 116A    12
# 025A    11
# 063A    11
# 005A    11
# 014B    10
# 040A    10
# 015A    10
# 033A     9
# 072A     9
# 051B     9
# 022A     9
# 095A     8
# 010A     8
# 094A     8
# 027A     7
# 053A     7
# 117A     7
# 050A     7
# 025C     6
# 023A     6
# 007A     6
# 108A     6
# 008A     6
# 070A     5
# 075A     5
# 062A     5
# 012A     5
# 034A     5
# 023B     5
# 044A     5
# 052A     4
# 035A     4
# 009A     4
# 026A     4
# 105A     4
# 014A     3
# 064A     3
# 056A     3
# 011A     3
# 058A     3
# 113A     3
# 006A     3
# 032A     2
# 054A     2
# 093A     2
# 102A     2
# 069A     2
# 018A     2
# 061A     2
# 087A     2
# 066A     2
# 038A     2
# 004A     1
# 041A     1
# 076A     1
# 115A     1
# 110A     1
# 073A     1
# 096A     1
# 048A     1
# 049A     1
# 024A     1
# 091A     1
# 026C     1
# 090A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 019A    17
# 111A    13
# 039A    12
# 051A    12
# 068A    11
# 036A    11
# 016A    11
# 071A    10
# 045A     9
# 065A     9
# 013B     8
# 031A     7
# 099A     7
# 021A     6
# 109A     6
# 037A     6
# 003A     4
# 104A     4
# 060A     3
# 025B     2
# 088A     1
# 043A     1
# 092A     1
# 019B     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    299
# X    258
# F    205
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    97
# M    57
# F    52
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 033A, 000B, 020A, 000A, 026A, 023...
# kitten    [046A, 042A, 014B, 110A, 040A, 047A, 049A, 048...
# senior    [028A, 117A, 015A, 106A, 053A, 057A, 001A, 090...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [071A, 065A, 068A, 021A, 013B, 019A, 031A, 092...
# kitten                             [109A, 045A, 111A, 043A]
# senior                 [051A, 103A, 016A, 060A, 104A, 039A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 46, 'kitten': 12, 'senior': 28}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 16, 'kitten': 4, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '005A' '006A' '007A' '008A'
#  '009A' '010A' '011A' '012A' '014A' '014B' '015A' '018A' '020A' '022A'
#  '023A' '023B' '024A' '025A' '025C' '026A' '026B' '026C' '027A' '028A'
#  '029A' '032A' '033A' '034A' '035A' '038A' '040A' '041A' '042A' '044A'
#  '046A' '047A' '048A' '049A' '050A' '051B' '052A' '053A' '054A' '055A'
#  '056A' '057A' '058A' '059A' '061A' '062A' '063A' '064A' '066A' '067A'
#  '069A' '070A' '072A' '073A' '074A' '075A' '076A' '087A' '090A' '091A'
#  '093A' '094A' '095A' '096A' '097A' '097B' '101A' '102A' '105A' '106A'
#  '108A' '110A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['003A' '013B' '016A' '019A' '019B' '021A' '025B' '031A' '036A' '037A'
#  '039A' '043A' '045A' '051A' '060A' '065A' '068A' '071A' '088A' '092A'
#  '099A' '100A' '103A' '104A' '109A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '005A' '006A' '007A' '008A'
#  '009A' '010A' '011A' '012A' '014A' '014B' '015A' '018A' '020A' '022A'
#  '023A' '023B' '024A' '025A' '025C' '026A' '026B' '026C' '027A' '028A'
#  '029A' '032A' '033A' '034A' '035A' '038A' '040A' '041A' '042A' '044A'
#  '046A' '047A' '048A' '049A' '050A' '051B' '052A' '053A' '054A' '055A'
#  '056A' '057A' '058A' '059A' '061A' '062A' '063A' '064A' '066A' '067A'
#  '069A' '070A' '072A' '073A' '074A' '075A' '076A' '087A' '090A' '091A'
#  '093A' '094A' '095A' '096A' '097A' '097B' '101A' '102A' '105A' '106A'
#  '108A' '110A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['003A' '013B' '016A' '019A' '019B' '021A' '025B' '031A' '036A' '037A'
#  '039A' '043A' '045A' '051A' '060A' '065A' '068A' '071A' '088A' '092A'
#  '099A' '100A' '103A' '104A' '109A' '111A']
# Length of X_train_val:
# 762
# Length of y_train_val:
# 762
# Length of groups_train_val:
# 762
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     370
# senior    245
# kitten    147
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     102
# senior     75
# kitten     29
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     370
# senior    245
# kitten    147
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     102
# senior     75
# kitten     29
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 370, 2: 245, 1: 147})
# Epoch 1/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 1.3006 - accuracy: 0.5945
# Epoch 2/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5215 - accuracy: 0.7861
# Epoch 3/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3464 - accuracy: 0.8543
# Epoch 4/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2712 - accuracy: 0.8780
# Epoch 5/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2118 - accuracy: 0.8976
# Epoch 6/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1759 - accuracy: 0.9252
# Epoch 7/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1392 - accuracy: 0.9344
# Epoch 8/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1338 - accuracy: 0.9501
# Epoch 9/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1004 - accuracy: 0.9659
# Epoch 10/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0895 - accuracy: 0.9646
# Epoch 11/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0933 - accuracy: 0.9593
# Epoch 12/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0791 - accuracy: 0.9711
# Epoch 13/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0730 - accuracy: 0.9698
# Epoch 14/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0567 - accuracy: 0.9790
# Epoch 15/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0559 - accuracy: 0.9803
# Epoch 16/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0501 - accuracy: 0.9803
# Epoch 17/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0458 - accuracy: 0.9829
# Epoch 18/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0542 - accuracy: 0.9751
# Epoch 19/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0489 - accuracy: 0.9882
# Epoch 20/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0280 - accuracy: 0.9921
# Epoch 21/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0423 - accuracy: 0.9843
# Epoch 22/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0392 - accuracy: 0.9803
# Epoch 23/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0513 - accuracy: 0.9790
# Epoch 24/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0271 - accuracy: 0.9921
# Epoch 25/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 0.9908
# Epoch 26/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0226 - accuracy: 0.9921
# Epoch 27/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0278 - accuracy: 0.9908
# Epoch 28/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 0.9895
# Epoch 29/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 0.9921
# Epoch 30/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0223 - accuracy: 0.9908
# Epoch 31/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 0.9934
# Epoch 32/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0202 - accuracy: 0.9961
# Epoch 33/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0162 - accuracy: 0.9934
# Epoch 34/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 0.9934
# Epoch 35/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0227 - accuracy: 0.9908
# Epoch 36/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 0.9934
# Epoch 37/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0205 - accuracy: 0.9908
# Epoch 38/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0260 - accuracy: 0.9869
# Epoch 39/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.9934
# Epoch 40/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0173 - accuracy: 0.9908
# Epoch 41/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0137 - accuracy: 0.9961
# Epoch 42/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0100 - accuracy: 0.9974
# Epoch 43/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 0.9961
# Epoch 44/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 0.9974
# Epoch 45/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0184 - accuracy: 0.9961
# Epoch 46/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0183 - accuracy: 0.9934
# Epoch 47/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0174 - accuracy: 0.9921
# Epoch 48/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0143 - accuracy: 0.9961
# Epoch 49/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.9987
# Epoch 50/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.9987
# Epoch 51/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 52/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9934
# Epoch 53/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 0.9934
# Epoch 54/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.9974
# Epoch 55/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.9961
# Epoch 56/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 0.9934
# Epoch 57/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 0.9934
# Epoch 58/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0228 - accuracy: 0.9895
# Epoch 59/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0234 - accuracy: 0.9895
# Epoch 60/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9961
# Epoch 61/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0087 - accuracy: 0.9987
# Epoch 62/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0110 - accuracy: 0.9987
# Epoch 63/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0173 - accuracy: 0.9908
# Epoch 64/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 0.9908
# Epoch 65/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 0.9987
# Epoch 66/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9961
# Epoch 67/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 0.9987
# Epoch 68/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 0.9961
# Epoch 69/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 0.9961
# Epoch 70/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 0.9974
# Epoch 71/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 0.9934
# Epoch 72/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0149 - accuracy: 0.9934
# Epoch 73/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9961
# Epoch 74/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 0.9961
# Epoch 75/1500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0088 - accuracy: 0.9948
# Epoch 76/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0094 - accuracy: 0.9961
# Epoch 77/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 78/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.9987
# Epoch 79/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0088 - accuracy: 0.9974
# Epoch 80/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 0.9934
# Epoch 81/1500
# 14/24 [================>.............] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000    Restoring model weights from the end of the best epoch: 51.
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0050 - accuracy: 0.9987
# Epoch 81: early stopping
# 7/7 [==============================] - 0s 2ms/step - loss: 3.7173 - accuracy: 0.5631
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.73 (19/26)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 206, Predictions: 206, Actuals: 206, Gender: 206
# Final Test Results - Loss: 3.7172791957855225, Accuracy: 0.5631067752838135, Precision: 0.5571584363495304, Recall: 0.6353121478476448, F1 Score: 0.5793851831003534
# Confusion Matrix:
#  [[60 15 27]
#  [ 1 27  1]
#  [41  5 29]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 067A    20
# 059A    18
# 029A    17
# 019A    17
# 101A    16
# 001A    15
# 097B    14
# 028A    14
# 111A    13
# 039A    12
# 116A    12
# 051A    12
# 068A    11
# 036A    11
# 005A    11
# 016A    11
# 040A    10
# 071A    10
# 014B    10
# 065A     9
# 022A     9
# 045A     9
# 072A     9
# 010A     8
# 013B     8
# 094A     8
# 050A     7
# 099A     7
# 031A     7
# 117A     7
# 027A     7
# 021A     6
# 008A     6
# 108A     6
# 109A     6
# 037A     6
# 023A     6
# 044A     5
# 034A     5
# 012A     5
# 003A     4
# 104A     4
# 105A     4
# 026A     4
# 035A     4
# 009A     4
# 014A     3
# 011A     3
# 064A     3
# 060A     3
# 056A     3
# 058A     3
# 025B     2
# 069A     2
# 054A     2
# 061A     2
# 087A     2
# 066A     2
# 102A     2
# 038A     2
# 093A     2
# 041A     1
# 019B     1
# 076A     1
# 115A     1
# 048A     1
# 088A     1
# 096A     1
# 043A     1
# 092A     1
# 049A     1
# 110A     1
# 024A     1
# 091A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000B    20
# 055A    20
# 097A    16
# 106A    15
# 042A    14
# 002A    13
# 025A    11
# 063A    11
# 015A    10
# 033A     9
# 051B     9
# 095A     8
# 053A     7
# 025C     6
# 007A     6
# 075A     5
# 062A     5
# 070A     5
# 023B     5
# 052A     4
# 006A     3
# 113A     3
# 018A     2
# 032A     2
# 090A     1
# 073A     1
# 026C     1
# 004A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    306
# M    277
# F    171
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    86
# M    79
# X    49
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [071A, 020A, 000A, 026A, 065A, 038A, 068A, 021...
# kitten    [046A, 014B, 110A, 109A, 040A, 047A, 049A, 045...
# senior    [028A, 117A, 057A, 001A, 116A, 091A, 051A, 024...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 070A, 033A, 000B, 023B, 026C, 007A, 018...
# kitten                                               [042A]
# senior    [015A, 106A, 053A, 090A, 113A, 051B, 097A, 055...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 44, 'kitten': 15, 'senior': 24}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 1, 'senior': 10}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '003A' '005A' '008A' '009A' '010A' '011A' '012A'
#  '013B' '014A' '014B' '016A' '019A' '019B' '020A' '021A' '022A' '023A'
#  '024A' '025B' '026A' '027A' '028A' '029A' '031A' '034A' '035A' '036A'
#  '037A' '038A' '039A' '040A' '041A' '043A' '044A' '045A' '046A' '047A'
#  '048A' '049A' '050A' '051A' '054A' '056A' '057A' '058A' '059A' '060A'
#  '061A' '064A' '065A' '066A' '067A' '068A' '069A' '071A' '072A' '074A'
#  '076A' '087A' '088A' '091A' '092A' '093A' '094A' '096A' '097B' '099A'
#  '100A' '101A' '102A' '103A' '104A' '105A' '108A' '109A' '110A' '111A'
#  '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000B' '002A' '004A' '006A' '007A' '015A' '018A' '023B' '025A' '025C'
#  '026B' '026C' '032A' '033A' '042A' '051B' '052A' '053A' '055A' '062A'
#  '063A' '070A' '073A' '075A' '090A' '095A' '097A' '106A' '113A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '003A' '005A' '008A' '009A' '010A' '011A' '012A'
#  '013B' '014A' '014B' '016A' '019A' '019B' '020A' '021A' '022A' '023A'
#  '024A' '025B' '026A' '027A' '028A' '029A' '031A' '034A' '035A' '036A'
#  '037A' '038A' '039A' '040A' '041A' '043A' '044A' '045A' '046A' '047A'
#  '048A' '049A' '050A' '051A' '054A' '056A' '057A' '058A' '059A' '060A'
#  '061A' '064A' '065A' '066A' '067A' '068A' '069A' '071A' '072A' '074A'
#  '076A' '087A' '088A' '091A' '092A' '093A' '094A' '096A' '097B' '099A'
#  '100A' '101A' '102A' '103A' '104A' '105A' '108A' '109A' '110A' '111A'
#  '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002A' '004A' '006A' '007A' '015A' '018A' '023B' '025A' '025C'
#  '026B' '026C' '032A' '033A' '042A' '051B' '052A' '053A' '055A' '062A'
#  '063A' '070A' '073A' '075A' '090A' '095A' '097A' '106A' '113A']
# Length of X_train_val:
# 754
# Length of y_train_val:
# 754
# Length of groups_train_val:
# 754
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     370
# senior    222
# kitten    162
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     102
# senior     98
# kitten     14
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     370
# senior    222
# kitten    162
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     102
# senior     98
# kitten     14
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 370, 2: 222, 1: 162})
# Epoch 1/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 1.3007 - accuracy: 0.5955
# Epoch 2/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5004 - accuracy: 0.7533
# Epoch 3/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3350 - accuracy: 0.8369
# Epoch 4/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2757 - accuracy: 0.8820
# Epoch 5/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2431 - accuracy: 0.8806
# Epoch 6/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1937 - accuracy: 0.9191
# Epoch 7/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1839 - accuracy: 0.9271
# Epoch 8/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1506 - accuracy: 0.9297
# Epoch 9/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1281 - accuracy: 0.9469
# Epoch 10/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1105 - accuracy: 0.9549
# Epoch 11/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0859 - accuracy: 0.9708
# Epoch 12/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1009 - accuracy: 0.9589
# Epoch 13/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0795 - accuracy: 0.9761
# Epoch 14/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0687 - accuracy: 0.9735
# Epoch 15/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0624 - accuracy: 0.9788
# Epoch 16/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0837 - accuracy: 0.9629
# Epoch 17/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0665 - accuracy: 0.9748
# Epoch 18/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0570 - accuracy: 0.9788
# Epoch 19/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0567 - accuracy: 0.9801
# Epoch 20/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0438 - accuracy: 0.9867
# Epoch 21/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0460 - accuracy: 0.9841
# Epoch 22/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0437 - accuracy: 0.9867
# Epoch 23/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0571 - accuracy: 0.9748
# Epoch 24/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0420 - accuracy: 0.9881
# Epoch 25/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0331 - accuracy: 0.9881
# Epoch 26/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0419 - accuracy: 0.9828
# Epoch 27/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0300 - accuracy: 0.9881
# Epoch 28/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0242 - accuracy: 0.9907
# Epoch 29/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0339 - accuracy: 0.9907
# Epoch 30/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0264 - accuracy: 0.9907
# Epoch 31/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0284 - accuracy: 0.9867
# Epoch 32/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0357 - accuracy: 0.9801
# Epoch 33/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0316 - accuracy: 0.9881
# Epoch 34/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0370 - accuracy: 0.9854
# Epoch 35/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0236 - accuracy: 0.9934
# Epoch 36/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0305 - accuracy: 0.9907
# Epoch 37/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0161 - accuracy: 0.9947
# Epoch 38/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0293 - accuracy: 0.9881
# Epoch 39/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0169 - accuracy: 0.9934
# Epoch 40/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0165 - accuracy: 0.9934
# Epoch 41/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0178 - accuracy: 0.9934
# Epoch 42/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0322 - accuracy: 0.9854
# Epoch 43/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0202 - accuracy: 0.9934
# Epoch 44/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 0.9894
# Epoch 45/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0122 - accuracy: 0.9987
# Epoch 46/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 0.9920
# Epoch 47/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0107 - accuracy: 0.9934
# Epoch 48/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0263 - accuracy: 0.9934
# Epoch 49/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 0.9973
# Epoch 50/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 0.9973
# Epoch 51/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0258 - accuracy: 0.9894
# Epoch 52/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0151 - accuracy: 0.9920
# Epoch 53/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 0.9947
# Epoch 54/1500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0061 - accuracy: 0.9973
# Epoch 55/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0185 - accuracy: 0.9947
# Epoch 56/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0234 - accuracy: 0.9894
# Epoch 57/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0173 - accuracy: 0.9934
# Epoch 58/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 0.9947
# Epoch 59/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0120 - accuracy: 0.9973
# Epoch 60/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9934
# Epoch 61/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 0.9960
# Epoch 62/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0315 - accuracy: 0.9920
# Epoch 63/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0165 - accuracy: 0.9960
# Epoch 64/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0159 - accuracy: 0.9894
# Epoch 65/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 0.9987
# Epoch 66/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 0.9960
# Epoch 67/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0120 - accuracy: 0.9973
# Epoch 68/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9987
# Epoch 69/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0184 - accuracy: 0.9973
# Epoch 70/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0212 - accuracy: 0.9947
# Epoch 71/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0182 - accuracy: 0.9960
# Epoch 72/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 73/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 0.9960
# Epoch 74/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 0.9960
# Epoch 75/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 76/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9987
# Epoch 77/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 0.9920
# Epoch 78/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 0.9987
# Epoch 79/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0084 - accuracy: 0.9987
# Epoch 80/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 81/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0084 - accuracy: 0.9987
# Epoch 82/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 83/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0185 - accuracy: 0.9947
# Epoch 84/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0084 - accuracy: 0.9960
# Epoch 85/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0196 - accuracy: 0.9907
# Epoch 86/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 0.9973
# Epoch 87/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 88/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 0.9987
# Epoch 89/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 90/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 0.9960
# Epoch 91/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 0.9987
# Epoch 92/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 0.9973
# Epoch 93/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 0.9987
# Epoch 94/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0076 - accuracy: 0.9973
# Epoch 95/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 0.9987
# Epoch 96/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0118 - accuracy: 0.9934
# Epoch 97/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0152 - accuracy: 0.9934
# Epoch 98/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0152 - accuracy: 0.9947
# Epoch 99/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0112 - accuracy: 0.9947
# Epoch 100/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0092 - accuracy: 0.9987
# Epoch 101/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 0.9947
# Epoch 102/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0193 - accuracy: 0.9907
# Epoch 103/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0135 - accuracy: 0.9947
# Epoch 104/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0069 - accuracy: 0.9987
# Epoch 105/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 106/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 0.9987
# Epoch 107/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 108/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0089 - accuracy: 0.9973
# Epoch 109/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 0.9987
# Epoch 110/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9973
# Epoch 111/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 0.9987
# Epoch 112/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 113/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 0.9987
# Epoch 114/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 115/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 0.9973
# Epoch 116/1500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0042 - accuracy: 0.9973
# Epoch 117/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9987
# Epoch 118/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 0.9973
# Epoch 119/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 0.9987
# Epoch 120/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 0.9934
# Epoch 121/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 0.9960
# Epoch 122/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 0.9973
# Epoch 123/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 0.9960
# Epoch 124/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0076 - accuracy: 0.9960
# Epoch 125/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0083 - accuracy: 0.9960
# Epoch 126/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0228 - accuracy: 0.9907
# Epoch 127/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 128/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0036 - accuracy: 0.9987
# Epoch 129/1500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 0.9987
# Epoch 130/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 131/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0059 - accuracy: 0.9960
# Epoch 132/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0120 - accuracy: 0.9960
# Epoch 133/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0148 - accuracy: 0.9960
# Epoch 134/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0157 - accuracy: 0.9934
# Epoch 135/1500
# 24/24 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 0.9934    Restoring model weights from the end of the best epoch: 105.
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 0.9934
# Epoch 135: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 6.6174 - accuracy: 0.5374
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.69 (20/29)
# Before appending - Cat IDs: 206, Predictions: 206, Actuals: 206, Gender: 206
# After appending - Cat IDs: 420, Predictions: 420, Actuals: 420, Gender: 420
# Final Test Results - Loss: 6.617351055145264, Accuracy: 0.5373831987380981, Precision: 0.5363795518207283, Recall: 0.5669601173802855, F1 Score: 0.5485694108783311
# Confusion Matrix:
#  [[59  6 37]
#  [ 4  9  1]
#  [49  2 47]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 103A    33
# 057A    28
# 000B    20
# 055A    20
# 059A    18
# 029A    17
# 019A    17
# 097A    16
# 106A    15
# 001A    15
# 097B    14
# 028A    14
# 042A    14
# 111A    13
# 002A    13
# 039A    12
# 051A    12
# 036A    11
# 068A    11
# 016A    11
# 063A    11
# 025A    11
# 005A    11
# 015A    10
# 071A    10
# 065A     9
# 051B     9
# 033A     9
# 072A     9
# 045A     9
# 013B     8
# 095A     8
# 094A     8
# 031A     7
# 027A     7
# 053A     7
# 099A     7
# 117A     7
# 109A     6
# 007A     6
# 037A     6
# 021A     6
# 025C     6
# 075A     5
# 062A     5
# 070A     5
# 023B     5
# 044A     5
# 052A     4
# 003A     4
# 104A     4
# 026A     4
# 105A     4
# 009A     4
# 060A     3
# 006A     3
# 113A     3
# 102A     2
# 038A     2
# 087A     2
# 061A     2
# 025B     2
# 032A     2
# 018A     2
# 093A     2
# 019B     1
# 115A     1
# 076A     1
# 004A     1
# 026B     1
# 026C     1
# 092A     1
# 073A     1
# 088A     1
# 096A     1
# 043A     1
# 049A     1
# 024A     1
# 090A     1
# 110A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 002B    36
# 047A    30
# 074A    25
# 020A    23
# 067A    20
# 101A    16
# 116A    12
# 014B    10
# 040A    10
# 022A     9
# 010A     8
# 050A     7
# 023A     6
# 008A     6
# 108A     6
# 034A     5
# 012A     5
# 035A     4
# 064A     3
# 058A     3
# 011A     3
# 014A     3
# 056A     3
# 054A     2
# 066A     2
# 069A     2
# 048A     1
# 091A     1
# 041A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    274
# M    224
# F    169
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    132
# F     88
# X     81
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 033A, 000B, 071A, 026A, 065A, 023...
# kitten    [046A, 042A, 110A, 109A, 049A, 045A, 111A, 044...
# senior    [028A, 117A, 015A, 106A, 053A, 057A, 001A, 090...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [020A, 000A, 034A, 002B, 022A, 010A, 074A, 069...
# kitten                 [014B, 040A, 047A, 048A, 050A, 041A]
# senior    [116A, 091A, 101A, 058A, 054A, 108A, 008A, 011...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 47, 'kitten': 10, 'senior': 25}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 6, 'senior': 9}
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Unique Training/Validation Group IDs:
# ['000B' '001A' '002A' '003A' '004A' '005A' '006A' '007A' '009A' '013B'
#  '015A' '016A' '018A' '019A' '019B' '021A' '023B' '024A' '025A' '025B'
#  '025C' '026A' '026B' '026C' '027A' '028A' '029A' '031A' '032A' '033A'
#  '036A' '037A' '038A' '039A' '042A' '043A' '044A' '045A' '046A' '049A'
#  '051A' '051B' '052A' '053A' '055A' '057A' '059A' '060A' '061A' '062A'
#  '063A' '065A' '068A' '070A' '071A' '072A' '073A' '075A' '076A' '087A'
#  '088A' '090A' '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A'
#  '100A' '102A' '103A' '104A' '105A' '106A' '109A' '110A' '111A' '113A'
#  '115A' '117A']
# Unique Test Group IDs:
# ['000A' '002B' '008A' '010A' '011A' '012A' '014A' '014B' '020A' '022A'
#  '023A' '034A' '035A' '040A' '041A' '047A' '048A' '050A' '054A' '056A'
#  '058A' '064A' '066A' '067A' '069A' '074A' '091A' '101A' '108A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'073A'}
# Moved to Test Set:
# {'073A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '005A' '006A' '007A' '009A'
#  '013B' '015A' '016A' '018A' '019A' '019B' '021A' '023B' '024A' '025A'
#  '025B' '025C' '026A' '026B' '026C' '027A' '028A' '029A' '031A' '032A'
#  '033A' '036A' '037A' '038A' '039A' '042A' '043A' '044A' '045A' '046A'
#  '049A' '051A' '051B' '052A' '053A' '055A' '057A' '059A' '060A' '061A'
#  '062A' '063A' '065A' '068A' '070A' '071A' '072A' '075A' '076A' '087A'
#  '088A' '090A' '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A'
#  '100A' '102A' '103A' '104A' '105A' '106A' '109A' '110A' '111A' '113A'
#  '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '008A' '010A' '011A' '012A' '014A' '014B' '020A' '022A' '023A'
#  '034A' '035A' '040A' '041A' '047A' '048A' '050A' '054A' '056A' '058A'
#  '064A' '066A' '067A' '069A' '073A' '074A' '091A' '101A' '108A' '116A']
# Length of X_train_val:
# 705
# Length of y_train_val:
# 705
# Length of groups_train_val:
# 705
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     282
# senior    268
# kitten    117
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     190
# kitten     59
# senior     52
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     320
# senior    268
# kitten    117
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     152
# kitten     59
# senior     52
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 320, 2: 268, 1: 117})
# Epoch 1/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 1.4477 - accuracy: 0.5546
# Epoch 2/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.4839 - accuracy: 0.7801
# Epoch 3/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.3361 - accuracy: 0.8426
# Epoch 4/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2626 - accuracy: 0.8738
# Epoch 5/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2323 - accuracy: 0.8922
# Epoch 6/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1811 - accuracy: 0.9163
# Epoch 7/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1594 - accuracy: 0.9333
# Epoch 8/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1477 - accuracy: 0.9404
# Epoch 9/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1110 - accuracy: 0.9518
# Epoch 10/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1065 - accuracy: 0.9574
# Epoch 11/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1076 - accuracy: 0.9560
# Epoch 12/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0936 - accuracy: 0.9645
# Epoch 13/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0873 - accuracy: 0.9716
# Epoch 14/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0689 - accuracy: 0.9801
# Epoch 15/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0870 - accuracy: 0.9617
# Epoch 16/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0589 - accuracy: 0.9801
# Epoch 17/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0504 - accuracy: 0.9787
# Epoch 18/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9745
# Epoch 19/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0632 - accuracy: 0.9801
# Epoch 20/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0570 - accuracy: 0.9787
# Epoch 21/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0403 - accuracy: 0.9915
# Epoch 22/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0500 - accuracy: 0.9830
# Epoch 23/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0436 - accuracy: 0.9830
# Epoch 24/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0683 - accuracy: 0.9759
# Epoch 25/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0405 - accuracy: 0.9858
# Epoch 26/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0333 - accuracy: 0.9887
# Epoch 27/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0511 - accuracy: 0.9830
# Epoch 28/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0419 - accuracy: 0.9787
# Epoch 29/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0312 - accuracy: 0.9929
# Epoch 30/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0242 - accuracy: 0.9901
# Epoch 31/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 0.9915
# Epoch 32/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0244 - accuracy: 0.9929
# Epoch 33/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0433 - accuracy: 0.9830
# Epoch 34/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0228 - accuracy: 0.9929
# Epoch 35/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0267 - accuracy: 0.9887
# Epoch 36/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0210 - accuracy: 0.9943
# Epoch 37/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0198 - accuracy: 0.9915
# Epoch 38/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0275 - accuracy: 0.9929
# Epoch 39/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0137 - accuracy: 0.9943
# Epoch 40/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0476 - accuracy: 0.9801
# Epoch 41/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0259 - accuracy: 0.9887
# Epoch 42/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0363 - accuracy: 0.9887
# Epoch 43/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0196 - accuracy: 0.9915
# Epoch 44/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0267 - accuracy: 0.9915
# Epoch 45/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0237 - accuracy: 0.9915
# Epoch 46/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0169 - accuracy: 0.9943
# Epoch 47/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0439 - accuracy: 0.9830
# Epoch 48/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0150 - accuracy: 0.9943
# Epoch 49/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0372 - accuracy: 0.9872
# Epoch 50/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0180 - accuracy: 0.9915
# Epoch 51/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0170 - accuracy: 0.9972
# Epoch 52/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0171 - accuracy: 0.9929
# Epoch 53/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 0.9943
# Epoch 54/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0129 - accuracy: 0.9943
# Epoch 55/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 0.9943
# Epoch 56/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0240 - accuracy: 0.9957
# Epoch 57/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 0.9957
# Epoch 58/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0264 - accuracy: 0.9915
# Epoch 59/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0180 - accuracy: 0.9929
# Epoch 60/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0115 - accuracy: 0.9972
# Epoch 61/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0091 - accuracy: 0.9986
# Epoch 62/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.9943
# Epoch 63/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0166 - accuracy: 0.9943
# Epoch 64/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 0.9915
# Epoch 65/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 0.9957
# Epoch 66/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0113 - accuracy: 0.9972
# Epoch 67/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9986
# Epoch 68/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 0.9972
# Epoch 69/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0144 - accuracy: 0.9972
# Epoch 70/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 0.9943
# Epoch 71/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 0.9972
# Epoch 72/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0100 - accuracy: 0.9972
# Epoch 73/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 74/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0091 - accuracy: 0.9986
# Epoch 75/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0119 - accuracy: 0.9972
# Epoch 76/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 0.9972
# Epoch 77/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0112 - accuracy: 0.9943
# Epoch 78/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0171 - accuracy: 0.9957
# Epoch 79/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0164 - accuracy: 0.9957
# Epoch 80/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 0.9986
# Epoch 81/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0113 - accuracy: 0.9943
# Epoch 82/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9929
# Epoch 83/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 0.9929
# Epoch 84/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0128 - accuracy: 0.9972
# Epoch 85/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0218 - accuracy: 0.9929
# Epoch 86/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 87/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0055 - accuracy: 0.9986
# Epoch 88/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 0.9972
# Epoch 89/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0120 - accuracy: 0.9943
# Epoch 90/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0153 - accuracy: 0.9943
# Epoch 91/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0197 - accuracy: 0.9943
# Epoch 92/1500
# ...
# 099A     7
# 050A     7
# 031A     7
# 053A     7
# 108A     6
# 109A     6
# 037A     6
# 008A     6
# 007A     6
# 021A     6
# 023A     6
# 025C     6
# 023B     5
# 062A     5
# 070A     5
# 075A     5
# 034A     5
# 012A     5
# 104A     4
# 035A     4
# 003A     4
# 052A     4
# 060A     3
# 011A     3
# 113A     3
# 014A     3
# 064A     3
# 006A     3
# 056A     3
# 058A     3
# 018A     2
# 025B     2
# 066A     2
# 069A     2
# 032A     2
# 054A     2
# 041A     1
# 019B     1
# 004A     1
# 026B     1
# 091A     1
# 026C     1
# 073A     1
# 088A     1
# 043A     1
# 048A     1
# 090A     1
# 092A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 057A    28
# 059A    18
# 029A    17
# 001A    15
# 028A    14
# 097B    14
# 005A    11
# 072A     9
# 094A     8
# 117A     7
# 027A     7
# 044A     5
# 105A     4
# 009A     4
# 026A     4
# 102A     2
# 038A     2
# 061A     2
# 087A     2
# 093A     2
# 049A     1
# 110A     1
# 024A     1
# 096A     1
# 115A     1
# 076A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    268
# X    227
# F    226
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    128
# M     88
# F     31
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 033A, 000B, 071A, 020A, 000A, 065...
# kitten    [042A, 014B, 109A, 040A, 047A, 045A, 048A, 111...
# senior    [015A, 106A, 053A, 090A, 113A, 051B, 116A, 091...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [026A, 038A, 105A, 072A, 005A, 009A, 029A, 102...
# kitten                       [046A, 110A, 049A, 044A, 115A]
# senior    [028A, 117A, 057A, 001A, 024A, 094A, 059A, 061...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 49, 'kitten': 11, 'senior': 25}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 13, 'kitten': 5, 'senior': 9}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '004A' '006A' '007A' '008A' '010A'
#  '011A' '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '022A' '023A' '023B' '025A' '025B' '025C' '026B' '026C'
#  '031A' '032A' '033A' '034A' '035A' '036A' '037A' '039A' '040A' '041A'
#  '042A' '043A' '045A' '047A' '048A' '050A' '051A' '051B' '052A' '053A'
#  '054A' '055A' '056A' '058A' '060A' '062A' '063A' '064A' '065A' '066A'
#  '067A' '068A' '069A' '070A' '071A' '073A' '074A' '075A' '088A' '090A'
#  '091A' '092A' '095A' '097A' '099A' '100A' '101A' '103A' '104A' '106A'
#  '108A' '109A' '111A' '113A' '116A']
# Unique Test Group IDs:
# ['001A' '005A' '009A' '024A' '026A' '027A' '028A' '029A' '038A' '044A'
#  '046A' '049A' '057A' '059A' '061A' '072A' '076A' '087A' '093A' '094A'
#  '096A' '097B' '102A' '105A' '110A' '115A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'041A'}
# Moved to Test Set:
# {'041A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '004A' '006A' '007A' '008A' '010A'
#  '011A' '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '022A' '023A' '023B' '025A' '025B' '025C' '026B' '026C'
#  '031A' '032A' '033A' '034A' '035A' '036A' '037A' '039A' '040A' '042A'
#  '043A' '045A' '046A' '047A' '048A' '050A' '051A' '051B' '052A' '053A'
#  '054A' '055A' '056A' '058A' '060A' '062A' '063A' '064A' '065A' '066A'
#  '067A' '068A' '069A' '070A' '071A' '073A' '074A' '075A' '088A' '090A'
#  '091A' '092A' '095A' '097A' '099A' '100A' '101A' '103A' '104A' '106A'
#  '108A' '109A' '111A' '113A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '005A' '009A' '024A' '026A' '027A' '028A' '029A' '038A' '041A'
#  '044A' '049A' '057A' '059A' '061A' '072A' '076A' '087A' '093A' '094A'
#  '096A' '097B' '102A' '105A' '110A' '115A' '117A']
# Length of X_train_val:
# 786
# Length of y_train_val:
# 786
# Length of groups_train_val:
# 786
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     394
# senior    225
# kitten    102
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# senior    95
# adult     78
# kitten    74
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     394
# senior    225
# kitten    167
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# senior    95
# adult     78
# kitten     9
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 394, 2: 225, 1: 167})
# Epoch 1/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4093 - accuracy: 0.5700
# Epoch 2/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5969 - accuracy: 0.7341
# Epoch 3/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3477 - accuracy: 0.8372
# Epoch 4/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2889 - accuracy: 0.8766
# Epoch 5/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2442 - accuracy: 0.8855
# Epoch 6/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1884 - accuracy: 0.9211
# Epoch 7/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1701 - accuracy: 0.9389
# Epoch 8/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1504 - accuracy: 0.9364
# Epoch 9/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1562 - accuracy: 0.9351
# Epoch 10/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1191 - accuracy: 0.9606
# Epoch 11/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1118 - accuracy: 0.9555
# Epoch 12/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1035 - accuracy: 0.9580
# Epoch 13/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0891 - accuracy: 0.9695
# Epoch 14/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0739 - accuracy: 0.9720
# Epoch 15/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0874 - accuracy: 0.9669
# Epoch 16/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0523 - accuracy: 0.9784
# Epoch 17/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0599 - accuracy: 0.9809
# Epoch 18/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0595 - accuracy: 0.9784
# Epoch 19/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0549 - accuracy: 0.9771
# Epoch 20/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0484 - accuracy: 0.9835
# Epoch 21/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0485 - accuracy: 0.9809
# Epoch 22/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0430 - accuracy: 0.9835
# Epoch 23/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0399 - accuracy: 0.9873
# Epoch 24/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0484 - accuracy: 0.9835
# Epoch 25/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0498 - accuracy: 0.9746
# Epoch 26/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0378 - accuracy: 0.9847
# Epoch 27/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0353 - accuracy: 0.9847
# Epoch 28/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0381 - accuracy: 0.9898
# Epoch 29/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0233 - accuracy: 0.9936
# Epoch 30/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0376 - accuracy: 0.9835
# Epoch 31/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 0.9835
# Epoch 32/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0151 - accuracy: 0.9949
# Epoch 33/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0288 - accuracy: 0.9873
# Epoch 34/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0244 - accuracy: 0.9911
# Epoch 35/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0310 - accuracy: 0.9835
# Epoch 36/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0416 - accuracy: 0.9860
# Epoch 37/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 0.9911
# Epoch 38/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0170 - accuracy: 0.9975
# Epoch 39/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0150 - accuracy: 0.9975
# Epoch 40/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 0.9924
# Epoch 41/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 0.9975
# Epoch 42/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0201 - accuracy: 0.9885
# Epoch 43/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 44/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0227 - accuracy: 0.9911
# Epoch 45/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 0.9987
# Epoch 46/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0148 - accuracy: 0.9949
# Epoch 47/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 0.9936
# Epoch 48/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0157 - accuracy: 0.9949
# Epoch 49/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 50/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 0.9949
# Epoch 51/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0201 - accuracy: 0.9936
# Epoch 52/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 0.9885
# Epoch 53/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 0.9885
# Epoch 54/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0231 - accuracy: 0.9936
# Epoch 55/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 0.9975
# Epoch 56/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0159 - accuracy: 0.9936
# Epoch 57/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 0.9936
# Epoch 58/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9987
# Epoch 59/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0230 - accuracy: 0.9962
# Epoch 60/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 0.9949
# Epoch 61/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0190 - accuracy: 0.9949
# Epoch 62/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 0.9949
# Epoch 63/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 0.9975
# Epoch 64/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 0.9962
# Epoch 65/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 0.9987
# Epoch 66/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 67/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 68/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 0.9975
# Epoch 69/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 0.9987
# Epoch 70/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 0.9975
# Epoch 71/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 0.9962
# Epoch 72/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.9962
# Epoch 73/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 74/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 0.9936
# Epoch 75/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 0.9898
# Epoch 76/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 0.9936
# Epoch 77/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0093 - accuracy: 0.9962
# Epoch 78/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9936
# Epoch 79/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 0.9975
# Epoch 80/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0052 - accuracy: 0.9987
# Epoch 81/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 0.9975
# Epoch 82/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 0.9975
# Epoch 83/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 0.9987
# Epoch 84/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 0.9898
# Epoch 85/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0100 - accuracy: 0.9975
# Epoch 86/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 0.9987
# Epoch 87/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0069 - accuracy: 0.9987
# Epoch 88/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 0.9987
# Epoch 89/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 0.9962
# Epoch 90/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 91/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 0.9975
# Epoch 92/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0054 - accuracy: 0.9975
# Epoch 93/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 0.9975
# Epoch 94/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 0.9936
# Epoch 95/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0069 - accuracy: 0.9962
# Epoch 96/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 0.9962
# Epoch 97/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 0.9987
# Epoch 98/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 99/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9987
# Epoch 100/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 0.9949
# Epoch 101/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 0.9987
# Epoch 102/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0058 - accuracy: 0.9987
# Epoch 103/1500
# 17/25 [===================>..........] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 73.
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0048 - accuracy: 0.9987
# Epoch 103: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 4.1972 - accuracy: 0.5714
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.74 (20/27)
# Before appending - Cat IDs: 683, Predictions: 683, Actuals: 683, Gender: 683
# After appending - Cat IDs: 865, Predictions: 865, Actuals: 865, Gender: 865
# Final Test Results - Loss: 4.197205066680908, Accuracy: 0.5714285969734192, Precision: 0.48926084083168114, Recall: 0.563907632328685, F1 Score: 0.5062686576986323
# Confusion Matrix:
#  [[41 12 25]
#  [ 4  5  0]
#  [34  3 58]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5287998578339783
#
# Final Average Loss across all UNSEEN TEST sets: 4.554349422454834
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.5482077747583389
#
# Final Average Precision across all UNSEEN TEST sets: 0.5167195888232594
#
# Final Average Recall across all UNSEEN TEST sets: 0.5689209436473711

# %%
seed_3_folds_values = [unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1]

seed_3_training_acc_values = cv_training_acc_total

# Plotting all fold metrics
seed_3_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 865, Predictions: 865, Actuals: 865, Gender: 865

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.70 (77/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, senior, adult, adult, adult, adult, se...         adult            adult                   True
# 78    072A  [adult, kitten, senior, adult, adult, kitten, ...         adult            adult                   True
# 76    070A              [adult, senior, senior, adult, adult]         adult            adult                   True
# 75    069A                                    [senior, adult]         adult            adult                   True
# 74    068A  [senior, adult, senior, adult, senior, senior,...         adult            adult                   True
# 73    067A  [adult, kitten, kitten, kitten, kitten, adult,...         adult            adult                   True
# 71    065A  [adult, senior, adult, kitten, adult, adult, k...         adult            adult                   True
# 70    064A                            [adult, kitten, senior]         adult            adult                   True
# 68    062A               [adult, adult, adult, senior, adult]         adult            adult                   True
# 65    059A  [senior, senior, senior, senior, senior, senio...        senior           senior                   True
# 64    058A                           [senior, senior, senior]        senior           senior                   True
# 63    057A  [adult, adult, senior, senior, adult, senior, ...        senior           senior                   True
# 62    056A                           [senior, senior, senior]        senior           senior                   True
# 59    053A  [senior, senior, kitten, adult, adult, senior,...        senior           senior                   True
# 58    052A                     [adult, adult, senior, senior]         adult            adult                   True
# 57    051B  [senior, senior, adult, senior, adult, senior,...        senior           senior                   True
# 1     001A  [adult, adult, senior, senior, senior, senior,...        senior           senior                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A  [kitten, senior, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 50    044A             [kitten, adult, adult, kitten, kitten]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 77    071A  [adult, senior, adult, kitten, senior, senior,...         adult            adult                   True
# 79    073A                                     [adult, adult]         adult            adult                   True
# 46    040A  [kitten, adult, adult, kitten, kitten, adult, ...        kitten           kitten                   True
# 80    074A  [kitten, kitten, adult, adult, adult, adult, k...         adult            adult                   True
# 108   116A  [senior, senior, adult, senior, adult, senior,...        senior           senior                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                           [senior, senior, senior]        senior           senior                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 103   109A   [kitten, kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 100   105A                     [senior, adult, adult, kitten]         adult            adult                   True
# 97    102A                                    [senior, adult]         adult            adult                   True
# 96    101A  [senior, senior, senior, adult, senior, senior...        senior           senior                   True
# 94    099A  [adult, kitten, senior, kitten, kitten, adult,...         adult            adult                   True
# 93    097B  [senior, senior, adult, kitten, adult, adult, ...         adult            adult                   True
# 92    097A  [adult, senior, senior, adult
adult           senior                  False
# 82    076A                                           [kitten]        kitten            adult                  False
# 18    016A  [kitten, adult, adult, senior, adult, adult, s...         adult           senior                  False
# 85    090A                                            [adult]         adult           senior                  False
# 86    091A                                            [adult]         adult           senior                  False
# 17    015A  [adult, adult, senior, senior, adult, adult, s...         adult           senior                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 88    093A                                     [adult, adult]         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']
# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()
# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')
# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Calculate the class statistics
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    accuracy=('Majority_Correct', lambda x: x.mean() * 100),
    total_count=('Majority_Correct', 'size')
).reset_index()

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group   accuracy  total_count
# 0            adult  80.327869           61
# 1           kitten  73.333333           15
# 2           senior  50.000000           34

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# For each fold
fold_class_stats = full_results.groupby('actual_age_group').agg(
    accuracy=('correct', lambda x: x.mean() * 100),
    total_count=('correct', 'size')
).reset_index()

# Store for final evaluation 
all_class_stats.append(fold_class_stats)

# Log the detailed stats
print("Detailed Class Statistics for this fold:")
print(fold_class_stats)
# Out:
# Detailed Class Statistics for this fold:
#   actual_age_group   accuracy  total_count
# 0            adult  56.221198          434
# 1           kitten  54.054054          111
# 2           senior  52.500000          320

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(fold_class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    218      126     57.80
# 1          M    356      181     50.84
# 2          X    291      165     56.70

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.6636363636363637, 0.6727272727272727, 0.7]
# Total Class Statistics so far:
#  [  actual_age_group   accuracy  total_count
# 0            adult  55.733945          436
# 1           kitten  57.657658          111
# 2           senior  51.562500          320,   actual_age_group   accuracy  total_count
# 0            adult  60.592255          439
# 1           kitten  53.153153          111
# 2           senior  55.000000          320,   actual_age_group   accuracy  total_count
# 0            adult  56.221198          434
# 1           kitten  54.054054          111
# 2           senior  52.500000          320]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      127     58.26
# 1          M    359      183     50.97
# 2          X    290      162     55.86,   all_gender  count  correct  accuracy
# 0          F    218      138     63.30
# 1          M    362      210     58.01
# 2          X    290      153     52.76,   all_gender  count  correct  accuracy
# 0          F    218      126     57.80
# 1          M    356      181     50.84
# 2          X    291      165     56.70]

# %% [markdown]
# # RANDOM SEED 4

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[3])) 
np.random.seed(int(random_seeds[3]))
tf.random.set_seed(int(random_seeds[3]))

# Load datasets
dataframe = pd.read_csv('yamnet_looped_embeddings.csv')


def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 10),
    'senior': (10, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     472
# senior    320
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[3]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

cv_training_acc_total = []
cv_training_acc_best = []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )
    
    accuracy_history = AccuracyHistory()

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_val),
        y=y_train_val
    )
    weight_dict = {i: class_weights[i] for i in range(len(class_weights))}

    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.009272615392034748)
    }
    
    # Full model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.40037235360372386))   
    model_full.add(Dense(3, activation='softmax'))  
    
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=32,
                                  verbose=1, callbacks=[early_stopping, accuracy_history], class_weight=weight_dict)
    
    
    # log epochs
    best_epoch_index = np.argmin(history_full.history['loss'])  
    best_training_accuracy = accuracy_history.acc[best_epoch_index]

    # Append training acc to total  
    all_best_training_acc.append(best_training_accuracy)
    total_training_acc.append(accuracy_history.acc)

    # Append training acc just for this CV
    cv_training_acc_total.append(accuracy_history.acc)
    cv_training_acc_best.append(best_training_accuracy)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
average_fold_f1.append(unseen_set_avg_f1)
average_fold_losses.append(unseen_set_avg_loss)
average_fold_accuracies.append(unseen_set_avg_acc)
average_fold_precisions.append(unseen_set_avg_precision)
average_fold_recalls.append(unseen_set_avg_recall)

# Append all to total lists
all_f1.append(unseen_f1)
all_losses.append(unseen_losses)
all_accuracies.append(unseen_accuracies)
all_precisions.append(unseen_precisions)
all_recalls.append(unseen_recalls)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 074A    25
# 020A    23
# 067A    20
# 059A    18
# 029A    17
# 019A    17
# 101A    16
# 106A    15
# 097B    14
# 028A    14
# 002A    13
# 111A    13
# 051A    12
# 039A    12
# 116A    12
# 016A    11
# 025A    11
# 005A    11
# 063A    11
# 068A    11
# 071A    10
# 015A    10
# 040A    10
# 014B    10
# 072A     9
# 045A     9
# 065A     9
# 022A     9
# 033A     9
# 051B     9
# 010A     8
# 099A     7
# 053A     7
# 027A     7
# 108A     6
# 021A     6
# 109A     6
# 008A     6
# 037A     6
# 007A     6
# 025C     6
# 023B     5
# 062A     5
# 070A     5
# 012A     5
# 075A     5
# 104A     4
# 052A     4
# 003A     4
# 035A     4
# 009A     4
# 026A     4
# 105A     4
# 060A     3
# 064A     3
# 056A     3
# 058A     3
# 006A     3
# 113A     3
# 054A     2
# 102A     2
# 087A     2
# 093A     2
# 066A     2
# 069A     2
# 032A     2
# 018A     2
# 048A     1
# 026B     1
# 004A     1
# 076A     1
# 041A     1
# 019B     1
# 026C     1
# 091A     1
# 024A     1
# 110A     1
# 073A     1
# 049A     1
# 096A     1
# 043A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 057A    28
# 000B    20
# 055A    20
# 097A    16
# 001A    15
# 042A    14
# 036A    11
# 095A     8
# 013B     8
# 094A     8
# 117A     7
# 050A     7
# 031A     7
# 023A     6
# 034A     5
# 044A     5
# 011A     3
# 014A     3
# 061A     2
# 038A     2
# 025B     2
# 092A     1
# 088A     1
# 090A     1
# 115A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    315
# X    202
# F    184
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    153
# F     73
# M     41
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 033A, 071A, 020A, 000A, 026A, 065...
# kitten    [014B, 110A, 109A, 040A, 047A, 049A, 045A, 048...
# senior    [028A, 015A, 106A, 053A, 113A, 051B, 116A, 091...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000B, 038A, 034A, 013B, 031A, 092A, 023A, 036...
# kitten                       [046A, 042A, 044A, 050A, 115A]
# senior    [117A, 057A, 001A, 090A, 097A, 094A, 055A, 061...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 50, 'kitten': 11, 'senior': 25}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 12, 'kitten': 5, 'senior': 9}
# Unique Training/Validation Group IDs:
# ['000A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '008A' '009A'
#  '010A' '012A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023B' '024A' '025A' '025C' '026A' '026B' '026C' '027A' '028A'
#  '029A' '032A' '033A' '035A' '037A' '039A' '040A' '041A' '043A' '045A'
#  '047A' '048A' '049A' '051A' '051B' '052A' '053A' '054A' '056A' '058A'
#  '059A' '060A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A'
#  '070A' '071A' '072A' '073A' '074A' '075A' '076A' '087A' '091A' '093A'
#  '096A' '097B' '099A' '100A' '101A' '102A' '103A' '104A' '105A' '106A'
#  '108A' '109A' '110A' '111A' '113A' '116A']
# Unique Test Group IDs:
# ['000B' '001A' '011A' '013B' '014A' '023A' '025B' '031A' '034A' '036A'
#  '038A' '042A' '044A' '046A' '050A' '055A' '057A' '061A' '088A' '090A'
#  '092A' '094A' '095A' '097A' '115A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'049A'}
# Moved to Test Set:
# {'049A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '008A' '009A'
#  '010A' '012A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023B' '024A' '025A' '025C' '026A' '026B' '026C' '027A' '028A'
#  '029A' '032A' '033A' '035A' '037A' '039A' '040A' '041A' '043A' '045A'
#  '046A' '047A' '048A' '051A' '051B' '052A' '053A' '054A' '056A' '058A'
#  '059A' '060A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A'
#  '070A' '071A' '072A' '073A' '074A' '075A' '076A' '087A' '091A' '093A'
#  '096A' '097B' '099A' '100A' '101A' '102A' '103A' '104A' '105A' '106A'
#  '108A' '109A' '110A' '111A' '113A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '001A' '011A' '013B' '014A' '023A' '025B' '031A' '034A' '036A'
#  '038A' '042A' '044A' '049A' '050A' '055A' '057A' '061A' '088A' '090A'
#  '092A' '094A' '095A' '097A' '115A' '117A']
# Length of X_train_val:
# 766
# Length of y_train_val:
# 766
# Length of groups_train_val:
# 766
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     398
# senior    220
# kitten     83
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# senior    100
# kitten     93
# adult      74
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     398
# senior    220
# kitten    148
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# senior    100
# adult      74
# kitten     28
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 398, 2: 220, 1: 148})
# Epoch 1/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 1.5035 - accuracy: 0.5209
# Epoch 2/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4840 - accuracy: 0.7624
# Epoch 3/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3556 - accuracy: 0.8486
# Epoch 4/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2851 - accuracy: 0.8538
# Epoch 5/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2486 - accuracy: 0.8916
# Epoch 6/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1864 - accuracy: 0.9256
# Epoch 7/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1754 - accuracy: 0.9191
# Epoch 8/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1579 - accuracy: 0.9334
# Epoch 9/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1344 - accuracy: 0.9465
# Epoch 10/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1220 - accuracy: 0.9543
# Epoch 11/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1073 - accuracy: 0.9504
# Epoch 12/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0781 - accuracy: 0.9687
# Epoch 13/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0928 - accuracy: 0.9700
# Epoch 14/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0802 - accuracy: 0.9595
# Epoch 15/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0700 - accuracy: 0.9713
# Epoch 16/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0552 - accuracy: 0.9778
# Epoch 17/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0618 - accuracy: 0.9713
# Epoch 18/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0583 - accuracy: 0.9752
# Epoch 19/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0623 - accuracy: 0.9739
# Epoch 20/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0349 - accuracy: 0.9869
# Epoch 21/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0442 - accuracy: 0.9804
# Epoch 22/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0517 - accuracy: 0.9830
# Epoch 23/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0408 - accuracy: 0.9830
# Epoch 24/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0473 - accuracy: 0.9830
# Epoch 25/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0431 - accuracy: 0.9896
# Epoch 26/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0286 - accuracy: 0.9909
# Epoch 27/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.9909
# Epoch 28/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 0.9961
# Epoch 29/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0297 - accuracy: 0.9883
# Epoch 30/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0266 - accuracy: 0.9935
# Epoch 31/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0283 - accuracy: 0.9883
# Epoch 32/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0297 - accuracy: 0.9856
# Epoch 33/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0410 - accuracy: 0.9830
# Epoch 34/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0313 - accuracy: 0.9922
# Epoch 35/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 0.9974
# Epoch 36/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 37/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0248 - accuracy: 0.9909
# Epoch 38/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 0.9961
# Epoch 39/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 0.9909
# Epoch 40/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0301 - accuracy: 0.9883
# Epoch 41/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 0.9974
# Epoch 42/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0172 - accuracy: 0.9948
# Epoch 43/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 0.9974
# Epoch 44/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 0.9987
# Epoch 45/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0148 - accuracy: 0.9935
# Epoch 46/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0111 - accuracy: 0.9974
# Epoch 47/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 0.9961
# Epoch 48/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0206 - accuracy: 0.9922
# Epoch 49/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0135 - accuracy: 0.9974
# Epoch 50/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 0.9935
# Epoch 51/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 0.9961
# Epoch 52/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 0.9974
# Epoch 53/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0091 - accuracy: 0.9987
# Epoch 54/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 0.9987
# Epoch 55/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9961
# Epoch 56/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0062 - accuracy: 0.9974
# Epoch 57/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 0.9974
# Epoch 58/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 0.9935
# Epoch 59/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 0.9974
# Epoch 60/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0193 - accuracy: 0.9922
# Epoch 61/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0122 - accuracy: 0.9961
# Epoch 62/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 0.9974
# Epoch 63/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0075 - accuracy: 0.9974
# Epoch 64/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 0.9987
# Epoch 65/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.9948
# Epoch 66/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0041 - accuracy: 0.9987
# Epoch 67/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 0.9974
# Epoch 68/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0061 - accuracy: 0.9974
# Epoch 69/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0170 - accuracy: 0.9909
# Epoch 70/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9987
# Epoch 71/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0271 - accuracy: 0.9935
# Epoch 72/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 0.9961
# Epoch 73/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 0.9961
# Epoch 74/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0147 - accuracy: 0.9974
# Epoch 75/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 0.9987
# Epoch 76/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0112 - accuracy: 0.9922
# Epoch 77/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0102 - accuracy: 0.9987
# Epoch 78/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0125 - accuracy: 0.9935
# Epoch 79/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 0.9974
# Epoch 80/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0052 - accuracy: 0.9974
# Epoch 81/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 0.9974
# Epoch 82/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 0.9987
# Epoch 83/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 0.9974
# Epoch 84/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0123 - accuracy: 0.9974
# Epoch 85/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0123 - accuracy: 0.9948
# Epoch 86/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.9974
# Epoch 87/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0275 - accuracy: 0.9974
# Epoch 88/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0051 - accuracy: 0.9987
# Epoch 89/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0122 - accuracy: 0.9961
# Epoch 90/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0054 - accuracy: 0.9987
# Epoch 91/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0094 - accuracy: 0.9948
# Epoch 92/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0052 - accuracy: 0.9987
# Epoch 93/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 94/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0055 - accuracy: 0.9987
# Epoch 95/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 0.9987
# Epoch 96/1500
# 17/24 [====================>.........] - ETA: 0s - loss: 0.0046 - accuracy: 0.9982Restoring model weights from the end of the best epoch: 66.
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 0.9987
# Epoch 96: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 5.1517 - accuracy: 0.6040
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.81 (21/26)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 202, Predictions: 202, Actuals: 202, Gender: 202
# Final Test Results - Loss: 5.151669502258301, Accuracy: 0.603960394859314, Precision: 0.6439451201355962, Recall: 0.6343114543114544, F1 Score: 0.6318605845606239
# Confusion Matrix:
#  [[48  5 21]
#  [ 6 20  2]
#  [44  2 54]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 002B    36
# 103A    33
# 047A    30
# 057A    28
# 020A    23
# 055A    20
# 000B    20
# 059A    18
# 029A    17
# 097A    16
# 101A    16
# 106A    15
# 001A    15
# 028A    14
# 042A    14
# 111A    13
# 002A    13
# 116A    12
# 039A    12
# 051A    12
# 036A    11
# 063A    11
# 025A    11
# 015A    10
# 014B    10
# 040A    10
# 051B     9
# 072A     9
# 022A     9
# 045A     9
# 094A     8
# 013B     8
# 095A     8
# 031A     7
# 117A     7
# 099A     7
# 053A     7
# 027A     7
# 050A     7
# 023A     6
# 037A     6
# 021A     6
# 044A     5
# 034A     5
# 070A     5
# 075A     5
# 012A     5
# 003A     4
# 035A     4
# 105A     4
# 026A     4
# 064A     3
# 113A     3
# 011A     3
# 058A     3
# 006A     3
# 060A     3
# 014A     3
# 025B     2
# 038A     2
# 069A     2
# 061A     2
# 087A     2
# 032A     2
# 054A     2
# 018A     2
# 076A     1
# 115A     1
# 090A     1
# 004A     1
# 026B     1
# 019B     1
# 092A     1
# 088A     1
# 110A     1
# 096A     1
# 043A     1
# 091A     1
# 024A     1
# 026C     1
# 048A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 074A    25
# 067A    20
# 019A    17
# 097B    14
# 016A    11
# 005A    11
# 068A    11
# 071A    10
# 033A     9
# 065A     9
# 010A     8
# 008A     6
# 109A     6
# 007A     6
# 025C     6
# 108A     6
# 023B     5
# 062A     5
# 009A     4
# 104A     4
# 052A     4
# 056A     3
# 066A     2
# 102A     2
# 093A     2
# 073A     1
# 049A     1
# 041A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    284
# M    245
# F    191
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    111
# X     71
# F     66
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 000B, 020A, 026A, 038A, 026C, 021...
# kitten    [046A, 042A, 014B, 110A, 040A, 047A, 045A, 048...
# senior    [028A, 117A, 015A, 106A, 053A, 057A, 001A, 090...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 071A, 000A, 065A, 023B, 007A, 068A, 062...
# kitten                                   [109A, 049A, 041A]
# senior           [016A, 108A, 008A, 104A, 025C, 056A, 093A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 43, 'kitten': 13, 'senior': 27}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 3, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000B' '001A' '002A' '002B' '003A' '004A' '006A' '011A' '012A' '013B'
#  '014A' '014B' '015A' '018A' '019B' '020A' '021A' '022A' '023A' '024A'
#  '025A' '025B' '026A' '026B' '026C' '027A' '028A' '029A' '031A' '032A'
#  '034A' '035A' '036A' '037A' '038A' '039A' '040A' '042A' '043A' '044A'
#  '045A' '046A' '047A' '048A' '050A' '051A' '051B' '053A' '054A' '055A'
#  '057A' '058A' '059A' '060A' '061A' '063A' '064A' '069A' '070A' '072A'
#  '075A' '076A' '087A' '088A' '090A' '091A' '092A' '094A' '095A' '096A'
#  '097A' '099A' '100A' '101A' '103A' '105A' '106A' '110A' '111A' '113A'
#  '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '005A' '007A' '008A' '009A' '010A' '016A' '019A' '023B' '025C'
#  '033A' '041A' '049A' '052A' '056A' '062A' '065A' '066A' '067A' '068A'
#  '071A' '073A' '074A' '093A' '097B' '102A' '104A' '108A' '109A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'095A'}
# Moved to Test Set:
# {'095A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '006A' '011A' '012A'
#  '013B' '014A' '014B' '015A' '018A' '019B' '020A' '021A' '022A' '023A'
#  '024A' '025A' '025B' '026A' '026B' '026C' '027A' '028A' '029A' '031A'
#  '032A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '042A' '043A'
#  '044A' '045A' '046A' '047A' '048A' '050A' '051A' '051B' '053A' '054A'
#  '055A' '057A' '058A' '059A' '060A' '061A' '063A' '064A' '069A' '070A'
#  '072A' '075A' '076A' '087A' '088A' '090A' '091A' '092A' '094A' '096A'
#  '097A' '099A' '100A' '101A' '103A' '105A' '106A' '110A' '111A' '113A'
#  '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['005A' '007A' '008A' '009A' '010A' '016A' '019A' '023B' '025C' '033A'
#  '041A' '049A' '052A' '056A' '062A' '065A' '066A' '067A' '068A' '071A'
#  '073A' '074A' '093A' '095A' '097B' '102A' '104A' '108A' '109A']
# Length of X_train_val:
# 751
# Length of y_train_val:
# 751
# Length of groups_train_val:
# 751
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# senior    282
# adult     270
# kitten    168
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     202
# senior     38
# kitten      8
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     301
# senior    282
# kitten    168
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     171
# senior     38
# kitten      8
# Name: age_group, dtype: int64
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 301, 2: 282, 1: 168})
# Epoch 1/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 1.3913 - accuracy: 0.6019
# Epoch 2/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4861 - accuracy: 0.7909
# Epoch 3/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3153 - accuracy: 0.8735
# Epoch 4/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3001 - accuracy: 0.8682
# Epoch 5/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2038 - accuracy: 0.9161
# Epoch 6/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1766 - accuracy: 0.9308
# Epoch 7/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1235 - accuracy: 0.9587
# Epoch 8/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1366 - accuracy: 0.9521
# Epoch 9/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1371 - accuracy: 0.9481
# Epoch 10/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0979 - accuracy: 0.9667
# Epoch 11/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0980 - accuracy: 0.9627
# Epoch 12/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0864 - accuracy: 0.9707
# Epoch 13/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0683 - accuracy: 0.9720
# Epoch 14/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0631 - accuracy: 0.9787
# Epoch 15/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0638 - accuracy: 0.9734
# Epoch 16/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0442 - accuracy: 0.9840
# Epoch 17/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0522 - accuracy: 0.9800
# Epoch 18/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0486 - accuracy: 0.9814
# Epoch 19/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0513 - accuracy: 0.9893
# Epoch 20/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0381 - accuracy: 0.9907
# Epoch 21/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0451 - accuracy: 0.9893
# Epoch 22/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0426 - accuracy: 0.9854
# Epoch 23/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0255 - accuracy: 0.9960
# Epoch 24/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0278 - accuracy: 0.9907
# Epoch 25/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0274 - accuracy: 0.9920
# Epoch 26/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 0.9920
# Epoch 27/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0286 - accuracy: 0.9920
# Epoch 28/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0369 - accuracy: 0.9814
# Epoch 29/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 0.9987
# Epoch 30/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 0.9973
# Epoch 31/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 0.9920
# Epoch 32/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0325 - accuracy: 0.9920
# Epoch 33/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0405 - accuracy: 0.9840
# Epoch 34/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 0.9933
# Epoch 35/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 0.9987
# Epoch 36/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0257 - accuracy: 0.9880
# Epoch 37/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0232 - accuracy: 0.9933
# Epoch 38/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0247 - accuracy: 0.9893
# Epoch 39/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 0.9933
# Epoch 40/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 0.9973
# Epoch 41/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0190 - accuracy: 0.9907
# Epoch 42/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0144 - accuracy: 0.9947
# Epoch 43/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 0.9933
# Epoch 44/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0234 - accuracy: 0.9920
# Epoch 45/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0122 - accuracy: 0.9960
# Epoch 46/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0201 - accuracy: 0.9947
# Epoch 47/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 0.9920
# Epoch 48/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 0.9907
# Epoch 49/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0113 - accuracy: 0.9987
# Epoch 50/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 0.9960
# Epoch 51/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 0.9933
# Epoch 52/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 0.9973
# Epoch 53/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 0.9973
# Epoch 54/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 0.9973
# Epoch 55/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0103 - accuracy: 0.9973
# Epoch 56/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 0.9960
# Epoch 57/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0086 - accuracy: 0.9960
# Epoch 58/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 0.9960
# Epoch 59/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 0.9960
# Epoch 60/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 0.9960
# Epoch 61/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 0.9933
# Epoch 62/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0207 - accuracy: 0.9907
# Epoch 63/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0163 - accuracy: 0.9933
# Epoch 64/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 0.9960
# Epoch 65/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 0.9987
# Epoch 66/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 0.9960
# Epoch 67/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 0.9947
# Epoch 68/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0203 - accuracy: 0.9920
# Epoch 69/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0271 - accuracy: 0.9920
# Epoch 70/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 0.9907
# Epoch 71/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0156 - accuracy: 0.9920
# Epoch 72/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0168 - accuracy: 0.9907
# Epoch 73/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0172 - accuracy: 0.9947
# Epoch 74/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 0.9973
# Epoch 75/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 0.9987
# Epoch 76/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 0.9987
# Epoch 77/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 0.9947
# Epoch 78/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 0.9973
# Epoch 79/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 0.9933
# Epoch 80/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 0.9947
# Epoch 81/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 82/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 83/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 84/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 0.9973
# Epoch 85/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0092 - accuracy: 0.9973
# Epoch 86/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 0.9973
# Epoch 87/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0114 - accuracy: 0.9947
# Epoch 88/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 0.9960
# Epoch 89/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.9973
# Epoch 90/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 0.9987
# Epoch 91/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 0.9973
# Epoch 92/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 0.9960
# Epoch 93/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 94/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 0.9973
# Epoch 95/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.9973
# Epoch 96/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0076 - accuracy: 0.9947
# Epoch 97/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 98/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0260 - accuracy: 0.9933
# Epoch 99/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 0.9973
# Epoch 100/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 0.9933
# Epoch 101/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.9973
# Epoch 102/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 0.9960
# Epoch 103/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 0.9973
# Epoch 104/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 105/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0205 - accuracy: 0.9973
# Epoch 106/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 0.9987
# Epoch 107/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 108/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 0.9947
# Epoch 109/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0082 - accuracy: 0.9987
# Epoch 110/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0087 - accuracy: 0.9960
# Epoch 111/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0137 - accuracy: 0.9960
# Epoch 112/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0062 - accuracy: 0.9960
# Epoch 113/1500
# 15/24 [=================>............] - ETA: 0s - loss: 0.0040 - accuracy: 0.9979Restoring model weights from the end of the best epoch: 83.
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 0.9987
# Epoch 113: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 4.4189 - accuracy: 0.5806
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.55 (16/29)
# Before appending - Cat IDs: 202, Predictions: 202, Actuals: 202, Gender: 202
# After appending - Cat IDs: 419, Predictions: 419, Actuals: 419, Gender: 419
# Final Test Results - Loss: 4.418916702270508, Accuracy: 0.5806451439857483, Precision: 0.3769953650550666, Recall: 0.4081384015594542, F1 Score: 0.3760256614307227
# Confusion Matrix:
#  [[107  17  47]
#  [  7   1   0]
#  [ 20   0  18]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 067A    20
# 055A    20
# 000B    20
# 019A    17
# 097A    16
# 001A    15
# 042A    14
# 097B    14
# 028A    14
# 111A    13
# 051A    12
# 116A    12
# 039A    12
# 016A    11
# 005A    11
# 036A    11
# 025A    11
# 063A    11
# 068A    11
# 014B    10
# 071A    10
# 072A     9
# 033A     9
# 065A     9
# 022A     9
# 013B     8
# 095A     8
# 094A     8
# 010A     8
# 050A     7
# 099A     7
# 053A     7
# 031A     7
# 117A     7
# 021A     6
# 025C     6
# 008A     6
# 007A     6
# 108A     6
# 109A     6
# 023A     6
# 070A     5
# 034A     5
# 044A     5
# 062A     5
# 023B     5
# 052A     4
# 009A     4
# 003A     4
# 104A     4
# 014A     3
# 011A     3
# 113A     3
# 056A     3
# 038A     2
# 069A     2
# 025B     2
# 061A     2
# 066A     2
# 093A     2
# 102A     2
# 032A     2
# 026B     1
# 076A     1
# 041A     1
# 115A     1
# 088A     1
# 090A     1
# 073A     1
# 096A     1
# 048A     1
# 110A     1
# 092A     1
# 049A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 002B    36
# 103A    33
# 059A    18
# 029A    17
# 101A    16
# 106A    15
# 002A    13
# 040A    10
# 015A    10
# 045A     9
# 051B     9
# 027A     7
# 037A     6
# 012A     5
# 075A     5
# 035A     4
# 105A     4
# 026A     4
# 064A     3
# 006A     3
# 058A     3
# 060A     3
# 087A     2
# 018A     2
# 054A     2
# 043A     1
# 026C     1
# 024A     1
# 091A     1
# 019B     1
# 004A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    316
# F    219
# M    188
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    168
# X     39
# F     38
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [070A, 033A, 000B, 071A, 020A, 000A, 065A, 023...
# kitten    [046A, 042A, 014B, 110A, 109A, 047A, 049A, 048...
# senior    [028A, 117A, 053A, 057A, 001A, 090A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 026A, 026C, 105A, 018A, 002B, 006A, 029...
# kitten                                   [040A, 045A, 043A]
# senior    [015A, 106A, 051B, 091A, 024A, 101A, 103A, 059...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 45, 'kitten': 13, 'senior': 23}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 17, 'kitten': 3, 'senior': 11}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '003A' '005A' '007A' '008A' '009A' '010A' '011A'
#  '013B' '014A' '014B' '016A' '019A' '020A' '021A' '022A' '023A' '023B'
#  '025A' '025B' '025C' '026B' '028A' '031A' '032A' '033A' '034A' '036A'
#  '038A' '039A' '041A' '042A' '044A' '046A' '047A' '048A' '049A' '050A'
#  '051A' '052A' '053A' '055A' '056A' '057A' '061A' '062A' '063A' '065A'
#  '066A' '067A' '068A' '069A' '070A' '071A' '072A' '073A' '074A' '076A'
#  '088A' '090A' '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A'
#  '100A' '102A' '104A' '108A' '109A' '110A' '111A' '113A' '115A' '116A'
#  '117A']
# Unique Test Group IDs:
# ['002A' '002B' '004A' '006A' '012A' '015A' '018A' '019B' '024A' '026A'
#  '026C' '027A' '029A' '035A' '037A' '040A' '043A' '045A' '051B' '054A'
#  '058A' '059A' '060A' '064A' '075A' '087A' '091A' '101A' '103A' '105A'
#  '106A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '003A' '005A' '007A' '008A' '009A' '010A' '011A'
#  '013B' '014A' '014B' '016A' '019A' '020A' '021A' '022A' '023A' '023B'
#  '025A' '025B' '025C' '026B' '028A' '031A' '032A' '033A' '034A' '036A'
#  '038A' '039A' '041A' '042A' '044A' '046A' '047A' '048A' '049A' '050A'
#  '051A' '052A' '053A' '055A' '056A' '057A' '061A' '062A' '063A' '065A'
#  '066A' '067A' '068A' '069A' '070A' '071A' '072A' '073A' '074A' '076A'
#  '088A' '090A' '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A'
#  '100A' '102A' '104A' '108A' '109A' '110A' '111A' '113A' '115A' '116A'
#  '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002A' '002B' '004A' '006A' '012A' '015A' '018A' '019B' '024A' '026A'
#  '026C' '027A' '029A' '035A' '037A' '040A' '043A' '045A' '051B' '054A'
#  '058A' '059A' '060A' '064A' '075A' '087A' '091A' '101A' '103A' '105A'
#  '106A']
# Length of X_train_val:
# 723
# Length of y_train_val:
# 723
# Length of groups_train_val:
# 723
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     358
# senior    209
# kitten    156
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     114
# senior    111
# kitten     20
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     358
# senior    209
# kitten    156
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     114
# senior    111
# kitten     20
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 358, 2: 209, 1: 156})
# Epoch 1/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 1.3345 - accuracy: 0.5864
# Epoch 2/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.4861 - accuracy: 0.7704
# Epoch 3/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.3367 - accuracy: 0.8534
# Epoch 4/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2608 - accuracy: 0.8797
# Epoch 5/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2131 - accuracy: 0.8990
# Epoch 6/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1693 - accuracy: 0.9225
# Epoch 7/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1824 - accuracy: 0.9198
# Epoch 8/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1361 - accuracy: 0.9433
# Epoch 9/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1290 - accuracy: 0.9461
# Epoch 10/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0960 - accuracy: 0.9640
# Epoch 11/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0966 - accuracy: 0.9668
# Epoch 12/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0930 - accuracy: 0.9613
# Epoch 13/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1069 - accuracy: 0.9544
# Epoch 14/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0850 - accuracy: 0.9682
# Epoch 15/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0704 - accuracy: 0.9737
# Epoch 16/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0613 - accuracy: 0.9737
# Epoch 17/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0590 - accuracy: 0.9779
# Epoch 18/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0504 - accuracy: 0.9793
# Epoch 19/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0503 - accuracy: 0.9793
# Epoch 20/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0490 - accuracy: 0.9848
# Epoch 21/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0489 - accuracy: 0.9806
# Epoch 22/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0310 - accuracy: 0.9931
# Epoch 23/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0468 - accuracy: 0.9834
# Epoch 24/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0446 - accuracy: 0.9806
# Epoch 25/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0418 - accuracy: 0.9834
# Epoch 26/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0264 - accuracy: 0.9959
# Epoch 27/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0383 - accuracy: 0.9862
# Epoch 28/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0317 - accuracy: 0.9917
# Epoch 29/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0522 - accuracy: 0.9834
# Epoch 30/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0296 - accuracy: 0.9862
# Epoch 31/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0197 - accuracy: 0.9931
# Epoch 32/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 0.9959
# Epoch 33/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0128 - accuracy: 0.9972
# Epoch 34/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0151 - accuracy: 0.9972
# Epoch 35/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 0.9945
# Epoch 36/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 0.9986
# Epoch 37/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0265 - accuracy: 0.9917
# Epoch 38/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 0.9931
# Epoch 39/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0205 - accuracy: 0.9931
# Epoch 40/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0327 - accuracy: 0.9903
# Epoch 41/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 42/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0196 - accuracy: 0.9889
# Epoch 43/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 0.9986
# Epoch 44/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 0.9959
# Epoch 45/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0175 - accuracy: 0.9917
# Epoch 46/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0153 - accuracy: 0.9931
# Epoch 47/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 0.9986
# Epoch 48/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 0.9972
# Epoch 49/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 0.9986
# Epoch 50/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0076 - accuracy: 0.9986
# Epoch 51/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0363 - accuracy: 0.9876
# Epoch 52/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 0.9889
# Epoch 53/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0214 - accuracy: 0.9889
# Epoch 54/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 0.9945
# Epoch 55/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0144 - accuracy: 0.9959
# Epoch 56/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 0.9986
# Epoch 57/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0134 - accuracy: 0.9972
# Epoch 58/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 0.9986
# Epoch 59/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 60/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 0.9986
# Epoch 61/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0435 - accuracy: 0.9876
# Epoch 62/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 0.9959
# Epoch 63/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 0.9945
# Epoch 64/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 0.9986
# Epoch 65/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 0.9931
# Epoch 66/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0203 - accuracy: 0.9959
# Epoch 67/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0075 - accuracy: 0.9986
# Epoch 68/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0136 - accuracy: 0.9945
# Epoch 69/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 70/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0170 - accuracy: 0.9945
# Epoch 71/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 0.9972
# Epoch 72/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0203 - accuracy: 0.9917
# Epoch 73/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 0.9986
# Epoch 74/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 0.9972
# Epoch 75/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0072 - accuracy: 0.9986
# Epoch 76/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 77/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 0.9986
# Epoch 78/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 0.9959
# Epoch 79/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 0.9945
# Epoch 80/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0100 - accuracy: 0.9972
# Epoch 81/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 0.9972
# Epoch 82/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 0.9972
# Epoch 83/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0147 - accuracy: 0.9931
# Epoch 84/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 0.9945
# Epoch 85/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0121 - accuracy: 0.9959
# Epoch 86/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0146 - accuracy: 0.9903
# Epoch 87/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 0.9931
# Epoch 88/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0110 - accuracy: 0.9945
# Epoch 89/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0120 - accuracy: 0.9945
# Epoch 90/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0103 - accuracy: 0.9959
# Epoch 91/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 0.9972
# Epoch 92/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0063 - accuracy: 0.9972
# Epoch 93/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 0.9986
# Epoch 94/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 0.9959
# Epoch 95/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 96/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 97/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0062 - accuracy: 0.9972
# Epoch 98/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0062 - accuracy: 0.9959
# Epoch 99/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 100/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 0.9972
# Epoch 101/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 0.9986
# Epoch 102/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0110 - accuracy: 0.9972
# Epoch 103/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 0.9972
# Epoch 104/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 105/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 0.9986
# Epoch 106/1500
# 20/23 [=========================>....] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000    Restoring model weights from the end of the best epoch: 76.
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 106: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 3.4312 - accuracy: 0.5592
# 8/8 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.68 (21/31)
# Before appending - Cat IDs: 419, Predictions: 419, Actuals: 419, Gender: 419
# After appending - Cat IDs: 664, Predictions: 664, Actuals: 664, Gender: 664
# Final Test Results - Loss: 3.431180715560913, Accuracy: 0.559183657169342, Precision: 0.5434071825540655, Recall: 0.6111506243085191, F1 Score: 0.5638483085541909
# Confusion Matrix:
#  [[66 15 33]
#  [ 5 15  0]
#  [53  2 56]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 057A    28
# 074A    25
# 000B    20
# 067A    20
# 055A    20
# 059A    18
# 029A    17
# 019A    17
# 101A    16
# 097A    16
# 001A    15
# 106A    15
# 097B    14
# 042A    14
# 002A    13
# 068A    11
# 036A    11
# 016A    11
# 005A    11
# 040A    10
# 071A    10
# 015A    10
# 045A     9
# 065A     9
# 033A     9
# 051B     9
# 095A     8
# 013B     8
# 010A     8
# 094A     8
# 027A     7
# 050A     7
# 031A     7
# 117A     7
# 108A     6
# 025C     6
# 007A     6
# 023A     6
# 008A     6
# 109A     6
# 037A     6
# 044A     5
# 012A     5
# 075A     5
# 062A     5
# 034A     5
# 023B     5
# 105A     4
# 104A     4
# 052A     4
# 009A     4
# 026A     4
# 035A     4
# 058A     3
# 006A     3
# 056A     3
# 011A     3
# 064A     3
# 014A     3
# 060A     3
# 025B     2
# 093A     2
# 087A     2
# 066A     2
# 102A     2
# 054A     2
# 018A     2
# 038A     2
# 061A     2
# 073A     1
# 024A     1
# 090A     1
# 115A     1
# 041A     1
# 091A     1
# 026C     1
# 019B     1
# 049A     1
# 092A     1
# 043A     1
# 088A     1
# 004A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    30
# 020A    23
# 028A    14
# 111A    13
# 116A    12
# 039A    12
# 051A    12
# 025A    11
# 063A    11
# 014B    10
# 022A     9
# 072A     9
# 053A     7
# 099A     7
# 021A     6
# 070A     5
# 003A     4
# 113A     3
# 069A     2
# 032A     2
# 026B     1
# 076A     1
# 048A     1
# 096A     1
# 110A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    320
# X    263
# F    177
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    92
# F    80
# M    36
# Name: gender, dtype: int64
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 033A, 000B, 071A, 000A, 026A, 065A, 023...
# kitten    [046A, 042A, 109A, 040A, 049A, 045A, 044A, 043...
# senior    [117A, 015A, 106A, 057A, 001A, 090A, 051B, 091...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [070A, 020A, 021A, 072A, 022A, 063A, 069A, 032...
# kitten                       [014B, 110A, 047A, 048A, 111A]
# senior           [028A, 053A, 113A, 116A, 051A, 025A, 039A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 48, 'kitten': 11, 'senior': 27}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 14, 'kitten': 5, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '005A' '006A' '007A' '008A'
#  '009A' '010A' '011A' '012A' '013B' '014A' '015A' '016A' '018A' '019A'
#  '019B' '023A' '023B' '024A' '025B' '025C' '026A' '026C' '027A' '029A'
#  '031A' '033A' '034A' '035A' '036A' '037A' '038A' '040A' '041A' '042A'
#  '043A' '044A' '045A' '046A' '049A' '050A' '051B' '052A' '054A' '055A'
#  '056A' '057A' '058A' '059A' '060A' '061A' '062A' '064A' '065A' '066A'
#  '067A' '068A' '071A' '073A' '074A' '075A' '087A' '088A' '090A' '091A'
#  '092A' '093A' '094A' '095A' '097A' '097B' '101A' '102A' '103A' '104A'
#  '105A' '106A' '108A' '109A' '115A' '117A']
# Unique Test Group IDs:
# ['003A' '014B' '020A' '021A' '022A' '025A' '026B' '028A' '032A' '039A'
#  '047A' '048A' '051A' '053A' '063A' '069A' '070A' '072A' '076A' '096A'
#  '099A' '100A' '110A' '111A' '113A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '005A' '006A' '007A' '008A'
#  '009A' '010A' '011A' '012A' '013B' '014A' '015A' '016A' '018A' '019A'
#  '019B' '023A' '023B' '024A' '025B' '025C' '026A' '026C' '027A' '029A'
#  '031A' '033A' '034A' '035A' '036A' '037A' '038A' '040A' '041A' '042A'
#  '043A' '044A' '045A' '046A' '049A' '050A' '051B' '052A' '054A' '055A'
#  '056A' '057A' '058A' '059A' '060A' '061A' '062A' '064A' '065A' '066A'
#  '067A' '068A' '071A' '073A' '074A' '075A' '087A' '088A' '090A' '091A'
#  '092A' '093A' '094A' '095A' '097A' '097B' '101A' '102A' '103A' '104A'
#  '105A' '106A' '108A' '109A' '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['003A' '014B' '020A' '021A' '022A' '025A' '026B' '028A' '032A' '039A'
#  '047A' '048A' '051A' '053A' '063A' '069A' '070A' '072A' '076A' '096A'
#  '099A' '100A' '110A' '111A' '113A' '116A']
# Length of X_train_val:
# 760
# Length of y_train_val:
# 760
# Length of groups_train_val:
# 760
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     390
# senior    249
# kitten    121
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     82
# senior    71
# kitten    55
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     390
# senior    249
# kitten    121
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     82
# senior    71
# kitten    55
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 390, 2: 249, 1: 121})
# Epoch 1/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 1.2155 - accuracy: 0.5921
# Epoch 2/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4734 - accuracy: 0.7750
# Epoch 3/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3463 - accuracy: 0.8263
# Epoch 4/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2642 - accuracy: 0.8763
# Epoch 5/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2209 - accuracy: 0.9132
# Epoch 6/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1910 - accuracy: 0.9250
# Epoch 7/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1561 - accuracy: 0.9316
# Epoch 8/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1367 - accuracy: 0.9461
# Epoch 9/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1390 - accuracy: 0.9342
# Epoch 10/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1196 - accuracy: 0.9474
# Epoch 11/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1137 - accuracy: 0.9553
# Epoch 12/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0767 - accuracy: 0.9579
# Epoch 13/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0974 - accuracy: 0.9592
# Epoch 14/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0811 - accuracy: 0.9671
# Epoch 15/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0742 - accuracy: 0.9711
# Epoch 16/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0604 - accuracy: 0.9737
# Epoch 17/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0433 - accuracy: 0.9803
# Epoch 18/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0459 - accuracy: 0.9868
# Epoch 19/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0583 - accuracy: 0.9763
# Epoch 20/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0441 - accuracy: 0.9816
# Epoch 21/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0529 - accuracy: 0.9816
# Epoch 22/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0591 - accuracy: 0.9737
# Epoch 23/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0449 - accuracy: 0.9816
# Epoch 24/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0344 - accuracy: 0.9921
# Epoch 25/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0423 - accuracy: 0.9829
# Epoch 26/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0386 - accuracy: 0.9803
# Epoch 27/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0309 - accuracy: 0.9868
# Epoch 28/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0364 - accuracy: 0.9829
# Epoch 29/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0169 - accuracy: 0.9961
# Epoch 30/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 0.9882
# Epoch 31/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 0.9974
# Epoch 32/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0346 - accuracy: 0.9868
# Epoch 33/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0315 - accuracy: 0.9908
# Epoch 34/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0186 - accuracy: 0.9934
# Epoch 35/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 0.9947
# Epoch 36/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0137 - accuracy: 0.9947
# Epoch 37/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0190 - accuracy: 0.9934
# Epoch 38/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0391 - accuracy: 0.9882
# Epoch 39/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0147 - accuracy: 0.9961
# Epoch 40/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 0.9961
# Epoch 41/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 0.9987
# Epoch 42/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0113 - accuracy: 0.9987
# Epoch 43/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0155 - accuracy: 0.9947
# Epoch 44/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0204 - accuracy: 0.9921
# Epoch 45/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 46/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0139 - accuracy: 0.9961
# Epoch 47/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 0.9947
# Epoch 48/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0185 - accuracy: 0.9934
# Epoch 49/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0147 - accuracy: 0.9921
# Epoch 50/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0134 - accuracy: 0.9947
# Epoch 51/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0263 - accuracy: 0.9882
# Epoch 52/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0147 - accuracy: 0.9947
# Epoch 53/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 0.9934
# Epoch 54/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 0.9921
# Epoch 55/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0134 - accuracy: 0.9947
# Epoch 56/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 0.9908
# Epoch 57/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 0.9974
# Epoch 58/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 0.9934
# Epoch 59/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 0.9961
# Epoch 60/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 0.9961
# Epoch 61/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0148 - accuracy: 0.9908
# Epoch 62/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 0.9934
# Epoch 63/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0088 - accuracy: 0.9947
# Epoch 64/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0191 - accuracy: 0.9908
# Epoch 65/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 0.9947
# Epoch 66/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0095 - accuracy: 0.9987
# Epoch 67/1500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0155 - accuracy: 0.9947
# Epoch 68/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0189 - accuracy: 0.9921
# Epoch 69/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0201 - accuracy: 0.9947
# Epoch 70/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0182 - accuracy: 0.9921
# Epoch 71/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0257 - accuracy: 0.9882
# Epoch 72/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0115 - accuracy: 0.9934
# Epoch 73/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 0.9934
# Epoch 74/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0131 - accuracy: 0.9934
# Epoch 75/1500
# 19/24 [======================>.......] - ETA: 0s - loss: 0.0197 - accuracy: 0.9934Restoring model weights from the end of the best epoch: 45.
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 0.9934
# Epoch 75: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 18.9315 - accuracy: 0.5481
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.73 (19/26)
# Before appending - Cat IDs: 664, Predictions: 664, Actuals: 664, Gender: 664
# After appending - Cat IDs: 872, Predictions: 872, Actuals: 872, Gender: 872
# Final Test Results - Loss: 18.93152618408203, Accuracy: 0.5480769276618958, Precision: 0.5699438934733052, Recall: 0.5284115632449539, F1 Score: 0.535872480179298
# Confusion Matrix:
#  [[52 15 15]
#  [31 19  5]
#  [28  0 43]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5269017586812088
#
# Final Average Loss across all UNSEEN TEST sets: 7.983323276042938
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.572966530919075
#
# Final Average Precision across all UNSEEN TEST sets: 0.5335728903045083
#
# Final Average Recall across all UNSEEN TEST sets: 0.5455030108560954

# %%
seed_4_folds_values = [unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1]

seed_4_training_acc_values = cv_training_acc_total

# Plotting all fold metrics
seed_4_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 872, Predictions: 872, Actuals: 872, Gender: 872

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.68 (75/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 62    056A                            [adult, senior, senior]        senior           senior                   True
# 76    070A              [adult, senior, senior, adult, adult]         adult            adult                   True
# 74    068A  [senior, adult, adult, adult, senior, senior, ...         adult            adult                   True
# 73    067A  [adult, adult, kitten, adult, adult, adult, ad...         adult            adult                   True
# 70    064A                             [kitten, adult, adult]         adult            adult                   True
# 69    063A  [kitten, adult, kitten, kitten, adult, adult, ...         adult            adult                   True
# 68    062A               [adult, adult, adult, senior, adult]         adult            adult                   True
# 65    059A  [senior, senior, senior, senior, senior, senio...        senior           senior                   True
# 63    057A  [adult, senior, senior, senior, adult, senior,...        senior           senior                   True
# 61    055A  [senior, senior, senior, senior, adult, adult,...        senior           senior                   True
# 78    072A  [adult, adult, adult, adult, adult, kitten, ad...         adult            adult                   True
# 58    052A                     [adult, adult, senior, senior]         adult            adult                   True
# 56    051A  [senior, senior, senior, adult, senior, senior...        senior           senior                   True
# 1     001A  [adult, adult, senior, senior, senior, adult, ...        senior           senior                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A  [kitten, adult, kitten, kitten, kitten, adult,...        kitten           kitten                   True
# 50    044A            [kitten, adult, kitten, kitten, senior]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 48    042A  [kitten, kitten, kitten, adult, kitten, kitten...        kitten           kitten                   True
# 77    071A  [adult, senior, adult, kitten, adult, senior, ...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 44    038A                                    [adult, kitten]         adult            adult                   True
# 96    101A  [senior, senior, adult, adult, adult, senior, ...        senior           senior                   True
# 108   116A  [senior, senior, adult, senior, senior, senior...        senior           senior                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                           [senior, senior, senior]        senior           senior                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 100   105A                     [senior, adult, adult, kitten]         adult            adult                   True
# 99    104A                    [senior, senior, adult, senior]        senior           senior                   True
# 97    102A                                    [adult, senior]         adult            adult                   True
#
  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 89    094A  [adult, senior, adult, adult, senior, senior, ...         adult           senior                  False
# 45    039A  [senior, senior, senior, senior, adult, adult,...         adult           senior                  False
# 64    058A                            [kitten, adult, senior]         adult           senior                  False
# 71    065A  [adult, senior, adult, kitten, kitten, kitten,...        kitten            adult                  False
# 72    066A                                   [senior, senior]        senior            adult                  False
# 26    023B            [adult, senior, senior, senior, senior]        senior            adult                  False
# 33    026C                                           [kitten]        kitten            adult                  False
# 75    069A                                   [senior, senior]        senior            adult                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 59    053A  [adult, senior, adult, adult, adult, adult, se...         adult           senior                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 21    019B                                           [senior]        senior            adult                  False
# 57    051B  [adult, adult, adult, senior, adult, senior, a...         adult           senior                  False
# 82    076A                                           [kitten]        kitten            adult                  False
# 18    016A  [adult, adult, adult, adult, senior, adult, se...         adult           senior                  False
# 17    015A  [adult, adult, adult, senior, adult, adult, se...         adult           senior                  False
# 85    090A                                            [adult]         adult           senior                  False
# 16    014B  [adult, adult, senior, adult, senior, kitten, ...         adult           kitten                  False
# 109   117A  [senior, adult, senior, senior, adult, adult, ...         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']
# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()
# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')
# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Calculate the class statistics
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    accuracy=('Majority_Correct', lambda x: x.mean() * 100),
    total_count=('Majority_Correct', 'size')
).reset_index()

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group   accuracy  total_count
# 0            adult  78.688525           61
# 1           kitten  66.666667           15
# 2           senior  50.000000           34

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# For each fold
fold_class_stats = full_results.groupby('actual_age_group').agg(
    accuracy=('correct', lambda x: x.mean() * 100),
    total_count=('correct', 'size')
).reset_index()

# Store for final evaluation 
all_class_stats.append(fold_class_stats)

# Log the detailed stats
print("Detailed Class Statistics for this fold:")
print(fold_class_stats)
# Out:
# Detailed Class Statistics for this fold:
#   actual_age_group   accuracy  total_count
# 0            adult  61.904762          441
# 1           kitten  49.549550          111
# 2           senior  53.437500          320

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(fold_class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    218      133     61.01
# 1          M    364      210     57.69
# 2          X    290      156     53.79

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.6636363636363637, 0.6727272727272727, 0.7, 0.6818181818181818]
# Total Class Statistics so far:
#  [  actual_age_group   accuracy  total_count
# 0            adult  55.733945          436
# 1           kitten  57.657658          111
# 2           senior  51.562500          320,   actual_age_group   accuracy  total_count
# 0            adult  60.592255          439
# 1           kitten  53.153153          111
# 2           senior  55.000000          320,   actual_age_group   accuracy  total_count
# 0            adult  56.221198          434
# 1           kitten  54.054054          111
# 2           senior  52.500000          320,   actual_age_group   accuracy  total_count
# 0            adult  61.904762          441
# 1           kitten  49.549550          111
# 2           senior  53.437500          320]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      127     58.26
# 1          M    359      183     50.97
# 2          X    290      162     55.86,   all_gender  count  correct  accuracy
# 0          F    218      138     63.30
# 1          M    362      210     58.01
# 2          X    290      153     52.76,   all_gender  count  correct  accuracy
# 0          F    218      126     57.80
# 1          M    356      181     50.84
# 2          X    291      165     56.70,   all_gender  count  correct  accuracy
# 0          F    218      133     61.01
# 1          M    364      210     57.69
# 2          X    290      156     53.79]

# %% [markdown]
# # RANDOM SEED 5

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[4]))
np.random.seed(int(random_seeds[4]))
tf.random.set_seed(int(random_seeds[4]))

# Load datasets
dataframe = pd.read_csv('yamnet_looped_embeddings.csv')


def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 10),
    'senior': (10, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     472
# senior    320
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[4]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

cv_training_acc_total = []
cv_training_acc_best = []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )
    
    accuracy_history = AccuracyHistory()

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_val),
        y=y_train_val
    )
    weight_dict = {i: class_weights[i] for i in range(len(class_weights))}

    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.009272615392034748)
    }
    
    # Full model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.40037235360372386))   
    model_full.add(Dense(3, activation='softmax'))  
    
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=32,
                                  verbose=1, callbacks=[early_stopping, accuracy_history], class_weight=weight_dict)
    
    
    # log epochs
    best_epoch_index = np.argmin(history_full.history['loss'])  
    best_training_accuracy = accuracy_history.acc[best_epoch_index]

    # Append training acc to total  
    all_best_training_acc.append(best_training_accuracy)
    total_training_acc.append(accuracy_history.acc)

    # Append training acc just for this CV
    cv_training_acc_total.append(accuracy_history.acc)
    cv_training_acc_best.append(best_training_accuracy)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
average_fold_f1.append(unseen_set_avg_f1)
average_fold_losses.append(unseen_set_avg_loss)
average_fold_accuracies.append(unseen_set_avg_acc)
average_fold_precisions.append(unseen_set_avg_precision)
average_fold_recalls.append(unseen_set_avg_recall)

# Append all to total lists
all_f1.append(unseen_f1)
all_losses.append(unseen_losses)
all_accuracies.append(unseen_accuracies)
all_precisions.append(unseen_precisions)
all_recalls.append(unseen_recalls)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 057A    28
# 074A    25
# 020A    23
# 055A    20
# 000B    20
# 029A    17
# 019A    17
# 097A    16
# 101A    16
# 001A    15
# 028A    14
# 042A    14
# 111A    13
# 039A    12
# 051A    12
# 116A    12
# 005A    11
# 016A    11
# 025A    11
# 063A    11
# 068A    11
# 014B    10
# 071A    10
# 065A     9
# 045A     9
# 022A     9
# 033A     9
# 051B     9
# 095A     8
# 094A     8
# 013B     8
# 010A     8
# 099A     7
# 050A     7
# 117A     7
# 027A     7
# 008A     6
# 007A     6
# 023A     6
# 108A     6
# 025C     6
# 109A     6
# 070A     5
# 044A     5
# 075A     5
# 012A     5
# 023B     5
# 034A     5
# 104A     4
# 105A     4
# 009A     4
# 026A     4
# 052A     4
# 011A     3
# 014A     3
# 060A     3
# 056A     3
# 113A     3
# 058A     3
# 006A     3
# 025B     2
# 018A     2
# 032A     2
# 054A     2
# 087A     2
# 066A     2
# 093A     2
# 038A     2
# 069A     2
# 019B     1
# 026B     1
# 041A     1
# 026C     1
# 092A     1
# 073A     1
# 088A     1
# 096A     1
# 043A     1
# 024A     1
# 091A     1
# 090A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    30
# 067A    20
# 059A    18
# 106A    15
# 097B    14
# 002A    13
# 036A    11
# 015A    10
# 040A    10
# 072A     9
# 031A     7
# 053A     7
# 037A     6
# 021A     6
# 062A     5
# 035A     4
# 003A     4
# 064A     3
# 102A     2
# 061A     2
# 115A     1
# 076A     1
# 049A     1
# 048A     1
# 110A     1
# 004A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    278
# X    259
# F    229
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    96
# M    78
# F    28
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [070A, 033A, 000B, 071A, 020A, 000A, 026A, 065...
# kitten    [046A, 042A, 014B, 109A, 045A, 111A, 044A, 043...
# senior    [028A, 117A, 057A, 001A, 090A, 113A, 051B, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 021A, 072A, 062A, 031A, 067A, 035A, 102...
# kitten                 [110A, 040A, 047A, 049A, 048A, 115A]
# senior                       [015A, 106A, 053A, 059A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 47, 'kitten': 10, 'senior': 29}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 6, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '005A' '006A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '013B' '014A' '014B' '016A' '018A' '019A' '019B' '020A'
#  '022A' '023A' '023B' '024A' '025A' '025B' '025C' '026A' '026B' '026C'
#  '027A' '028A' '029A' '032A' '033A' '034A' '038A' '039A' '041A' '042A'
#  '043A' '044A' '045A' '046A' '050A' '051A' '051B' '052A' '054A' '055A'
#  '056A' '057A' '058A' '060A' '063A' '065A' '066A' '068A' '069A' '070A'
#  '071A' '073A' '074A' '075A' '087A' '088A' '090A' '091A' '092A' '093A'
#  '094A' '095A' '096A' '097A' '099A' '100A' '101A' '103A' '104A' '105A'
#  '108A' '109A' '111A' '113A' '116A' '117A']
# Unique Test Group IDs:
# ['002A' '003A' '004A' '015A' '021A' '031A' '035A' '036A' '037A' '040A'
#  '047A' '048A' '049A' '053A' '059A' '061A' '062A' '064A' '067A' '072A'
#  '076A' '097B' '102A' '106A' '110A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '005A' '006A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '013B' '014A' '014B' '016A' '018A' '019A' '019B' '020A'
#  '022A' '023A' '023B' '024A' '025A' '025B' '025C' '026A' '026B' '026C'
#  '027A' '028A' '029A' '032A' '033A' '034A' '038A' '039A' '041A' '042A'
#  '043A' '044A' '045A' '046A' '050A' '051A' '051B' '052A' '054A' '055A'
#  '056A' '057A' '058A' '060A' '063A' '065A' '066A' '068A' '069A' '070A'
#  '071A' '073A' '074A' '075A' '087A' '088A' '090A' '091A' '092A' '093A'
#  '094A' '095A' '096A' '097A' '099A' '100A' '101A' '103A' '104A' '105A'
#  '108A' '109A' '111A' '113A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002A' '003A' '004A' '015A' '021A' '031A' '035A' '036A' '037A' '040A'
#  '047A' '048A' '049A' '053A' '059A' '061A' '062A' '064A' '067A' '072A'
#  '076A' '097B' '102A' '106A' '110A' '115A']
# Length of X_train_val:
# 766
# Length of y_train_val:
# 766
# Length of groups_train_val:
# 766
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     366
# senior    268
# kitten    132
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     106
# senior     52
# kitten     44
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     366
# senior    268
# kitten    132
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     106
# senior     52
# kitten     44
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 366, 2: 268, 1: 132})
# Epoch 1/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 1.5184 - accuracy: 0.5770
# Epoch 2/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5132 - accuracy: 0.7676
# Epoch 3/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3587 - accuracy: 0.8355
# Epoch 4/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3131 - accuracy: 0.8499
# Epoch 5/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2281 - accuracy: 0.9021
# Epoch 6/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2035 - accuracy: 0.9138
# Epoch 7/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1718 - accuracy: 0.9204
# Epoch 8/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1893 - accuracy: 0.9282
# Epoch 9/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1300 - accuracy: 0.9491
# Epoch 10/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1263 - accuracy: 0.9465
# Epoch 11/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1210 - accuracy: 0.9504
# Epoch 12/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1146 - accuracy: 0.9582
# Epoch 13/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1022 - accuracy: 0.9634
# Epoch 14/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1041 - accuracy: 0.9595
# Epoch 15/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1241 - accuracy: 0.9491
# Epoch 16/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0712 - accuracy: 0.9726
# Epoch 17/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0531 - accuracy: 0.9791
# Epoch 18/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0643 - accuracy: 0.9752
# Epoch 19/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0545 - accuracy: 0.9791
# Epoch 20/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0445 - accuracy: 0.9791
# Epoch 21/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0372 - accuracy: 0.9909
# Epoch 22/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0300 - accuracy: 0.9896
# Epoch 23/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0510 - accuracy: 0.9778
# Epoch 24/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0612 - accuracy: 0.9778
# Epoch 25/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0398 - accuracy: 0.9843
# Epoch 26/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0295 - accuracy: 0.9896
# Epoch 27/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0311 - accuracy: 0.9856
# Epoch 28/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0408 - accuracy: 0.9869
# Epoch 29/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0299 - accuracy: 0.9883
# Epoch 30/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 0.9961
# Epoch 31/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0202 - accuracy: 0.9961
# Epoch 32/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0312 - accuracy: 0.9922
# Epoch 33/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 0.9922
# Epoch 34/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0255 - accuracy: 0.9909
# Epoch 35/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0238 - accuracy: 0.9896
# Epoch 36/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 0.9948
# Epoch 37/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 0.9935
# Epoch 38/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0286 - accuracy: 0.9843
# Epoch 39/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0155 - accuracy: 0.9948
# Epoch 40/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 0.9974
# Epoch 41/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 0.9935
# Epoch 42/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0127 - accuracy: 0.9935
# Epoch 43/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0126 - accuracy: 0.9948
# Epoch 44/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0128 - accuracy: 0.9961
# Epoch 45/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 0.9987
# Epoch 46/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 0.9961
# Epoch 47/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 0.9922
# Epoch 48/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.9974
# Epoch 49/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 0.9935
# Epoch 50/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0136 - accuracy: 0.9948
# Epoch 51/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0151 - accuracy: 0.9948
# Epoch 52/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 0.9896
# Epoch 53/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0270 - accuracy: 0.9922
# Epoch 54/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.9909
# Epoch 55/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0197 - accuracy: 0.9922
# Epoch 56/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0286 - accuracy: 0.9948
# Epoch 57/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0305 - accuracy: 0.9896
# Epoch 58/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 0.9987
# Epoch 59/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0091 - accuracy: 0.9961
# Epoch 60/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 0.9935
# Epoch 61/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0093 - accuracy: 0.9961
# Epoch 62/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 0.9974
# Epoch 63/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0118 - accuracy: 0.9987
# Epoch 64/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0111 - accuracy: 0.9948
# Epoch 65/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0320 - accuracy: 0.9856
# Epoch 66/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0072 - accuracy: 0.9974
# Epoch 67/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 0.9987
# Epoch 68/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 0.9961
# Epoch 69/1500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 70/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0061 - accuracy: 0.9987
# Epoch 71/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0115 - accuracy: 0.9961
# Epoch 72/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 0.9974
# Epoch 73/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 0.9987
# Epoch 74/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.9974
# Epoch 75/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9987
# Epoch 76/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 0.9961
# Epoch 77/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 0.9987
# Epoch 78/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9987
# Epoch 79/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 0.9935
# Epoch 80/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0346 - accuracy: 0.9869
# Epoch 81/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0137 - accuracy: 0.9961
# Epoch 82/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 0.9896
# Epoch 83/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0051 - accuracy: 0.9987
# Epoch 84/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 0.9961
# Epoch 85/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0084 - accuracy: 0.9961
# Epoch 86/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 0.9987
# Epoch 87/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0069 - accuracy: 0.9974
# Epoch 88/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 0.9974
# Epoch 89/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0137 - accuracy: 0.9961
# Epoch 90/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 91/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 0.9961
# Epoch 92/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 0.9948
# Epoch 93/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 0.9974
# Epoch 94/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 95/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 96/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0091 - accuracy: 0.9961
# Epoch 97/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0186 - accuracy: 0.9961
# Epoch 98/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0274 - accuracy: 0.9922
# Epoch 99/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 0.9922
# Epoch 100/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 0.9883
# Epoch 101/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0088 - accuracy: 0.9974
# Epoch 102/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 0.9922
# Epoch 103/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 0.9922
# Epoch 104/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 0.9974
# Epoch 105/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 0.9935
# Epoch 106/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 0.9987
# Epoch 107/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 0.9987
# Epoch 108/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0105 - accuracy: 0.9961
# Epoch 109/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 110/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9987
# Epoch 111/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0128 - accuracy: 0.9922
# Epoch 112/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 0.9948
# Epoch 113/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0063 - accuracy: 0.9961
# Epoch 114/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0089 - accuracy: 0.9987
# Epoch 115/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 116/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 117/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 118/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 119/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 120/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 121/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0036 - accuracy: 0.9987
# Epoch 122/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0025 - accuracy: 0.9987
# Epoch 123/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 0.9961
# Epoch 124/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9987
# Epoch 125/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 0.9987
# Epoch 126/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9987
# Epoch 127/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.9987
# Epoch 128/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 0.9987
# Epoch 129/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 0.9909
# Epoch 130/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0153 - accuracy: 0.9961
# Epoch 131/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 0.9974
# Epoch 132/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 0.9974
# Epoch 133/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.9987
# Epoch 134/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 0.9935
# Epoch 135/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 0.9974
# Epoch 136/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0081 - accuracy: 0.9974
# Epoch 137/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 0.9974
# Epoch 138/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 0.9961
# Epoch 139/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 0.9974
# Epoch 140/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 0.9974
# Epoch 141/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0134 - accuracy: 0.9948
# Epoch 142/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.9987
# Epoch 143/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 0.9987
# Epoch 144/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 0.9948
# Epoch 145/1500
# 18/24 [=====================>........] - ETA: 0s - loss: 0.0264 - accuracy: 0.9913Restoring model weights from the end of the best epoch: 115.
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0265 - accuracy: 0.9922
# Epoch 145: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 5.8727 - accuracy: 0.5693
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.81 (21/26)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 202, Predictions: 202, Actuals: 202, Gender: 202
# Final Test Results - Loss: 5.872692584991455, Accuracy: 0.5693069100379944, Precision: 0.5604507916229411, Recall: 0.5458943572151119, F1 Score: 0.544203162535308
# Confusion Matrix:
#  [[65 13 28]
#  [16 18 10]
#  [20  0 32]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 002B    36
# 103A    33
# 047A    30
# 057A    28
# 020A    23
# 000B    20
# 055A    20
# 067A    20
# 059A    18
# 019A    17
# 029A    17
# 101A    16
# 097A    16
# 106A    15
# 042A    14
# 097B    14
# 111A    13
# 002A    13
# 039A    12
# 025A    11
# 036A    11
# 005A    11
# 063A    11
# 068A    11
# 071A    10
# 015A    10
# 014B    10
# 040A    10
# 072A     9
# 051B     9
# 045A     9
# 022A     9
# 094A     8
# 095A     8
# 053A     7
# 031A     7
# 027A     7
# 117A     7
# 021A     6
# 109A     6
# 037A     6
# 007A     6
# 008A     6
# 023A     6
# 025C     6
# 108A     6
# 012A     5
# 062A     5
# 070A     5
# 052A     4
# 003A     4
# 026A     4
# 035A     4
# 104A     4
# 009A     4
# 056A     3
# 006A     3
# 058A     3
# 014A     3
# 064A     3
# 060A     3
# 018A     2
# 087A     2
# 061A     2
# 032A     2
# 038A     2
# 102A     2
# 054A     2
# 026B     1
# 115A     1
# 004A     1
# 076A     1
# 048A     1
# 073A     1
# 088A     1
# 043A     1
# 049A     1
# 026C     1
# 110A     1
# 091A     1
# 090A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 074A    25
# 001A    15
# 028A    14
# 116A    12
# 051A    12
# 016A    11
# 033A     9
# 065A     9
# 013B     8
# 010A     8
# 050A     7
# 099A     7
# 023B     5
# 034A     5
# 044A     5
# 075A     5
# 105A     4
# 011A     3
# 113A     3
# 025B     2
# 069A     2
# 066A     2
# 093A     2
# 096A     1
# 092A     1
# 019B     1
# 024A     1
# 041A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    331
# M    270
# F    148
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    109
# M     86
# X     24
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 000B, 071A, 020A, 026A, 038A, 026...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 047A, 049...
# senior    [117A, 015A, 106A, 053A, 057A, 090A, 051B, 091...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 000A, 065A, 023B, 105A, 034A, 013B, 010...
# kitten                                   [044A, 050A, 041A]
# senior    [028A, 001A, 113A, 116A, 051A, 024A, 016A, 011...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 45, 'kitten': 13, 'senior': 25}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 17, 'kitten': 3, 'senior': 9}
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Unique Training/Validation Group IDs:
# ['000B' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '008A' '009A'
#  '012A' '014A' '014B' '015A' '018A' '019A' '020A' '021A' '022A' '023A'
#  '025A' '025C' '026A' '026B' '026C' '027A' '029A' '031A' '032A' '035A'
#  '036A' '037A' '038A' '039A' '040A' '042A' '043A' '045A' '046A' '047A'
#  '048A' '049A' '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A'
#  '059A' '060A' '061A' '062A' '063A' '064A' '067A' '068A' '070A' '071A'
#  '072A' '073A' '076A' '087A' '088A' '090A' '091A' '094A' '095A' '097A'
#  '097B' '100A' '101A' '102A' '103A' '104A' '106A' '108A' '109A' '110A'
#  '111A' '115A' '117A']
# Unique Test Group IDs:
# ['000A' '001A' '010A' '011A' '013B' '016A' '019B' '023B' '024A' '025B'
#  '028A' '033A' '034A' '041A' '044A' '050A' '051A' '065A' '066A' '069A'
#  '074A' '075A' '092A' '093A' '096A' '099A' '105A' '113A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'021A'}
# Moved to Test Set:
# {'021A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '008A'
#  '009A' '012A' '014A' '014B' '015A' '018A' '019A' '020A' '022A' '023A'
#  '025A' '025C' '026A' '026B' '026C' '027A' '029A' '031A' '032A' '035A'
#  '036A' '037A' '038A' '039A' '040A' '042A' '043A' '045A' '046A' '047A'
#  '048A' '049A' '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A'
#  '059A' '060A' '061A' '062A' '063A' '064A' '067A' '068A' '070A' '071A'
#  '072A' '073A' '076A' '087A' '088A' '090A' '091A' '094A' '095A' '097A'
#  '097B' '100A' '101A' '102A' '103A' '104A' '106A' '108A' '109A' '110A'
#  '111A' '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '010A' '011A' '013B' '016A' '019B' '021A' '023B' '024A' '025B'
#  '028A' '033A' '034A' '041A' '044A' '050A' '051A' '065A' '066A' '069A'
#  '074A' '075A' '092A' '093A' '096A' '099A' '105A' '113A' '116A']
# Length of X_train_val:
# 782
# Length of y_train_val:
# 782
# Length of groups_train_val:
# 782
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     339
# senior    247
# kitten    163
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     133
# senior     73
# kitten     13
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     372
# senior    247
# kitten    163
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     100
# senior     73
# kitten     13
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 372, 2: 247, 1: 163})
# Epoch 1/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.3767 - accuracy: 0.5767
# Epoch 2/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4528 - accuracy: 0.7813
# Epoch 3/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3525 - accuracy: 0.8414
# Epoch 4/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3039 - accuracy: 0.8350
# Epoch 5/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2226 - accuracy: 0.8964
# Epoch 6/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2270 - accuracy: 0.8977
# Epoch 7/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1635 - accuracy: 0.9322
# Epoch 8/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1287 - accuracy: 0.9425
# Epoch 9/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1175 - accuracy: 0.9540
# Epoch 10/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0999 - accuracy: 0.9604
# Epoch 11/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0996 - accuracy: 0.9565
# Epoch 12/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0938 - accuracy: 0.9668
# Epoch 13/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0831 - accuracy: 0.9719
# Epoch 14/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0728 - accuracy: 0.9719
# Epoch 15/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0716 - accuracy: 0.9693
# Epoch 16/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0596 - accuracy: 0.9808
# Epoch 17/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0945 - accuracy: 0.9616
# Epoch 18/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0518 - accuracy: 0.9808
# Epoch 19/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0422 - accuracy: 0.9834
# Epoch 20/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0624 - accuracy: 0.9783
# Epoch 21/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0581 - accuracy: 0.9757
# Epoch 22/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0688 - accuracy: 0.9744
# Epoch 23/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0482 - accuracy: 0.9834
# Epoch 24/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0439 - accuracy: 0.9821
# Epoch 25/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0295 - accuracy: 0.9910
# Epoch 26/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0415 - accuracy: 0.9834
# Epoch 27/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0446 - accuracy: 0.9821
# Epoch 28/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0440 - accuracy: 0.9898
# Epoch 29/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0487 - accuracy: 0.9834
# Epoch 30/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 0.9949
# Epoch 31/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0269 - accuracy: 0.9898
# Epoch 32/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0312 - accuracy: 0.9910
# Epoch 33/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0526 - accuracy: 0.9834
# Epoch 34/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0374 - accuracy: 0.9859
# Epoch 35/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 0.9910
# Epoch 36/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0280 - accuracy: 0.9898
# Epoch 37/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0169 - accuracy: 0.9949
# Epoch 38/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0354 - accuracy: 0.9859
# Epoch 39/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.9898
# Epoch 40/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0120 - accuracy: 0.9974
# Epoch 41/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0224 - accuracy: 0.9910
# Epoch 42/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 0.9949
# Epoch 43/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0236 - accuracy: 0.9910
# Epoch 44/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0122 - accuracy: 0.9974
# Epoch 45/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0126 - accuracy: 0.9949
# Epoch 46/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 0.9923
# Epoch 47/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 0.9923
# Epoch 48/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 0.9949
# Epoch 49/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0268 - accuracy: 0.9936
# Epoch 50/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0166 - accuracy: 0.9936
# Epoch 51/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0198 - accuracy: 0.9949
# Epoch 52/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.9936
# Epoch 53/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0242 - accuracy: 0.9872
# Epoch 54/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0252 - accuracy: 0.9885
# Epoch 55/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0148 - accuracy: 0.9962
# Epoch 56/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0136 - accuracy: 0.9949
# Epoch 57/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 0.9936
# Epoch 58/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 0.9974
# Epoch 59/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 0.9949
# Epoch 60/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.9974
# Epoch 61/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.9987
# Epoch 62/1500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.9949
# Epoch 63/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0169 - accuracy: 0.9974
# Epoch 64/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 0.9936
# Epoch 65/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 0.9962
# Epoch 66/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0097 - accuracy: 0.9949
# Epoch 67/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0123 - accuracy: 0.9949
# Epoch 68/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0186 - accuracy: 0.9910
# Epoch 69/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0287 - accuracy: 0.9885
# Epoch 70/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 0.9974
# Epoch 71/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0226 - accuracy: 0.9923
# Epoch 72/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0250 - accuracy: 0.9910
# Epoch 73/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0194 - accuracy: 0.9923
# Epoch 74/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 0.9987
# Epoch 75/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 0.9974
# Epoch 76/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0169 - accuracy: 0.9949
# Epoch 77/1500
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0109 - accuracy: 0.9949
# Epoch 78/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0140 - accuracy: 0.9962
# Epoch 79/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 0.9974
# Epoch 80/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.9962
# Epoch 81/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 0.9962
# Epoch 82/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0169 - accuracy: 0.9898
# Epoch 83/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0087 - accuracy: 0.9987
# Epoch 84/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0110 - accuracy: 0.9962
# Epoch 85/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0095 - accuracy: 0.9962
# Epoch 86/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9962
# Epoch 87/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 0.9936
# Epoch 88/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 0.9923
# Epoch 89/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 0.9949
# Epoch 90/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0163 - accuracy: 0.9949
# Epoch 91/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0073 - accuracy: 0.9974
# Epoch 92/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 0.9974
# Epoch 93/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 0.9974
# Epoch 94/1500
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0069 - accuracy: 0.9987
# Epoch 95/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0071 - accuracy: 0.9962
# Epoch 96/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 97/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 98/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0083 - accuracy: 0.9962
# Epoch 99/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0061 - accuracy: 0.9974
# Epoch 100/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 0.9987
# Epoch 101/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 102/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 0.9962
# Epoch 103/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 0.9936
# Epoch 104/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0249 - accuracy: 0.9910
# Epoch 105/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 0.9987
# Epoch 106/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 0.9974
# Epoch 107/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.9974
# Epoch 108/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 109/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 110/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 111/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0185 - accuracy: 0.9974
# Epoch 112/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0137 - accuracy: 0.9962
# Epoch 113/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0103 - accuracy: 0.9949
# Epoch 114/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0055 - accuracy: 0.9987
# Epoch 115/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 116/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 0.9923
# Epoch 117/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 0.9987
# Epoch 118/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0134 - accuracy: 0.9974
# Epoch 119/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 0.9962
# Epoch 120/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0076 - accuracy: 0.9987
# Epoch 121/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 0.9962
# Epoch 122/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0050 - accuracy: 0.9987
# Epoch 123/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0062 - accuracy: 0.9974
# Epoch 124/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 125/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 0.9962
# Epoch 126/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.9987
# Epoch 127/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 0.9987
# Epoch 128/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 129/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 0.9974
# Epoch 130/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 0.9987
# Epoch 131/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0082 - accuracy: 0.9974
# Epoch 132/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 133/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 0.9974
# Epoch 134/1500
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 135/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 136/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 137/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 0.9962
# Epoch 138/1500
# 17/25 [===================>..........] - ETA: 0s - loss: 0.0119 - accuracy: 0.9963Restoring model weights from the end of the best epoch: 108.
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0126 - accuracy: 0.9962
# Epoch 138: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 3.9952 - accuracy: 0.6344
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.79 (23/29)
# Before appending - Cat IDs: 202, Predictions: 202, Actuals: 202, Gender: 202
# After appending - Cat IDs: 388, Predictions: 388, Actuals: 388, Gender: 388
# Final Test Results - Loss: 3.9951658248901367, Accuracy: 0.6344085931777954, Precision: 0.5569334215167548, Recall: 0.5566526167896031, F1 Score: 0.555400454731355
# Confusion Matrix:
#  [[71  7 22]
#  [ 8  5  0]
#  [29  2 42]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 103A    33
# 047A    30
# 074A    25
# 000B    20
# 055A    20
# 067A    20
# 059A    18
# 097A    16
# 101A    16
# 106A    15
# 001A    15
# 042A    14
# 028A    14
# 097B    14
# 002A    13
# 039A    12
# 051A    12
# 116A    12
# 068A    11
# 036A    11
# 016A    11
# 040A    10
# 015A    10
# 014B    10
# 033A     9
# 072A     9
# 065A     9
# 013B     8
# 095A     8
# 010A     8
# 050A     7
# 099A     7
# 027A     7
# 031A     7
# 117A     7
# 053A     7
# 108A     6
# 025C     6
# 037A     6
# 109A     6
# 008A     6
# 021A     6
# 044A     5
# 023B     5
# 012A     5
# 062A     5
# 070A     5
# 075A     5
# 034A     5
# 104A     4
# 003A     4
# 035A     4
# 105A     4
# 113A     3
# 064A     3
# 011A     3
# 060A     3
# 087A     2
# 018A     2
# 069A     2
# 066A     2
# 102A     2
# 061A     2
# 032A     2
# 025B     2
# 093A     2
# 038A     2
# 004A     1
# 076A     1
# 019B     1
# 041A     1
# 115A     1
# 024A     1
# 096A     1
# 026C     1
# 110A     1
# 048A     1
# 092A     1
# 049A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 002B    36
# 057A    28
# 020A    23
# 019A    17
# 029A    17
# 111A    13
# 063A    11
# 025A    11
# 005A    11
# 071A    10
# 022A     9
# 051B     9
# 045A     9
# 094A     8
# 007A     6
# 023A     6
# 052A     4
# 009A     4
# 026A     4
# 006A     3
# 056A     3
# 058A     3
# 014A     3
# 054A     2
# 043A     1
# 088A     1
# 073A     1
# 091A     1
# 090A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    257
# M    234
# F    221
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    122
# X     98
# F     36
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 033A, 000B, 000A, 065A, 023B, 038...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 047A, 049...
# senior    [028A, 117A, 015A, 106A, 053A, 001A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [071A, 020A, 026A, 007A, 002B, 005A, 009A, 006...
# kitten                                   [045A, 111A, 043A]
# senior    [057A, 090A, 051B, 091A, 094A, 025A, 058A, 054...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 44, 'kitten': 13, 'senior': 25}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 3, 'senior': 9}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '008A' '010A' '011A' '012A'
#  '013B' '014B' '015A' '016A' '018A' '019B' '021A' '023B' '024A' '025B'
#  '025C' '026C' '027A' '028A' '031A' '032A' '033A' '034A' '035A' '036A'
#  '037A' '038A' '039A' '040A' '041A' '042A' '044A' '046A' '047A' '048A'
#  '049A' '050A' '051A' '053A' '055A' '059A' '060A' '061A' '062A' '064A'
#  '065A' '066A' '067A' '068A' '069A' '070A' '072A' '074A' '075A' '076A'
#  '087A' '092A' '093A' '095A' '096A' '097A' '097B' '099A' '100A' '101A'
#  '102A' '103A' '104A' '105A' '106A' '108A' '109A' '110A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['002B' '005A' '006A' '007A' '009A' '014A' '019A' '020A' '022A' '023A'
#  '025A' '026A' '026B' '029A' '043A' '045A' '051B' '052A' '054A' '056A'
#  '057A' '058A' '063A' '071A' '073A' '088A' '090A' '091A' '094A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '008A' '010A' '011A' '012A'
#  '013B' '014B' '015A' '016A' '018A' '019B' '021A' '023B' '024A' '025B'
#  '025C' '026C' '027A' '028A' '031A' '032A' '033A' '034A' '035A' '036A'
#  '037A' '038A' '039A' '040A' '041A' '042A' '044A' '046A' '047A' '048A'
#  '049A' '050A' '051A' '053A' '055A' '059A' '060A' '061A' '062A' '064A'
#  '065A' '066A' '067A' '068A' '069A' '070A' '072A' '074A' '075A' '076A'
#  '087A' '092A' '093A' '095A' '096A' '097A' '097B' '099A' '100A' '101A'
#  '102A' '103A' '104A' '105A' '106A' '108A' '109A' '110A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '005A' '006A' '007A' '009A' '014A' '019A' '020A' '022A' '023A'
#  '025A' '026A' '026B' '029A' '043A' '045A' '051B' '052A' '054A' '056A'
#  '057A' '058A' '063A' '071A' '073A' '088A' '090A' '091A' '094A' '111A']
# Length of X_train_val:
# 712
# Length of y_train_val:
# 712
# Length of groups_train_val:
# 712
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     305
# senior    254
# kitten    153
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     167
# senior     66
# kitten     23
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     305
# senior    254
# kitten    153
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     167
# senior     66
# kitten     23
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 305, 2: 254, 1: 153})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.5508 - accuracy: 0.5674
# Epoch 2/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.5152 - accuracy: 0.7809
# Epoch 3/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.3785 - accuracy: 0.8287
# Epoch 4/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2704 - accuracy: 0.8933
# Epoch 5/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2298 - accuracy: 0.9185
# Epoch 6/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1842 - accuracy: 0.9228
# Epoch 7/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1333 - accuracy: 0.9508
# Epoch 8/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1607 - accuracy: 0.9312
# Epoch 9/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1461 - accuracy: 0.9424
# Epoch 10/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1322 - accuracy: 0.9508
# Epoch 11/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0948 - accuracy: 0.9691
# Epoch 12/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1077 - accuracy: 0.9635
# Epoch 13/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0935 - accuracy: 0.9719
# Epoch 14/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0887 - accuracy: 0.9635
# Epoch 15/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0710 - accuracy: 0.9789
# Epoch 16/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0583 - accuracy: 0.9803
# Epoch 17/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0663 - accuracy: 0.9747
# Epoch 18/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0557 - accuracy: 0.9831
# Epoch 19/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0431 - accuracy: 0.9860
# Epoch 20/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0524 - accuracy: 0.9789
# Epoch 21/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0438 - accuracy: 0.9902
# Epoch 22/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0467 - accuracy: 0.9831
# Epoch 23/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0445 - accuracy: 0.9846
# Epoch 24/1500
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0294 - accuracy: 0.9902
# Epoch 25/1500
# ...
# 060A     3
# 087A     2
# 032A     2
# 018A     2
# 038A     2
# 026C     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    286
# X    218
# F    173
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    137
# F     84
# M     70
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 033A, 071A, 020A, 000A, 026A, 065A, 023...
# kitten    [110A, 040A, 047A, 049A, 045A, 048A, 111A, 044...
# senior    [028A, 015A, 106A, 053A, 057A, 001A, 090A, 113...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [070A, 000B, 038A, 026C, 068A, 018A, 032A, 027...
# kitten                             [046A, 042A, 014B, 109A]
# senior    [117A, 101A, 103A, 097A, 055A, 108A, 060A, 008...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 50, 'kitten': 12, 'senior': 23}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 12, 'kitten': 4, 'senior': 11}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '009A'
#  '010A' '011A' '013B' '014A' '015A' '016A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '023B' '024A' '025A' '025B' '026A' '026B' '028A' '029A'
#  '031A' '033A' '034A' '035A' '036A' '037A' '040A' '041A' '043A' '044A'
#  '045A' '047A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '056A' '057A' '058A' '059A' '061A' '062A' '063A' '064A' '065A' '066A'
#  '067A' '069A' '071A' '072A' '073A' '074A' '075A' '076A' '088A' '090A'
#  '091A' '092A' '093A' '094A' '096A' '097B' '099A' '102A' '105A' '106A'
#  '110A' '111A' '113A' '115A' '116A']
# Unique Test Group IDs:
# ['000B' '008A' '012A' '014B' '018A' '025C' '026C' '027A' '032A' '038A'
#  '039A' '042A' '046A' '055A' '060A' '068A' '070A' '087A' '095A' '097A'
#  '100A' '101A' '103A' '104A' '108A' '109A' '117A']
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'049A'}
# Moved to Test Set:
# {'049A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '009A'
#  '010A' '011A' '013B' '014A' '015A' '016A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '023B' '024A' '025A' '025B' '026A' '026B' '028A' '029A'
#  '031A' '033A' '034A' '035A' '036A' '037A' '040A' '041A' '043A' '044A'
#  '045A' '046A' '047A' '048A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '056A' '057A' '058A' '059A' '061A' '062A' '063A' '064A' '065A' '066A'
#  '067A' '069A' '071A' '072A' '073A' '074A' '075A' '076A' '088A' '090A'
#  '091A' '092A' '093A' '094A' '096A' '097B' '099A' '102A' '105A' '106A'
#  '110A' '111A' '113A' '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '008A' '012A' '014B' '018A' '025C' '026C' '027A' '032A' '038A'
#  '039A' '042A' '049A' '055A' '060A' '068A' '070A' '087A' '095A' '097A'
#  '100A' '101A' '103A' '104A' '108A' '109A' '117A']
# Length of X_train_val:
# 742
# Length of y_train_val:
# 742
# Length of groups_train_val:
# 742
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     406
# senior    191
# kitten     80
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# senior    129
# kitten     96
# adult      66
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     406
# senior    191
# kitten    145
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# senior    129
# adult      66
# kitten     31
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 406, 2: 191, 1: 145})
# Epoch 1/1500
# 24/24 [==============================] - 1s 3ms/step - loss: 1.1959 - accuracy: 0.5876
# Epoch 2/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4738 - accuracy: 0.7857
# Epoch 3/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2947 - accuracy: 0.8518
# Epoch 4/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2540 - accuracy: 0.8706
# Epoch 5/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2352 - accuracy: 0.8976
# Epoch 6/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1722 - accuracy: 0.9178
# Epoch 7/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1447 - accuracy: 0.9407
# Epoch 8/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1541 - accuracy: 0.9299
# Epoch 9/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1173 - accuracy: 0.9515
# Epoch 10/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1359 - accuracy: 0.9380
# Epoch 11/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1040 - accuracy: 0.9582
# Epoch 12/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1151 - accuracy: 0.9555
# Epoch 13/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0971 - accuracy: 0.9569
# Epoch 14/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0662 - accuracy: 0.9744
# Epoch 15/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0818 - accuracy: 0.9650
# Epoch 16/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0634 - accuracy: 0.9730
# Epoch 17/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0694 - accuracy: 0.9757
# Epoch 18/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0618 - accuracy: 0.9757
# Epoch 19/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0819 - accuracy: 0.9650
# Epoch 20/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0554 - accuracy: 0.9865
# Epoch 21/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0395 - accuracy: 0.9906
# Epoch 22/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0468 - accuracy: 0.9825
# Epoch 23/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0452 - accuracy: 0.9838
# Epoch 24/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0474 - accuracy: 0.9865
# Epoch 25/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0522 - accuracy: 0.9757
# Epoch 26/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0663 - accuracy: 0.9690
# Epoch 27/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0356 - accuracy: 0.9838
# Epoch 28/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0433 - accuracy: 0.9852
# Epoch 29/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0464 - accuracy: 0.9811
# Epoch 30/1500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0459 - accuracy: 0.9852
# Epoch 31/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0301 - accuracy: 0.9906
# Epoch 32/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0387 - accuracy: 0.9852
# Epoch 33/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0411 - accuracy: 0.9825
# Epoch 34/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0294 - accuracy: 0.9946
# Epoch 35/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0246 - accuracy: 0.9919
# Epoch 36/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.9919
# Epoch 37/1500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0409 - accuracy: 0.9879
# Epoch 38/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0251 - accuracy: 0.9919
# Epoch 39/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 0.9973
# Epoch 40/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0205 - accuracy: 0.9919
# Epoch 41/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0235 - accuracy: 0.9906
# Epoch 42/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0193 - accuracy: 0.9946
# Epoch 43/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0137 - accuracy: 0.9987
# Epoch 44/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0257 - accuracy: 0.9919
# Epoch 45/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0281 - accuracy: 0.9879
# Epoch 46/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 47/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 0.9946
# Epoch 48/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 0.9960
# Epoch 49/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 0.9946
# Epoch 50/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0226 - accuracy: 0.9919
# Epoch 51/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0135 - accuracy: 0.9919
# Epoch 52/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 0.9960
# Epoch 53/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0164 - accuracy: 0.9933
# Epoch 54/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0195 - accuracy: 0.9946
# Epoch 55/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0333 - accuracy: 0.9865
# Epoch 56/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0389 - accuracy: 0.9906
# Epoch 57/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0334 - accuracy: 0.9906
# Epoch 58/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0304 - accuracy: 0.9838
# Epoch 59/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 0.9933
# Epoch 60/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 0.9973
# Epoch 61/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0450 - accuracy: 0.9933
# Epoch 62/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0169 - accuracy: 0.9933
# Epoch 63/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0249 - accuracy: 0.9838
# Epoch 64/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 65/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 0.9946
# Epoch 66/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0149 - accuracy: 0.9960
# Epoch 67/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 0.9960
# Epoch 68/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 0.9973
# Epoch 69/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0071 - accuracy: 0.9987
# Epoch 70/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 0.9919
# Epoch 71/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0175 - accuracy: 0.9946
# Epoch 72/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 73/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 0.9946
# Epoch 74/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0147 - accuracy: 0.9946
# Epoch 75/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 0.9933
# Epoch 76/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0083 - accuracy: 0.9960
# Epoch 77/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 0.9973
# Epoch 78/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 0.9987
# Epoch 79/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 0.9987
# Epoch 80/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 0.9960
# Epoch 81/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 0.9987
# Epoch 82/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0155 - accuracy: 0.9933
# Epoch 83/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0080 - accuracy: 0.9973
# Epoch 84/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0075 - accuracy: 0.9973
# Epoch 85/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0178 - accuracy: 0.9919
# Epoch 86/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 0.9946
# Epoch 87/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0295 - accuracy: 0.9906
# Epoch 88/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 89/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 0.9960
# Epoch 90/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0077 - accuracy: 0.9973
# Epoch 91/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 92/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0086 - accuracy: 0.9946
# Epoch 93/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0191 - accuracy: 0.9933
# Epoch 94/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 0.9960
# Epoch 95/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0102 - accuracy: 0.9987
# Epoch 96/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0241 - accuracy: 0.9960
# Epoch 97/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.9987
# Epoch 98/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 0.9973
# Epoch 99/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0059 - accuracy: 0.9987
# Epoch 100/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 0.9987
# Epoch 101/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 102/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 103/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 104/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 0.9987
# Epoch 105/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0110 - accuracy: 0.9946
# Epoch 106/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0091 - accuracy: 0.9960
# Epoch 107/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0192 - accuracy: 0.9960
# Epoch 108/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0063 - accuracy: 0.9973
# Epoch 109/1500
# 10/24 [===========>..................] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 79.
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 0.9987
# Epoch 109: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 5.5917 - accuracy: 0.5088
# 8/8 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.63 (17/27)
# Before appending - Cat IDs: 644, Predictions: 644, Actuals: 644, Gender: 644
# After appending - Cat IDs: 870, Predictions: 870, Actuals: 870, Gender: 870
# Final Test Results - Loss: 5.59173059463501, Accuracy: 0.508849561214447, Precision: 0.5903846153846154, Recall: 0.49800707752695744, F1 Score: 0.49728736042925775
# Confusion Matrix:
#  [[45  3 18]
#  [17 11  3]
#  [68  2 59]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.534876745173203
#
# Final Average Loss across all UNSEEN TEST sets: 5.144946455955505
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.5648600161075592
#
# Final Average Precision across all UNSEEN TEST sets: 0.5567551323011459
#
# Final Average Recall across all UNSEEN TEST sets: 0.564624429061102

# %%
seed_5_folds_values = [unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1]

seed_5_training_acc_values = cv_training_acc_total

# Plotting all fold metrics|
seed_5_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 870, Predictions: 870, Actuals: 870, Gender: 870

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.73 (80/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, senior, adult, adult, adult, se...         adult            adult                   True
# 78    072A  [adult, adult, senior, senior, adult, adult, a...         adult            adult                   True
# 75    069A                                     [adult, adult]         adult            adult                   True
# 73    067A  [senior, adult, kitten, adult, adult, adult, a...         adult            adult                   True
# 71    065A  [adult, senior, adult, kitten, adult, adult, k...         adult            adult                   True
# 70    064A                            [kitten, adult, senior]         adult            adult                   True
# 69    063A  [kitten, kitten, kitten, adult, adult, adult, ...         adult            adult                   True
# 68    062A               [kitten, adult, adult, adult, adult]         adult            adult                   True
# 66    060A                            [senior, adult, senior]        senior           senior                   True
# 65    059A  [senior, senior, senior, senior, senior, senio...        senior           senior                   True
# 62    056A                           [senior, senior, senior]        senior           senior                   True
# 61    055A  [senior, senior, senior, senior, adult, senior...        senior           senior                   True
# 60    054A                                   [senior, senior]        senior           senior                   True
# 59    053A  [senior, senior, senior, adult, adult, adult, ...        senior           senior                   True
# 58    052A                     [adult, adult, senior, senior]         adult            adult                   True
# 57    051B  [adult, senior, adult, senior, adult, senior, ...        senior           senior                   True
# 1     001A  [adult, adult, senior, senior, senior, senior,...        senior           senior                   True
# 54    049A                                   [kitten, kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A  [kitten, senior, kitten, kitten, kitten, kitte...        kitten           kitten                   True
#
# 39    033A  [adult, adult, adult, adult, senior, senior, a...         adult            adult                   True
# 40    034A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 35    028A  [senior, adult, senior, senior, adult, adult, ...        senior           senior                   True
# 41    035A                     [adult, senior, adult, senior]         adult            adult                   True
# 34    027A  [adult, adult, senior, adult, adult, senior, a...         adult            adult                   True
# 37    031A  [senior, adult, adult, adult, kitten, adult, s...         adult            adult                   True
# 31    026A                     [senior, adult, adult, senior]         adult            adult                   True
# 43    037A      [kitten, adult, senior, adult, adult, senior]         adult            adult                   True
# 103   109A       [adult, adult, kitten, adult, kitten, adult]         adult           kitten                  False
# 102   108A      [adult, adult, senior, senior, senior, adult]         adult           senior                  False
# 101   106A  [adult, adult, adult, adult, adult, adult, sen...         adult           senior                  False
# 6     005A  [adult, senior, senior, kitten, senior, senior...        senior            adult                  False
# 99    104A                     [senior, adult, adult, senior]         adult           senior                  False
# 42    036A  [senior, senior, senior, senior, adult, senior...        senior            adult                  False
# 98    103A  [adult, senior, adult, adult, kitten, adult, a...         adult           senior                  False
# 9     008A         [adult, adult, adult, adult, adult, adult]         adult           senior                  False
# 50    044A              [kitten, adult, adult, kitten, adult]         adult           kitten                  False
# 48    042A  [adult, adult, adult, adult, adult, kitten, ki...         adult           kitten                  False
# 56    051A  [adult, senior, senior, adult, senior, adult, ...         adult           senior                  False
# 52    047A  [adult, senior, kitten, adult, kitten, adult, ...         adult           kitten                  False
# 36    029A  [adult, senior, senior, senior, adult, senior,...        senior            adult                  False
# 30    025C        [senior, adult, adult, adult, adult, adult]         adult           senior                  False
# 63    057A  [adult, adult, adult, senior, adult, senior, a...         adult           senior                  False
# 72    066A                                   [senior, senior]        senior            adult                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 74    068A  [adult, adult, senior, senior, senior, senior,...        senior            adult                  False
# 32    026B                                           [senior]        senior            adult                  False
# 77    071A  [adult, senior, adult, kitten, adult, senior, ...        senior            adult                  False
# 64    058A                            [kitten, adult, kitten]        kitten           senior                  False
# 33    026C                                           [senior]        senior            adult                  False
# 16    014B  [adult, adult, senior, senior, senior, kitten,...         adult           kitten                  False
# 20    019A  [adult, adult, kitten, kitten, adult, senior, ...        kitten            adult                  False
# 82    076A                                           [kitten]        kitten            adult                  False
# 18    016A  [kitten, adult, adult, adult, adult, adult, se...         adult           senior                  False
# 85    090A                                            [adult]         adult           senior                  False
# 86    091A                                            [adult]         adult           senior                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 55    050A  [adult, kitten, adult, adult, adult, kitten, a...         adult           kitten                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']
# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()
# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')
# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Calculate the class statistics
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    accuracy=('Majority_Correct', lambda x: x.mean() * 100),
    total_count=('Majority_Correct', 'size')
).reset_index()

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group   accuracy  total_count
# 0            adult  83.606557           61
# 1           kitten  60.000000           15
# 2           senior  58.823529           34

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %%
full_results
# Out:
#     cat_id predicted_age_group actual_age_group all_gender  correct
# 0     002A               adult            adult          F     True
# 1     015A               adult           senior          M    False
# 2     106A               adult           senior          M    False
# 3     053A              senior           senior          F     True
# 4     053A              senior           senior          F     True
# ..     ...                 ...              ...        ...      ...
# 865   039A              senior           senior          X     True
# 866   025C               adult           senior          M    False
# 867   025C               adult           senior          M    False
# 868   025C               adult           senior          M    False
# 869   049A              kitten           kitten          X     True
#
# [870 rows x 5 columns]

# %% [markdown]
# ## Detailed Class Statistics

# %%
# For each fold
fold_class_stats = full_results.groupby('actual_age_group').agg(
    accuracy=('correct', lambda x: x.mean() * 100),
    total_count=('correct', 'size')
).reset_index()

# Store for final evaluation 
all_class_stats.append(fold_class_stats)

# Log the detailed stats
print("Detailed Class Statistics for this fold:")
print(fold_class_stats)
# Out:
# Detailed Class Statistics for this fold:
#   actual_age_group   accuracy  total_count
# 0            adult  59.681093          439
# 1           kitten  49.549550          111
# 2           senior  53.437500          320

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(fold_class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    218      139     63.76
# 1          M    362      201     55.52
# 2          X    290      148     51.03

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats) 
print("Total Majority Vote Statistics so far:\n", all_majority_vote_details) 
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.6636363636363637, 0.6727272727272727, 0.7, 0.6818181818181818, 0.7272727272727273]
# Total Class Statistics so far:
#  [  actual_age_group   accuracy  total_count
# 0            adult  55.733945          436
# 1           kitten  57.657658          111
# 2           senior  51.562500          320,   actual_age_group   accuracy  total_count
# 0            adult  60.592255          439
# 1           kitten  53.153153          111
# 2           senior  55.000000          320,   actual_age_group   accuracy  total_count
# 0            adult  56.221198          434
# 1           kitten  54.054054          111
# 2           senior  52.500000          320,   actual_age_group   accuracy  total_count
# 0            adult  61.904762          441
# 1           kitten  49.549550          111
# 2           senior  53.437500          320,   actual_age_group   accuracy  total_count
# 0            adult  59.681093          439
# 1           kitten  49.549550          111
# 2           senior  53.437500          320]
# Total Majority Vote Statistics so far:
#  [  actual_age_group   accuracy  total_count
# 0            adult  78.688525           61
# 1           kitten  66.666667           15
# 2           senior  44.117647           34,   actual_age_group   accuracy  total_count
# 0            adult  75.409836           61
# 1           kitten  66.666667           15
# 2           senior  52.941176           34,   actual_age_group   accuracy  total_count
# 0            adult  80.327869           61
# 1           kitten  73.333333           15
# 2           senior  50.000000           34,   actual_age_group   accuracy  total_count
# 0            adult  78.688525           61
# 1           kitten  66.666667           15
# 2           senior  50.000000           34,   actual_age_group   accuracy  total_count
# 0            adult  83.606557           61
# 1           kitten  60.000000           15
# 2           senior  58.823529           34]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      127     58.26
# 1          M    359      183     50.97
# 2          X    290      162     55.86,   all_gender  count  correct  accuracy
# 0          F    218      138     63.30
# 1          M    362      210     58.01
# 2          X    290      153     52.76,   all_gender  count  correct  accuracy
# 0          F    218      126     57.80
# 1          M    356      181     50.84
# 2          X    291      165     56.70,   all_gender  count  correct  accuracy
# 0          F    218      133     61.01
# 1          M    364      210     57.69
# 2          X    290      156     53.79,   all_gender  count  correct  accuracy
# 0          F    218      139     63.76
# 1          M    362      201     55.52
# 2          X    290      148     51.03]

# %% [markdown]
# # --------------

# %% [markdown]
# # Total Final Results & Analysis

# %%
# Count unique cat_id per age group 
unique_cats_per_age_group = dataframe.groupby('age_group')['cat_id'].nunique()

# Display the counts
print("Unique cat_id counts in original dataframe:", unique_cats_per_age_group)
# Out:
# Unique cat_id counts in original dataframe: age_group
# adult     62
# kitten    16
# senior    34
# Name: cat_id, dtype: int64

# %% [markdown]
# ## Metrics

# %%
# Calculate overall metrics
overall_avg_loss = np.mean(all_losses)
overall_avg_acc = np.mean(all_accuracies)
overall_avg_precision = np.mean(all_precisions)
overall_avg_recall = np.mean(all_recalls)
overall_avg_f1 = np.mean(all_f1)

print("Overall Average Metrics:")
print("Loss:", overall_avg_loss)
print("Accuracy:", overall_avg_acc)
print("Precision:", overall_avg_precision)
print("Recall:", overall_avg_recall)
print("F1 Score:", overall_avg_f1)
# Out:
# Overall Average Metrics:
# Loss: 5.583205366134644
# Accuracy: 0.5628187879920006
# Precision: 0.5387259916530425
# Recall: 0.5634558003842738
# F1 Score: 0.5361591722608988

# %% [markdown]
# ## Majority Votes

# %%
# After calculating class_stats for each fold
all_majority_vote_details.append(class_stats)

# At the end, when calculating the final metrics:
total_majority_vote_details = pd.concat(all_majority_vote_details)

macro_avg_majority_vote_accuracy = (
    total_majority_vote_details.groupby('actual_age_group')['accuracy'].mean().mean()
)

print(f"Macro-Averaged Majority Vote Accuracy: {macro_avg_majority_vote_accuracy}")

# For class-wise accuracies:
macro_avg_class_accuracies = total_majority_vote_details.groupby('actual_age_group')['accuracy'].mean()

print("Macro-Averaged Class Accuracies:")
print(macro_avg_class_accuracies)

macro_avg_class_accuracies_df = macro_avg_class_accuracies.reset_index()
macro_avg_class_accuracies_df.columns = ['actual_age_group', 'accuracy']
# Out:
# Macro-Averaged Majority Vote Accuracy: 66.0203935854852
# Macro-Averaged Class Accuracies:
# actual_age_group
# adult     80.054645
# kitten    65.555556
# senior    52.450980
# Name: accuracy, dtype: float64

# %%
# Use the modified function
styled_barplot_with_average(macro_avg_class_accuracies_df, 'actual_age_group', 'accuracy', 
                            'Average Accuracy of Majority Votes by Age Group', 
                            'Age Group', 'Accuracy (%)', 
                            average_line=macro_avg_majority_vote_accuracy)

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the average class statistics across all folds and seeds
average_class_stats = pd.concat(all_class_stats).groupby('actual_age_group').agg({
    'accuracy': 'mean',
    'total_count': 'mean'
}).reset_index()
print("Average Class Statistics across all folds and seeds:")
print(average_class_stats)

# Calculate macro-averaged accuracy
macro_accuracy = average_class_stats['accuracy'].mean()
print(f"Macro-Averaged Accuracy: {macro_accuracy:.2f}%")

# Calculate macro-averaged accuracy for detailed class statistics
macro_avg_class_accuracy = average_class_stats['accuracy'].mean()
# Out:
# Average Class Statistics across all folds and seeds:
#   actual_age_group   accuracy  total_count
# 0            adult  58.826651        437.8
# 1           kitten  52.792793        111.0
# 2           senior  53.187500        320.0
# Macro-Averaged Accuracy: 54.94%

# %%
# Use the modified function for detailed class statistics
styled_barplot_with_average(average_class_stats, 'actual_age_group', 'accuracy', 
                            'Average Accuracy by Age Group', 
                            'Age Group', 'Accuracy (%)', 
                            average_line=macro_avg_class_accuracy)

# %%
# Concatenate all gender stats DataFrames and calculate the mean of accuracies
total_gender_stats = pd.concat(all_gender_stats)
average_gender_stats = total_gender_stats.groupby('all_gender').agg({
    'count': 'sum',  
    'correct': 'sum'  
}).reset_index()
average_gender_stats['accuracy'] = (average_gender_stats['correct'] / average_gender_stats['count']) * 100

print("Average Gender Accuracy:")
print(average_gender_stats)
# Out:
# Average Gender Accuracy:
#   all_gender  count  correct   accuracy
# 0          F   1090      663  60.825688
# 1          M   1803      985  54.631170
# 2          X   1451      784  54.031702

# %%
# Plot for Accuracy by Gender
styled_barplot(total_gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# # Visualisations

# %%
# Plotting all metrics
metrics_across_seeds = plot_all_metrics(all_losses, all_accuracies, all_precisions, all_recalls, all_f1, "Seeds", "Seed Number")

# %% [markdown]
# ## Display the seed folds results together

# %%
# Create a figure with subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))  

# Flatten the axes array for easier indexing
axes = axes.flatten()

def plot_metrics_on_axes(ax, losses, accuracies, precisions, recalls, f1, title):
    ax.plot(range(1, len(losses)+1), losses, marker='o', color='blue', label='Loss')
    ax.plot(range(1, len(accuracies)+1), accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(range(1, len(precisions)+1), precisions, marker='o', color='red', label='Precision')
    ax.plot(range(1, len(recalls)+1), recalls, marker='o', color='purple', label='Recall')
    ax.plot(range(1, len(f1)+1), f1, marker='o', color='orange', label='F1 Score')
    ax.set_xticks([1, 2, 3, 4])  # Set x-axis ticks to full integers
    ax.set_title(title)
    ax.set_xlabel('Fold Number')
    ax.set_ylabel('Metric Value')
    ax.legend()
    ax.grid(True)

# Plot onto each axes object
plot_metrics_on_axes(axes[0], *seed_1_folds_values, "Seed 1 Metrics")
plot_metrics_on_axes(axes[1], *seed_2_folds_values, "Seed 2 Metrics")
plot_metrics_on_axes(axes[2], *seed_3_folds_values, "Seed 3 Metrics")
plot_metrics_on_axes(axes[3], *seed_4_folds_values, "Seed 4 Metrics")
plot_metrics_on_axes(axes[4], *seed_5_folds_values, "Seed 5 Metrics")

# Hide the unused subplot 
for ax in axes[5:]:
    ax.set_visible(False)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# # Statistics

# %%
# Calculate the standard deviation for each metric
std_loss = np.std(all_losses)
std_accuracy = np.std(all_accuracies)
std_precision = np.std(all_precisions)
std_recall = np.std(all_recalls)
std_f1 = np.std(all_f1)

print("Standard Deviations:")
print(f"Loss: {std_loss}")
print(f"Accuracy: {std_accuracy}")
print(f"Precision: {std_precision}")
print(f"Recall: {std_recall}")
print(f"F1 Score: {std_f1}")
# Out:
# Standard Deviations:
# Loss: 3.2275065745541354
# Accuracy: 0.03830145332287016
# Precision: 0.05871714716917157
# Recall: 0.061968216529191364
# F1 Score: 0.057288573873462686

# %%
# Calculate the interquartile range for each metric
iqr_loss = np.percentile(all_losses, 75) - np.percentile(all_losses, 25)
iqr_accuracy = np.percentile(all_accuracies, 75) - np.percentile(all_accuracies, 25)
iqr_precision = np.percentile(all_precisions, 75) - np.percentile(all_precisions, 25)
iqr_recall = np.percentile(all_recalls, 75) - np.percentile(all_recalls, 25)
iqr_f1 = np.percentile(all_f1, 75) - np.percentile(all_f1, 25)

print("Interquartile Ranges:")
print(f"Loss: {iqr_loss}")
print(f"Accuracy: {iqr_accuracy}")
print(f"Precision: {iqr_precision}")
print(f"Recall: {iqr_recall}")
print(f"F1 Score: {iqr_f1}")
# Out:
# Interquartile Ranges:
# Loss: 1.7875310182571411
# Accuracy: 0.04107515513896942
# Precision: 0.04641071697307131
# Recall: 0.09213630973273401
# F1 Score: 0.059149190085846515

# %% [markdown]
# ### Variation

# %%
# Calculate the variation for each metric
var_loss = np.var(all_losses)
var_accuracy = np.var(all_accuracies)
var_precision = np.var(all_precisions)
var_recall = np.var(all_recalls)
var_f1 = np.var(all_f1)

print("Variations:")
print(f"Loss: {var_loss}")
print(f"Accuracy: {var_accuracy}")
print(f"Precision: {var_precision}")
print(f"Recall: {var_recall}")
print(f"F1 Score: {var_f1}")
# Out:
# Variations:
# Loss: 10.41679868879017
# Accuracy: 0.0014670013266440019
# Precision: 0.003447703371686153
# Recall: 0.003840059859808746
# F1 Score: 0.003281980696455191

# %% [markdown]
# ### Levene tests for variation significance between seeds

# %% [markdown]
# #### Levene across seeds for LOSS

# %%
# Levene across seeds for LOSS
stat_val, p_val = levene(seed_1_folds_values[0], seed_2_folds_values[0], seed_3_folds_values[0], seed_4_folds_values[0], seed_5_folds_values[0])
print(f'levene test statistic: {stat_val:.2f}, P-value: {p_val:.3f}')
# Out:
# levene test statistic: 0.90, P-value: 0.488

# %% [markdown]
# #### Levene across seeds for ACCURACY

# %%
# Levene across seeds for ACCURACY
stat_val, p_val = levene(seed_1_folds_values[1], seed_2_folds_values[1], seed_3_folds_values[1], seed_4_folds_values[1], seed_5_folds_values[1])
print(f'levene test statistic: {stat_val:.2f}, P-value: {p_val:.3f}')
# Out:
# levene test statistic: 0.69, P-value: 0.613

# %% [markdown]
# #### Levene across seeds for PRECISION

# %%
# Levene across seeds for PRECISION
stat_val, p_val = levene(seed_1_folds_values[2], seed_2_folds_values[2], seed_3_folds_values[2], seed_4_folds_values[2], seed_5_folds_values[2])
print(f'levene test statistic: {stat_val:.2f}, P-value: {p_val:.3f}')
# Out:
# levene test statistic: 1.16, P-value: 0.367

# %% [markdown]
# #### Levene across seeds for RECALL

# %%
# Levene across seeds for RECALL
stat_val, p_val = levene(seed_1_folds_values[3], seed_2_folds_values[3], seed_3_folds_values[3], seed_4_folds_values[3], seed_5_folds_values[3])
print(f'levene test statistic: {stat_val:.2f}, P-value: {p_val:.3f}')
# Out:
# levene test statistic: 0.65, P-value: 0.637

# %% [markdown]
# #### Levene across seeds for F1

# %%
# Levene across seeds for F1
stat_val, p_val = levene(seed_1_folds_values[4], seed_2_folds_values[4], seed_3_folds_values[4], seed_4_folds_values[4], seed_5_folds_values[4])
print(f'levene test statistic: {stat_val:.2f}, P-value: {p_val:.3f}')
# Out:
# levene test statistic: 0.90, P-value: 0.488

# %% [markdown]
# ## Print out measurements for future further analysis (without rerunning notebook)

# %%
seed_1_folds_values
# Out:
# [[3.70603346824646, 6.183104515075684, 5.738619804382324, 5.656033039093018],
#  [0.6516854166984558,
#   0.5321100950241089,
#   0.4942965805530548,
#   0.5288461446762085],
#  [0.635978835978836,
#   0.5477104924473345,
#   0.4495572946692801,
#   0.522716049382716],
#  [0.6336120401337793,
#   0.5384936381445479,
#   0.6068140644064036,
#   0.5077403245942572],
#  [0.6345667722999143,
#   0.5379969663428033,
#   0.47267809945294736,
#   0.5121051534401984]]

# %%
seed_2_folds_values
# Out:
# [[6.822924613952637, 3.952930450439453, 4.859235763549805, 4.014749050140381],
#  [0.6000000238418579,
#   0.5604395866394043,
#   0.5759717226028442,
#   0.5688889026641846],
#  [0.5852152023085897,
#   0.5438177903931328,
#   0.5078982984090271,
#   0.5534354237562794],
#  [0.6298319327731093,
#   0.5723032886967313,
#   0.4795407185129616,
#   0.5845864661654135],
#  [0.6019473081328751,
#   0.5525823112568461,
#   0.48604612576738004,
#   0.56294726177145]]

# %%
seed_3_folds_values
# Out:
# [[3.7172791957855225,
#   6.617351055145264,
#   3.6855623722076416,
#   4.197205066680908],
#  [0.5631067752838135,
#   0.5373831987380981,
#   0.5209125280380249,
#   0.5714285969734192],
#  [0.5571584363495304,
#   0.5363795518207283,
#   0.4840795262910977,
#   0.48926084083168114],
#  [0.6353121478476448,
#   0.5669601173802855,
#   0.509503877032869,
#   0.563907632328685],
#   0.9971910119056702,
#   1.0,
#   0.9971910119056702,
#   0.9943820238113403,
#   1.0,
#   0.9957864880561829,
#   0.9957864880561829],
#  [0.5876010656356812,
#   0.7857142686843872,
#   0.8517520427703857,
#   0.8706199526786804,
#   0.8975741267204285,
#   0.9177897572517395,
#   0.9407008290290833,
#   0.9299191236495972,
#   0.9514824748039246,
#   0.9380053877830505,
#   0.9582210183143616,
#   0.9555255770683289,
#   0.9568732976913452,
#   0.9743935465812683,
#   0.9649595618247986,
#   0.973045825958252,
#   0.9757412672042847,
#   0.9757412672042847,
#   0.9649595618247986,
#   0.986522912979126,
#   0.9905660152435303,
#   0.9824798107147217,
#   0.9838274717330933,
#   0.986522912979126,
#   0.9757412672042847,
#   0.9690027236938477,
#   0.9838274717330933,
#   0.9851751923561096,
#   0.9811320900917053,
#   0.9851751923561096,
#   0.9905660152435303,
#   0.9851751923561096,
#   0.9824798107147217,
#   0.9946091771125793,
#   0.9919137358665466,
#   0.9919137358665466,
#   0.9878706336021423,
#   0.9919137358665466,
#   0.9973045587539673,
#   0.9919137358665466,
#   0.9905660152435303,
#   0.9946091771125793,
#   0.9986522793769836,
#   0.9919137358665466,
#   0.9878706336021423,
#   1.0,
#   0.9946091771125793,
#   0.9959568977355957,
#   0.9946091771125793,
#   0.9919137358665466,
#   0.9919137358665466,
#   0.9959568977355957,
#   0.993261456489563,
#   0.9946091771125793,
#   0.986522912979126,
#   0.9905660152435303,
#   0.9905660152435303,
#   0.9838274717330933,
#   0.993261456489563,
#   0.9973045587539673,
#   0.993261456489563,
#   0.993261456489563,
#   0.9838274717330933,
#   1.0,
#   0.9946091771125793,
#   0.9959568977355957,
#   0.9959568977355957,
#   0.9973045587539673,
#   0.9986522793769836,
#   0.9919137358665466,
#   0.9946091771125793,
#   1.0,
#   0.9946091771125793,
#   0.9946091771125793,
#   0.993261456489563,
#   0.9959568977355957,
#   0.9973045587539673,
#   0.9986522793769836,
#   0.9986522793769836,
#   0.9959568977355957,
#   0.9986522793769836,
#   0.993261456489563,
#   0.9973045587539673,
#   0.9973045587539673,
#   0.9919137358665466,
#   0.9946091771125793,
#   0.9905660152435303,
#   1.0,
#   0.9959568977355957,
#   0.9973045587539673,
#   1.0,
#   0.9946091771125793,
#   0.993261456489563,
#   0.9959568977355957,
#   0.9986522793769836,
#   0.9959568977355957,
#   0.9986522793769836,
#   0.9973045587539673,
#   0.9986522793769836,
#   0.9986522793769836,
#   1.0,
#   1.0,
#   1.0,
#   0.9986522793769836,
#   0.9946091771125793,
#   0.9959568977355957,
#   0.9959568977355957,
#   0.9973045587539673,
#   0.9986522793769836]]

# %%
# Plot accuracy histories for all folds
for i, fold_accuracy in enumerate(total_training_acc):
    plt.plot(fold_accuracy, label=f'Fold {i+1}')

plt.title('Training Accuracy by Fold')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.savefig("YAMNet_categorical_training_accuracy")

plt.legend()
plt.show()

# %%
# running time including analysis
end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Execution time: 200.9108371734619 seconds
